# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/en/thumb/7/7c/Monash_University_logo.svg/1280px-Monash_University_logo.svg.png" style="height:100px">

# %% [markdown]
# # FIT5196 Assessment 1: Text Pre-processing
#
#    #### Name: Subhasish Sarkar
#    #### Student ID: 29819253
#    #### Date:15/4/2019
#    #### Environment: Python 3.6.8 and Jupyter notebook
#    #### Libraries used:
#    * slate3k - To read PDF files as text in Python
#    * re - To use regular expressions in Python
#    * pandas - To make use of Pandas dataframes for ease of use in computation
#    * nltk - To use NLP in Python, like Stemming, tokenization, etc
#
#
#    ##### The following code reads a given PDF file with tabular data, parses the data from it, and gives out 2 files - `29819253_vocab.txt` and
#    ##### `29819253_countVec.txt`, the first file containing vocabulary, and their indices, and the second file containing the occurrences of these words along with their word frequencies
#
#
#    ## 1. Introduction
#    The following code reads tabular data from a PDF file named `29819253.pdf` which contains information about subjects offered
#    by a Univeristy. It contains details about the Unit code, synopsis, and outcomes written as a table.
#
#    This data is read using the `slate3k` library which is built on top of the `PDFMiner` library. It enables us to read tabular
#    data as text. This text is then converted to a Pandas Dataframe.
#
#    Regular Expressions were extensively used to extract and clean the data.
#
#    From this extracted data inside the dataframe, text preprocessing was done on a set of unit information and then converted
#    into numerical representations which are suitable for input into recommender-systems/ information-retrieval algorithms.
#
#    The data-set that was provided contains 400 unit information crawled from Monash University. The pdf file contains a table
#    in which each row contains information about a unit which is unit code, synopsis, and outcomes. The task was to extract and
#    transform the information for each unit into a vector space model.

# %% [markdown]
# ## 2. Implementation of Code
#
# #### Importing all required libraries

# %%
import slate3k
import re
import pandas as pd
import nltk
from nltk.tokenize import RegexpTokenizer

# %% [markdown]
# #### The PDF file is opened in read-binary mode, and taken into the variable `page`. This contains all the data from all the pages from the PDF as a string.

# %%
with open('29819253.pdf','rb') as file:
    page = slate3k.PDF(file)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-9bf516c2e18a> in <module>
#       1 with open('29819253.pdf','rb') as file:
# ----> 2     page = slate3k.PDF(file)
#
# c:\program files\python36\lib\site-packages\slate3k\classes.py in __init__(self, file, password, just_text, check_extractable, char_margin, line_margin, word_margin)
#      57
#      58         if PYTHON_3:
# ---> 59             self.doc = PDFDocument()
#      60             self.parser.set_document(self.doc)
#      61             self.doc.set_parser(self.parser)
#
# TypeError: __init__() missing 1 required positional argument: 'parser'

# %% [markdown]
# #### The unit numbers, synopsis and outcomes all need to be placed inside lists so that it is easy to use their indices to make a data frame. These will be used inside a dictionary which can be directly converted to a dataframe.
#
# #### The text data from `page` is split into a list by splitting on `\n\n` which separates out all the unit numbers, synopsis and outcomes from each other. The `re.search` function returns the first occurrence of `^[A-Z0-9]*$`

# %% [markdown]
# #### These are basically those patterns that begin and end with a capital alphabet and numbers which can repeat 0 or many times. These are basically the unit numbers. So the `re.search` keeps returning the unit numbers for the whole loop. These are thus appended to the `unit_numbers` list
#
# #### Any occurence within the string which starts with a `[` is an outcome, and is thus appended to the `outcomes_list`
#
# #### if the string has anything other than the above mentioned conditions and is is not one of:
# * '\x0c' - Garbage value
# * 'Title' - Header
# * 'Synopsis' - Header
# * 'Outcomes' - Header
#
# It is then data for the synopsis and is thus appended to the `synopsis_list`

# %%
unit_numbers = []
synopsis_list = []
outcomes_list = []

for i in range(len(page)):
    file_1=page[i].split("\n\n")
    for i in range(len(file_1)):
        if re.search(r"^[A-Z0-9]*$",file_1[i]):
            unit_numbers.append(file_1[i])
        elif file_1[i].startswith('['):
            outcomes_list.append(file_1[i])
        else:
            if (file_1[i]=='\x0c' or file_1[i]=='Title' or file_1[i] == 'Synopsis'or file_1[i] == 'Outcomes'):
                continue
            synopsis_list.append(file_1[i])
# Out:
# 200
# 200
# 200

# %% [markdown]
# #### The data frame is thus made from the dictionary structure containing the previously made lists

# %%
pdf_dataframe = pd.DataFrame({'Unit Codes': unit_numbers,'Synopsis': synopsis_list, 'Outcomes': outcomes_list})
pdf_dataframe
# Out:
#                                               Outcomes  \
# 0    ['provide a working knowledge of key concepts ...
# 1    ['critically analyse and interpret basic resea...
# 2    ['analyse and explain the policies, programs a...
# 3    ['Apply knowledge and skills of research desig...
# 4    ['Examine and implement health education strat...
# 5    ['Evaluate the role of taxation in the modern ...
# 6    ['Understand the dynamical principles governin...
# 7    ['critically reflect on, comprehensively analy...
# 8                                               ['NA']
# 9    ['recognise and evaluate the developing role o...
# 10   ['explain basic and advanced concepts in democ...
# 11   ['generate questions/aims/hypotheses within\ns...
# 12   ['Critique the premises and foundations for th...
# 13   ['critically analyse the most recent developme...
# 14   ['Examine the differences between chronic and\...
# 15   ['Demonstrate a capability to research and exp...
# 16   ['apply traditional and contemporary performan...
# 17   ['Comply with the code of conduct for Monash m...
# 18   ['Explain the place of health and its determin...
# 19   ['apply newly acquired skills to negotiate eff...
# 20   ['A broad overview of the conceptual, historic...
# 21   ['Weekly lecture/seminar on prescribed texts w...
# 22   ['Comprehend a variety of spoken and written t...
# 23                                              ['NA']
# 24   ['describe the rules and sections of the act r...
# 25   ['To foster an understanding of the importance...
# 26                                              ['NA']
# 27   ['Interpret and communicate the policy develop...
# 28   ['understand Enlightenment debates about minor...
# 29   ['Apply principles of fracture mechanics to en...
# ..                                                 ...
# 170  ['discriminate between the marketing of sport\...
# 171  ['Deepen and broaden their knowledge via advan...
# 172  ['Interpret the contemporary research evidence...
# 173  ['Demonstrate understanding of the concepts of...
# 174  ['Describe the epidemiology, population health...
# 175  ['Identify concepts of thermodynamic equilibri...
# 176  ['Identify and describe in detail; structural ...
# 177  ['To acquaint students with developments in\ne...
# 178  ['design a rigorous Bachelor Honours level res...
# 179                                             ['NA']
# 180  ['critically assess contributions to developme...
# 181  ['Demonstrate an understanding of an integrate...
# 182                                             ['NA']
# 183  ['Familiarity with the basic parameters and th...
# 184  ['Commence planning, conducting and reporting ...
# 185  ['Have been exposed to, and have a competent\n...
# 186  ['explain the various suggested normative foun...
# 187  ['Analyse scientific communications to identif...
# 188  ['analyse and apply current management theory ...
# 189  ['Demonstrate knowledge of the essential princ...
# 190  ['Describe the epidemiology, presentation and\...
# 191  ['define and describe the scope of corporate t...
# 192  ['an ability to undertake independent legal re...
# 193  ['describe the legal framework that regulates ...
# 194  ['explain the different theoretical perspectiv...
# 195  ['factual information', 'sources and resources...
# 196  ['critically analyse the structure of global f...
# 197  ['Recognise and distinguish between the differ...
# 198  ['Apply knowledge of pathophysiological,\npsyc...
# 199  ['provide students with experience in an area ...
#
#                                               Synopsis Unit Codes
# 0    The process of marketing research. Role of res...    MKF2121
# 1    Basic introduction to research design in manag...    MGX5000
# 2    In this unit, students will examine key patter...    ATS3223
# 3    This unit provides an opportunity for high ach...    PBH3006
# 4    This unit prepares third year students in the ...    PAR3022
# 5    The primary function of taxation - to raise re...    LAW4243
# 6    Dynamical meteorology concerns itself with the...    EAE5021
# 7    The aim of the unit is to ensure that students...    AZA3184
# 8    This unit provides the student with the opport...    MAE4904
# 9    This unit introduces students to central conce...    ATS1208
# 10   The idea of democracy is ubiquitous in the\nco...    ATS3905
# 11   This elective is designed to allow students to...    BTM3290
# 12   This unit provides an introduction and overvie...    ASC5001
# 13   In the unit, students will engage in a special...    APG5052
# 14   Wounds can become non-healing due to factors\n...    PGW5211
# 15   The first of a three part design project. In m...    MDC4001
# 16   Topics include the budget planning process inc...    ACB3021
# 17   This unit is an integrated medicine/surgery cu...    MED3100
# 18   In this unit, we ask you to think about the va...    PHH1112
# 19   Leaders and professionals in organisations fac...    MBA5211
# 20   This unit will introduce the core conceptual a...    APG5900
# 21   Through a number of text-analysis focused proj...    ATS2043
# 22   The unit provides advanced students of the Jap...    ATS3978
# 23   This unit provides a thorough introduction to ...    CHE4162
# 24   This unit introduces value added tax (VAT) and...    BTS3302
# 25   This is an advanced unit in Politics which\nco...    ATS2699
# 26   ATS1835 is an introduction to metaphysics. It ...    ATS1835
# 27   Delivery of health services is underpinned by ...    MPH5269
# 28   The unit deals with the interactions between J...    ATS3190
# 29   This unit will explain why aircraft\nstructure...    MAE4408
# ..                                                 ...        ...
# 170  The unit introduces the omnipresence of sport ...    MKX3200
# 171  The unit represents the Honours coursework pro...    EAE4200
# 172  This unit introduces concepts related to provi...    PAR5400
# 173  Design Thinking applies the skills and strateg...    ADA3111
# 174  This unit continues to develop the role of the...    BEH3121
# 175  Introduce fundamentals and applications of cla...    CHE2164
# 176  This unit is the second of three units dealing...    RTS5103
# 177  The subject will take the form of student-init...    ATS3876
# 178  This unit is a research unit and a core requir...    FIT4443
# 179  A choice of lecture topics chosen in consultat...    MSC4220
# 180  What does 'development' mean as a body of idea...    APG5628
# 181  The aim of the unit is to enable students to a...    AZA2030
# 182  This unit looks at the development of the Ital...    ATS3241
# 183  This unit introduces students to the field of ...    CIV2282
# 184  Under the supervision of an academic staff mem...    ATS4231
# 185  The unit covers how people from different cult...    ATS2250
# 186  The unit will discuss the normative foundation...    ATS2868
# 187  This unit addresses the scientific method in r...    MEC6410
# 188  The overall aim of this unit is to introduce\n...    MGF5962
# 189  Food product development covers the trends and...    FST3850
# 190  This unit continues to develop the role of the...    PAR3031
# 191  This unit explores the roles, responsibilities...    BFW3652
# 192  Classes in legal problem-solving techniques. A...    LAW4176
# 193  The unit introduces students to the legal fram...    BTW2241
# 194  This unit will provide students with insights ...    MGF5722
# 195  The child and youth care worker needs to be\nk...    AZA2765
# 196  This unit analyses the characteristics, uses a...    BFF5230
# 197  Additive Manufacturing (AM) of polymeric mater...    MTE6887
# 198  This unit builds on NUR2225, NUR2226, NUR2228\...    NUR3310
# 199  This unit will provide students with a prelimi...    PAC3522
#
# [200 rows x 3 columns]

# %%
#nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /home/ssar0014/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# #### Tokenizer was downloaded from `nltk.data`
#
# #### Data was read from the dataframe, and then `re` was used to clean them of unusable tags. The cleaned data was then used to create tokens out of, and appended to a dictionary as per the unit codes.
#
# #### The sentences obtained from tokenization are then normalized and dumped into a dictionary

# %%
import nltk.data
tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')

# %%
dictionary_unitcode = dict()
for i in range(pdf_dataframe.shape[0]):
    temp_string = ''
    string = pdf_dataframe.iloc[i,0] + pdf_dataframe.iloc[i,1]
    string = string.capitalize()
    string = re.sub(r'\[', '', string)
    string = re.sub(r'\]', '', string)
    string = re.sub(r'\\','',string)
    string = re.sub(r'\n',' ',string)
    string = re.sub(r'/',' ',string)
    string = string.replace(r'(\\)','')
    sentence = tokenizer.tokenize(string)
    sentence = [re.sub('([a-zA-Z])', lambda x: x.groups()[0].lower(), sent, 1) for sent in sentences]
    for tokens in sentence:
        temp_string+=tokens
    dictionary_unitcode.update({pdf_dataframe.iloc[i,2]:temp_string})
dictionary_unitcode
# Out:
# {'ACB3021': "'apply traditional and contemporary performance measurement and control techniques to enable managers to measure and enhance organisational performance', 'analyse and make recommendations regarding the design of performance measurement and control systems', 'explain how behavioural implications are crucial for the effective design of performance measurement and control systems', 'apply critical thinking, problem solving and presentation skills to individual and or group activities dealing with performance measurement and control and demonstrate in an individual summative assessment task the acquisition of a comprehensive understanding of the topics covered by acb3021.'topics include the budget planning process including master budget preparation, budgeting standard costs and variance analysis, responsibility accounting, management by objectives and non-financial performance measurement, divisional performance, transfer pricing issues, program budgeting and other approaches, capital budgeting, strategic planning and control.",
#  'ACW3041': '"demonstrate an understanding of the role, limitations and demand for audits in modern corporate society including the auditor\'s professional, ethical and legal obligations", "examine the auditor\'s role in corporate governance with particular emphasis on the detection and reporting of fraud and error", \'describe the assurance framework, and apply planning processes and evidence gathering procedures that are used by auditors to form an audit opinion\', \'apply critical thinking, problem solving and presentation skills to individual and   or group activities dealing with auditing and assurance and demonstrate in an individual summative assessment task the acquisition of a comprehensive understanding of the topics covered by acw3041.\'overview of auditing, the auditor\'s legal liabilities, audit process and evidence, the concepts of materiality and risks, study and evaluation of internal control, edp auditing, audit sampling techniques, the test of transactions cycles and the verification of account balances, auditors reports, and internal and operational auditing.',
#  'ACX4018': "'implement a research proposal', 'recognise practical problems of conducting scientific research and propose solutions', 'complete a research dissertation', 'develop the ability to conduct and manage a planned study', 'apply critical thinking, problem solving and presentation skills in individual and or group activities dealing with a research dissertation.'students conduct a critical review of the literature relevant to their study; derive appropriate hypotheses for testing; devise an empirical test of the hypotheses showing regard to practical problems of conducting research, ethical considerations, and principles of scientific method; conduct a planned study and manage any problems arising in the data collection; select and conduct an appropriate analysis of the data; and write a report on the project, showing due regard to relevant stylistic conventions.",
#  'ADA3111': "'demonstrate understanding of the concepts of design thinking and their application;', 'identify and analyse ill-defined, real-world project problems and relevant design thinking approaches;', 'apply design thinking methods and approaches to a project-based problem, to develop new perspectives on key issues and to identify potential opportunties;', 'develop, test and evaluate original proposals in response to project-based problems;', 'develop an awareness of their preferred approaches to complex tasks, and ways these may be extended through design thinking.'design thinking applies the skills and strategies developed by designers to a wide range of problems and situations.these skills and strategies include a range of conceptual and communication approaches, ways to explore and reconsider the context in which we work, as well as what should or could be achieved.design thinking brings together some approaches that are known in the sciences and humanities, such as analysis and synthesis, but applies them in ways that are particular to a design approach.design thinking can enable a more flexible approach to problem solving, and a more nuanced engagement with the complex issues of our contemporary world.this unit will introduce students to the key skills and practices associated with design thinking, and offer opportunities to explore the application of these basic creativity techniques in a range of disciplines.",
#  'ADA5001': "'operate constructively and collaboratively as part of a team;', 'develop observation, research, communication and information gathering skills;', 'contribute as a discipline-specific practitioner within an interdisciplinary context;', 'conduct critical enquiry and provide summative reviews of peers across disciplines;', 'conceptualise, design and create a response to a given interdisciplinary problem;', 'understand and apply the rules of occupational health and safety appropriate to the interdisciplinary practice, in order to collaborate safely with peers.'the interdisciplinary studio environment provides through team-based project activities and problem-based learning, the further application of knowledge, techniques and methodologies from the students' individual disciplines, whilst addressing a complex multi-faceted problem.the unit may involve any combination of art, design or architecture students.the ability to critically and creatively engage with research and 'real world' problems through interdisciplinary approaches will be the core of this unit.students will further develop skills in communication, collaboration and innovation, essential tools for both professional practice and research activities within their chosen field and beyond.the final outcomes from the unit may be collaborative or individual.",
#  'AHT3801': "'understand and articulate what a medium is both conceptually and practically;', 'analyse the debates surrounding the defence and criticism of medium specificity and the trans-disciplinary;', 'contextualise studio practice within the conceptual models explored in the unit;', 'reflect and engage in critical dialogue about the medium and its importance in twenty-first century art.'this unit examines the medium and its materiality across a range of visual art practices including: painting, sculpture, installation, photography, video, multi-media, social practices and performance art.it focuses on a historical lineage of art's mediums and disciplines and how they are framed, constituted and judged in a diverse range of academic fields.concepts and traditions of modern aesthetics, the effect of late-capitalism, socio-economic critiques of art and technology are pivotal to any understanding of how art's form moves between modes of medium-specificity to trans-disciplinary realms.the unit introduces key theoretical tenets to analyse late modernist and contemporary art practices as case studies.it introduces students to the critical dialogue around the medium and artists' material processes.",
#  'AMG5743': "'knowledge, skills and attributes necessary for understanding and engaging in advanced research;', 'an ability to design, write and edit a research thesis;', 'an ability at advanced level to analyse and evaluate arguments, and to understand critical approaches relating to the communication industries and communication issues;', 'the capacity to contribute advanced knowledge in the chosen area of research;', 'an enhanced intellectual independence, and greater self-reliance and critical distance in intellectual and professional activity.'the unit is an alternative to amg5742 for students who want the option of progression to a higher degree by research.it is undertaken in the final semester of the master of communications and media studies and allows students to develop an independent research project.the topic is chosen by the student and developed with the advice and support of a supervisor.the project is written up in an 18000 word dissertation, allowing the student to demonstrate advanced skills in research, writing and project management.students are encouraged to consider the project not only as a formal requirement for the degree, but also as contributing to a portfolio of professional and scholarly development.",
#  'APG5050': "'a familiarity with the major research methods used in communication and media studies.', 'an understanding of the difference between research topics and research questions and an ability to identify productive research questions.', 'an ability to apply research methods critically and appropriately in addressing research questions.', 'a capacity to design research projects in communication and media studies, from conceptualization to project planning.', 'an ability to develop innovative solutions to problems in communication and media studies cf.monash graduate attributes policy.', 'an ability to apply research skills to a range of challenges in communication and media studies cf.monash graduate attributes policy.'the unit introduces students to principles of problem-solving in communication and media research.it will consider a range of traditional and emerging research methods - including textual analysis, content analysis, interviews, ethnographic fieldwork, digital humanities approaches, sentiment analysis and audience research.the focus, however, will be not be simply on learning and applying these methods, but also on understanding their relation to problems in the fields they address.the unit will develop skills in research design, from identifying productive research questions to selecting appropriate methodologies and project planning.these skills provide a platform for further development in the communications research project or masters thesis.",
#  'APG5052': "'critically analyse the most recent developments in communications and media, through engaging with an emerging problem or question in the field;', 'contribute original thinking to produce innovative solutions to contemporary problems in communication and media;', 'articulate the ethical values relevant in the rapid development of communication and media with particular attention to the impact of digital technologies;', 'utilise research skills to evaluate issues in the field and communicate findings in a professional context.'in the unit, students will engage in a specialised course of study examining a cutting-edge development in communication and media.in each year of offering, the unit will address a different question or topic within the general field of digital media, developing specialist insight, as appropriate to the expertise of the media researcher or industry practitioner engaged to teach it.the unit will have a strong research focus, which may include experimental development of an professional or industry practice.students will be expected to bring their work to a point of intersection with the most recent work addressing problems emerging in media studies scholarship or practices in media and communication industries.",
#  'APG5077': "'identify, assess and interpret cultural and nature-based assets for a tourist audience', 'devise effective management strategy for sustainable cultural and nature-based tourism development', 'propose appropriate research-based solutions to sustainable cultural and nature-based tourism challenges', 'exhibit ethical values in the development of sustainable tourism in diverse cultural and nature-based contexts', 'effectively communicate a well-argued tourism strategy across diverse medium.'the sustainable use of nature-based and cultural resources is vital to successful tourism destination development globally.in this unit students learn how to identify, assess, interpret and strategically manage these critical assets to maximise visitor experience and minimise negative environmental and cultural impacts.students will learn from industry experts during the case-based field study of hobart in tasmania, a leading destination in both cultural, heritage and nature-based product development.",
#  'APG5082': "'explain creative industries structures and markets;', 'identify business opportunities in specific creative cultural industries;', 'utilise academic concepts to understand audiences and challenges in creative products branding;', 'develop marketing strategy using independent research skills;', 'engage with different cultural contexts;', 'pitch and communicate ideas to stakeholders effectively.'in this unit, students analyse creative enterprises and creative entrepreneurial mindsets.we differentiate marketing and business approaches in the cultural industries from other sectors by analysing the changing marketing models, the creative industries value chains and their audience.by treating creative entrepreneurship as a specialism, we identify key strategic approaches by entrepreneurs in global cultural industries of various sizes and in both traditional and emergent niche markets.we will also identify challenges in the increasingly commercializing creative industries.the implication of 'creative' solutions to marketing and management outside of creative industries is important for entrepreneurs in order for them to place 'culture' at the heart of what doing business means in contemporary society.",
#  'APG5103': "'employ expert knowledge and specialist skills in policy analysis and evaluation to enable discipline based solutions relevant to diverse business, professional and public policy communities;', 'devise and deliver innovative solutions to policy-related challenges employing advanced critical thinking, evaluation and research skills;', 'communicate policy analysis and options with clarity and purpose.'the unit provides students with understandings of the conceptual and theoretical frameworks for policy analysis and evaluation which are necessary to present effective policy advice to the highest levels of government.using real-life examples of public policy, the unit explores the challenges of problem definition, analysing and evaluating evidence, choosing policy instruments, developing policy options, and preparing and submitting policy advice.",
#  'APG5230': "'explain key concepts in landscape ecology, including resilience and connectivity;', 'apply these concepts in real-world environmental contexts;', 'understand the role of expertise in shaping policy design and implementation;', 'critically evaluate the interaction between governance approaches and their realisation in practice in terms of sustainability outcomes.'the unit provides a broad introduction to ecology and environmental management at the interface between science and policy.it is suitable for those looking to understand how policy works in practice to best further their professional careers.no prior ecological experience is required.through australian and international case studies, the unit will introduce the challenges in translating ecological knowledge into effective policy tools.",
#  'APG5348': "'summarize key theoretical debates in relation to second language acquisition, and evaluate relevant empirical evidence;', 'compare the work of competing theorists, and recognise their role in the development of sla theory;', 'reflect on their own language learning experience and classroom practice in the light of theoretical and empirical studies;', 'evaluate major methodological approaches to the study of second language acquisition;', 'conduct a major research project on an area of second language acquisition.'the course will address key concepts, theoretical models, accepted approaches and contested frameworks and theories in the rapidly changing field of second language acquisition.topics covered include models and theories of second language acquisition, first and second language acquisition, error analysis and interlanguage, interlanguage pragmatics, input and interaction, learner strategies, learning styles, cognitive processes, second language identity, learners' rights and methods in sla research.",
#  'APG5351': "'identify and explain how international news stories are selected, gathered and distributed;', 'compare the particular approaches to news gathering and publishing in different countries;', 'conceptualise how big global news stories contain inherent ethical dilemmas;', 'explore and analyse an international news issue;', 'design an international research project using media theories and methodologies;', 'evaluate and communicate the results of the media project through class (and online) presentation and by writing a media report.'the unit will enable students to understand how international news stories are sourced, gathered and distributed around the world.the unit explores the changing nature of the media ecosystem, from staff foreign correspondents working for international news organisations to local journalists and eyewitnesses.the content for this unit includes the history of the international news agencies, global news flows, transnational broadcasters, the role of the foreign correspondent, the evolution of the citizen journalist, and the big world news stories dominating the international news agenda.students will use international news resources to research, study and write their own international media research report.",
#  'APG5400': "'have a sound understanding of globalisation as it affects communications and media industries;', 'be able to analyse global media and the policies which affect them;', 'be aware of the potentials and problems of cross-cultural communication and of the major theories which have been developed to explain them;', 'understand changing modes of reception by global audiences, together with the implications of these processes for national and personal identity;', 'be aware of the major legal and ethical challenges thrown up by the globalisation of communications and media;', 'demonstrate an enhanced ability to conduct independent research.'this subject explores key issues arising from the rapid change, development and growth in international communications.it examines the impact of globalisation and shifts in production, distribution and consumption in international communications.students will consider power and disadvantage; cultural flows and exchange; development communication; cross-cultural communication; international advertising and public relations; diasporic cultures; and legal and ethical issues in international communications.examples will be drawn from many different countries, including case studies of communications and media in asia, europe, north america and the middle east.",
#  'APG5628': "'critically assess contributions to development as an academic field that explores the history of development thinking and the spatial patterns of development in practice;', 'articulate different approaches to and practices of development, and to evaluate various alternatives in light of the most recent scholarly work on contemporary uneven development;', 'argue for or against the contemporary development paradigm as we know it, with an appropriate degree of personal and socio-political reflection.'what does 'development' mean as a body of ideas that structures systems of power, flows of resources, and social transformations across the globe?what does it mean in practice to intervene - often across diverse cultural contexts - with programmes designed according to these ideas of development?this unit addresses such questions by deconstructing the conceptual and practical pillars of development, and by interrogating similar concepts such as economic growth, progress, and modernisation.in addition to briefly reviewing some early theorisations of development and their links to colonialism and ideas of modernisation, the unit exposes the power-laden and unequal nature of contemporary development as an institutionalised set of practices that rose to prominence after world war ii.using case studies to paint a picture of geographically uneven development today, the unit explores whether development theories correlate with development-in-practice.it also explores the ways in which diverse social groups and social movements resist western notions of progress, attempting to reclaim development to forge more autonomous pathways to well-being.these alternative pathways raise questions about the normative side of development, and about whether the contemporary development institution should be deconstructed in practice.",
#  'APG5849': "'formulate a research project;', 'conduct research independently;', 'demonstrate a command of the relevant literature;', 'critically analyse the relevant academic literature;', 'develop an academically sound argument;', 'demonstrate sophisticated written skills.'under the supervision of suitable academic staff, students will conduct independent research on an appropriate topic.this research process continues in apg5850 graduate research thesis b, as a part of which students submit their research thesis.",
#  'APG5881': "'na'students will undertake in-country study at the institution with which monash university has an exchange agreement.this study will be the equivalent of 12 points of fifth-year postgraduate study in arts at monash university in the form of 5th year unit(s) offered by the host institution in the domain of translation studies.",
#  'APG5900': '\'a broad overview of the conceptual, historical and contemporary issues involved in notions of the cultural economy;\', \'critically evaluate the different approaches to cultural economy and the issues they raise;\', \'apply independent research skills to a range of conceptual and historical problems in the field of cultural economy;\', \'an ability to write and communicate effectively and in analytical depth;\', \'an ability to effectively utilise academic concepts to identify and investigate concrete challenges and issues involved in specific aspects of the cultural economy.\'this unit will introduce the core conceptual and historical dimensions of the mca, including the emergence of arts and cultural policy, the rise of the cultural and creative industries, urban regeneration and urban cultural economies, and the evolution of cultural  creative work.in particular it will explore the concepts and claims of "cultural economy" - that the economy is a constructed socio-cultural phenomenon - and examine the consequences of these for existing and future practices by individuals, businesses and policy agencies operating within the cultural economy per se.students will be asked to submit two assignments based on concepts and issues generated by the unit content.',
#  'ARC3002': "'demonstrate a refined level of competence in architectural design;', 'have a demonstrated ability to critically analyse and successfully respond to the complex range of issues inherent in an architectural design project;', 'have developed a sophisticated understanding of how observation, analysis, experiment and critique apply to the architectural design process;', 'have acquired an advanced level of competence and consolidation of all presentation skills: verbal, graphic and 3-dimensional;', 'understand and be able to apply the rules of occupational health and safety appropriate to the unit of study.'architecture design studio 6 aims to consolidate the conceptual understanding and skill base of preceding design studios.it continues to elaborate on architectural design as a process of investigation, critical observation, and experiment.it increases the emphasis on design as a synthetic process encompassing a range of complex issues inherent in the production of architecture: material, structure, program, site, history and representation are investigated in their relationship to the production of architectural form.",
#  'ARC5401': "'be able to locate design research within relevant contexts;', 'have acquired proficiency in architectural design research methods;', 'have the ability to critically analyse and successfully respond to issues inherent in formulating architecture research;', 'have developed and demonstrated a sophisticated understanding of how observation, analysis, experiment and critique apply to the development of architecture design research;', 'understand and be able to apply the rules of occupational health and safety appropriate to the unit of study.'architecture research methods is the prelude to the final architecture design research project.addressing diverse methodologies and tactics, this unit provides the background and foundation for undertaking independently guided design research.the unit will establish the necessary parameters for the development of the subsequent design research projects including methodological, conceptual and physical contexts and operative frameworks for architectural speculations.",
#  'ASC5001': '\'critique the premises and foundations for the biopsychosocial model of addiction in relation to other models of addiction\', \'consider and critique the role of various factors in the aetiology of addiction with reference to the research evidence base.\', \'analyse the neurobiological and genetic bases of addictive behaviours.\', \'critically evaluate the psychological and sociocultural bases of addictive behaviours.\', "demonstrate the use of the \'drug, set and setting\' model in understanding substance effects on the individual.", \'synthesise the implications of the harm minimisation approach for understanding interventions.\', \'present an argument based on theoretical and empirical literature regarding whether process addictions such as gambling should be grouped with substance addictions.\', \'evaluate the role of research evidence and the various models of addiction in the development of policies relevant to alcohol illicit drug use and addictive behaviours.\'this unit provides an introduction and overview to addiction as a concept.in particular, consideration is given to the biological, psychological, developmental, sociocultural and environmental factors that may contribute to the development of addiction.',
#  'ASC5009': "'identify and contextualise developmental factors that contribute to addictive behaviours in young people', 'explain youth substance abuse in terms of family and social contexts such as trauma and youth disadvantage', 'synthesise the available information on the impact of addictive behaviours on young people and families in order to demonstrate an understanding of the complexity of this issue', 'reflect critically on psychological and sociological theories relevant to key contemporary issues in youth addiction', 'evaluate and critique current responses to addiction including school-based interventions', 'compare and contrast contemporary models of addiction behaviours among young people through an analysis of national and international research', 'critically review the effectiveness of family-based interventions including family inclusive practice and parents under pressure', 'critically appraise a range of youth-focused aod treatment services and key elements of youth-focused service delivery', 'critically review policy issues relevant to youth including those pertaining to social media.'this unit begins with a focus on child and adolescent biopsychosocial development followed by an overview of the prevalence and patterns of substance use and other addictive behaviours in these populations.",
#  'ASP3162': "'demonstrate a basic understanding of astrophysical fluid dynamics, involving the physics of fluids at high mach number, including sound waves and shocks.', 'demonstrate practical skills in scientific computing, computational modelling, data analysis and visualisation.', 'perform computer simulations of astrophysical flows using advanced astrophysical simulation codes, and demonstrate an understanding of the physics and mathematics behind modern large-scale astrophysical simulations.'in this unit students will learn the basic principles of astrophysical fluid dynamics and how it can be used to model the most extreme events in the universe.the unit covers the basic equations of compressible hydrodynamics, including the behaviour of linear waves, the transition to shocks and the behaviour of fluids at high mach number.students will apply this to understand the physical processes that power accreting sources including white dwarfs, neutron stars and black holes, and the physics behind the explosion of stars as supernovae.students will gain practical experience in computational fluid dynamics including basic programming skills and an understanding of how large scale astrophysical simulations are performed.",
#  'ATS1062': "'use basic speaking, listening, reading and writing skills (and appropriate vocabulary) to communicate effectively in french in a range of past, present and future situations and on a range of topics;', 'locate information in basic texts in french;', 'recognise and use key structures and sounds of french;', 'identify and use prescribed grammatical items;', 'critique aspects of modern and contemporary french history, values and identity and their evolution;', 'interpret several prescribed sources to synthesise knowledge into a standard format.'this unit develops basic language skills (speaking listening and reading writing) beyond the level acquired in ats1061 and provides an introduction to modern french society.it is designed for those with limited knowledge of french.students will be encouraged to develop appropriate language learning strategies.regular assessed homework and tests emphasize the continuous nature of language learning and the need for frequent practice.in the specialized culture component, students will explore an aspect of french culture and society and develop competence appropriate to their year level in the theory, practices and discourses involved in analysis of it.",
#  'ATS1208': "'recognise and evaluate the developing role of digital technologies in society and culture;', 'analyse the impact of digital technologies on the areas of media, heritage and scholarship;', 'examine and assess examples of the application of digital technologies in the analysis and dissemination of humanities data;', 'identify complex research problems and conceptualise interdisciplinary approaches to them;', 'communicate effectively utilising both traditional and innovative means.'this unit introduces students to central concepts at the intersection of the digital world and a range of humanistic endeavours.through case studies based in each of the themes of the major, we examine how technological possibilities have interacted with recent work in scholarship, media and heritage studies allowing exciting new techniques and methods of research and presentation of data.we consider the bases necessary for such work, the data sources and the tools, and also investigate the new communicative possibilities that result.as well as critically engaging with existing applications in the field, students in this unit will produce digital objects presenting their own work.through exploring the impact of technological change in this field, the unit also will foster a more general understanding of such impacts and of the inter-relation of digital technologies, society and culture.",
#  'ATS1835': "'na'ats1835 is an introduction to metaphysics.it deals with questions about the nature of time, causation, human freedom, personal identity and the possibility of artificial intelligence.an unusual feature of the subject is that each topic is introduced by way of science fiction stories in which metaphysical issues are explored.so the first topic takes off from a discussion of time travel.",
#  'ATS2043': "'weekly lecture seminar on prescribed texts will provide basic concepts of issues in translation studies in general and text analysis in particular.the unit will focus on basic principles of text analysis and some popular theories relating to the translation of source texts into target language.students are expected to improve their understanding of theories relating to the classification and identification of source texts and translation strategies;', 'by applying some basic concepts relating to text analysis and translation strategy to weekly project-based translation practice and class discussion, students are also expected to improve their ability to determine correct translation strategies for specific professional purposes;', 'three supervised translation projects and one examination in a time controlled situation will be conducted during the semesters in order to test the progress of students.'through a number of text-analysis focused projects, this unit will introduce students to various basic conceptual and practical issues in chinese translation; it will help students to identify different types of source texts, build up their skills in text analysis and help students to choose correct strategies when translating different texts for professional purposes; through project-based exercises, this unit will provide an opportunity for students to improve their analytical skills and understanding and of all factors that affect the translation of source texts into target language; the integration of classroom teaching and translation projects encourages students to apply the theories and skills they have learnt in class to translation practices.",
#  'ATS2250': '\'have been exposed to, and have a competent understanding of contemporary scholarship on the relationships between communications and culture;\', \'have acquired an informed understanding of how different worldviews impact on communications;\', "have come to understand the processes of immigrants\' economic and cultural adaptations as part of their development of effective intercultural communications;", \'have obtained in-depth understanding of nonverbal communications;\', \'have developed greater capacities to deal with inter-ethnic tension for effective communications;\', \'have come to understand a range of theories on intercultural communications, e.g., cultural convergence theory, identity management theory, identity negotiation theory, communication accommodation theory, and cultural schema theory;\', \'have acquired an informed understanding of how ethnic identities and immigrant life are represented through a range of media.\'the unit covers how people from different cultural backgrounds communicate or miscommunicate and how they can overcome any difficulties, resulting from cultural diversities.',
#  'ATS2275': '\'explain and analyse the course and dynamics of european integration since the end of the second world war;\', "identify and explain the origins of the european union\'s current crises in a global context;", \'identify and appraise the architecture of the european union and how this shapes responses to current crises;\', "distinguish between \'european\' and \'national\' responses to the crises and the inter-play between these two levels of european union governance;", \'integrate one set of academic literature (european integration theory and history) with another (european politics and international relations);\', \'undertake a research analysis of an important aspect of european integration or a major policy area, utilising primary and secondary-source materials with written feedback.\'the european union is a unique historic and political achievement.it helped turn europe into a zone of peace and contributed to the consolidation of democracy in the post-fascist and communist eras.yet it is also a polity in profound crisis.it is challenged from within by critics of its own democratic credentials in the wake of the eurozone crisis and from without by security threats from a resurgent russia and an influx of refugees.students completing this unit in prato will gain a deep understanding of the origins of today\'s european union and the pathologies of its multiple crises.they will simulate policy paths out of the eu\'s \'wicked\' problems and leave prato equipped to respond to the global repercussions of the challenges facing the \'new old world\'.',
#  'ATS2385': '"demonstrate a critical understanding of the history of australia\'s involvement in war and the significance of that involvement, and have interrogated the mythologies that have grown up around anzac;", \'exhibit an in-depth understanding of the lived experience of war and an ability to interrogate personal testimonies.\', "show an awareness of the historical and social context of australia\'s involvement in particular campaigns and how these have redefined australia\'s relationship with the region and the world;", \'have built the capacity to research and critically evaluate topical and historiographical debates regarding the impact of war on australian identity and society.\', \'have developed skills in constructing evidence-based arguments using a variety of primary and secondary sources, and demonstrated their ability to reflect critically on what they have learnt.\', \'have developed skills in written and oral presentation and communication.\'how has war shaped australians and australian society and why has war become central to national mythology and identity?this unit explores the experience of australians at war - both overseas and on the home front - from confrontations between indigenous australians and european settlers on the colonial frontier through the major conflicts of the twentieth century, with a particular focus on the two world wars.we examine the \'face of battle\' and how war affected men and women on the front line (including indigenous servicemen), and we consider how war was experienced on the home front and reshaped australian society.we explore the contested creation of an \'anzac legend\' and how war challenged and consolidated social relations and national identities.students will undertake hands-on research using the rich primary source record of australians at war, including service records, diaries and letters, oral histories, photographs and repatriation files that illuminate the impact of war on veterans, their families, and their communities.',
#  'ATS2394': '"demonstrate a critical understanding of the breadth and complexity of australia\'s contacts with asia, at diplomatic, economic, social and cultural levels.", \'exhibit an understanding of the ways in which past encounters, discourses and policies affect contemporary cross-cultural and international relations.\', \'have attained an understanding of the impacts of representation and discourse in shaping international relations.\', \'have developed the capacity to reflect on the implications between personal attitudes and views and broader patterns of culture and discourse.\', \'have developed skills in constructing evidence-based arguments using a variety of primary and secondary sources, and demonstrated their ability to reflect critically on what they have learnt.\', \'have developed skills in written and oral presentation and communication.\', \'have developed a capacity to undertake location-based fieldwork, enhancing personal resilience and the capacity to work cooperatively in teams, and conduct independent research.\', \'students taking this unit at level 3 will demonstrate a higher level of skills in independent research and critical analysis.\'this unit examines australia\'s past and present relations with asia, culminating in a study tour of an asian country.it traverses a broad terrain, investigating cross-cultural contact at political and diplomatic, economic and trade, as well as cultural and personal levels.the unit places contemporary events within their broader historical contexts, to identify enduring themes that influence australian-asian relations.it also looks ahead to future developments as australia negotiates the \'asian century\'.the unit begins in australia, before students embark on a study tour of an asian nation to gain an in-depth awareness of the complex social, cultural and political context of asia, and how australia fits into a regional frame.',
#  'ATS2422': "'develop a general understanding of the new ways of thinking and writing about history and nationhood, god and nature, art and the self that were articulated by romantic thinkers;', 'gain in-depth knowledge of the work of at least two romantic writers;', 'become more aware of the ongoing legacy of romanticism in later literature and culture;', 'develop skills in the areas of literary research, textual analysis and interpretation, and communication, both oral and written.'the unit will introduce students to new forms of representation and ways of thinking that emerged in europe from the late eighteenth century, and are now termed 'romanticism'.it will focus in particular on romantic conceptualisations of literature, history and nationhood, god and nature, visual art and the self.romanticism will be considered both as a revolutionary period in european history and as a continuing strand of western culture, with a diverse literary legacy.",
#  'ATS2586': "'explain the historical development of islamic societies, and familiarity with the essential texts and major schools of thought;', 'identify and discuss key figures, narratives, doctrines, practices, and their rich variety across changing landscapes throughout the history;', 'read and analyse primary sources, and draw connections between these and the lectures and tutorial discussions in order to respond critically to the material;', 'work effectively in group situations, and communicate their ideas through formal presentations.'the unit examines the evolution and influence of islam, with particular emphasis on the principles underpinning islamic law, theology, philosophy, arts, and mysticism, and islamic civilisation in its classic phase.it examines core themes in the qur'an, and in early works of islamic history, literature and jurisprudence, as well as the different ways in which these principles were interpreted in practice from a historical perspective.we will review the discussions surrounding the birth of islam, islamic pre-modern and modern history, islamic concepts of god and society, roles of women and minorities, islamic doctrines, movements, colonial encounters, politics, modernism, and islam in the world, among other themes.the course materials entail selections from important primary sources, as well as video documentaries.",
#  'ATS2600': "'a knowledge of events leading to the holocaust, its course and aftermath', 'an understanding of jewish responses to the holocaust across europe', 'an understanding of the responses of perpetrators and bystanders across europe', 'an understanding of the issues involved in representations of the holocaust, including testimony, museums, and memorials.'this unit examines the holocaust and its place in the broader phenomenon of genocide and mass killing in history.major topics covered include antisemitism, the nazi state, ghettos and death camps, responses of victims, and the role of perpetrators and bystanders.the course will reflect on the holocaust as a symbol of the modern condition, its uniqueness and relationship to other forms of violence and genocide.other themes studied are the reconstruction of jewish communities in europe, the memory of the holocaust and its meaning in the immediate postwar world, and trauma and testimony.",
#  'ATS2687': "'identify and explain the theoretical and practical aspects of improvisation in music;', 'discuss the formative relationship between culture, music and improvisation practices;', 'interpret the forms and processes of improvisatory practices from a diverse range of cultural sources;', 'implement practical skills and strategies for developing individual improvisatory approaches to music.'this unit provides a series of structured strategies and devices for developing a systematic approach to melodic based improvisation skills.it looks at melodic elements and structures in terms of modes, intonation, microtonal inflections and flavours and draws upon systems and processes for developing improvisatory approaches from jazz, blues, hindustani music, arabic music, latin music, western art music and other musical sources.the unit involves both practical and theoretical components.",
#  'ATS2699': "'to foster an understanding of the importance of political parties as organizational forms by which citizens in a liberal democracy seek to influence governance;nii.to foster a comparative understanding of how parties and party systems are organized in liberal democratic statesnniii.to develop a knowledge of the contribution political science has made to the theorizing about parties and party systems;niv.to foster an understanding of the applicability of theories about organisation and power to an analysis of political parties', 'to develop a clear understanding of the forms and dynamics of inter-party and intra-party politics, and the impact this has on debates about public policy and governance;nvi.to develop advanced analytical skills so that graduates can analyse organisational power and communicate these skills by way of coherent argument in tutorial situations, and to present rigorously analytical research essays.'this is an advanced unit in politics which concentrates on the political party system.it involves an examination of:",
#  'ATS2868': "'explain the various suggested normative foundations of the state and of property rights;', 'critically evaluate arguments made for and against the justification of the state; and,', 'critically evaluate arguments made for and against the justification of private property.'the unit will discuss the normative foundations of the state and of the institution of private property.what is the proper role of government?why should we obey the law?what is the relation between property and liberty?when, if ever, is the government justified in redistributing property?these issues will be discussed mainly in the light of the work of classical thinkers, but some reference will also be made to contemporary political philosophers.",
#  'ATS2898': '\'have a greater understanding of italy, the italian city (prato) and italian culture;\', \'have consolidated both oral and written language through linguistic and cultural immersion;\', "have gained knowledge of the city\'s long history and its contemporary cultural and urban landscape;", \'have acquired an understanding of how italian archives work and be able to further develop research skills;\', \'have acquired an understanding theoretical issues surrounding the conception of city.\'the italian city, a microcosm of italian society, reveals the rich layers of italian culture and history.this unit explores italian cityscapes through their monuments and art works and their representation in literature and film.it offers a journey through the social spaces of the modern city to the virtual zones of the postmodern city.by visiting the city through literature and film students will be exposed to a diversity of texts, written and visual, that grapple with the complexity of urban spaces and with challenges posed to italian cities by increased migration.in addition to considering textual representations of urban spaces, a particular focus of the unit will be the urban biography of prato, from the middle ages to the present day.this will include examining how prato\'s remarkable economic history has contributed to its distinctive civic identity, and how the culture of the city is reflected in contemporary writings.',
# ...
#  'PHH1112': "'explain the place of health and its determinants in a globalising world;', 'compare and contrast initiatives to address global health challenges;', 'identify opportunities for action and design relevant approaches to global health challenges;', 'identify future global health challenges and their determinants;', 'analyse the determinants of global health;', 'critically reflect on contemporary debates regarding globalization and health.'in this unit, we ask you to think about the vast and growing inequities in health that exist across the world and the challenges for people living in developing countries.we explore their underlying causes including: globalisation, transnational trade, tourism, rapid development, social and political transitions, climate change, violence and insecurity.using research reports and case studies, we examine the wider context for working in international settings as well as the issues faced by indigenous peoples, migrants and refugees.we explore our responsibilities as 'global citizens' and we challenge you to think about ways you could make a difference.",
#  'PSY5104': "'equip students with knowledge of the laws and ethical principles which govern research and professional practice in psychology and understand how to apply their knowledge of relevant legislation and codes of professional conduct to such issues as confidentiality, informed consent, freedom of information, intra and inter professional relationships, responsibilities, and professional conduct.', 'have an understanding of the intercultural and ethnic issues that impact on their practice.'a range of topics associated with the provision of psychological services, including basic counselling skills, review of relevant legislation and ethical professional standards, and developing ethically and culturally sensitive psychological practice.this unit comprises a two day workshop, held prior to the commencement of formal course-work and seminars.material will be presented in various formats including didactic teaching, small group exercises and role plays.the workshop and seminars will be supplemented by readings and handouts.",
#  'RTS5103': "'identify and describe in detail; structural and sectional anatomy, physiology, pathology and oncology related to: loco-motor, lymphatic, and cardiovascular systems.', 'critically analyse radiation therapy planning, treatment and verification techniques with reference to international standards, the evidence-base and personal reflections for: the loco-motor, lymphatic, and cardiovascular systems and demonstrate beginner level planning, treatment and verification procedures for a range of diagnoses.', 'describe with reference to the evidence-base, acute and late radiation therapy side effects, analysing patient care and management strategies related to the above body systems, demonstrating the provision of beginner level multi-disciplinary patient care, management, communication and professional skills for a range of patients.', 'describe the process of how 3d datasets are generated and evaluate the clinical use of 3d images for planning and verification.', 'describe in detail and apply the principles of radiation safety, quality management, occupational health and safety.', 'appraise protocols, procedures and legal requirements used for incident reporting.', 'appraise the imaging modalities used for treatment verification and demonstrate beginner level image matching.', 'analyse and synthesis the principles and clinical applications of plan evaluation tools, demonstrating beginner level use of these.', 'evaluate the rationale for use of beam modification accessories.', 'describe and discuss effective and respectful working collaborations with the multi-disciplinary team.'this unit is the second of three units dealing specifically with the principles and applications of radiation therapy planning and treatment.this unit will cover the: loco-motor, lymphatic, cardio-vascular, and haematological systems.in addition students will also analyse and evaluate the principles of quality assurance and how they relate to the practice of radiation therapy.students will gain in-depth knowledge on the role applications of image verification in radiation therapy treatment delivery.students will be able to analyse and evaluate radiation therapy beam modification devices and planning evaluation tools.this unit includes one week of clinically oriented simulated learning and a four week clinical placement that will allow students to develop further clinical and professional skills to a beginner intermediate beginner level.whilst studying these topics, students will be encouraged to critically reflect, analyse and synthesis relevant information from the literature and reflect on their clinical experiences.",
#  'SCI3716': "'discuss selected issues in managing a scientific laboratory;', 'describe their obligations under the occupational health and safety act and related legislation;', 'recognise hazards associated with chemical and biological materials, instruments and ionising radiation and the risks they impose;', 'undertake a risk assessment and recommend safe working procedures;', 'outline their legislated obligations in recycling and disposal of hazardous materials;', 'apply the principles of chemistry, biology, microbiology and physical science to the treatment of hazardous materials;', 'discuss the effects of waste materials on the environment;', 'recommend procedures for the analysis and treatment of hazardous wastes before disposal to the environment.'this unit is designed to introduce intending scientists to the principles of laboratory and workplace management and their obligations as experts and supervisors.it will cover legislation and the responsibilities of both employers and employees in issues such as occupational health and safety; handling of dangerous goods and the analysis, treatment and disposal of hazardous materials.emphasis will be placed on the assessment and management of these issues in a laboratory and workplace environment.the subject will be taught by programmed learning material and practical work consisting of assessment and discussion of case studies and workplace excursions.",
#  'SWK3220': "'describe the nature of social work in a range of contexts and settings as well as describe contemporary debates about the nature of social work.', 'critically analyse the ethical value base of social work with particular reference to human rights and the promotion of social justice.', 'critically analyse key global social policy issues including, but not limited to, mass movement of people, climate change, reconstruction, and poverty.', 'critically review and analyse contemporary trends in the delivery of social work services.', 'articulate the nature of social change and the strategies to achieve this.'this unit offers an overview of the history and contemporary context of social work practice within a framework of understanding the connection between social issues, policy development and strategies for sustainable change at both local and global levels.the unit is underpinned by notions of social justice and human rights and offers a preview of topics that will be studied in greater depth in subsequent units within the course.",
#  'SWM5170': "'work collaboratively with an academic supervisor on the development of an assessment topic and during the completion of the assessment.', 'integrate research knowledge with past and present professional experience.', 'work collaboratively with an academic supervisor on the development of an assessment topic and during the completion of the assessment.', 'combine advanced specialised research knowledge and skills to develop a research-based practice at clinical, program and policy levels.', 'articulate specialised practice and knowledge and skills in while developing the research report, evaluation report or assignment.', 'develop and appraise personal role as a professional social work practitioner-researcher.', 'develop and appraise personal role as a professional social work practitioner-researcher.', 'prepare a report which would be suitable for publication'unit content will be developed between the student and an appointed staff supervisor.one piece of assessment will be developed and completed by the student for this unit.",
#  'TAD2214': "'recognise key works of design and their relationship to critical issues;', 'demonstrate an understanding of the influence and impact of physical, social and cultural concerns on the role of the designer and the design product;', 'demonstrate critical and analytical skills in the interpretation and appreciation of works of design;', 'articulate evaluative responses as to the significance of ideological and cultural forces on the work of design;', 'appreciate and critique multiple perspectives for the interpretation of design;', 'understand and be able to apply the rules of occupational health and safety appropriate to the unit of study.'this unit investigates the visual and theoretical languages of design in relation to a number of key critical issues.it focuses on issues including the engagement of works of design with society, consumerism, gender, politics, and the environment.the role of the designer in responding to aesthetic and social challenges is also considered.students will continue to develop a range of approaches to understanding works of design and related issues while also refining the broader critical and analytical skills necessary to their disciplines.",
#  'TDN1002': "'identify and describe the major movements of modernism in design;', 'recognise and analyse key examples of practices in design;', 'discuss the legacy of the european avant-gardes and their lasting influence upon the social role of the designer;', 'translate basic theoretical contexts in to practice;', 'critique works of design, and articulate these analyses in both spoken and written form;', 'identify questions and consider ways to search for information.'this unit examines the history of european modernism as it relates to the disciplines of visual communication, industrial design and spatial design.key modernist movements and practices are studied with particular consideration given to their ideological, political and cultural contexts and motives.the critical tendencies of twentieth-century avant-garde practices are considered in terms of their lasting implications for the social role of design.students will develop a range of critical approaches to analysing design in relation to its historical, social and cultural context skills necessary to their disciplines and practice.",
#  'UPD4002': "'demonstrate capabilities and competencies in ethical approaches to contemporary urban planning;', 'have the ability to strategically respond to complex problems and develop appropriate planning responses, processes and outcomes;', 'have developed skills in research, applying creativity and critique to address planning issues;', 'have acquired a high level of competence in communication and presentation skills: written, verbal and graphic ones;', 'understand and be able to apply the rules of occupational health and safety appropriate to the unit of study.'project 2 explores the creation of ecologically sensitive cities.through projects that coordinate the built and natural systems that shape our cities, students develop research foundations, technical capacity, analytical approaches and modes of articulation through planning systems.",
#  'UPD5001': "'critically reflect on and practice ethical approaches to contemporary urban planning;', 'strategically respond to complex problems related to urban sprawl;', 'apply skills in research to address metropolitan planning issues;', 'communicate in written, verbal and graphic formats on issues pertaining to urban sprawl;', 'understand and be able to apply the rules of occupational health and safety appropriate to the unit of study.'planning project 3: the sprawling city considers the role of metropolitan planning in addressing issues associated with urban sprawl.the unit expands and consolidates advanced concepts, knowledge and skills encompassing a range of complex issues relevant to practising urban planning at the metropolitan level.through critical research, analysis and synthesis undertaken in real spatial settings, the unit develops concepts, creative approaches, processes and outcomes and the skills to communicate these effectively to diverse communities.",
#  'UPD5002': "'critically reflect on and practice ethical approaches to contemporary urban planning in diverse communities;', 'strategically respond to complex problems and develop appropriate planning responses, processes and outcomes pertinent to social and community planning;', 'apply skills in research to address social and community planning issues;', 'communicate in written, verbal and graphic formats on social and community planning issues;', 'understand and be able to apply the rules of occupational health and safety appropriate to the unit of study.'planning project 4: the inclusive city focusses on issues pertinent to social and community planning to address the challenge of creating people-centred cities.the unit expands and consolidates advanced concepts, knowledge and skills encompassing a range of complex issues relevant to practising urban planning.through critical research, analysis and synthesis undertaken in real spatial settings, the unit develops concepts, creative approaches, processes and outcomes and the skills to communicate these effectively to diverse communities.",
#  'VCM4029': "'utilise a range of systems analysis, design methodologies and their associated tools and principles;', 'understand the main participants and their roles in the development of interactive systems;', 'apply quality assurance techniques for the analysis, design, implementation and maintenance of interactive systems;', 'understand the advantages and disadvantages of alternative approaches in systems analysis and design;', 'convert requirement analysis models to design models that represent a workable solution system;', 'prepare analysis and design documentation for an interactive system;', 'apply sound programming principles to the use of an interactive scripting language;', 'develop skills in team collaboration.'this unit will examine the activities integral to the development of interactive systems, detailing the techniques of systems analysis and design used in the development process.fundamental programming concepts will be introduced within an interactive-media scripting language framework as a mechanism for system development.students will be involved in a mixture of individual and group-based work which will require application of the theoretical knowledge gained in lectures to a series of practical problems in interactive systems development.",
#  'VCM4601': "'recognise, analyse and use the elements of design;', 'understand the role of visual communication and fundamental design principles as applied to multimedia new media;', 'recognise some of the theoretical and psychological issues of selected colour theories;', 'understand and apply selected colour theories to digital media;', 'recognise, analyse and use typography;', 'express ideas and concepts for multimedia using visual communication forms, drawing, digital imaging, graphic design and typography; and', 'observe and employ occupational health and safety appropriate to studio practice.'students are introduced to how the fundamental elements and principles of two and three-dimensional design are applied to multimedia.students gain the necessary design skills and knowledge to produce complex integrations of those selected principles of design, which form a solid basis to support visual communications for screen based media.set projects encourage experimentation with various techniques and methods of interpretation."}

# %% [markdown]
# #### The following function was made to tokenize words obtained from the dictionary above
# #### The regular expression tokenizer mentioned in the specifications file was used to tokenize these keys.

# %%
def tokenizeKeys(keys):
    key_tokenizer = RegexpTokenizer(r"\w+(?:[-']\w+)?")
    unit_tokens = key_tokenizer.tokenize(dictionary_unitcode[keys])
    return (keys,unit_tokens)

# %%
unit_tokens =  dict(tokenizeKeys(keys) for keys in dictionary_unitcode.keys())

# %%
unit_tokens
# Out:
# {'ACB3021': ['apply',
#   'traditional',
#   'and',
#   'contemporary',
#   'performance',
#   'measurement',
#   'and',
#   'control',
#   'techniques',
#   'to',
#   'enable',
#   'managers',
#   'to',
#   'measure',
#   'and',
#   'enhance',
#   'organisational',
#   'performance',
#   'analyse',
#   'and',
#   'make',
#   'recommendations',
#   'regarding',
#   'the',
#   'design',
#   'of',
#   'performance',
#   'measurement',
#   'and',
#   'control',
#   'systems',
#   'explain',
#   'how',
#   'behavioural',
#   'implications',
#   'are',
#   'crucial',
#   'for',
#   'the',
#   'effective',
#   'design',
#   'of',
#   'performance',
#   'measurement',
#   'and',
#   'control',
#   'systems',
#   'apply',
#   'critical',
#   'thinking',
#   'problem',
#   'solving',
#   'and',
#   'presentation',
#   'skills',
#   'to',
#   'individual',
#   'and',
#   'or',
#   'group',
#   'activities',
#   'dealing',
#   'with',
#   'performance',
#   'measurement',
#   'and',
#   'control',
#   'and',
#   'demonstrate',
#   'in',
#   'an',
#   'individual',
#   'summative',
#   'assessment',
#   'task',
#   'the',
#   'acquisition',
#   'of',
#   'a',
#   'comprehensive',
#   'understanding',
#   'of',
#   'the',
#   'topics',
#   'covered',
#   'by',
#   'acb3021',
#   'topics',
#   'include',
#   'the',
#   'budget',
#   'planning',
#   'process',
#   'including',
#   'master',
#   'budget',
#   'preparation',
#   'budgeting',
#   'standard',
#   'costs',
#   'and',
#   'variance',
#   'analysis',
#   'responsibility',
#   'accounting',
#   'management',
#   'by',
#   'objectives',
#   'and',
#   'non-financial',
#   'performance',
#   'measurement',
#   'divisional',
#   'performance',
#   'transfer',
#   'pricing',
#   'issues',
#   'program',
#   'budgeting',
#   'and',
#   'other',
#   'approaches',
#   'capital',
#   'budgeting',
#   'strategic',
#   'planning',
#   'and',
#   'control'],
#  'ACW3041': ['demonstrate',
#   'an',
#   'understanding',
#   'of',
#   'the',
#   'role',
#   'limitations',
#   'and',
#   'demand',
#   'for',
#   'audits',
#   'in',
#   'modern',
#   'corporate',
#   'society',
#   'including',
#   'the',
#   "auditor's",
#   'professional',
#   'ethical',
#   'and',
#   'legal',
#   'obligations',
#   'examine',
#   'the',
#   "auditor's",
#   'role',
#   'in',
#   'corporate',
#   'governance',
#   'with',
#   'particular',
#   'emphasis',
#   'on',
#   'the',
#   'detection',
#   'and',
#   'reporting',
#   'of',
#   'fraud',
#   'and',
#   'error',
#   'describe',
#   'the',
#   'assurance',
#   'framework',
#   'and',
#   'apply',
#   'planning',
#   'processes',
#   'and',
#   'evidence',
#   'gathering',
#   'procedures',
#   'that',
#   'are',
#   'used',
#   'by',
#   'auditors',
#   'to',
#   'form',
#   'an',
#   'audit',
#   'opinion',
#   'apply',
#   'critical',
#   'thinking',
#   'problem',
#   'solving',
#   'and',
#   'presentation',
#   'skills',
#   'to',
#   'individual',
#   'and',
#   'or',
#   'group',
#   'activities',
#   'dealing',
#   'with',
#   'auditing',
#   'and',
#   'assurance',
#   'and',
#   'demonstrate',
#   'in',
#   'an',
#   'individual',
#   'summative',
#   'assessment',
#   'task',
#   'the',
#   'acquisition',
#   'of',
#   'a',
#   'comprehensive',
#   'understanding',
#   'of',
#   'the',
#   'topics',
#   'covered',
#   'by',
#   'acw3041',
#   'overview',
#   'of',
#   'auditing',
#   'the',
#   "auditor's",
#   'legal',
#   'liabilities',
#   'audit',
#   'process',
#   'and',
#   'evidence',
#   'the',
#   'concepts',
#   'of',
#   'materiality',
#   'and',
#   'risks',
#   'study',
#   'and',
#   'evaluation',
#   'of',
#   'internal',
#   'control',
#   'edp',
#   'auditing',
#   'audit',
#   'sampling',
#   'techniques',
#   'the',
#   'test',
#   'of',
#   'transactions',
#   'cycles',
#   'and',
#   'the',
#   'verification',
#   'of',
#   'account',
#   'balances',
#   'auditors',
#   'reports',
#   'and',
#   'internal',
#   'and',
#   'operational',
#   'auditing'],
#  'ACX4018': ['implement',
#   'a',
#   'research',
#   'proposal',
#   'recognise',
#   'practical',
#   'problems',
#   'of',
#   'conducting',
#   'scientific',
#   'research',
#   'and',
#   'propose',
#   'solutions',
#   'complete',
#   'a',
#   'research',
#   'dissertation',
#   'develop',
#   'the',
#   'ability',
#   'to',
#   'conduct',
#   'and',
#   'manage',
#   'a',
#   'planned',
#   'study',
#   'apply',
#   'critical',
#   'thinking',
#   'problem',
#   'solving',
#   'and',
#   'presentation',
#   'skills',
#   'in',
#   'individual',
#   'and',
#   'or',
#   'group',
#   'activities',
#   'dealing',
#   'with',
#   'a',
#   'research',
#   'dissertation',
#   'students',
#   'conduct',
#   'a',
#   'critical',
#   'review',
#   'of',
#   'the',
#   'literature',
#   'relevant',
#   'to',
#   'their',
#   'study',
#   'derive',
#   'appropriate',
#   'hypotheses',
#   'for',
#   'testing',
#   'devise',
#   'an',
#   'empirical',
#   'test',
#   'of',
#   'the',
#   'hypotheses',
#   'showing',
#   'regard',
#   'to',
#   'practical',
#   'problems',
#   'of',
#   'conducting',
#   'research',
#   'ethical',
#   'considerations',
#   'and',
#   'principles',
#   'of',
#   'scientific',
#   'method',
#   'conduct',
#   'a',
#   'planned',
#   'study',
#   'and',
#   'manage',
#   'any',
#   'problems',
#   'arising',
#   'in',
#   'the',
#   'data',
#   'collection',
#   'select',
#   'and',
#   'conduct',
#   'an',
#   'appropriate',
#   'analysis',
#   'of',
#   'the',
#   'data',
#   'and',
#   'write',
#   'a',
#   'report',
#   'on',
#   'the',
#   'project',
#   'showing',
#   'due',
#   'regard',
#   'to',
#   'relevant',
#   'stylistic',
#   'conventions'],
#  'ADA3111': ['demonstrate',
#   'understanding',
#   'of',
#   'the',
#   'concepts',
#   'of',
#   'design',
#   'thinking',
#   'and',
#   'their',
#   'application',
#   'identify',
#   'and',
#   'analyse',
#   'ill-defined',
#   'real-world',
#   'project',
#   'problems',
#   'and',
#   'relevant',
#   'design',
#   'thinking',
#   'approaches',
#   'apply',
#   'design',
#   'thinking',
#   'methods',
#   'and',
#   'approaches',
#   'to',
#   'a',
#   'project-based',
#   'problem',
#   'to',
#   'develop',
#   'new',
#   'perspectives',
#   'on',
#   'key',
#   'issues',
#   'and',
#   'to',
#   'identify',
#   'potential',
#   'opportunties',
#   'develop',
#   'test',
#   'and',
#   'evaluate',
#   'original',
#   'proposals',
#   'in',
#   'response',
#   'to',
#   'project-based',
#   'problems',
#   'develop',
#   'an',
#   'awareness',
#   'of',
#   'their',
#   'preferred',
#   'approaches',
#   'to',
#   'complex',
#   'tasks',
#   'and',
#   'ways',
#   'these',
#   'may',
#   'be',
#   'extended',
#   'through',
#   'design',
#   'thinking',
#   'design',
#   'thinking',
#   'applies',
#   'the',
#   'skills',
#   'and',
#   'strategies',
#   'developed',
#   'by',
#   'designers',
#   'to',
#   'a',
#   'wide',
#   'range',
#   'of',
#   'problems',
#   'and',
#   'situations',
#   'these',
#   'skills',
#   'and',
#   'strategies',
#   'include',
#   'a',
#   'range',
#   'of',
#   'conceptual',
#   'and',
#   'communication',
#   'approaches',
#   'ways',
#   'to',
#   'explore',
#   'and',
#   'reconsider',
#   'the',
#   'context',
#   'in',
#   'which',
#   'we',
#   'work',
#   'as',
#   'well',
#   'as',
#   'what',
#   'should',
#   'or',
#   'could',
#   'be',
#   'achieved',
#   'design',
#   'thinking',
#   'brings',
#   'together',
#   'some',
#   'approaches',
#   'that',
#   'are',
#   'known',
#   'in',
#   'the',
#   'sciences',
#   'and',
#   'humanities',
#   'such',
#   'as',
#   'analysis',
#   'and',
#   'synthesis',
#   'but',
#   'applies',
#   'them',
#   'in',
#   'ways',
#   'that',
#   'are',
#   'particular',
#   'to',
#   'a',
#   'design',
#   'approach',
#   'design',
#   'thinking',
#   'can',
#   'enable',
#   'a',
#   'more',
#   'flexible',
#   'approach',
#   'to',
#   'problem',
#   'solving',
#   'and',
#   'a',
#   'more',
#   'nuanced',
#   'engagement',
#   'with',
#   'the',
#   'complex',
#   'issues',
#   'of',
#   'our',
#   'contemporary',
#   'world',
#   'this',
#   'unit',
#   'will',
#   'introduce',
#   'students',
#   'to',
#   'the',
#   'key',
#   'skills',
#   'and',
#   'practices',
#   'associated',
#   'with',
#   'design',
#   'thinking',
#   'and',
#   'offer',
#   'opportunities',
#   'to',
#   'explore',
#   'the',
#   'application',
#   'of',
#   'these',
#   'basic',
#   'creativity',
#   'techniques',
#   'in',
#   'a',
#   'range',
#   'of',
#   'disciplines'],
#  'ADA5001': ['operate',
#   'constructively',
#   'and',
#   'collaboratively',
#   'as',
#   'part',
#   'of',
#   'a',
#   'team',
#   'develop',
#   'observation',
#   'research',
#   'communication',
#   'and',
#   'information',
#   'gathering',
#   'skills',
#   'contribute',
#   'as',
#   'a',
#   'discipline-specific',
#   'practitioner',
#   'within',
#   'an',
#   'interdisciplinary',
#   'context',
#   'conduct',
#   'critical',
#   'enquiry',
#   'and',
#   'provide',
#   'summative',
#   'reviews',
#   'of',
#   'peers',
#   'across',
#   'disciplines',
#   'conceptualise',
#   'design',
#   'and',
#   'create',
#   'a',
#   'response',
#   'to',
#   'a',
#   'given',
#   'interdisciplinary',
#   'problem',
#   'understand',
#   'and',
#   'apply',
#   'the',
#   'rules',
#   'of',
#   'occupational',
#   'health',
#   'and',
#   'safety',
#   'appropriate',
#   'to',
#   'the',
#   'interdisciplinary',
#   'practice',
#   'in',
#   'order',
#   'to',
#   'collaborate',
#   'safely',
#   'with',
#   'peers',
#   'the',
#   'interdisciplinary',
#   'studio',
#   'environment',
#   'provides',
#   'through',
#   'team-based',
#   'project',
#   'activities',
#   'and',
#   'problem-based',
#   'learning',
#   'the',
#   'further',
#   'application',
#   'of',
#   'knowledge',
#   'techniques',
#   'and',
#   'methodologies',
#   'from',
#   'the',
#   'students',
#   'individual',
#   'disciplines',
#   'whilst',
#   'addressing',
#   'a',
#   'complex',
#   'multi-faceted',
#   'problem',
#   'the',
#   'unit',
#   'may',
#   'involve',
#   'any',
#   'combination',
#   'of',
#   'art',
#   'design',
#   'or',
#   'architecture',
#   'students',
#   'the',
#   'ability',
#   'to',
#   'critically',
#   'and',
#   'creatively',
#   'engage',
#   'with',
#   'research',
#   'and',
#   'real',
#   'world',
#   'problems',
#   'through',
#   'interdisciplinary',
#   'approaches',
#   'will',
#   'be',
#   'the',
#   'core',
#   'of',
#   'this',
#   'unit',
#   'students',
#   'will',
#   'further',
#   'develop',
#   'skills',
#   'in',
#   'communication',
#   'collaboration',
#   'and',
#   'innovation',
#   'essential',
#   'tools',
#   'for',
#   'both',
#   'professional',
#   'practice',
#   'and',
#   'research',
#   'activities',
#   'within',
#   'their',
#   'chosen',
#   'field',
#   'and',
#   'beyond',
#   'the',
#   'final',
#   'outcomes',
#   'from',
#   'the',
#   'unit',
#   'may',
#   'be',
#   'collaborative',
#   'or',
#   'individual'],
#  'AHT3801': ['understand',
#   'and',
#   'articulate',
#   'what',
#   'a',
#   'medium',
#   'is',
#   'both',
#   'conceptually',
#   'and',
#   'practically',
#   'analyse',
#   'the',
#   'debates',
#   'surrounding',
#   'the',
#   'defence',
#   'and',
#   'criticism',
#   'of',
#   'medium',
#   'specificity',
#   'and',
#   'the',
#   'trans-disciplinary',
#   'contextualise',
#   'studio',
#   'practice',
#   'within',
#   'the',
#   'conceptual',
#   'models',
#   'explored',
#   'in',
#   'the',
#   'unit',
#   'reflect',
#   'and',
#   'engage',
#   'in',
#   'critical',
#   'dialogue',
#   'about',
#   'the',
#   'medium',
#   'and',
#   'its',
#   'importance',
#   'in',
#   'twenty-first',
#   'century',
#   'art',
#   'this',
#   'unit',
#   'examines',
#   'the',
#   'medium',
#   'and',
#   'its',
#   'materiality',
#   'across',
#   'a',
#   'range',
#   'of',
#   'visual',
#   'art',
#   'practices',
#   'including',
#   'painting',
#   'sculpture',
#   'installation',
#   'photography',
#   'video',
#   'multi-media',
#   'social',
#   'practices',
#   'and',
#   'performance',
#   'art',
#   'it',
#   'focuses',
#   'on',
#   'a',
#   'historical',
#   'lineage',
#   'of',
#   "art's",
#   'mediums',
#   'and',
#   'disciplines',
#   'and',
#   'how',
#   'they',
#   'are',
#   'framed',
#   'constituted',
#   'and',
#   'judged',
#   'in',
#   'a',
#   'diverse',
#   'range',
#   'of',
#   'academic',
#   'fields',
#   'concepts',
#   'and',
#   'traditions',
#   'of',
#   'modern',
#   'aesthetics',
#   'the',
#   'effect',
#   'of',
#   'late-capitalism',
#   'socio-economic',
#   'critiques',
#   'of',
#   'art',
#   'and',
#   'technology',
#   'are',
#   'pivotal',
#   'to',
#   'any',
#   'understanding',
#   'of',
#   'how',
#   "art's",
#   'form',
#   'moves',
#   'between',
#   'modes',
#   'of',
#   'medium-specificity',
#   'to',
#   'trans-disciplinary',
#   'realms',
#   'the',
#   'unit',
#   'introduces',
#   'key',
#   'theoretical',
#   'tenets',
#   'to',
#   'analyse',
#   'late',
#   'modernist',
#   'and',
#   'contemporary',
#   'art',
#   'practices',
#   'as',
#   'case',
#   'studies',
#   'it',
#   'introduces',
#   'students',
#   'to',
#   'the',
#   'critical',
#   'dialogue',
#   'around',
#   'the',
#   'medium',
#   'and',
#   'artists',
#   'material',
#   'processes'],
#  'AMG5743': ['knowledge',
#   'skills',
#   'and',
#   'attributes',
#   'necessary',
#   'for',
#   'understanding',
#   'and',
#   'engaging',
#   'in',
#   'advanced',
#   'research',
#   'an',
#   'ability',
#   'to',
#   'design',
#   'write',
#   'and',
#   'edit',
#   'a',
#   'research',
#   'thesis',
#   'an',
#   'ability',
#   'at',
#   'advanced',
#   'level',
#   'to',
#   'analyse',
#   'and',
#   'evaluate',
#   'arguments',
#   'and',
#   'to',
#   'understand',
#   'critical',
#   'approaches',
#   'relating',
#   'to',
#   'the',
#   'communication',
#   'industries',
#   'and',
#   'communication',
#   'issues',
#   'the',
#   'capacity',
#   'to',
#   'contribute',
#   'advanced',
#   'knowledge',
#   'in',
#   'the',
#   'chosen',
#   'area',
#   'of',
#   'research',
#   'an',
#   'enhanced',
#   'intellectual',
#   'independence',
#   'and',
#   'greater',
#   'self-reliance',
#   'and',
#   'critical',
#   'distance',
#   'in',
#   'intellectual',
#   'and',
#   'professional',
#   'activity',
#   'the',
#   'unit',
#   'is',
#   'an',
#   'alternative',
#   'to',
#   'amg5742',
#   'for',
#   'students',
#   'who',
#   'want',
#   'the',
#   'option',
#   'of',
#   'progression',
#   'to',
#   'a',
#   'higher',
#   'degree',
#   'by',
#   'research',
#   'it',
#   'is',
#   'undertaken',
#   'in',
#   'the',
#   'final',
#   'semester',
#   'of',
#   'the',
#   'master',
#   'of',
#   'communications',
#   'and',
#   'media',
#   'studies',
#   'and',
#   'allows',
#   'students',
#   'to',
#   'develop',
#   'an',
#   'independent',
#   'research',
#   'project',
#   'the',
#   'topic',
#   'is',
#   'chosen',
#   'by',
#   'the',
#   'student',
#   'and',
#   'developed',
#   'with',
#   'the',
#   'advice',
#   'and',
#   'support',
#   'of',
#   'a',
#   'supervisor',
#   'the',
#   'project',
#   'is',
#   'written',
#   'up',
#   'in',
#   'an',
#   '18000',
#   'word',
#   'dissertation',
#   'allowing',
#   'the',
#   'student',
#   'to',
#   'demonstrate',
#   'advanced',
#   'skills',
#   'in',
#   'research',
#   'writing',
#   'and',
#   'project',
#   'management',
#   'students',
#   'are',
#   'encouraged',
#   'to',
#   'consider',
#   'the',
#   'project',
#   'not',
#   'only',
#   'as',
#   'a',
#   'formal',
#   'requirement',
#   'for',
#   'the',
#   'degree',
#   'but',
#   'also',
#   'as',
#   'contributing',
#   'to',
#   'a',
#   'portfolio',
#   'of',
#   'professional',
#   'and',
#   'scholarly',
#   'development'],
#  'APG5050': ['a',
#   'familiarity',
#   'with',
#   'the',
#   'major',
#   'research',
#   'methods',
#   'used',
#   'in',
#   'communication',
#   'and',
#   'media',
#   'studies',
#   'an',
#   'understanding',
#   'of',
#   'the',
#   'difference',
#   'between',
#   'research',
#   'topics',
#   'and',
#   'research',
#   'questions',
#   'and',
#   'an',
#   'ability',
#   'to',
#   'identify',
#   'productive',
#   'research',
#   'questions',
#   'an',
#   'ability',
#   'to',
#   'apply',
#   'research',
#   'methods',
#   'critically',
#   'and',
#   'appropriately',
#   'in',
#   'addressing',
#   'research',
#   'questions',
#   'a',
#   'capacity',
#   'to',
#   'design',
#   'research',
#   'projects',
#   'in',
#   'communication',
#   'and',
#   'media',
#   'studies',
#   'from',
#   'conceptualization',
#   'to',
#   'project',
#   'planning',
#   'an',
#   'ability',
#   'to',
#   'develop',
#   'innovative',
#   'solutions',
#   'to',
#   'problems',
#   'in',
#   'communication',
#   'and',
#   'media',
#   'studies',
#   'cf',
#   'monash',
#   'graduate',
#   'attributes',
#   'policy',
#   'an',
#   'ability',
#   'to',
#   'apply',
#   'research',
#   'skills',
#   'to',
#   'a',
#   'range',
#   'of',
#   'challenges',
#   'in',
#   'communication',
#   'and',
#   'media',
#   'studies',
#   'cf',
#   'monash',
#   'graduate',
#   'attributes',
#   'policy',
#   'the',
#   'unit',
#   'introduces',
#   'students',
#   'to',
#   'principles',
#   'of',
#   'problem-solving',
#   'in',
#   'communication',
#   'and',
#   'media',
#   'research',
#   'it',
#   'will',
#   'consider',
#   'a',
#   'range',
#   'of',
#   'traditional',
#   'and',
#   'emerging',
#   'research',
#   'methods',
#   'including',
#   'textual',
#   'analysis',
#   'content',
#   'analysis',
#   'interviews',
#   'ethnographic',
#   'fieldwork',
#   'digital',
#   'humanities',
#   'approaches',
#   'sentiment',
#   'analysis',
#   'and',
#   'audience',
#   'research',
#   'the',
#   'focus',
#   'however',
#   'will',
#   'be',
#   'not',
#   'be',
#   'simply',
#   'on',
#   'learning',
#   'and',
#   'applying',
#   'these',
#   'methods',
#   'but',
#   'also',
#   'on',
#   'understanding',
#   'their',
#   'relation',
#   'to',
#   'problems',
#   'in',
#   'the',
#   'fields',
#   'they',
#   'address',
#   'the',
#   'unit',
#   'will',
#   'develop',
#   'skills',
#   'in',
#   'research',
#   'design',
#   'from',
#   'identifying',
#   'productive',
#   'research',
#   'questions',
#   'to',
#   'selecting',
#   'appropriate',
#   'methodologies',
#   'and',
#   'project',
#   'planning',
#   'these',
#   'skills',
#   'provide',
#   'a',
#   'platform',
#   'for',
#   'further',
#   'development',
#   'in',
#   'the',
#   'communications',
#   'research',
#   'project',
#   'or',
#   'masters',
#   'thesis'],
#  'APG5052': ['critically',
#   'analyse',
#   'the',
#   'most',
#   'recent',
#   'developments',
#   'in',
#   'communications',
#   'and',
#   'media',
#   'through',
#   'engaging',
#   'with',
#   'an',
#   'emerging',
#   'problem',
#   'or',
#   'question',
#   'in',
#   'the',
#   'field',
#   'contribute',
#   'original',
#   'thinking',
#   'to',
#   'produce',
#   'innovative',
#   'solutions',
#   'to',
#   'contemporary',
#   'problems',
#   'in',
#   'communication',
#   'and',
#   'media',
#   'articulate',
#   'the',
#   'ethical',
#   'values',
#   'relevant',
#   'in',
#   'the',
#   'rapid',
#   'development',
#   'of',
#   'communication',
#   'and',
#   'media',
#   'with',
#   'particular',
#   'attention',
#   'to',
#   'the',
#   'impact',
#   'of',
#   'digital',
#   'technologies',
#   'utilise',
#   'research',
#   'skills',
#   'to',
#   'evaluate',
#   'issues',
#   'in',
#   'the',
#   'field',
#   'and',
#   'communicate',
#   'findings',
#   'in',
#   'a',
#   'professional',
#   'context',
#   'in',
#   'the',
#   'unit',
#   'students',
#   'will',
#   'engage',
#   'in',
#   'a',
#   'specialised',
#   'course',
#   'of',
#   'study',
#   'examining',
#   'a',
#   'cutting-edge',
#   'development',
#   'in',
#   'communication',
#   'and',
#   'media',
#   'in',
#   'each',
#   'year',
#   'of',
#   'offering',
#   'the',
#   'unit',
#   'will',
#   'address',
#   'a',
#   'different',
#   'question',
#   'or',
#   'topic',
#   'within',
#   'the',
#   'general',
#   'field',
#   'of',
#   'digital',
#   'media',
#   'developing',
#   'specialist',
#   'insight',
#   'as',
#   'appropriate',
#   'to',
#   'the',
#   'expertise',
#   'of',
#   'the',
#   'media',
#   'researcher',
#   'or',
#   'industry',
#   'practitioner',
#   'engaged',
#   'to',
#   'teach',
#   'it',
#   'the',
#   'unit',
#   'will',
#   'have',
#   'a',
#   'strong',
#   'research',
#   'focus',
#   'which',
#   'may',
#   'include',
#   'experimental',
#   'development',
#   'of',
#   'an',
#   'professional',
#   'or',
#   'industry',
#   'practice',
#   'students',
#   'will',
#   'be',
#   'expected',
#   'to',
#   'bring',
#   'their',
#   'work',
#   'to',
#   'a',
#   'point',
#   'of',
#   'intersection',
#   'with',
#   'the',
#   'most',
#   'recent',
#   'work',
#   'addressing',
#   'problems',
#   'emerging',
#   'in',
#   'media',
#   'studies',
#   'scholarship',
#   'or',
#   'practices',
#   'in',
#   'media',
#   'and',
#   'communication',
#   'industries'],
#  'APG5077': ['identify',
#   'assess',
#   'and',
#   'interpret',
#   'cultural',
#   'and',
#   'nature-based',
#   'assets',
#   'for',
#   'a',
#   'tourist',
#   'audience',
#   'devise',
#   'effective',
#   'management',
#   'strategy',
#   'for',
#   'sustainable',
#   'cultural',
#   'and',
#   'nature-based',
#   'tourism',
#   'development',
#   'propose',
#   'appropriate',
#   'research-based',
#   'solutions',
#   'to',
#   'sustainable',
#   'cultural',
#   'and',
#   'nature-based',
#   'tourism',
#   'challenges',
#   'exhibit',
#   'ethical',
#   'values',
#   'in',
#   'the',
#   'development',
#   'of',
#   'sustainable',
#   'tourism',
#   'in',
#   'diverse',
#   'cultural',
#   'and',
#   'nature-based',
#   'contexts',
#   'effectively',
#   'communicate',
#   'a',
#   'well-argued',
#   'tourism',
#   'strategy',
#   'across',
#   'diverse',
#   'medium',
#   'the',
#   'sustainable',
#   'use',
#   'of',
#   'nature-based',
#   'and',
#   'cultural',
#   'resources',
#   'is',
#   'vital',
#   'to',
#   'successful',
#   'tourism',
#   'destination',
#   'development',
#   'globally',
#   'in',
#   'this',
#   'unit',
#   'students',
#   'learn',
#   'how',
#   'to',
#   'identify',
#   'assess',
#   'interpret',
#   'and',
#   'strategically',
#   'manage',
#   'these',
#   'critical',
#   'assets',
#   'to',
#   'maximise',
#   'visitor',
#   'experience',
#   'and',
#   'minimise',
#   'negative',
#   'environmental',
#   'and',
#   'cultural',
#   'impacts',
#   'students',
#   'will',
#   'learn',
#   'from',
#   'industry',
#   'experts',
#   'during',
#   'the',
#   'case-based',
#   'field',
#   'study',
#   'of',
#   'hobart',
#   'in',
#   'tasmania',
#   'a',
#   'leading',
#   'destination',
#   'in',
#   'both',
#   'cultural',
#   'heritage',
#   'and',
#   'nature-based',
#   'product',
#   'development'],
#  'APG5082': ['explain',
#   'creative',
#   'industries',
#   'structures',
#   'and',
#   'markets',
#   'identify',
#   'business',
#   'opportunities',
#   'in',
#   'specific',
#   'creative',
#   'cultural',
#   'industries',
#   'utilise',
#   'academic',
#   'concepts',
#   'to',
#   'understand',
#   'audiences',
#   'and',
#   'challenges',
#   'in',
#   'creative',
#   'products',
#   'branding',
#   'develop',
#   'marketing',
#   'strategy',
#   'using',
#   'independent',
#   'research',
#   'skills',
#   'engage',
#   'with',
#   'different',
#   'cultural',
#   'contexts',
#   'pitch',
#   'and',
#   'communicate',
#   'ideas',
#   'to',
#   'stakeholders',
#   'effectively',
#   'in',
#   'this',
#   'unit',
#   'students',
#   'analyse',
#   'creative',
#   'enterprises',
#   'and',
#   'creative',
#   'entrepreneurial',
#   'mindsets',
#   'we',
#   'differentiate',
#   'marketing',
#   'and',
#   'business',
#   'approaches',
#   'in',
#   'the',
#   'cultural',
#   'industries',
#   'from',
#   'other',
#   'sectors',
#   'by',
#   'analysing',
#   'the',
#   'changing',
#   'marketing',
#   'models',
#   'the',
#   'creative',
#   'industries',
#   'value',
#   'chains',
#   'and',
#   'their',
#   'audience',
#   'by',
#   'treating',
#   'creative',
#   'entrepreneurship',
#   'as',
#   'a',
#   'specialism',
#   'we',
#   'identify',
#   'key',
#   'strategic',
#   'approaches',
#   'by',
#   'entrepreneurs',
#   'in',
#   'global',
#   'cultural',
#   'industries',
#   'of',
#   'various',
#   'sizes',
#   'and',
#   'in',
#   'both',
#   'traditional',
#   'and',
#   'emergent',
#   'niche',
#   'markets',
#   'we',
#   'will',
#   'also',
#   'identify',
#   'challenges',
#   'in',
#   'the',
#   'increasingly',
#   'commercializing',
#   'creative',
#   'industries',
#   'the',
#   'implication',
#   'of',
#   'creative',
#   'solutions',
#   'to',
#   'marketing',
#   'and',
#   'management',
#   'outside',
#   'of',
#   'creative',
#   'industries',
#   'is',
#   'important',
#   'for',
#   'entrepreneurs',
#   'in',
#   'order',
#   'for',
#   'them',
#   'to',
#   'place',
#   'culture',
#   'at',
#   'the',
#   'heart',
#   'of',
#   'what',
#   'doing',
#   'business',
#   'means',
#   'in',
#   'contemporary',
#   'society'],
#  'APG5103': ['employ',
#   'expert',
#   'knowledge',
#   'and',
#   'specialist',
#   'skills',
#   'in',
#   'policy',
#   'analysis',
#   'and',
#   'evaluation',
#   'to',
#   'enable',
#   'discipline',
#   'based',
#   'solutions',
#   'relevant',
#   'to',
#   'diverse',
#   'business',
#   'professional',
#   'and',
#   'public',
#   'policy',
#   'communities',
#   'devise',
#   'and',
#   'deliver',
#   'innovative',
#   'solutions',
#   'to',
#   'policy-related',
#   'challenges',
#   'employing',
#   'advanced',
#   'critical',
#   'thinking',
#   'evaluation',
#   'and',
#   'research',
#   'skills',
#   'communicate',
#   'policy',
#   'analysis',
#   'and',
#   'options',
#   'with',
#   'clarity',
#   'and',
#   'purpose',
#   'the',
#   'unit',
#   'provides',
#   'students',
#   'with',
#   'understandings',
#   'of',
#   'the',
#   'conceptual',
#   'and',
#   'theoretical',
#   'frameworks',
#   'for',
#   'policy',
#   'analysis',
#   'and',
#   'evaluation',
#   'which',
#   'are',
#   'necessary',
#   'to',
#   'present',
#   'effective',
#   'policy',
#   'advice',
#   'to',
#   'the',
#   'highest',
#   'levels',
#   'of',
#   'government',
#   'using',
#   'real-life',
#   'examples',
#   'of',
#   'public',
#   'policy',
#   'the',
#   'unit',
#   'explores',
#   'the',
#   'challenges',
#   'of',
#   'problem',
#   'definition',
#   'analysing',
#   'and',
#   'evaluating',
#   'evidence',
#   'choosing',
#   'policy',
#   'instruments',
#   'developing',
#   'policy',
#   'options',
#   'and',
#   'preparing',
#   'and',
#   'submitting',
#   'policy',
#   'advice'],
#  'APG5230': ['explain',
#   'key',
#   'concepts',
#   'in',
#   'landscape',
#   'ecology',
#   'including',
#   'resilience',
#   'and',
#   'connectivity',
#   'apply',
#   'these',
#   'concepts',
#   'in',
#   'real-world',
#   'environmental',
#   'contexts',
#   'understand',
#   'the',
#   'role',
#   'of',
#   'expertise',
#   'in',
#   'shaping',
#   'policy',
#   'design',
#   'and',
#   'implementation',
#   'critically',
#   'evaluate',
#   'the',
#   'interaction',
#   'between',
#   'governance',
#   'approaches',
#   'and',
#   'their',
#   'realisation',
#   'in',
#   'practice',
#   'in',
#   'terms',
#   'of',
#   'sustainability',
#   'outcomes',
#   'the',
#   'unit',
#   'provides',
#   'a',
#   'broad',
#   'introduction',
#   'to',
#   'ecology',
#   'and',
#   'environmental',
#   'management',
#   'at',
#   'the',
#   'interface',
#   'between',
#   'science',
#   'and',
#   'policy',
#   'it',
#   'is',
#   'suitable',
#   'for',
#   'those',
#   'looking',
#   'to',
#   'understand',
#   'how',
#   'policy',
#   'works',
#   'in',
#   'practice',
#   'to',
#   'best',
#   'further',
#   'their',
#   'professional',
#   'careers',
#   'no',
#   'prior',
#   'ecological',
#   'experience',
#   'is',
#   'required',
#   'through',
#   'australian',
#   'and',
#   'international',
#   'case',
#   'studies',
#   'the',
#   'unit',
#   'will',
#   'introduce',
#   'the',
#   'challenges',
#   'in',
#   'translating',
#   'ecological',
#   'knowledge',
#   'into',
#   'effective',
#   'policy',
#   'tools'],
#  'APG5348': ['summarize',
#   'key',
#   'theoretical',
#   'debates',
#   'in',
#   'relation',
#   'to',
#   'second',
#   'language',
#   'acquisition',
#   'and',
#   'evaluate',
#   'relevant',
#   'empirical',
#   'evidence',
#   'compare',
#   'the',
#   'work',
#   'of',
#   'competing',
#   'theorists',
#   'and',
#   'recognise',
#   'their',
#   'role',
#   'in',
#   'the',
#   'development',
#   'of',
#   'sla',
#   'theory',
#   'reflect',
#   'on',
#   'their',
#   'own',
#   'language',
#   'learning',
#   'experience',
#   'and',
#   'classroom',
#   'practice',
#   'in',
#   'the',
#   'light',
#   'of',
#   'theoretical',
#   'and',
#   'empirical',
#   'studies',
#   'evaluate',
#   'major',
#   'methodological',
#   'approaches',
#   'to',
#   'the',
#   'study',
#   'of',
#   'second',
#   'language',
#   'acquisition',
#   'conduct',
#   'a',
#   'major',
#   'research',
#   'project',
#   'on',
#   'an',
#   'area',
#   'of',
#   'second',
#   'language',
#   'acquisition',
#   'the',
#   'course',
#   'will',
#   'address',
#   'key',
#   'concepts',
#   'theoretical',
#   'models',
#   'accepted',
#   'approaches',
#   'and',
#   'contested',
#   'frameworks',
#   'and',
#   'theories',
#   'in',
#   'the',
#   'rapidly',
#   'changing',
#   'field',
#   'of',
#   'second',
#   'language',
#   'acquisition',
#   'topics',
#   'covered',
#   'include',
#   'models',
#   'and',
#   'theories',
#   'of',
#   'second',
#   'language',
#   'acquisition',
#   'first',
#   'and',
#   'second',
#   'language',
#   'acquisition',
#   'error',
#   'analysis',
#   'and',
#   'interlanguage',
#   'interlanguage',
#   'pragmatics',
#   'input',
#   'and',
#   'interaction',
#   'learner',
#   'strategies',
#   'learning',
#   'styles',
#   'cognitive',
#   'processes',
#   'second',
#   'language',
#   'identity',
#   'learners',
#   'rights',
#   'and',
#   'methods',
#   'in',
#   'sla',
#   'research'],
#  'APG5351': ['identify',
#   'and',
#   'explain',
#   'how',
#   'international',
#   'news',
#   'stories',
#   'are',
#   'selected',
#   'gathered',
#   'and',
#   'distributed',
#   'compare',
#   'the',
#   'particular',
#   'approaches',
#   'to',
#   'news',
#   'gathering',
#   'and',
#   'publishing',
#   'in',
#   'different',
#   'countries',
#   'conceptualise',
#   'how',
#   'big',
#   'global',
#   'news',
#   'stories',
#   'contain',
#   'inherent',
#   'ethical',
#   'dilemmas',
#   'explore',
#   'and',
#   'analyse',
#   'an',
#   'international',
#   'news',
#   'issue',
#   'design',
#   'an',
#   'international',
#   'research',
#   'project',
#   'using',
#   'media',
#   'theories',
#   'and',
#   'methodologies',
#   'evaluate',
#   'and',
#   'communicate',
#   'the',
#   'results',
#   'of',
#   'the',
#   'media',
#   'project',
#   'through',
#   'class',
#   'and',
#   'online',
#   'presentation',
#   'and',
#   'by',
#   'writing',
#   'a',
#   'media',
#   'report',
#   'the',
#   'unit',
#   'will',
#   'enable',
#   'students',
#   'to',
#   'understand',
#   'how',
#   'international',
#   'news',
#   'stories',
#   'are',
#   'sourced',
#   'gathered',
#   'and',
#   'distributed',
#   'around',
#   'the',
#   'world',
#   'the',
#   'unit',
#   'explores',
#   'the',
#   'changing',
#   'nature',
#   'of',
#   'the',
#   'media',
#   'ecosystem',
#   'from',
#   'staff',
#   'foreign',
#   'correspondents',
#   'working',
#   'for',
#   'international',
#   'news',
#   'organisations',
#   'to',
#   'local',
#   'journalists',
#   'and',
#   'eyewitnesses',
#   'the',
#   'content',
#   'for',
#   'this',
#   'unit',
#   'includes',
#   'the',
#   'history',
#   'of',
#   'the',
#   'international',
#   'news',
#   'agencies',
#   'global',
#   'news',
#   'flows',
#   'transnational',
#   'broadcasters',
#   'the',
#   'role',
#   'of',
#   'the',
#   'foreign',
#   'correspondent',
#   'the',
#   'evolution',
#   'of',
#   'the',
#   'citizen',
#   'journalist',
#   'and',
#   'the',
#   'big',
#   'world',
#   'news',
#   'stories',
#   'dominating',
#   'the',
#   'international',
#   'news',
#   'agenda',
#   'students',
#   'will',
#   'use',
#   'international',
#   'news',
#   'resources',
#   'to',
#   'research',
#   'study',
#   'and',
#   'write',
#   'their',
#   'own',
#   'international',
#   'media',
#   'research',
#   'report'],
#  'APG5400': ['have',
#   'a',
#   'sound',
#   'understanding',
#   'of',
#   'globalisation',
#   'as',
#   'it',
#   'affects',
#   'communications',
#   'and',
#   'media',
#   'industries',
#   'be',
#   'able',
#   'to',
#   'analyse',
#   'global',
#   'media',
#   'and',
#   'the',
#   'policies',
#   'which',
#   'affect',
#   'them',
#   'be',
#   'aware',
#   'of',
#   'the',
#   'potentials',
#   'and',
#   'problems',
#   'of',
#   'cross-cultural',
#   'communication',
#   'and',
#   'of',
#   'the',
#   'major',
#   'theories',
#   'which',
#   'have',
#   'been',
#   'developed',
#   'to',
#   'explain',
#   'them',
#   'understand',
#   'changing',
#   'modes',
#   'of',
#   'reception',
#   'by',
#   'global',
#   'audiences',
#   'together',
#   'with',
#   'the',
#   'implications',
#   'of',
#   'these',
#   'processes',
#   'for',
#   'national',
#   'and',
#   'personal',
#   'identity',
#   'be',
#   'aware',
#   'of',
#   'the',
#   'major',
#   'legal',
#   'and',
#   'ethical',
#   'challenges',
#   'thrown',
#   'up',
#   'by',
#   'the',
#   'globalisation',
#   'of',
#   'communications',
#   'and',
#   'media',
#   'demonstrate',
#   'an',
#   'enhanced',
#   'ability',
#   'to',
#   'conduct',
#   'independent',
#   'research',
#   'this',
#   'subject',
#   'explores',
#   'key',
#   'issues',
#   'arising',
#   'from',
#   'the',
#   'rapid',
#   'change',
#   'development',
#   'and',
#   'growth',
#   'in',
#   'international',
#   'communications',
#   'it',
#   'examines',
#   'the',
#   'impact',
#   'of',
#   'globalisation',
#   'and',
#   'shifts',
#   'in',
#   'production',
#   'distribution',
#   'and',
#   'consumption',
#   'in',
#   'international',
#   'communications',
#   'students',
#   'will',
#   'consider',
#   'power',
#   'and',
#   'disadvantage',
#   'cultural',
#   'flows',
#   'and',
#   'exchange',
#   'development',
#   'communication',
#   'cross-cultural',
#   'communication',
#   'international',
#   'advertising',
#   'and',
#   'public',
#   'relations',
#   'diasporic',
#   'cultures',
#   'and',
#   'legal',
#   'and',
#   'ethical',
#   'issues',
#   'in',
#   'international',
#   'communications',
#   'examples',
#   'will',
#   'be',
#   'drawn',
#   'from',
#   'many',
#   'different',
#   'countries',
#   'including',
#   'case',
#   'studies',
#   'of',
#   'communications',
#   'and',
#   'media',
#   'in',
#   'asia',
#   'europe',
#   'north',
#   'america',
#   'and',
#   'the',
#   'middle',
#   'east'],
#  'APG5628': ['critically',
#   'assess',
#   'contributions',
#   'to',
#   'development',
#   'as',
#   'an',
#   'academic',
#   'field',
#   'that',
#   'explores',
#   'the',
#   'history',
#   'of',
#   'development',
#   'thinking',
#   'and',
#   'the',
#   'spatial',
#   'patterns',
#   'of',
#   'development',
#   'in',
#   'practice',
#   'articulate',
#   'different',
#   'approaches',
#   'to',
#   'and',
#   'practices',
#   'of',
#   'development',
#   'and',
#   'to',
#   'evaluate',
#   'various',
#   'alternatives',
#   'in',
#   'light',
#   'of',
#   'the',
#   'most',
#   'recent',
#   'scholarly',
#   'work',
#   'on',
#   'contemporary',
#   'uneven',
#   'development',
#   'argue',
#   'for',
#   'or',
#   'against',
#   'the',
#   'contemporary',
#   'development',
#   'paradigm',
#   'as',
#   'we',
#   'know',
#   'it',
#   'with',
#   'an',
#   'appropriate',
#   'degree',
#   'of',
#   'personal',
#   'and',
#   'socio-political',
#   'reflection',
#   'what',
#   'does',
#   'development',
#   'mean',
#   'as',
#   'a',
#   'body',
#   'of',
#   'ideas',
#   'that',
#   'structures',
#   'systems',
#   'of',
#   'power',
#   'flows',
#   'of',
#   'resources',
#   'and',
#   'social',
#   'transformations',
#   'across',
#   'the',
#   'globe',
#   'what',
#   'does',
#   'it',
#   'mean',
#   'in',
#   'practice',
#   'to',
#   'intervene',
#   'often',
#   'across',
#   'diverse',
#   'cultural',
#   'contexts',
#   'with',
#   'programmes',
#   'designed',
#   'according',
#   'to',
#   'these',
#   'ideas',
#   'of',
#   'development',
#   'this',
#   'unit',
#   'addresses',
#   'such',
#   'questions',
#   'by',
#   'deconstructing',
#   'the',
#   'conceptual',
#   'and',
#   'practical',
#   'pillars',
#   'of',
#   'development',
#   'and',
#   'by',
#   'interrogating',
#   'similar',
#   'concepts',
#   'such',
#   'as',
#   'economic',
#   'growth',
#   'progress',
#   'and',
#   'modernisation',
#   'in',
#   'addition',
#   'to',
#   'briefly',
#   'reviewing',
#   'some',
#   'early',
#   'theorisations',
#   'of',
#   'development',
#   'and',
#   'their',
#   'links',
#   'to',
#   'colonialism',
#   'and',
#   'ideas',
#   'of',
#   'modernisation',
#   'the',
#   'unit',
#   'exposes',
#   'the',
#   'power-laden',
#   'and',
#   'unequal',
#   'nature',
#   'of',
#   'contemporary',
#   'development',
#   'as',
#   'an',
#   'institutionalised',
#   'set',
#   'of',
#   'practices',
#   'that',
#   'rose',
#   'to',
#   'prominence',
#   'after',
#   'world',
#   'war',
#   'ii',
#   'using',
#   'case',
#   'studies',
#   'to',
#   'paint',
#   'a',
#   'picture',
#   'of',
#   'geographically',
#   'uneven',
#   'development',
#   'today',
#   'the',
#   'unit',
#   'explores',
#   'whether',
#   'development',
#   'theories',
#   'correlate',
#   'with',
#   'development-in',
#   'practice',
#   'it',
#   'also',
#   'explores',
#   'the',
#   'ways',
#   'in',
#   'which',
#   'diverse',
#   'social',
#   'groups',
#   'and',
#   'social',
#   'movements',
#   'resist',
#   'western',
#   'notions',
#   'of',
#   'progress',
#   'attempting',
#   'to',
#   'reclaim',
#   'development',
#   'to',
#   'forge',
#   'more',
#   'autonomous',
#   'pathways',
#   'to',
#   'well-being',
#   'these',
#   'alternative',
#   'pathways',
#   'raise',
#   'questions',
#   'about',
#   'the',
#   'normative',
#   'side',
#   'of',
#   'development',
#   'and',
#   'about',
#   'whether',
#   'the',
#   'contemporary',
#   'development',
#   'institution',
#   'should',
#   'be',
#   'deconstructed',
#   'in',
#   'practice'],
#  'APG5849': ['formulate',
#   'a',
#   'research',
#   'project',
#   'conduct',
#   'research',
#   'independently',
#   'demonstrate',
#   'a',
#   'command',
#   'of',
#   'the',
#   'relevant',
#   'literature',
#   'critically',
#   'analyse',
#   'the',
#   'relevant',
#   'academic',
#   'literature',
#   'develop',
#   'an',
#   'academically',
#   'sound',
#   'argument',
#   'demonstrate',
#   'sophisticated',
#   'written',
#   'skills',
#   'under',
#   'the',
#   'supervision',
#   'of',
#   'suitable',
#   'academic',
#   'staff',
#   'students',
#   'will',
#   'conduct',
#   'independent',
#   'research',
#   'on',
#   'an',
#   'appropriate',
#   'topic',
#   'this',
#   'research',
#   'process',
#   'continues',
#   'in',
#   'apg5850',
#   'graduate',
#   'research',
#   'thesis',
#   'b',
#   'as',
#   'a',
#   'part',
#   'of',
#   'which',
#   'students',
#   'submit',
#   'their',
#   'research',
#   'thesis'],
#  'APG5881': ["na'students",
#   'will',
#   'undertake',
#   'in-country',
#   'study',
#   'at',
#   'the',
#   'institution',
#   'with',
#   'which',
#   'monash',
#   'university',
#   'has',
#   'an',
#   'exchange',
#   'agreement',
#   'this',
#   'study',
#   'will',
#   'be',
#   'the',
#   'equivalent',
#   'of',
#   '12',
#   'points',
#   'of',
#   'fifth-year',
#   'postgraduate',
#   'study',
#   'in',
#   'arts',
#   'at',
#   'monash',
#   'university',
#   'in',
#   'the',
#   'form',
#   'of',
#   '5th',
#   'year',
#   'unit',
#   's',
#   'offered',
#   'by',
#   'the',
#   'host',
#   'institution',
#   'in',
#   'the',
#   'domain',
#   'of',
#   'translation',
#   'studies'],
#  'APG5900': ['a',
#   'broad',
#   'overview',
#   'of',
#   'the',
#   'conceptual',
#   'historical',
#   'and',
#   'contemporary',
#   'issues',
#   'involved',
#   'in',
#   'notions',
#   'of',
#   'the',
#   'cultural',
#   'economy',
#   'critically',
#   'evaluate',
#   'the',
#   'different',
#   'approaches',
#   'to',
#   'cultural',
#   'economy',
#   'and',
#   'the',
#   'issues',
#   'they',
#   'raise',
#   'apply',
#   'independent',
#   'research',
#   'skills',
#   'to',
#   'a',
#   'range',
#   'of',
#   'conceptual',
#   'and',
#   'historical',
#   'problems',
#   'in',
#   'the',
#   'field',
#   'of',
#   'cultural',
#   'economy',
#   'an',
#   'ability',
#   'to',
#   'write',
#   'and',
#   'communicate',
#   'effectively',
#   'and',
#   'in',
#   'analytical',
#   'depth',
#   'an',
#   'ability',
#   'to',
#   'effectively',
#   'utilise',
#   'academic',
#   'concepts',
#   'to',
#   'identify',
#   'and',
#   'investigate',
#   'concrete',
#   'challenges',
#   'and',
#   'issues',
#   'involved',
#   'in',
#   'specific',
#   'aspects',
#   'of',
#   'the',
#   'cultural',
#   'economy',
#   'this',
#   'unit',
#   'will',
#   'introduce',
#   'the',
#   'core',
#   'conceptual',
#   'and',
#   'historical',
#   'dimensions',
#   'of',
#   'the',
#   'mca',
#   'including',
#   'the',
#   'emergence',
#   'of',
#   'arts',
#   'and',
#   'cultural',
#   'policy',
#   'the',
#   'rise',
#   'of',
#   'the',
#   'cultural',
#   'and',
#   'creative',
#   'industries',
#   'urban',
#   'regeneration',
#   'and',
#   'urban',
#   'cultural',
#   'economies',
#   'and',
#   'the',
#   'evolution',
#   'of',
#   'cultural',
#   'creative',
#   'work',
#   'in',
#   'particular',
#   'it',
#   'will',
#   'explore',
#   'the',
#   'concepts',
#   'and',
#   'claims',
#   'of',
#   'cultural',
#   'economy',
#   'that',
#   'the',
#   'economy',
#   'is',
#   'a',
#   'constructed',
#   'socio-cultural',
#   'phenomenon',
#   'and',
#   'examine',
#   'the',
#   'consequences',
#   'of',
#   'these',
#   'for',
#   'existing',
#   'and',
#   'future',
#   'practices',
#   'by',
#   'individuals',
#   'businesses',
#   'and',
#   'policy',
#   'agencies',
#   'operating',
#   'within',
#   'the',
#   'cultural',
#   'economy',
#   'per',
#   'se',
#   'students',
#   'will',
#   'be',
#   'asked',
#   'to',
#   'submit',
#   'two',
#   'assignments',
#   'based',
#   'on',
#   'concepts',
#   'and',
#   'issues',
#   'generated',
#   'by',
#   'the',
#   'unit',
#   'content'],
#  'ARC3002': ['demonstrate',
#   'a',
#   'refined',
#   'level',
#   'of',
#   'competence',
#   'in',
#   'architectural',
#   'design',
#   'have',
#   'a',
#   'demonstrated',
#   'ability',
#   'to',
#   'critically',
#   'analyse',
#   'and',
#   'successfully',
#   'respond',
#   'to',
#   'the',
#   'complex',
#   'range',
#   'of',
#   'issues',
#   'inherent',
#   'in',
#   'an',
#   'architectural',
#   'design',
#   'project',
#   'have',
#   'developed',
#   'a',
#   'sophisticated',
#   'understanding',
#   'of',
#   'how',
#   'observation',
#   'analysis',
#   'experiment',
#   'and',
#   'critique',
#   'apply',
#   'to',
#   'the',
#   'architectural',
#   'design',
#   'process',
#   'have',
#   'acquired',
#   'an',
#   'advanced',
#   'level',
#   'of',
#   'competence',
#   'and',
#   'consolidation',
#   'of',
#   'all',
#   'presentation',
#   'skills',
#   'verbal',
#   'graphic',
#   'and',
#   '3-dimensional',
#   'understand',
#   'and',
#   'be',
#   'able',
#   'to',
#   'apply',
#   'the',
#   'rules',
#   'of',
#   'occupational',
#   'health',
#   'and',
#   'safety',
#   'appropriate',
#   'to',
#   'the',
#   'unit',
#   'of',
#   'study',
#   'architecture',
#   'design',
#   'studio',
#   '6',
#   'aims',
#   'to',
#   'consolidate',
#   'the',
#   'conceptual',
#   'understanding',
#   'and',
#   'skill',
#   'base',
#   'of',
#   'preceding',
#   'design',
#   'studios',
#   'it',
#   'continues',
#   'to',
#   'elaborate',
#   'on',
#   'architectural',
#   'design',
#   'as',
#   'a',
#   'process',
#   'of',
#   'investigation',
#   'critical',
#   'observation',
#   'and',
#   'experiment',
#   'it',
#   'increases',
#   'the',
#   'emphasis',
#   'on',
#   'design',
#   'as',
#   'a',
#   'synthetic',
#   'process',
#   'encompassing',
#   'a',
#   'range',
#   'of',
#   'complex',
#   'issues',
#   'inherent',
#   'in',
#   'the',
#   'production',
#   'of',
#   'architecture',
#   'material',
#   'structure',
#   'program',
#   'site',
#   'history',
#   'and',
#   'representation',
#   'are',
#   'investigated',
#   'in',
#   'their',
#   'relationship',
#   'to',
#   'the',
#   'production',
#   'of',
#   'architectural',
#   'form'],
#  'ARC5401': ['be',
#   'able',
#   'to',
#   'locate',
#   'design',
#   'research',
#   'within',
#   'relevant',
#   'contexts',
#   'have',
#   'acquired',
#   'proficiency',
#   'in',
#   'architectural',
#   'design',
#   'research',
#   'methods',
#   'have',
#   'the',
#   'ability',
#   'to',
#   'critically',
#   'analyse',
#   'and',
#   'successfully',
#   'respond',
#   'to',
#   'issues',
#   'inherent',
#   'in',
#   'formulating',
#   'architecture',
#   'research',
#   'have',
#   'developed',
#   'and',
#   'demonstrated',
#   'a',
#   'sophisticated',
#   'understanding',
#   'of',
#   'how',
#   'observation',
#   'analysis',
#   'experiment',
#   'and',
#   'critique',
#   'apply',
#   'to',
#   'the',
#   'development',
#   'of',
#   'architecture',
#   'design',
#   'research',
#   'understand',
#   'and',
#   'be',
#   'able',
#   'to',
#   'apply',
#   'the',
#   'rules',
#   'of',
#   'occupational',
#   'health',
#   'and',
#   'safety',
#   'appropriate',
#   'to',
#   'the',
#   'unit',
#   'of',
#   'study',
#   'architecture',
#   'research',
#   'methods',
#   'is',
#   'the',
#   'prelude',
#   'to',
#   'the',
#   'final',
#   'architecture',
#   'design',
#   'research',
#   'project',
#   'addressing',
#   'diverse',
#   'methodologies',
#   'and',
#   'tactics',
#   'this',
#   'unit',
#   'provides',
#   'the',
#   'background',
#   'and',
#   'foundation',
#   'for',
#   'undertaking',
#   'independently',
#   'guided',
#   'design',
#   'research',
#   'the',
#   'unit',
#   'will',
#   'establish',
#   'the',
#   'necessary',
#   'parameters',
#   'for',
#   'the',
#   'development',
#   'of',
#   'the',
#   'subsequent',
#   'design',
#   'research',
#   'projects',
#   'including',
#   'methodological',
#   'conceptual',
#   'and',
#   'physical',
#   'contexts',
#   'and',
#   'operative',
#   'frameworks',
#   'for',
#   'architectural',
#   'speculations'],
#  'ASC5001': ['critique',
#   'the',
#   'premises',
#   'and',
#   'foundations',
#   'for',
#   'the',
#   'biopsychosocial',
#   'model',
#   'of',
#   'addiction',
#   'in',
#   'relation',
#   'to',
#   'other',
#   'models',
#   'of',
#   'addiction',
#   'consider',
#   'and',
#   'critique',
#   'the',
#   'role',
#   'of',
#   'various',
#   'factors',
#   'in',
#   'the',
#   'aetiology',
#   'of',
#   'addiction',
#   'with',
#   'reference',
#   'to',
#   'the',
#   'research',
#   'evidence',
#   'base',
#   'analyse',
#   'the',
#   'neurobiological',
#   'and',
#   'genetic',
#   'bases',
#   'of',
#   'addictive',
#   'behaviours',
#   'critically',
#   'evaluate',
#   'the',
#   'psychological',
#   'and',
#   'sociocultural',
#   'bases',
#   'of',
#   'addictive',
#   'behaviours',
#   'demonstrate',
#   'the',
#   'use',
#   'of',
#   'the',
#   'drug',
#   'set',
#   'and',
#   'setting',
#   'model',
#   'in',
#   'understanding',
#   'substance',
#   'effects',
#   'on',
#   'the',
#   'individual',
#   'synthesise',
#   'the',
#   'implications',
#   'of',
#   'the',
#   'harm',
#   'minimisation',
#   'approach',
#   'for',
#   'understanding',
#   'interventions',
#   'present',
#   'an',
#   'argument',
#   'based',
#   'on',
#   'theoretical',
#   'and',
#   'empirical',
#   'literature',
#   'regarding',
#   'whether',
#   'process',
#   'addictions',
#   'such',
#   'as',
#   'gambling',
#   'should',
#   'be',
#   'grouped',
#   'with',
#   'substance',
#   'addictions',
#   'evaluate',
#   'the',
#   'role',
#   'of',
#   'research',
#   'evidence',
#   'and',
#   'the',
#   'various',
#   'models',
#   'of',
#   'addiction',
#   'in',
#   'the',
#   'development',
#   'of',
#   'policies',
#   'relevant',
#   'to',
#   'alcohol',
#   'illicit',
#   'drug',
#   'use',
#   'and',
#   'addictive',
#   'behaviours',
#   'this',
#   'unit',
#   'provides',
#   'an',
#   'introduction',
#   'and',
#   'overview',
#   'to',
#   'addiction',
#   'as',
#   'a',
#   'concept',
#   'in',
#   'particular',
#   'consideration',
#   'is',
#   'given',
#   'to',
#   'the',
#   'biological',
#   'psychological',
#   'developmental',
#   'sociocultural',
#   'and',
#   'environmental',
#   'factors',
#   'that',
#   'may',
#   'contribute',
#   'to',
#   'the',
#   'development',
#   'of',
#   'addiction'],
#  'ASC5009': ['identify',
#   'and',
#   'contextualise',
#   'developmental',
#   'factors',
#   'that',
#   'contribute',
#   'to',
#   'addictive',
#   'behaviours',
#   'in',
#   'young',
#   'people',
#   'explain',
#   'youth',
#   'substance',
#   'abuse',
#   'in',
#   'terms',
#   'of',
#   'family',
#   'and',
#   'social',
#   'contexts',
#   'such',
#   'as',
#   'trauma',
#   'and',
#   'youth',
#   'disadvantage',
#   'synthesise',
#   'the',
#   'available',
#   'information',
#   'on',
#   'the',
#   'impact',
#   'of',
#   'addictive',
#   'behaviours',
#   'on',
#   'young',
#   'people',
#   'and',
#   'families',
#   'in',
#   'order',
#   'to',
#   'demonstrate',
#   'an',
#   'understanding',
#   'of',
#   'the',
#   'complexity',
#   'of',
#   'this',
#   'issue',
#   'reflect',
#   'critically',
#   'on',
#   'psychological',
#   'and',
#   'sociological',
#   'theories',
#   'relevant',
#   'to',
#   'key',
#   'contemporary',
#   'issues',
#   'in',
#   'youth',
#   'addiction',
#   'evaluate',
#   'and',
#   'critique',
#   'current',
#   'responses',
#   'to',
#   'addiction',
#   'including',
#   'school-based',
#   'interventions',
#   'compare',
#   'and',
#   'contrast',
#   'contemporary',
#   'models',
#   'of',
#   'addiction',
#   'behaviours',
#   'among',
#   'young',
#   'people',
#   'through',
#   'an',
#   'analysis',
#   'of',
#   'national',
#   'and',
#   'international',
#   'research',
#   'critically',
#   'review',
#   'the',
#   'effectiveness',
#   'of',
#   'family-based',
#   'interventions',
#   'including',
#   'family',
#   'inclusive',
#   'practice',
#   'and',
#   'parents',
#   'under',
#   'pressure',
#   'critically',
#   'appraise',
#   'a',
#   'range',
#   'of',
#   'youth-focused',
#   'aod',
#   'treatment',
#   'services',
#   'and',
#   'key',
#   'elements',
#   'of',
#   'youth-focused',
#   'service',
#   'delivery',
#   'critically',
#   'review',
#   'policy',
#   'issues',
#   'relevant',
#   'to',
#   'youth',
#   'including',
#   'those',
#   'pertaining',
#   'to',
#   'social',
#   'media',
#   'this',
#   'unit',
#   'begins',
#   'with',
#   'a',
#   'focus',
#   'on',
#   'child',
#   'and',
#   'adolescent',
#   'biopsychosocial',
#   'development',
#   'followed',
#   'by',
#   'an',
#   'overview',
#   'of',
#   'the',
#   'prevalence',
#   'and',
#   'patterns',
#   'of',
#   'substance',
#   'use',
#   'and',
#   'other',
#   'addictive',
#   'behaviours',
#   'in',
#   'these',
#   'populations'],
#  'ASP3162': ['demonstrate',
#   'a',
#   'basic',
#   'understanding',
#   'of',
#   'astrophysical',
#   'fluid',
#   'dynamics',
#   'involving',
#   'the',
#   'physics',
#   'of',
#   'fluids',
#   'at',
#   'high',
#   'mach',
#   'number',
#   'including',
#   'sound',
#   'waves',
#   'and',
#   'shocks',
#   'demonstrate',
#   'practical',
#   'skills',
#   'in',
#   'scientific',
#   'computing',
#   'computational',
#   'modelling',
#   'data',
#   'analysis',
#   'and',
#   'visualisation',
#   'perform',
#   'computer',
#   'simulations',
#   'of',
#   'astrophysical',
#   'flows',
#   'using',
#   'advanced',
#   'astrophysical',
#   'simulation',
#   'codes',
#   'and',
#   'demonstrate',
#   'an',
#   'understanding',
#   'of',
#   'the',
#   'physics',
#   'and',
#   'mathematics',
#   'behind',
#   'modern',
#   'large-scale',
#   'astrophysical',
#   'simulations',
#   'in',
#   'this',
#   'unit',
#   'students',
#   'will',
#   'learn',
#   'the',
#   'basic',
#   'principles',
#   'of',
#   'astrophysical',
#   'fluid',
#   'dynamics',
#   'and',
#   'how',
#   'it',
#   'can',
#   'be',
#   'used',
#   'to',
#   'model',
#   'the',
#   'most',
#   'extreme',
#   'events',
#   'in',
#   'the',
#   'universe',
#   'the',
#   'unit',
#   'covers',
#   'the',
#   'basic',
#   'equations',
#   'of',
#   'compressible',
#   'hydrodynamics',
#   'including',
#   'the',
#   'behaviour',
#   'of',
#   'linear',
#   'waves',
#   'the',
#   'transition',
#   'to',
#   'shocks',
#   'and',
#   'the',
#   'behaviour',
#   'of',
#   'fluids',
#   'at',
#   'high',
#   'mach',
#   'number',
#   'students',
#   'will',
#   'apply',
#   'this',
#   'to',
#   'understand',
#   'the',
#   'physical',
#   'processes',
#   'that',
#   'power',
#   'accreting',
#   'sources',
#   'including',
#   'white',
#   'dwarfs',
#   'neutron',
#   'stars',
#   'and',
#   'black',
#   'holes',
#   'and',
#   'the',
#   'physics',
#   'behind',
#   'the',
#   'explosion',
#   'of',
#   'stars',
#   'as',
#   'supernovae',
#   'students',
#   'will',
#   'gain',
#   'practical',
#   'experience',
#   'in',
#   'computational',
#   'fluid',
#   'dynamics',
#   'including',
#   'basic',
#   'programming',
#   'skills',
#   'and',
#   'an',
#   'understanding',
#   'of',
#   'how',
#   'large',
#   'scale',
#   'astrophysical',
#   'simulations',
#   'are',
#   'performed'],
#  'ATS1062': ['use',
#   'basic',
#   'speaking',
#   'listening',
#   'reading',
#   'and',
#   'writing',
#   'skills',
#   'and',
#   'appropriate',
#   'vocabulary',
#   'to',
#   'communicate',
#   'effectively',
#   'in',
#   'french',
#   'in',
#   'a',
#   'range',
#   'of',
#   'past',
#   'present',
#   'and',
#   'future',
#   'situations',
#   'and',
#   'on',
#   'a',
#   'range',
#   'of',
#   'topics',
#   'locate',
#   'information',
#   'in',
#   'basic',
#   'texts',
#   'in',
#   'french',
#   'recognise',
#   'and',
#   'use',
#   'key',
#   'structures',
#   'and',
#   'sounds',
#   'of',
#   'french',
#   'identify',
#   'and',
#   'use',
#   'prescribed',
#   'grammatical',
#   'items',
#   'critique',
#   'aspects',
#   'of',
#   'modern',
#   'and',
#   'contemporary',
#   'french',
#   'history',
# ...
#   'describe',
#   'contemporary',
#   'debates',
#   'about',
#   'the',
#   'nature',
#   'of',
#   'social',
#   'work',
#   'critically',
#   'analyse',
#   'the',
#   'ethical',
#   'value',
#   'base',
#   'of',
#   'social',
#   'work',
#   'with',
#   'particular',
#   'reference',
#   'to',
#   'human',
#   'rights',
#   'and',
#   'the',
#   'promotion',
#   'of',
#   'social',
#   'justice',
#   'critically',
#   'analyse',
#   'key',
#   'global',
#   'social',
#   'policy',
#   'issues',
#   'including',
#   'but',
#   'not',
#   'limited',
#   'to',
#   'mass',
#   'movement',
#   'of',
#   'people',
#   'climate',
#   'change',
#   'reconstruction',
#   'and',
#   'poverty',
#   'critically',
#   'review',
#   'and',
#   'analyse',
#   'contemporary',
#   'trends',
#   'in',
#   'the',
#   'delivery',
#   'of',
#   'social',
#   'work',
#   'services',
#   'articulate',
#   'the',
#   'nature',
#   'of',
#   'social',
#   'change',
#   'and',
#   'the',
#   'strategies',
#   'to',
#   'achieve',
#   'this',
#   'this',
#   'unit',
#   'offers',
#   'an',
#   'overview',
#   'of',
#   'the',
#   'history',
#   'and',
#   'contemporary',
#   'context',
#   'of',
#   'social',
#   'work',
#   'practice',
#   'within',
#   'a',
#   'framework',
#   'of',
#   'understanding',
#   'the',
#   'connection',
#   'between',
#   'social',
#   'issues',
#   'policy',
#   'development',
#   'and',
#   'strategies',
#   'for',
#   'sustainable',
#   'change',
#   'at',
#   'both',
#   'local',
#   'and',
#   'global',
#   'levels',
#   'the',
#   'unit',
#   'is',
#   'underpinned',
#   'by',
#   'notions',
#   'of',
#   'social',
#   'justice',
#   'and',
#   'human',
#   'rights',
#   'and',
#   'offers',
#   'a',
#   'preview',
#   'of',
#   'topics',
#   'that',
#   'will',
#   'be',
#   'studied',
#   'in',
#   'greater',
#   'depth',
#   'in',
#   'subsequent',
#   'units',
#   'within',
#   'the',
#   'course'],
#  'SWM5170': ['work',
#   'collaboratively',
#   'with',
#   'an',
#   'academic',
#   'supervisor',
#   'on',
#   'the',
#   'development',
#   'of',
#   'an',
#   'assessment',
#   'topic',
#   'and',
#   'during',
#   'the',
#   'completion',
#   'of',
#   'the',
#   'assessment',
#   'integrate',
#   'research',
#   'knowledge',
#   'with',
#   'past',
#   'and',
#   'present',
#   'professional',
#   'experience',
#   'work',
#   'collaboratively',
#   'with',
#   'an',
#   'academic',
#   'supervisor',
#   'on',
#   'the',
#   'development',
#   'of',
#   'an',
#   'assessment',
#   'topic',
#   'and',
#   'during',
#   'the',
#   'completion',
#   'of',
#   'the',
#   'assessment',
#   'combine',
#   'advanced',
#   'specialised',
#   'research',
#   'knowledge',
#   'and',
#   'skills',
#   'to',
#   'develop',
#   'a',
#   'research-based',
#   'practice',
#   'at',
#   'clinical',
#   'program',
#   'and',
#   'policy',
#   'levels',
#   'articulate',
#   'specialised',
#   'practice',
#   'and',
#   'knowledge',
#   'and',
#   'skills',
#   'in',
#   'while',
#   'developing',
#   'the',
#   'research',
#   'report',
#   'evaluation',
#   'report',
#   'or',
#   'assignment',
#   'develop',
#   'and',
#   'appraise',
#   'personal',
#   'role',
#   'as',
#   'a',
#   'professional',
#   'social',
#   'work',
#   'practitioner-researcher',
#   'develop',
#   'and',
#   'appraise',
#   'personal',
#   'role',
#   'as',
#   'a',
#   'professional',
#   'social',
#   'work',
#   'practitioner-researcher',
#   'prepare',
#   'a',
#   'report',
#   'which',
#   'would',
#   'be',
#   'suitable',
#   'for',
#   "publication'unit",
#   'content',
#   'will',
#   'be',
#   'developed',
#   'between',
#   'the',
#   'student',
#   'and',
#   'an',
#   'appointed',
#   'staff',
#   'supervisor',
#   'one',
#   'piece',
#   'of',
#   'assessment',
#   'will',
#   'be',
#   'developed',
#   'and',
#   'completed',
#   'by',
#   'the',
#   'student',
#   'for',
#   'this',
#   'unit'],
#  'TAD2214': ['recognise',
#   'key',
#   'works',
#   'of',
#   'design',
#   'and',
#   'their',
#   'relationship',
#   'to',
#   'critical',
#   'issues',
#   'demonstrate',
#   'an',
#   'understanding',
#   'of',
#   'the',
#   'influence',
#   'and',
#   'impact',
#   'of',
#   'physical',
#   'social',
#   'and',
#   'cultural',
#   'concerns',
#   'on',
#   'the',
#   'role',
#   'of',
#   'the',
#   'designer',
#   'and',
#   'the',
#   'design',
#   'product',
#   'demonstrate',
#   'critical',
#   'and',
#   'analytical',
#   'skills',
#   'in',
#   'the',
#   'interpretation',
#   'and',
#   'appreciation',
#   'of',
#   'works',
#   'of',
#   'design',
#   'articulate',
#   'evaluative',
#   'responses',
#   'as',
#   'to',
#   'the',
#   'significance',
#   'of',
#   'ideological',
#   'and',
#   'cultural',
#   'forces',
#   'on',
#   'the',
#   'work',
#   'of',
#   'design',
#   'appreciate',
#   'and',
#   'critique',
#   'multiple',
#   'perspectives',
#   'for',
#   'the',
#   'interpretation',
#   'of',
#   'design',
#   'understand',
#   'and',
#   'be',
#   'able',
#   'to',
#   'apply',
#   'the',
#   'rules',
#   'of',
#   'occupational',
#   'health',
#   'and',
#   'safety',
#   'appropriate',
#   'to',
#   'the',
#   'unit',
#   'of',
#   'study',
#   'this',
#   'unit',
#   'investigates',
#   'the',
#   'visual',
#   'and',
#   'theoretical',
#   'languages',
#   'of',
#   'design',
#   'in',
#   'relation',
#   'to',
#   'a',
#   'number',
#   'of',
#   'key',
#   'critical',
#   'issues',
#   'it',
#   'focuses',
#   'on',
#   'issues',
#   'including',
#   'the',
#   'engagement',
#   'of',
#   'works',
#   'of',
#   'design',
#   'with',
#   'society',
#   'consumerism',
#   'gender',
#   'politics',
#   'and',
#   'the',
#   'environment',
#   'the',
#   'role',
#   'of',
#   'the',
#   'designer',
#   'in',
#   'responding',
#   'to',
#   'aesthetic',
#   'and',
#   'social',
#   'challenges',
#   'is',
#   'also',
#   'considered',
#   'students',
#   'will',
#   'continue',
#   'to',
#   'develop',
#   'a',
#   'range',
#   'of',
#   'approaches',
#   'to',
#   'understanding',
#   'works',
#   'of',
#   'design',
#   'and',
#   'related',
#   'issues',
#   'while',
#   'also',
#   'refining',
#   'the',
#   'broader',
#   'critical',
#   'and',
#   'analytical',
#   'skills',
#   'necessary',
#   'to',
#   'their',
#   'disciplines'],
#  'TDN1002': ['identify',
#   'and',
#   'describe',
#   'the',
#   'major',
#   'movements',
#   'of',
#   'modernism',
#   'in',
#   'design',
#   'recognise',
#   'and',
#   'analyse',
#   'key',
#   'examples',
#   'of',
#   'practices',
#   'in',
#   'design',
#   'discuss',
#   'the',
#   'legacy',
#   'of',
#   'the',
#   'european',
#   'avant-gardes',
#   'and',
#   'their',
#   'lasting',
#   'influence',
#   'upon',
#   'the',
#   'social',
#   'role',
#   'of',
#   'the',
#   'designer',
#   'translate',
#   'basic',
#   'theoretical',
#   'contexts',
#   'in',
#   'to',
#   'practice',
#   'critique',
#   'works',
#   'of',
#   'design',
#   'and',
#   'articulate',
#   'these',
#   'analyses',
#   'in',
#   'both',
#   'spoken',
#   'and',
#   'written',
#   'form',
#   'identify',
#   'questions',
#   'and',
#   'consider',
#   'ways',
#   'to',
#   'search',
#   'for',
#   'information',
#   'this',
#   'unit',
#   'examines',
#   'the',
#   'history',
#   'of',
#   'european',
#   'modernism',
#   'as',
#   'it',
#   'relates',
#   'to',
#   'the',
#   'disciplines',
#   'of',
#   'visual',
#   'communication',
#   'industrial',
#   'design',
#   'and',
#   'spatial',
#   'design',
#   'key',
#   'modernist',
#   'movements',
#   'and',
#   'practices',
#   'are',
#   'studied',
#   'with',
#   'particular',
#   'consideration',
#   'given',
#   'to',
#   'their',
#   'ideological',
#   'political',
#   'and',
#   'cultural',
#   'contexts',
#   'and',
#   'motives',
#   'the',
#   'critical',
#   'tendencies',
#   'of',
#   'twentieth-century',
#   'avant-garde',
#   'practices',
#   'are',
#   'considered',
#   'in',
#   'terms',
#   'of',
#   'their',
#   'lasting',
#   'implications',
#   'for',
#   'the',
#   'social',
#   'role',
#   'of',
#   'design',
#   'students',
#   'will',
#   'develop',
#   'a',
#   'range',
#   'of',
#   'critical',
#   'approaches',
#   'to',
#   'analysing',
#   'design',
#   'in',
#   'relation',
#   'to',
#   'its',
#   'historical',
#   'social',
#   'and',
#   'cultural',
#   'context',
#   'skills',
#   'necessary',
#   'to',
#   'their',
#   'disciplines',
#   'and',
#   'practice'],
#  'UPD4002': ['demonstrate',
#   'capabilities',
#   'and',
#   'competencies',
#   'in',
#   'ethical',
#   'approaches',
#   'to',
#   'contemporary',
#   'urban',
#   'planning',
#   'have',
#   'the',
#   'ability',
#   'to',
#   'strategically',
#   'respond',
#   'to',
#   'complex',
#   'problems',
#   'and',
#   'develop',
#   'appropriate',
#   'planning',
#   'responses',
#   'processes',
#   'and',
#   'outcomes',
#   'have',
#   'developed',
#   'skills',
#   'in',
#   'research',
#   'applying',
#   'creativity',
#   'and',
#   'critique',
#   'to',
#   'address',
#   'planning',
#   'issues',
#   'have',
#   'acquired',
#   'a',
#   'high',
#   'level',
#   'of',
#   'competence',
#   'in',
#   'communication',
#   'and',
#   'presentation',
#   'skills',
#   'written',
#   'verbal',
#   'and',
#   'graphic',
#   'ones',
#   'understand',
#   'and',
#   'be',
#   'able',
#   'to',
#   'apply',
#   'the',
#   'rules',
#   'of',
#   'occupational',
#   'health',
#   'and',
#   'safety',
#   'appropriate',
#   'to',
#   'the',
#   'unit',
#   'of',
#   'study',
#   'project',
#   '2',
#   'explores',
#   'the',
#   'creation',
#   'of',
#   'ecologically',
#   'sensitive',
#   'cities',
#   'through',
#   'projects',
#   'that',
#   'coordinate',
#   'the',
#   'built',
#   'and',
#   'natural',
#   'systems',
#   'that',
#   'shape',
#   'our',
#   'cities',
#   'students',
#   'develop',
#   'research',
#   'foundations',
#   'technical',
#   'capacity',
#   'analytical',
#   'approaches',
#   'and',
#   'modes',
#   'of',
#   'articulation',
#   'through',
#   'planning',
#   'systems'],
#  'UPD5001': ['critically',
#   'reflect',
#   'on',
#   'and',
#   'practice',
#   'ethical',
#   'approaches',
#   'to',
#   'contemporary',
#   'urban',
#   'planning',
#   'strategically',
#   'respond',
#   'to',
#   'complex',
#   'problems',
#   'related',
#   'to',
#   'urban',
#   'sprawl',
#   'apply',
#   'skills',
#   'in',
#   'research',
#   'to',
#   'address',
#   'metropolitan',
#   'planning',
#   'issues',
#   'communicate',
#   'in',
#   'written',
#   'verbal',
#   'and',
#   'graphic',
#   'formats',
#   'on',
#   'issues',
#   'pertaining',
#   'to',
#   'urban',
#   'sprawl',
#   'understand',
#   'and',
#   'be',
#   'able',
#   'to',
#   'apply',
#   'the',
#   'rules',
#   'of',
#   'occupational',
#   'health',
#   'and',
#   'safety',
#   'appropriate',
#   'to',
#   'the',
#   'unit',
#   'of',
#   'study',
#   'planning',
#   'project',
#   '3',
#   'the',
#   'sprawling',
#   'city',
#   'considers',
#   'the',
#   'role',
#   'of',
#   'metropolitan',
#   'planning',
#   'in',
#   'addressing',
#   'issues',
#   'associated',
#   'with',
#   'urban',
#   'sprawl',
#   'the',
#   'unit',
#   'expands',
#   'and',
#   'consolidates',
#   'advanced',
#   'concepts',
#   'knowledge',
#   'and',
#   'skills',
#   'encompassing',
#   'a',
#   'range',
#   'of',
#   'complex',
#   'issues',
#   'relevant',
#   'to',
#   'practising',
#   'urban',
#   'planning',
#   'at',
#   'the',
#   'metropolitan',
#   'level',
#   'through',
#   'critical',
#   'research',
#   'analysis',
#   'and',
#   'synthesis',
#   'undertaken',
#   'in',
#   'real',
#   'spatial',
#   'settings',
#   'the',
#   'unit',
#   'develops',
#   'concepts',
#   'creative',
#   'approaches',
#   'processes',
#   'and',
#   'outcomes',
#   'and',
#   'the',
#   'skills',
#   'to',
#   'communicate',
#   'these',
#   'effectively',
#   'to',
#   'diverse',
#   'communities'],
#  'UPD5002': ['critically',
#   'reflect',
#   'on',
#   'and',
#   'practice',
#   'ethical',
#   'approaches',
#   'to',
#   'contemporary',
#   'urban',
#   'planning',
#   'in',
#   'diverse',
#   'communities',
#   'strategically',
#   'respond',
#   'to',
#   'complex',
#   'problems',
#   'and',
#   'develop',
#   'appropriate',
#   'planning',
#   'responses',
#   'processes',
#   'and',
#   'outcomes',
#   'pertinent',
#   'to',
#   'social',
#   'and',
#   'community',
#   'planning',
#   'apply',
#   'skills',
#   'in',
#   'research',
#   'to',
#   'address',
#   'social',
#   'and',
#   'community',
#   'planning',
#   'issues',
#   'communicate',
#   'in',
#   'written',
#   'verbal',
#   'and',
#   'graphic',
#   'formats',
#   'on',
#   'social',
#   'and',
#   'community',
#   'planning',
#   'issues',
#   'understand',
#   'and',
#   'be',
#   'able',
#   'to',
#   'apply',
#   'the',
#   'rules',
#   'of',
#   'occupational',
#   'health',
#   'and',
#   'safety',
#   'appropriate',
#   'to',
#   'the',
#   'unit',
#   'of',
#   'study',
#   'planning',
#   'project',
#   '4',
#   'the',
#   'inclusive',
#   'city',
#   'focusses',
#   'on',
#   'issues',
#   'pertinent',
#   'to',
#   'social',
#   'and',
#   'community',
#   'planning',
#   'to',
#   'address',
#   'the',
#   'challenge',
#   'of',
#   'creating',
#   'people-centred',
#   'cities',
#   'the',
#   'unit',
#   'expands',
#   'and',
#   'consolidates',
#   'advanced',
#   'concepts',
#   'knowledge',
#   'and',
#   'skills',
#   'encompassing',
#   'a',
#   'range',
#   'of',
#   'complex',
#   'issues',
#   'relevant',
#   'to',
#   'practising',
#   'urban',
#   'planning',
#   'through',
#   'critical',
#   'research',
#   'analysis',
#   'and',
#   'synthesis',
#   'undertaken',
#   'in',
#   'real',
#   'spatial',
#   'settings',
#   'the',
#   'unit',
#   'develops',
#   'concepts',
#   'creative',
#   'approaches',
#   'processes',
#   'and',
#   'outcomes',
#   'and',
#   'the',
#   'skills',
#   'to',
#   'communicate',
#   'these',
#   'effectively',
#   'to',
#   'diverse',
#   'communities'],
#  'VCM4029': ['utilise',
#   'a',
#   'range',
#   'of',
#   'systems',
#   'analysis',
#   'design',
#   'methodologies',
#   'and',
#   'their',
#   'associated',
#   'tools',
#   'and',
#   'principles',
#   'understand',
#   'the',
#   'main',
#   'participants',
#   'and',
#   'their',
#   'roles',
#   'in',
#   'the',
#   'development',
#   'of',
#   'interactive',
#   'systems',
#   'apply',
#   'quality',
#   'assurance',
#   'techniques',
#   'for',
#   'the',
#   'analysis',
#   'design',
#   'implementation',
#   'and',
#   'maintenance',
#   'of',
#   'interactive',
#   'systems',
#   'understand',
#   'the',
#   'advantages',
#   'and',
#   'disadvantages',
#   'of',
#   'alternative',
#   'approaches',
#   'in',
#   'systems',
#   'analysis',
#   'and',
#   'design',
#   'convert',
#   'requirement',
#   'analysis',
#   'models',
#   'to',
#   'design',
#   'models',
#   'that',
#   'represent',
#   'a',
#   'workable',
#   'solution',
#   'system',
#   'prepare',
#   'analysis',
#   'and',
#   'design',
#   'documentation',
#   'for',
#   'an',
#   'interactive',
#   'system',
#   'apply',
#   'sound',
#   'programming',
#   'principles',
#   'to',
#   'the',
#   'use',
#   'of',
#   'an',
#   'interactive',
#   'scripting',
#   'language',
#   'develop',
#   'skills',
#   'in',
#   'team',
#   'collaboration',
#   'this',
#   'unit',
#   'will',
#   'examine',
#   'the',
#   'activities',
#   'integral',
#   'to',
#   'the',
#   'development',
#   'of',
#   'interactive',
#   'systems',
#   'detailing',
#   'the',
#   'techniques',
#   'of',
#   'systems',
#   'analysis',
#   'and',
#   'design',
#   'used',
#   'in',
#   'the',
#   'development',
#   'process',
#   'fundamental',
#   'programming',
#   'concepts',
#   'will',
#   'be',
#   'introduced',
#   'within',
#   'an',
#   'interactive-media',
#   'scripting',
#   'language',
#   'framework',
#   'as',
#   'a',
#   'mechanism',
#   'for',
#   'system',
#   'development',
#   'students',
#   'will',
#   'be',
#   'involved',
#   'in',
#   'a',
#   'mixture',
#   'of',
#   'individual',
#   'and',
#   'group-based',
#   'work',
#   'which',
#   'will',
#   'require',
#   'application',
#   'of',
#   'the',
#   'theoretical',
#   'knowledge',
#   'gained',
#   'in',
#   'lectures',
#   'to',
#   'a',
#   'series',
#   'of',
#   'practical',
#   'problems',
#   'in',
#   'interactive',
#   'systems',
#   'development'],
#  'VCM4601': ['recognise',
#   'analyse',
#   'and',
#   'use',
#   'the',
#   'elements',
#   'of',
#   'design',
#   'understand',
#   'the',
#   'role',
#   'of',
#   'visual',
#   'communication',
#   'and',
#   'fundamental',
#   'design',
#   'principles',
#   'as',
#   'applied',
#   'to',
#   'multimedia',
#   'new',
#   'media',
#   'recognise',
#   'some',
#   'of',
#   'the',
#   'theoretical',
#   'and',
#   'psychological',
#   'issues',
#   'of',
#   'selected',
#   'colour',
#   'theories',
#   'understand',
#   'and',
#   'apply',
#   'selected',
#   'colour',
#   'theories',
#   'to',
#   'digital',
#   'media',
#   'recognise',
#   'analyse',
#   'and',
#   'use',
#   'typography',
#   'express',
#   'ideas',
#   'and',
#   'concepts',
#   'for',
#   'multimedia',
#   'using',
#   'visual',
#   'communication',
#   'forms',
#   'drawing',
#   'digital',
#   'imaging',
#   'graphic',
#   'design',
#   'and',
#   'typography',
#   'and',
#   'observe',
#   'and',
#   'employ',
#   'occupational',
#   'health',
#   'and',
#   'safety',
#   'appropriate',
#   'to',
#   'studio',
#   'practice',
#   'students',
#   'are',
#   'introduced',
#   'to',
#   'how',
#   'the',
#   'fundamental',
#   'elements',
#   'and',
#   'principles',
#   'of',
#   'two',
#   'and',
#   'three-dimensional',
#   'design',
#   'are',
#   'applied',
#   'to',
#   'multimedia',
#   'students',
#   'gain',
#   'the',
#   'necessary',
#   'design',
#   'skills',
#   'and',
#   'knowledge',
#   'to',
#   'produce',
#   'complex',
#   'integrations',
#   'of',
#   'those',
#   'selected',
#   'principles',
#   'of',
#   'design',
#   'which',
#   'form',
#   'a',
#   'solid',
#   'basis',
#   'to',
#   'support',
#   'visual',
#   'communications',
#   'for',
#   'screen',
#   'based',
#   'media',
#   'set',
#   'projects',
#   'encourage',
#   'experimentation',
#   'with',
#   'various',
#   'techniques',
#   'and',
#   'methods',
#   'of',
#   'interpretation']}

# %% [markdown]
# #### This code block is generating bigram collocations. The first step is to concatenate all the tokenized patents using the chain.from_iterable function. The returned list by the function contains a list of all the words seprated by white space.

# %%
from itertools import chain
all_words = list(chain.from_iterable(unit_tokens.values()))
all_words
# Out:
# ['provide',
#  'students',
#  'with',
#  'experience',
#  'in',
#  'an',
#  'area',
#  'of',
#  'research',
#  'provide',
#  'students',
#  'with',
#  'an',
#  'insight',
#  'into',
#  'future',
#  'opportunities',
#  'in',
#  'the',
#  'area',
#  'of',
#  'research',
#  'encourage',
#  'and',
#  'attract',
#  'high',
#  'quality',
#  'students',
#  'interested',
#  'in',
#  'pursuing',
#  'a',
#  'career',
#  'in',
#  'research',
#  'the',
#  'biotechnology',
#  'or',
#  'pharmaceutical',
#  'industry',
#  'or',
#  'academia',
#  'an',
#  'understanding',
#  'of',
#  'some',
#  'recent',
#  'advances',
#  'in',
#  'research',
#  'in',
#  'pharmaceutical',
#  'science',
#  'or',
#  'pharmacy',
#  'practice',
#  'and',
#  'the',
#  'literature',
#  'within',
#  'their',
#  'area',
#  'of',
#  'research',
#  'an',
#  'appreciation',
#  'of',
#  'the',
#  'need',
#  'to',
#  'define',
#  'a',
#  'hypothesis',
#  'design',
#  'an',
#  'approach',
#  'to',
#  'test',
#  'the',
#  'hypothesis',
#  'plan',
#  'the',
#  'experiments',
#  'undertake',
#  'the',
#  'experiments',
#  'analyse',
#  'and',
#  'interpret',
#  'the',
#  'data',
#  'and',
#  'write',
#  'a',
#  'research',
#  'report',
#  'an',
#  'appreciation',
#  'of',
#  'basic',
#  'research',
#  'philosophies',
#  'and',
#  'approaches',
#  'this',
#  'unit',
#  'will',
#  'provide',
#  'students',
#  'with',
#  'a',
#  'preliminary',
#  'training',
#  'in',
#  'research',
#  'in',
#  'pharmaceutical',
#  'science',
#  'or',
#  'pharmacy',
#  'practice',
#  'within',
#  'the',
#  'faculty',
#  'as',
#  'well',
#  'as',
#  'provide',
#  'the',
#  'knowledge',
#  'of',
#  'research',
#  'philosophy',
#  'and',
#  'approaches',
#  'be',
#  'able',
#  'to',
#  'articulate',
#  'and',
#  'explain',
#  'the',
#  'causes',
#  'of',
#  'construction',
#  'disputes',
#  'and',
#  'the',
#  'factors',
#  'contributing',
#  'to',
#  'the',
#  'escalation',
#  'of',
#  'construction',
#  'conflicts',
#  'into',
#  'construction',
#  'disputes',
#  'identify',
#  'and',
#  'distinguish',
#  'between',
#  'different',
#  'types',
#  'of',
#  'dispute',
#  'avoidance',
#  'processes',
#  'daps',
#  'used',
#  'on',
#  'construction',
#  'projects',
#  'around',
#  'the',
#  'world',
#  'and',
#  'evaluate',
#  'the',
#  'pros',
#  'and',
#  'cons',
#  'of',
#  'each',
#  'be',
#  'able',
#  'to',
#  'explain',
#  'the',
#  'ways',
#  'in',
#  'which',
#  'parties',
#  'can',
#  'engage',
#  'in',
#  'real',
#  'time',
#  'resolution',
#  'of',
#  'construction',
#  'disputes',
#  'during',
#  'the',
#  'course',
#  'of',
#  'a',
#  'project',
#  'and',
#  'the',
#  'legal',
#  'ramifications',
#  'of',
#  'such',
#  'processes',
#  'be',
#  'able',
#  'to',
#  'compare',
#  'and',
#  'contrast',
#  'different',
#  'adr',
#  'options',
#  'available',
#  'mediation',
#  'expert',
#  'determination',
#  'senior',
#  'executive',
#  'appraisal',
#  'and',
#  'early',
#  'neutral',
#  'evaluation',
#  'and',
#  'identify',
#  'the',
#  'factors',
#  'that',
#  'influence',
#  'the',
#  'suitability',
#  'of',
#  'each',
#  'for',
#  'particular',
#  'construction',
#  'disputes',
#  'be',
#  'able',
#  'to',
#  'critically',
#  'evaluate',
#  'the',
#  'use',
#  'of',
#  'arbitration',
#  'for',
#  'the',
#  'resolution',
#  'of',
#  'construction',
#  'disputes',
#  'at',
#  'both',
#  'a',
#  'domestic',
#  'and',
#  'international',
#  'level',
#  'be',
#  'able',
#  'to',
#  'describe',
#  'and',
#  'outline',
#  'the',
#  'regulatory',
#  'regimes',
#  'governing',
#  'domestic',
#  'and',
#  'international',
#  'arbitrations',
#  'of',
#  'construction',
#  'disputes',
#  'be',
#  'able',
#  'to',
#  'assess',
#  'the',
#  'judicial',
#  'systems',
#  'in',
#  'place',
#  'in',
#  'australia',
#  'and',
#  'other',
#  'countries',
#  'for',
#  'the',
#  'determination',
#  'of',
#  'construction',
#  'litigation',
#  'and',
#  'the',
#  'need',
#  'for',
#  'reform',
#  'and',
#  'be',
#  'able',
#  'to',
#  'undertake',
#  'scholarly',
#  'research',
#  'and',
#  'write',
#  'clearly',
#  'concisely',
#  'and',
#  'logically',
#  'on',
#  'the',
#  'avoidance',
#  'management',
#  'and',
#  'resolution',
#  'of',
#  'construction',
#  'disputes',
#  'this',
#  'unit',
#  'focuses',
#  'on',
#  'the',
#  'avoidance',
#  'management',
#  'and',
#  'resolution',
#  'of',
#  'construction',
#  'disputes',
#  'it',
#  'critically',
#  'analyses',
#  'the',
#  'causes',
#  'of',
#  'conflicts',
#  'and',
#  'disputes',
#  'and',
#  'the',
#  'role',
#  'that',
#  'the',
#  'construction',
#  'contract',
#  'plays',
#  'students',
#  'explore',
#  'various',
#  'dispute',
#  'avoidance',
#  'processes',
#  'daps',
#  'that',
#  'can',
#  'prevent',
#  'conflicts',
#  'from',
#  'escalating',
#  'into',
#  'disputes',
#  'and',
#  'examine',
#  'various',
#  'real',
#  'time',
#  'dispute',
#  'resolution',
#  'methods',
#  'that',
#  'can',
#  'be',
#  'used',
#  'during',
#  'the',
#  'course',
#  'of',
#  'a',
#  'construction',
#  'project',
#  'to',
#  'manage',
#  'and',
#  'resolve',
#  'disputes',
#  'students',
#  'also',
#  'explore',
#  'the',
#  'processes',
#  'that',
#  'are',
#  'available',
#  'for',
#  'resolving',
#  'disputes',
#  'that',
#  'remain',
#  'outstanding',
#  'after',
#  'a',
#  'project',
#  'has',
#  'been',
#  'completed',
#  'including',
#  'adr',
#  'arbitration',
#  'and',
#  'litigation',
#  'students',
#  'will',
#  'engage',
#  'in',
#  'comparative',
#  'analysis',
#  'of',
#  'construction',
#  'dispute',
#  'resolution',
#  'processes',
#  'used',
#  'in',
#  'other',
#  'jurisdictions',
#  'students',
#  'will',
#  'analyse',
#  'traditional',
#  'and',
#  'alternative',
#  'ways',
#  'of',
#  'resolving',
#  'construction',
#  'disputes',
#  'and',
#  'learn',
#  'to',
#  'research',
#  'and',
#  'write',
#  'on',
#  'construction',
#  'dispute',
#  'resolution',
#  'issues',
#  'apply',
#  'the',
#  'stiffness',
#  'method',
#  'of',
#  'matrix',
#  'structural',
#  'analysis',
#  'apply',
#  'the',
#  'coordinate',
#  'transformation',
#  'method',
#  'for',
#  'matrix',
#  'structural',
#  'analysis',
#  'identify',
#  'the',
#  'theoretical',
#  'basis',
#  'of',
#  'finite',
#  'element',
#  'methods',
#  'such',
#  'as',
#  'discretisation',
#  'process',
#  'element',
#  'formation',
#  'shape',
#  'functions',
#  'and',
#  'gaussian',
#  'integration',
#  'discern',
#  'simple',
#  'elements',
#  'in',
#  'the',
#  'finite',
#  'element',
#  'method',
#  'construct',
#  'the',
#  'framework',
#  'of',
#  'the',
#  'finite',
#  'element',
#  'method',
#  'generate',
#  'high',
#  'quality',
#  'reports',
#  'for',
#  'assessing',
#  'the',
#  'behaviour',
#  'of',
#  'a',
#  'multi-storey',
#  'building',
#  'under',
#  'static',
#  'thermal',
#  'and',
#  'dynamic',
#  'loading',
#  'using',
#  'a',
#  'finite',
#  'element',
#  'computer',
#  'package',
#  'this',
#  'unit',
#  'covers',
#  'advanced',
#  'structural',
#  'analysis',
#  'techniques',
#  'including',
#  'matrix',
#  'analysis',
#  'for',
#  'truss',
#  'and',
#  'beam',
#  'structures',
#  'and',
#  'also',
#  'the',
#  'theoretical',
#  'basis',
#  'and',
#  'application',
#  'of',
#  'the',
#  'finite',
#  'element',
#  'method',
#  'for',
#  'truss',
#  'beam',
#  'and',
#  'plate',
#  'elements',
#  'the',
#  'unit',
#  'will',
#  'provide',
#  'an',
#  'opportunity',
#  'for',
#  'students',
#  'to',
#  'learn',
#  'how',
#  'to',
#  'analyse',
#  'a',
#  'structure',
#  'using',
#  'computer',
#  'packages',
#  'such',
#  'as',
#  'abaqus',
#  'that',
#  'will',
#  'be',
#  'introduced',
#  'to',
#  'perform',
#  'static',
#  'analysis',
#  'dynamic',
#  'and',
#  'or',
#  'buckling',
#  'analyses',
#  'comparison',
#  'between',
#  'hand',
#  'calculations',
#  'and',
#  'predictions',
#  'from',
#  'computer',
#  'analyses',
#  'are',
#  'made',
#  'wherever',
#  'practicable',
#  'describe',
#  'the',
#  'roles',
#  'and',
#  'responsibilities',
#  'of',
#  'paramedics',
#  'emergency',
#  'services',
#  'and',
#  'other',
#  'health',
#  'agencies',
#  'in',
#  'relation',
#  'to',
#  'a',
#  'multi-casualty',
#  'or',
#  'major',
#  'incident',
#  'compare',
#  'and',
#  'contrast',
#  'the',
#  'management',
#  'of',
#  'major',
#  'incident',
#  'in',
#  'a',
#  'rural',
#  'remote',
#  'or',
#  'complex',
#  'setting',
#  'compared',
#  'to',
#  'the',
#  'urban',
#  'environment',
#  'describe',
#  'the',
#  'broader',
#  'requirements',
#  'of',
#  'paramedics',
#  'emergency',
#  'services',
#  'and',
#  'other',
#  'health',
#  'agencies',
#  'during',
#  'disaster',
#  'management',
#  'in',
#  'particular',
#  'the',
#  'management',
#  'of',
#  'public',
#  'health',
#  'issues',
#  'and',
#  'logistics',
#  'management',
#  'analyse',
#  'the',
#  'contemporary',
#  'structure',
#  'of',
#  'a',
#  'major',
#  'incident',
#  'control',
#  'system',
#  'in',
#  'the',
#  'australian',
#  'context',
#  'and',
#  'describe',
#  'the',
#  'role',
#  'of',
#  'the',
#  'paramedic',
#  'in',
#  'major',
#  'incidents',
#  'and',
#  'disasters',
#  'particularly',
#  'compared',
#  'to',
#  'normal',
#  'operations',
#  'outline',
#  'the',
#  'role',
#  'of',
#  'the',
#  'paramedic',
#  'in',
#  'emergency',
#  'management',
#  'planning',
#  'and',
#  'preparedness',
#  'in',
#  'local',
#  'and',
#  'international',
#  'settings',
#  'demonstrate',
#  'effective',
#  'logistical',
#  'management',
#  'patient',
#  'triage',
#  'or',
#  'participation',
#  'in',
#  'a',
#  'response',
#  'team',
#  'during',
#  'a',
#  'simulated',
#  'mass-casualty',
#  'situation',
#  'or',
#  'major',
#  'incident',
#  'this',
#  'unit',
#  'develops',
#  'the',
#  'role',
#  'of',
#  'the',
#  'paramedic',
#  'as',
#  'a',
#  'clinical',
#  'leader',
#  'in',
#  'the',
#  'community',
#  'with',
#  'the',
#  'focus',
#  'on',
#  'major',
#  'incidents',
#  'and',
#  'disasters',
#  'the',
#  'unit',
#  'explores',
#  'disaster',
#  'planning',
#  'response',
#  'and',
#  'recovery',
#  'and',
#  'the',
#  'roles',
#  'and',
#  'responsibilities',
#  'of',
#  'the',
#  'paramedic',
#  'when',
#  'managing',
#  'multiple',
#  'patients',
#  'or',
#  'a',
#  'complex',
#  'setting',
#  'during',
#  'a',
#  'major',
#  'health',
#  'emergency',
#  'or',
#  'during',
#  'a',
#  'humanitarian',
#  'disaster',
#  'apply',
#  'knowledge',
#  'of',
#  'pathophysiological',
#  'psychological',
#  'and',
#  'psychosocial',
#  'concepts',
#  'to',
#  'patients',
#  'with',
#  'complex',
#  'and',
#  'or',
#  'life',
#  'threatening',
#  'illness',
#  'throughout',
#  'the',
#  'lifespan',
#  'demonstrate',
#  'evidence-based',
#  'knowledge',
#  'of',
#  'a',
#  'range',
#  'of',
#  'complex',
#  'health',
#  'problems',
#  'experienced',
#  'by',
#  'patients',
#  'throughout',
#  'the',
#  'lifespan',
#  'in',
#  'a',
#  'range',
#  'of',
#  'settings',
#  'identify',
#  'and',
#  'implement',
#  'response',
#  'systems',
#  'for',
#  'the',
#  'deteriorating',
#  'patient',
#  'in',
#  'the',
#  'clinical',
#  'setting',
#  'apply',
#  'knowledge',
#  'of',
#  'appropriate',
#  'therapeutic',
#  'medications',
#  'in',
#  'terms',
#  'of',
#  'their',
#  'mechanism',
#  'of',
#  'action',
#  'important',
#  'aspects',
#  'of',
#  'pharmacokinetics',
#  'adverse',
#  'effects',
#  'interactions',
#  'and',
#  'contraindications',
#  'in',
#  'the',
#  'patient',
#  'with',
#  'complex',
#  'and',
#  'or',
#  'life',
#  'threatening',
#  'illness',
#  'demonstrate',
#  'clinical',
#  'judgement',
#  'skills',
#  'to',
#  'identify',
#  'analyse',
#  'and',
#  'resolve',
#  'clinical',
#  'concerns',
#  'in',
#  'the',
#  'patient',
#  'with',
#  'complex',
#  'and',
#  'or',
#  'life',
#  'threatening',
#  'illness',
#  'develop',
#  'and',
#  'implement',
#  'patient-centred',
#  'care',
#  'appropriate',
#  'to',
#  'the',
#  'needs',
#  'and',
#  'wishes',
#  'of',
#  'the',
#  'patient',
#  'and',
#  'their',
#  'family',
#  'carer',
#  'inclusive',
#  'of',
#  'race',
#  'age',
#  'gender',
#  'sexual',
#  'preference',
#  'physical',
#  'or',
#  'mental',
#  'state',
#  'or',
#  'other',
#  'diverse',
#  'needs',
#  'undertake',
#  'complex',
#  'nursing',
#  'activities',
#  'in',
#  'a',
#  'range',
#  'of',
#  'health',
#  'settings',
#  'and',
#  'apply',
#  'appropriate',
#  'principles',
#  'of',
#  'prioritising',
#  'and',
#  'time',
#  'management',
#  'appropriate',
#  'to',
#  'the',
#  'clinical',
#  'setting',
#  'critically',
#  'reflect',
#  'on',
#  'decisions',
#  'and',
#  'judgements',
#  'made',
#  'to',
#  'demonstrate',
#  'accountability',
#  'for',
#  'informed',
#  'patient',
#  'care',
#  'practice',
#  'with',
#  'increasing',
#  'dependence',
#  'in',
#  'accordance',
#  'with',
#  'the',
#  ...]

# %% [markdown]
# #### Collocations are created. These are then filtered to remove those than have a length less than 3
# #### The top 200 meaningful bigrams are made from collocations and included in the vocab using the PMI measure.

# %%
import nltk.collocations
bigram_measures = nltk.collocations.BigramAssocMeasures()
bigram_finder = nltk.collocations.BigramCollocationFinder.from_words(all_words)
bigram_finder.apply_word_filter(lambda w: len(w) < 3)# or w.lower() in ignored_words)
top_200_bigrams = bigram_finder.nbest(bigram_measures.pmi, 100) # Top-100 bigrams
top_200_bigrams
# Out:
# [('associated', 'with'),
#  ('critically', 'evaluate'),
#  ('this', 'unit'),
#  ('students', 'will'),
#  ('research', 'project'),
#  ('unit', 'will'),
#  ('the', 'role'),
#  ('explain', 'the'),
#  ('understand', 'the'),
#  ('describe', 'the'),
#  ('the', 'unit'),
#  ('evaluate', 'the'),
#  ('the', 'ability'),
#  ('and', 'other'),
#  ('the', 'development'),
#  ('analyse', 'the'),
#  ('identify', 'and'),
#  ('from', 'the'),
#  ('analysis', 'and'),
#  ('with', 'the'),
#  ('and', 'how'),
#  ('communication', 'and'),
#  ('analyse', 'and'),
#  ('apply', 'the'),
#  ('and', 'their'),
#  ('and', 'apply'),
#  ('for', 'the'),
#  ('health', 'and'),
#  ('skills', 'and'),
#  ('design', 'and'),
#  ('research', 'and'),
#  ('the', 'research'),
#  ('and', 'the')]

# %% [markdown]
# #### The bigrams are tokenized, using the Multi Word Tokenizer `MWETokenizer`
# #### These tokens are then appended to a collocations dictionary for further use.
# #### `colloc_vocab` is a list of all the unique word collocations obtained from the `unit_collocations `

# %%
#Multi Word Tokenizer
from nltk.tokenize import MWETokenizer
mwetokenizer = MWETokenizer(top_200_bigrams)
unit_collocations =  dict((keys, mwetokenizer.tokenize(values)) for keys,values in unit_tokens.items())
all_words_collocations = list(chain.from_iterable(unit_collocations.values()))
colloc_vocab = list(set(all_words_collocations))
# Out:
# 4013

# %% [markdown]
# #### There was a stopwords text file given, which is read into `stop_words_file`
# #### These are then appended to a list, based on being split wrt `\n`
# #### They are then made unique by being but into a `set`, and put into the list `unique_stop_words_list`

# %%
stop_words_file=open('stopwords_en.txt','r')
stopwords_list = stop_words_file.read().split('\n')
unique_stop_words_list = list(set(stopwords_list))
unique_stop_words_list
# Out:
# ['truly',
#  'amongst',
#  'beside',
#  'few',
#  'l',
#  'liked',
#  'otherwise',
#  'becoming',
#  'came',
#  'entirely',
#  'us',
#  'seen',
#  'second',
#  'whereafter',
#  'vs',
#  'also',
#  'out',
#  'seeming',
#  'que',
#  'almost',
#  'however',
#  'eight',
#  'itself',
#  'shall',
#  'through',
#  'can',
#  'thanks',
#  'three',
#  'whatever',
#  'please',
#  'r',
#  'later',
#  'alone',
#  'five',
#  'enough',
#  'yourself',
#  'still',
#  'having',
#  'quite',
#  'throughout',
#  'changes',
#  'a',
#  'you',
#  "wasn't",
#  'consequently',
#  'wonder',
#  'regards',
#  'v',
#  'twice',
#  'overall',
#  'unfortunately',
#  'com',
#  "you're",
#  'm',
#  "aren't",
#  "where's",
#  "isn't",
#  'other',
#  'ask',
#  'under',
#  'way',
#  'think',
#  'everyone',
#  'meanwhile',
#  'noone',
#  'whereas',
#  "you've",
#  'indicates',
#  'as',
#  'first',
#  'others',
#  'allow',
#  'qv',
#  'four',
#  'let',
#  'contain',
#  'therein',
#  'anywhere',
#  'saying',
#  'said',
#  'now',
#  'both',
#  'into',
#  'furthermore',
#  'much',
#  'herself',
#  'd',
#  "they'll",
#  'ok',
#  'those',
#  'moreover',
#  'uses',
#  'regardless',
#  'down',
#  'were',
#  'anyhow',
#  'with',
#  'theres',
#  'over',
#  'wish',
#  'immediate',
#  'comes',
#  'hereafter',
#  'without',
#  'w',
#  "wouldn't",
#  'nobody',
#  'howbeit',
#  'different',
#  'that',
#  'appear',
#  'being',
#  'lest',
#  'from',
#  'seem',
#  'elsewhere',
#  'unto',
#  'own',
#  'although',
#  'took',
#  'etc',
#  'might',
#  'next',
#  'off',
#  'seven',
#  'want',
#  'our',
#  'had',
#  'whenever',
#  'plus',
#  "that's",
#  'whoever',
#  'j',
#  'ought',
#  "c'mon",
#  'than',
#  'who',
#  'none',
#  "i'll",
#  'goes',
#  'him',
#  'onto',
#  "t's",
#  "ain't",
#  'further',
#  'last',
#  'like',
#  'described',
#  'specified',
#  'done',
#  'respectively',
#  'ie',
#  'sometime',
#  'too',
#  'its',
#  'indicate',
#  'together',
#  'before',
#  'k',
#  'during',
#  "let's",
#  'they',
#  'though',
#  'consider',
#  'beyond',
#  'himself',
#  'hopefully',
#  'happens',
#  'thereupon',
#  'zero',
#  'sup',
#  "we're",
#  "c's",
#  'fifth',
#  'very',
#  'when',
#  'many',
#  'everywhere',
#  'unlikely',
#  'certainly',
#  'sub',
#  'somewhat',
#  "he's",
#  'tends',
#  'ones',
#  'was',
#  'since',
#  'be',
#  "what's",
#  'always',
#  'outside',
#  "a's",
#  'willing',
#  'tried',
#  'about',
#  'according',
#  'definitely',
#  'every',
#  'i',
#  'but',
#  'get',
#  'selves',
#  'trying',
#  'everything',
#  'whose',
#  'any',
#  'c',
#  'cant',
#  'hers',
#  'indicated',
#  'at',
#  'herein',
#  'thru',
#  'name',
#  'behind',
#  "haven't",
#  'same',
#  'x',
#  'ex',
#  'could',
#  'nowhere',
#  'anybody',
#  'just',
#  'new',
#  'appropriate',
#  'latter',
#  'hello',
#  'go',
#  'tries',
#  'mainly',
#  'nor',
#  'formerly',
#  'o',
#  'went',
#  'two',
#  'see',
#  'corresponding',
#  'except',
#  'got',
#  'afterwards',
#  'per',
#  'for',
#  'after',
#  'seriously',
#  'toward',
#  'became',
#  'merely',
#  'yes',
#  'brief',
#  'because',
#  'keep',
#  'seeing',
#  'whereby',
#  'whether',
#  'yours',
#  'thereby',
#  'right',
#  'take',
#  'least',
#  'whom',
#  'particular',
#  'yourselves',
#  'upon',
#  'given',
#  'somewhere',
#  'allows',
#  'ever',
#  'say',
#  'near',
#  'anything',
#  'something',
#  'specifying',
#  'is',
#  'knows',
#  'an',
#  'believe',
#  'f',
#  'well',
#  'gotten',
#  'really',
#  'regarding',
#  'hence',
#  'u',
#  'anyone',
#  'doing',
#  'been',
#  'thus',
#  'g',
#  'contains',
#  'above',
#  'hereupon',
#  'which',
#  'rather',
#  'e',
#  'may',
#  'between',
#  'probably',
#  'am',
#  'some',
#  "couldn't",
#  'several',
#  'whereupon',
#  'seems',
#  'going',
#  'should',
#  'awfully',
#  'accordingly',
#  'hither',
#  'will',
#  'would',
#  'apart',
#  'best',
#  'hereby',
#  'until',
#  'beforehand',
#  'against',
#  'third',
#  'neither',
#  'kept',
#  'nd',
#  'by',
#  'seemed',
#  "there's",
#  "who's",
#  'she',
#  'welcome',
#  'certain',
#  'everybody',
#  'not',
#  'un',
#  'thorough',
#  'oh',
#  'q',
#  'to',
#  "you'll",
#  'viz',
#  "we'll",
#  'associated',
#  'inner',
#  'mostly',
#  "it's",
#  "here's",
#  "it'd",
#  'below',
#  'around',
#  'cannot',
#  'ltd',
#  'nothing',
#  'known',
#  'inc',
#  'relatively',
#  'wherein',
#  'ours',
#  'myself',
#  'instead',
#  "won't",
#  'often',
#  'thence',
#  "i'm",
#  'somebody',
#  'whole',
#  'maybe',
#  'do',
#  'insofar',
#  "they're",
#  'never',
#  'value',
#  'keeps',
#  'one',
#  'course',
#  'among',
#  'someone',
#  'containing',
#  "it'll",
#  'forth',
#  'did',
#  "hadn't",
#  'on',
#  'how',
#  'former',
#  "hasn't",
#  'if',
#  'why',
#  'gets',
#  'along',
#  'help',
#  "shouldn't",
#  'looking',
#  'know',
#  'sometimes',
#  "don't",
#  'either',
#  'asking',
#  'followed',
#  'need',
#  'example',
#  'currently',
#  'okay',
#  'does',
#  'me',
#  'secondly',
#  'unless',
#  'using',
#  'useful',
#  "i've",
#  "we've",
#  'getting',
#  'most',
#  'no',
#  'sorry',
#  'looks',
#  'look',
#  'following',
#  'up',
#  'becomes',
#  'less',
#  'able',
#  'sure',
#  'and',
#  'eg',
#  'away',
#  'far',
#  'rd',
#  'have',
#  'h',
#  'has',
#  'therefore',
#  'themselves',
#  'theirs',
#  "i'd",
#  'so',
#  'n',
#  'nine',
#  'follows',
#  'presumably',
#  'such',
#  'used',
#  'placed',
#  'again',
#  'his',
#  'considering',
#  'each',
#  'b',
#  'more',
#  'taken',
#  'use',
#  'needs',
#  'tell',
#  'once',
#  'become',
#  'or',
#  't',
#  'of',
#  'wherever',
#  'possible',
#  'already',
#  'inasmuch',
#  'while',
#  "they've",
#  'nearly',
#  'perhaps',
#  'wants',
#  "we'd",
#  'uucp',
#  'reasonably',
#  'else',
#  'normally',
#  'serious',
#  'little',
#  'co',
#  'where',
#  'these',
#  'z',
#  'in',
#  'gone',
#  "you'd",
#  'nevertheless',
#  'must',
#  'this',
#  'ourselves',
#  'latterly',
#  "didn't",
#  'he',
#  'novel',
#  'try',
#  'downwards',
#  'clearly',
#  'across',
#  'various',
#  'usually',
#  'hardly',
#  'likely',
#  'ignored',
#  'we',
#  'specify',
#  'thank',
#  "they'd",
#  'despite',
#  'old',
#  'thats',
#  'come',
#  'better',
#  'especially',
#  'yet',
#  'obviously',
#  'gives',
#  're',
#  'their',
#  'the',
#  'causes',
#  'non',
#  'another',
#  'it',
#  'somehow',
#  'namely',
#  'th',
#  'et',
#  'self',
#  "can't",
#  'them',
#  'via',
#  'y',
#  'thoroughly',
#  'anyway',
#  'exactly',
#  'says',
#  'sent',
#  'appreciate',
#  'thanx',
#  'available',
#  'actually',
#  'thereafter',
#  "weren't",
#  "doesn't",
#  'particularly',
#  'soon',
#  'besides',
#  'provides',
#  'her',
#  'whither',
#  'p',
#  'indeed',
#  'all',
#  'inward',
#  'are',
#  'concerning',
#  'here',
#  's',
#  'towards',
#  'lately',
#  'cause',
#  'saw',
#  'within',
#  'even',
#  'then',
#  'hi',
#  'only',
#  'mean',
#  'necessary',
#  'six',
#  'what',
#  'your',
#  'greetings',
#  'aside',
#  'whence',
#  'there',
#  'sensible',
#  'my',
#  'edu',
#  'anyways']

# %% [markdown]
# #### The following function finds all the stopwords from the stop word document, and returns a dictionary of the values returning from  the regexptokenizer tokens without the stop words

# %%
#Finds all the stopwords from the stop word document, and returns a dictionary of the values returning from 
#the regexptokenizer tokens without the stop words
def clean_stopwords(key):
    values_stop_words = [iterator for iterator in unit_collocations[key] if iterator.lower() not in unique_stop_words_list]
    return(key,values_stop_words)
cleaned_stop_words =  dict(clean_stopwords(key) for key,values in unit_collocations.items())

# %%
cleaned_stop_words
# Out:
# {'ACB3021': ['apply',
#   'traditional',
#   'contemporary',
#   'performance',
#   'measurement',
#   'control',
#   'techniques',
#   'enable',
#   'managers',
#   'measure',
#   'enhance',
#   'organisational',
#   'performance',
#   'analyse_and',
#   'make',
#   'recommendations',
#   'design',
#   'performance',
#   'measurement',
#   'control',
#   'systems',
#   'explain',
#   'behavioural',
#   'implications',
#   'crucial',
#   'for_the',
#   'effective',
#   'design',
#   'performance',
#   'measurement',
#   'control',
#   'systems',
#   'apply',
#   'critical',
#   'thinking',
#   'problem',
#   'solving',
#   'presentation',
#   'skills',
#   'individual',
#   'group',
#   'activities',
#   'dealing',
#   'performance',
#   'measurement',
#   'control',
#   'demonstrate',
#   'individual',
#   'summative',
#   'assessment',
#   'task',
#   'acquisition',
#   'comprehensive',
#   'understanding',
#   'topics',
#   'covered',
#   'acb3021',
#   'topics',
#   'include',
#   'budget',
#   'planning',
#   'process',
#   'including',
#   'master',
#   'budget',
#   'preparation',
#   'budgeting',
#   'standard',
#   'costs',
#   'variance',
#   'analysis',
#   'responsibility',
#   'accounting',
#   'management',
#   'objectives',
#   'non-financial',
#   'performance',
#   'measurement',
#   'divisional',
#   'performance',
#   'transfer',
#   'pricing',
#   'issues',
#   'program',
#   'budgeting',
#   'and_other',
#   'approaches',
#   'capital',
#   'budgeting',
#   'strategic',
#   'planning',
#   'control'],
#  'ACW3041': ['demonstrate',
#   'understanding',
#   'the_role',
#   'limitations',
#   'demand',
#   'audits',
#   'modern',
#   'corporate',
#   'society',
#   'including',
#   "auditor's",
#   'professional',
#   'ethical',
#   'legal',
#   'obligations',
#   'examine',
#   "auditor's",
#   'role',
#   'corporate',
#   'governance',
#   'emphasis',
#   'detection',
#   'reporting',
#   'fraud',
#   'error',
#   'describe_the',
#   'assurance',
#   'framework',
#   'and_apply',
#   'planning',
#   'processes',
#   'evidence',
#   'gathering',
#   'procedures',
#   'auditors',
#   'form',
#   'audit',
#   'opinion',
#   'apply',
#   'critical',
#   'thinking',
#   'problem',
#   'solving',
#   'presentation',
#   'skills',
#   'individual',
#   'group',
#   'activities',
#   'dealing',
#   'auditing',
#   'assurance',
#   'demonstrate',
#   'individual',
#   'summative',
#   'assessment',
#   'task',
#   'acquisition',
#   'comprehensive',
#   'understanding',
#   'topics',
#   'covered',
#   'acw3041',
#   'overview',
#   'auditing',
#   "auditor's",
#   'legal',
#   'liabilities',
#   'audit',
#   'process',
#   'evidence',
#   'concepts',
#   'materiality',
#   'risks',
#   'study',
#   'evaluation',
#   'internal',
#   'control',
#   'edp',
#   'auditing',
#   'audit',
#   'sampling',
#   'techniques',
#   'test',
#   'transactions',
#   'cycles',
#   'and_the',
#   'verification',
#   'account',
#   'balances',
#   'auditors',
#   'reports',
#   'internal',
#   'operational',
#   'auditing'],
#  'ACX4018': ['implement',
#   'research',
#   'proposal',
#   'recognise',
#   'practical',
#   'problems',
#   'conducting',
#   'scientific',
#   'research_and',
#   'propose',
#   'solutions',
#   'complete',
#   'research',
#   'dissertation',
#   'develop',
#   'the_ability',
#   'conduct',
#   'manage',
#   'planned',
#   'study',
#   'apply',
#   'critical',
#   'thinking',
#   'problem',
#   'solving',
#   'presentation',
#   'skills',
#   'individual',
#   'group',
#   'activities',
#   'dealing',
#   'research',
#   'dissertation',
#   'students',
#   'conduct',
#   'critical',
#   'review',
#   'literature',
#   'relevant',
#   'study',
#   'derive',
#   'hypotheses',
#   'testing',
#   'devise',
#   'empirical',
#   'test',
#   'hypotheses',
#   'showing',
#   'regard',
#   'practical',
#   'problems',
#   'conducting',
#   'research',
#   'ethical',
#   'considerations',
#   'principles',
#   'scientific',
#   'method',
#   'conduct',
#   'planned',
#   'study',
#   'manage',
#   'problems',
#   'arising',
#   'data',
#   'collection',
#   'select',
#   'conduct',
#   'analysis',
#   'data',
#   'write',
#   'report',
#   'project',
#   'showing',
#   'due',
#   'regard',
#   'relevant',
#   'stylistic',
#   'conventions'],
#  'ADA3111': ['demonstrate',
#   'understanding',
#   'concepts',
#   'design',
#   'thinking',
#   'and_their',
#   'application',
#   'identify_and',
#   'analyse',
#   'ill-defined',
#   'real-world',
#   'project',
#   'problems',
#   'relevant',
#   'design',
#   'thinking',
#   'approaches',
#   'apply',
#   'design',
#   'thinking',
#   'methods',
#   'approaches',
#   'project-based',
#   'problem',
#   'develop',
#   'perspectives',
#   'key',
#   'issues',
#   'identify',
#   'potential',
#   'opportunties',
#   'develop',
#   'test',
#   'evaluate',
#   'original',
#   'proposals',
#   'response',
#   'project-based',
#   'problems',
#   'develop',
#   'awareness',
#   'preferred',
#   'approaches',
#   'complex',
#   'tasks',
#   'ways',
#   'extended',
#   'design',
#   'thinking',
#   'design',
#   'thinking',
#   'applies',
#   'skills_and',
#   'strategies',
#   'developed',
#   'designers',
#   'wide',
#   'range',
#   'problems',
#   'situations',
#   'skills_and',
#   'strategies',
#   'include',
#   'range',
#   'conceptual',
#   'communication',
#   'approaches',
#   'ways',
#   'explore',
#   'reconsider',
#   'context',
#   'work',
#   'achieved',
#   'design',
#   'thinking',
#   'brings',
#   'approaches',
#   'sciences',
#   'humanities',
#   'analysis_and',
#   'synthesis',
#   'applies',
#   'ways',
#   'design',
#   'approach',
#   'design',
#   'thinking',
#   'enable',
#   'flexible',
#   'approach',
#   'problem',
#   'solving',
#   'nuanced',
#   'engagement',
#   'with_the',
#   'complex',
#   'issues',
#   'contemporary',
#   'world',
#   'this_unit',
#   'introduce',
#   'students',
#   'key',
#   'skills_and',
#   'practices',
#   'associated_with',
#   'design',
#   'thinking',
#   'offer',
#   'opportunities',
#   'explore',
#   'application',
#   'basic',
#   'creativity',
#   'techniques',
#   'range',
#   'disciplines'],
#  'ADA5001': ['operate',
#   'constructively',
#   'collaboratively',
#   'part',
#   'team',
#   'develop',
#   'observation',
#   'research',
#   'communication_and',
#   'information',
#   'gathering',
#   'skills',
#   'contribute',
#   'discipline-specific',
#   'practitioner',
#   'interdisciplinary',
#   'context',
#   'conduct',
#   'critical',
#   'enquiry',
#   'provide',
#   'summative',
#   'reviews',
#   'peers',
#   'disciplines',
#   'conceptualise',
#   'design_and',
#   'create',
#   'response',
#   'interdisciplinary',
#   'problem',
#   'understand',
#   'and_apply',
#   'rules',
#   'occupational',
#   'health_and',
#   'safety',
#   'interdisciplinary',
#   'practice',
#   'order',
#   'collaborate',
#   'safely',
#   'peers',
#   'interdisciplinary',
#   'studio',
#   'environment',
#   'team-based',
#   'project',
#   'activities',
#   'problem-based',
#   'learning',
#   'application',
#   'knowledge',
#   'techniques',
#   'methodologies',
#   'from_the',
#   'students',
#   'individual',
#   'disciplines',
#   'whilst',
#   'addressing',
#   'complex',
#   'multi-faceted',
#   'problem',
#   'the_unit',
#   'involve',
#   'combination',
#   'art',
#   'design',
#   'architecture',
#   'students',
#   'the_ability',
#   'critically',
#   'creatively',
#   'engage',
#   'research_and',
#   'real',
#   'world',
#   'problems',
#   'interdisciplinary',
#   'approaches',
#   'core',
#   'this_unit',
#   'students_will',
#   'develop',
#   'skills',
#   'communication',
#   'collaboration',
#   'innovation',
#   'essential',
#   'tools',
#   'professional',
#   'practice',
#   'research',
#   'activities',
#   'chosen',
#   'field',
#   'final',
#   'outcomes',
#   'from_the',
#   'unit',
#   'collaborative',
#   'individual'],
#  'AHT3801': ['understand',
#   'articulate',
#   'medium',
#   'conceptually',
#   'practically',
#   'analyse_the',
#   'debates',
#   'surrounding',
#   'defence',
#   'criticism',
#   'medium',
#   'specificity',
#   'and_the',
#   'trans-disciplinary',
#   'contextualise',
#   'studio',
#   'practice',
#   'conceptual',
#   'models',
#   'explored',
#   'the_unit',
#   'reflect',
#   'engage',
#   'critical',
#   'dialogue',
#   'medium',
#   'importance',
#   'twenty-first',
#   'century',
#   'art',
#   'this_unit',
#   'examines',
#   'medium',
#   'materiality',
#   'range',
#   'visual',
#   'art',
#   'practices',
#   'including',
#   'painting',
#   'sculpture',
#   'installation',
#   'photography',
#   'video',
#   'multi-media',
#   'social',
#   'practices',
#   'performance',
#   'art',
#   'focuses',
#   'historical',
#   'lineage',
#   "art's",
#   'mediums',
#   'disciplines',
#   'and_how',
#   'framed',
#   'constituted',
#   'judged',
#   'diverse',
#   'range',
#   'academic',
#   'fields',
#   'concepts',
#   'traditions',
#   'modern',
#   'aesthetics',
#   'effect',
#   'late-capitalism',
#   'socio-economic',
#   'critiques',
#   'art',
#   'technology',
#   'pivotal',
#   'understanding',
#   "art's",
#   'form',
#   'moves',
#   'modes',
#   'medium-specificity',
#   'trans-disciplinary',
#   'realms',
#   'the_unit',
#   'introduces',
#   'key',
#   'theoretical',
#   'tenets',
#   'analyse',
#   'late',
#   'modernist',
#   'contemporary',
#   'art',
#   'practices',
#   'case',
#   'studies',
#   'introduces',
#   'students',
#   'critical',
#   'dialogue',
#   'medium',
#   'artists',
#   'material',
#   'processes'],
#  'AMG5743': ['knowledge',
#   'skills_and',
#   'attributes',
#   'understanding',
#   'engaging',
#   'advanced',
#   'research',
#   'ability',
#   'design',
#   'write',
#   'edit',
#   'research',
#   'thesis',
#   'ability',
#   'advanced',
#   'level',
#   'analyse_and',
#   'evaluate',
#   'arguments',
#   'understand',
#   'critical',
#   'approaches',
#   'relating',
#   'communication',
#   'industries',
#   'communication',
#   'issues',
#   'capacity',
#   'contribute',
#   'advanced',
#   'knowledge',
#   'chosen',
#   'area',
#   'research',
#   'enhanced',
#   'intellectual',
#   'independence',
#   'greater',
#   'self-reliance',
#   'critical',
#   'distance',
#   'intellectual',
#   'professional',
#   'activity',
#   'the_unit',
#   'alternative',
#   'amg5742',
#   'students',
#   'option',
#   'progression',
#   'higher',
#   'degree',
#   'research',
#   'undertaken',
#   'final',
#   'semester',
#   'master',
#   'communications',
#   'media',
#   'studies',
#   'students',
#   'develop',
#   'independent',
#   'research_project',
#   'topic',
#   'chosen',
#   'student',
#   'developed',
#   'with_the',
#   'advice',
#   'support',
#   'supervisor',
#   'project',
#   'written',
#   '18000',
#   'word',
#   'dissertation',
#   'allowing',
#   'student',
#   'demonstrate',
#   'advanced',
#   'skills',
#   'research',
#   'writing',
#   'project',
#   'management',
#   'students',
#   'encouraged',
#   'project',
#   'formal',
#   'requirement',
#   'for_the',
#   'degree',
#   'contributing',
#   'portfolio',
#   'professional',
#   'scholarly',
#   'development'],
#  'APG5050': ['familiarity',
#   'with_the',
#   'major',
#   'research',
#   'methods',
#   'communication_and',
#   'media',
#   'studies',
#   'understanding',
#   'difference',
#   'research',
#   'topics',
#   'research',
#   'questions',
#   'ability',
#   'identify',
#   'productive',
#   'research',
#   'questions',
#   'ability',
#   'apply',
#   'research',
#   'methods',
#   'critically',
#   'appropriately',
#   'addressing',
#   'research',
#   'questions',
#   'capacity',
#   'design',
#   'research',
#   'projects',
#   'communication_and',
#   'media',
#   'studies',
#   'conceptualization',
#   'project',
#   'planning',
#   'ability',
#   'develop',
#   'innovative',
#   'solutions',
#   'problems',
#   'communication_and',
#   'media',
#   'studies',
#   'cf',
#   'monash',
#   'graduate',
#   'attributes',
#   'policy',
#   'ability',
#   'apply',
#   'research',
#   'skills',
#   'range',
#   'challenges',
#   'communication_and',
#   'media',
#   'studies',
#   'cf',
#   'monash',
#   'graduate',
#   'attributes',
#   'policy',
#   'the_unit',
#   'introduces',
#   'students',
#   'principles',
#   'problem-solving',
#   'communication_and',
#   'media',
#   'research',
#   'range',
#   'traditional',
#   'emerging',
#   'research',
#   'methods',
#   'including',
#   'textual',
#   'analysis',
#   'content',
#   'analysis',
#   'interviews',
#   'ethnographic',
#   'fieldwork',
#   'digital',
#   'humanities',
#   'approaches',
#   'sentiment',
#   'analysis_and',
#   'audience',
#   'research',
#   'focus',
#   'simply',
#   'learning',
#   'applying',
#   'methods',
#   'understanding',
#   'relation',
#   'problems',
#   'fields',
#   'address',
#   'the_unit',
#   'develop',
#   'skills',
#   'research',
#   'design',
#   'identifying',
#   'productive',
#   'research',
#   'questions',
#   'selecting',
#   'methodologies',
#   'project',
#   'planning',
#   'skills',
#   'provide',
#   'platform',
#   'development',
#   'communications',
#   'research_project',
#   'masters',
#   'thesis'],
#  'APG5052': ['critically',
#   'analyse_the',
#   'recent',
#   'developments',
#   'communications',
#   'media',
#   'engaging',
#   'emerging',
#   'problem',
#   'question',
#   'field',
#   'contribute',
#   'original',
#   'thinking',
#   'produce',
#   'innovative',
#   'solutions',
#   'contemporary',
#   'problems',
#   'communication_and',
#   'media',
#   'articulate',
#   'ethical',
#   'values',
#   'relevant',
#   'rapid',
#   'development',
#   'communication_and',
#   'media',
#   'attention',
#   'impact',
#   'digital',
#   'technologies',
#   'utilise',
#   'research',
#   'skills',
#   'evaluate',
#   'issues',
#   'field',
#   'communicate',
#   'findings',
#   'professional',
#   'context',
#   'the_unit',
#   'students_will',
#   'engage',
#   'specialised',
#   'study',
#   'examining',
#   'cutting-edge',
#   'development',
#   'communication_and',
#   'media',
#   'year',
#   'offering',
#   'the_unit',
#   'address',
#   'question',
#   'topic',
#   'general',
#   'field',
#   'digital',
#   'media',
#   'developing',
#   'specialist',
#   'insight',
#   'expertise',
#   'media',
#   'researcher',
#   'industry',
#   'practitioner',
#   'engaged',
#   'teach',
#   'the_unit',
#   'strong',
#   'research',
#   'focus',
#   'include',
#   'experimental',
#   'development',
#   'professional',
#   'industry',
#   'practice',
#   'students_will',
#   'expected',
#   'bring',
#   'work',
#   'point',
#   'intersection',
#   'with_the',
#   'recent',
#   'work',
#   'addressing',
#   'problems',
#   'emerging',
#   'media',
#   'studies',
#   'scholarship',
#   'practices',
#   'media',
#   'communication',
#   'industries'],
#  'APG5077': ['identify',
#   'assess',
#   'interpret',
#   'cultural',
#   'nature-based',
#   'assets',
#   'tourist',
#   'audience',
#   'devise',
#   'effective',
#   'management',
#   'strategy',
#   'sustainable',
#   'cultural',
#   'nature-based',
#   'tourism',
#   'development',
#   'propose',
#   'research-based',
#   'solutions',
#   'sustainable',
#   'cultural',
#   'nature-based',
#   'tourism',
#   'challenges',
#   'exhibit',
#   'ethical',
#   'values',
#   'the_development',
#   'sustainable',
#   'tourism',
#   'diverse',
#   'cultural',
#   'nature-based',
#   'contexts',
#   'effectively',
#   'communicate',
#   'well-argued',
#   'tourism',
#   'strategy',
#   'diverse',
#   'medium',
#   'sustainable',
#   'nature-based',
#   'cultural',
#   'resources',
#   'vital',
#   'successful',
#   'tourism',
#   'destination',
#   'development',
#   'globally',
#   'this_unit',
#   'students',
#   'learn',
#   'identify',
#   'assess',
#   'interpret',
#   'strategically',
#   'manage',
#   'critical',
#   'assets',
#   'maximise',
#   'visitor',
#   'experience',
#   'minimise',
#   'negative',
#   'environmental',
#   'cultural',
#   'impacts',
#   'students_will',
#   'learn',
#   'industry',
#   'experts',
#   'case-based',
#   'field',
#   'study',
#   'hobart',
#   'tasmania',
#   'leading',
#   'destination',
#   'cultural',
#   'heritage',
#   'nature-based',
#   'product',
#   'development'],
#  'APG5082': ['explain',
#   'creative',
#   'industries',
#   'structures',
#   'markets',
#   'identify',
#   'business',
#   'opportunities',
#   'specific',
#   'creative',
#   'cultural',
#   'industries',
#   'utilise',
#   'academic',
#   'concepts',
#   'understand',
#   'audiences',
#   'challenges',
#   'creative',
#   'products',
#   'branding',
#   'develop',
#   'marketing',
#   'strategy',
#   'independent',
#   'research',
#   'skills',
#   'engage',
#   'cultural',
#   'contexts',
#   'pitch',
#   'communicate',
#   'ideas',
#   'stakeholders',
#   'effectively',
#   'this_unit',
#   'students',
#   'analyse',
#   'creative',
#   'enterprises',
#   'creative',
#   'entrepreneurial',
#   'mindsets',
#   'differentiate',
#   'marketing',
#   'business',
#   'approaches',
#   'cultural',
#   'industries',
#   'sectors',
#   'analysing',
#   'changing',
#   'marketing',
#   'models',
#   'creative',
#   'industries',
#   'chains',
#   'and_their',
#   'audience',
#   'treating',
#   'creative',
#   'entrepreneurship',
#   'specialism',
#   'identify',
#   'key',
#   'strategic',
#   'approaches',
#   'entrepreneurs',
#   'global',
#   'cultural',
#   'industries',
#   'sizes',
#   'traditional',
#   'emergent',
#   'niche',
#   'markets',
#   'identify',
#   'challenges',
#   'increasingly',
#   'commercializing',
#   'creative',
#   'industries',
#   'implication',
#   'creative',
#   'solutions',
#   'marketing',
#   'management',
#   'creative',
#   'industries',
#   'important',
#   'entrepreneurs',
#   'order',
#   'place',
#   'culture',
#   'heart',
#   'business',
#   'means',
#   'contemporary',
#   'society'],
#  'APG5103': ['employ',
#   'expert',
#   'knowledge',
#   'specialist',
#   'skills',
#   'policy',
#   'analysis_and',
#   'evaluation',
#   'enable',
#   'discipline',
#   'based',
#   'solutions',
#   'relevant',
#   'diverse',
#   'business',
#   'professional',
#   'public',
#   'policy',
#   'communities',
#   'devise',
#   'deliver',
#   'innovative',
#   'solutions',
#   'policy-related',
#   'challenges',
#   'employing',
#   'advanced',
#   'critical',
#   'thinking',
#   'evaluation',
#   'research',
#   'skills',
#   'communicate',
#   'policy',
#   'analysis_and',
#   'options',
#   'clarity',
#   'purpose',
#   'the_unit',
#   'students',
#   'understandings',
#   'conceptual',
#   'theoretical',
#   'frameworks',
#   'policy',
#   'analysis_and',
#   'evaluation',
#   'present',
#   'effective',
#   'policy',
#   'advice',
#   'highest',
#   'levels',
#   'government',
#   'real-life',
#   'examples',
#   'public',
#   'policy',
#   'the_unit',
#   'explores',
#   'challenges',
#   'problem',
#   'definition',
#   'analysing',
#   'evaluating',
#   'evidence',
#   'choosing',
#   'policy',
#   'instruments',
#   'developing',
#   'policy',
#   'options',
#   'preparing',
#   'submitting',
#   'policy',
#   'advice'],
#  'APG5230': ['explain',
#   'key',
#   'concepts',
#   'landscape',
#   'ecology',
#   'including',
#   'resilience',
#   'connectivity',
#   'apply',
#   'concepts',
#   'real-world',
#   'environmental',
#   'contexts',
#   'understand_the',
#   'role',
#   'expertise',
#   'shaping',
#   'policy',
#   'design_and',
#   'implementation',
#   'critically_evaluate',
#   'interaction',
#   'governance',
#   'approaches',
#   'and_their',
#   'realisation',
#   'practice',
#   'terms',
#   'sustainability',
#   'outcomes',
#   'the_unit',
#   'broad',
#   'introduction',
#   'ecology',
#   'environmental',
#   'management',
#   'interface',
#   'science',
#   'policy',
#   'suitable',
#   'understand',
#   'policy',
#   'works',
#   'practice',
#   'professional',
#   'careers',
#   'prior',
#   'ecological',
#   'experience',
#   'required',
#   'australian',
#   'international',
#   'case',
#   'studies',
#   'the_unit',
#   'introduce',
#   'challenges',
#   'translating',
#   'ecological',
#   'knowledge',
#   'effective',
#   'policy',
#   'tools'],
#  'APG5348': ['summarize',
#   'key',
#   'theoretical',
#   'debates',
#   'relation',
#   'language',
#   'acquisition',
#   'evaluate',
#   'relevant',
#   'empirical',
#   'evidence',
#   'compare',
#   'work',
#   'competing',
#   'theorists',
#   'recognise',
#   'role',
#   'the_development',
#   'sla',
#   'theory',
#   'reflect',
#   'language',
#   'learning',
#   'experience',
#   'classroom',
#   'practice',
#   'light',
#   'theoretical',
#   'empirical',
#   'studies',
#   'evaluate',
#   'major',
#   'methodological',
#   'approaches',
#   'study',
#   'language',
#   'acquisition',
#   'conduct',
#   'major',
#   'research_project',
#   'area',
#   'language',
#   'acquisition',
#   'address',
#   'key',
#   'concepts',
#   'theoretical',
#   'models',
#   'accepted',
#   'approaches',
#   'contested',
#   'frameworks',
#   'theories',
#   'rapidly',
#   'changing',
#   'field',
#   'language',
#   'acquisition',
#   'topics',
#   'covered',
#   'include',
#   'models',
#   'theories',
#   'language',
#   'acquisition',
#   'language',
#   'acquisition',
#   'error',
#   'analysis_and',
#   'interlanguage',
#   'interlanguage',
#   'pragmatics',
#   'input',
#   'interaction',
#   'learner',
#   'strategies',
#   'learning',
#   'styles',
#   'cognitive',
#   'processes',
#   'language',
#   'identity',
#   'learners',
#   'rights',
#   'methods',
#   'sla',
#   'research'],
#  'APG5351': ['identify_and',
#   'explain',
#   'international',
#   'news',
#   'stories',
#   'selected',
#   'gathered',
#   'distributed',
#   'compare',
#   'approaches',
#   'news',
#   'gathering',
#   'publishing',
#   'countries',
#   'conceptualise',
#   'big',
#   'global',
#   'news',
#   'stories',
#   'inherent',
#   'ethical',
#   'dilemmas',
#   'explore',
#   'analyse',
#   'international',
#   'news',
#   'issue',
#   'design',
#   'international',
#   'research_project',
#   'media',
#   'theories',
#   'methodologies',
#   'evaluate',
#   'communicate',
#   'results',
#   'media',
#   'project',
#   'class',
#   'online',
#   'presentation',
#   'writing',
#   'media',
#   'report',
#   'the_unit',
#   'enable',
#   'students',
#   'understand',
#   'international',
#   'news',
#   'stories',
#   'sourced',
#   'gathered',
#   'distributed',
#   'world',
#   'the_unit',
#   'explores',
#   'changing',
#   'nature',
#   'media',
#   'ecosystem',
#   'staff',
#   'foreign',
#   'correspondents',
#   'working',
#   'international',
#   'news',
#   'organisations',
#   'local',
#   'journalists',
#   'eyewitnesses',
#   'content',
#   'this_unit',
#   'includes',
#   'history',
#   'international',
#   'news',
#   'agencies',
#   'global',
#   'news',
#   'flows',
#   'transnational',
#   'broadcasters',
#   'the_role',
#   'foreign',
#   'correspondent',
#   'evolution',
#   'citizen',
#   'journalist',
#   'and_the',
#   'big',
#   'world',
#   'news',
#   'stories',
#   'dominating',
#   'international',
#   'news',
#   'agenda',
#   'students_will',
#   'international',
#   'news',
#   'resources',
#   'research',
#   'study',
#   'write',
#   'international',
#   'media',
#   'research',
#   'report'],
#  'APG5400': ['sound',
#   'understanding',
#   'globalisation',
#   'affects',
#   'communications',
#   'media',
#   'industries',
#   'analyse',
#   'global',
#   'media',
#   'and_the',
#   'policies',
#   'affect',
#   'aware',
#   'potentials',
#   'problems',
#   'cross-cultural',
#   'communication_and',
#   'major',
#   'theories',
#   'developed',
#   'explain',
#   'understand',
#   'changing',
#   'modes',
#   'reception',
#   'global',
#   'audiences',
#   'with_the',
#   'implications',
#   'processes',
#   'national',
#   'personal',
#   'identity',
#   'aware',
#   'major',
#   'legal',
#   'ethical',
#   'challenges',
#   'thrown',
#   'globalisation',
#   'communications',
#   'media',
#   'demonstrate',
#   'enhanced',
#   'ability',
#   'conduct',
#   'independent',
#   'research',
#   'subject',
#   'explores',
#   'key',
#   'issues',
#   'arising',
#   'from_the',
#   'rapid',
#   'change',
#   'development',
#   'growth',
#   'international',
#   'communications',
#   'examines',
#   'impact',
#   'globalisation',
#   'shifts',
#   'production',
#   'distribution',
#   'consumption',
#   'international',
#   'communications',
#   'students_will',
#   'power',
#   'disadvantage',
#   'cultural',
#   'flows',
#   'exchange',
#   'development',
#   'communication',
#   'cross-cultural',
#   'communication',
#   'international',
#   'advertising',
#   'public',
#   'relations',
#   'diasporic',
#   'cultures',
#   'legal',
#   'ethical',
#   'issues',
#   'international',
#   'communications',
#   'examples',
#   'drawn',
#   'countries',
#   'including',
#   'case',
#   'studies',
#   'communications',
#   'media',
#   'asia',
#   'europe',
#   'north',
#   'america',
#   'and_the',
#   'middle',
#   'east'],
#  'APG5628': ['critically',
#   'assess',
#   'contributions',
#   'development',
#   'academic',
#   'field',
#   'explores',
#   'history',
#   'development',
#   'thinking',
#   'and_the',
#   'spatial',
#   'patterns',
#   'development',
#   'practice',
#   'articulate',
#   'approaches',
#   'practices',
#   'development',
#   'evaluate',
#   'alternatives',
#   'light',
#   'recent',
#   'scholarly',
#   'work',
#   'contemporary',
#   'uneven',
#   'development',
#   'argue',
#   'contemporary',
#   'development',
#   'paradigm',
#   'degree',
#   'personal',
#   'socio-political',
#   'reflection',
#   'development',
#   'body',
#   'ideas',
#   'structures',
#   'systems',
#   'power',
#   'flows',
#   'resources',
#   'social',
#   'transformations',
#   'globe',
#   'practice',
#   'intervene',
#   'diverse',
#   'cultural',
#   'contexts',
#   'programmes',
#   'designed',
#   'ideas',
#   'development',
#   'this_unit',
#   'addresses',
#   'questions',
#   'deconstructing',
#   'conceptual',
#   'practical',
#   'pillars',
#   'development',
#   'interrogating',
#   'similar',
#   'concepts',
#   'economic',
#   'growth',
#   'progress',
#   'modernisation',
#   'addition',
#   'briefly',
#   'reviewing',
#   'early',
#   'theorisations',
#   'development',
#   'and_their',
#   'links',
#   'colonialism',
#   'ideas',
#   'modernisation',
#   'the_unit',
#   'exposes',
#   'power-laden',
#   'unequal',
#   'nature',
#   'contemporary',
#   'development',
#   'institutionalised',
#   'set',
#   'practices',
#   'rose',
#   'prominence',
#   'world',
#   'war',
#   'ii',
#   'case',
#   'studies',
#   'paint',
#   'picture',
#   'geographically',
#   'uneven',
#   'development',
#   'today',
#   'the_unit',
#   'explores',
#   'development',
#   'theories',
#   'correlate',
#   'development-in',
#   'practice',
#   'explores',
#   'ways',
#   'diverse',
#   'social',
#   'groups',
#   'social',
#   'movements',
#   'resist',
#   'western',
#   'notions',
#   'progress',
#   'attempting',
#   'reclaim',
#   'development',
#   'forge',
#   'autonomous',
#   'pathways',
#   'well-being',
#   'alternative',
#   'pathways',
#   'raise',
#   'questions',
#   'normative',
#   'side',
#   'development',
#   'contemporary',
#   'development',
#   'institution',
#   'deconstructed',
#   'practice'],
#  'APG5849': ['formulate',
#   'research_project',
#   'conduct',
#   'research',
#   'independently',
#   'demonstrate',
#   'command',
#   'relevant',
#   'literature',
#   'critically',
#   'analyse_the',
#   'relevant',
#   'academic',
#   'literature',
#   'develop',
#   'academically',
#   'sound',
#   'argument',
#   'demonstrate',
#   'sophisticated',
#   'written',
#   'skills',
#   'supervision',
#   'suitable',
#   'academic',
#   'staff',
#   'students_will',
#   'conduct',
#   'independent',
#   'research',
#   'topic',
#   'research',
#   'process',
#   'continues',
#   'apg5850',
#   'graduate',
#   'research',
#   'thesis',
#   'part',
#   'students',
#   'submit',
#   'research',
#   'thesis'],
#  'APG5881': ["na'students",
#   'undertake',
#   'in-country',
#   'study',
#   'institution',
#   'monash',
#   'university',
#   'exchange',
#   'agreement',
#   'study',
#   'equivalent',
#   '12',
#   'points',
#   'fifth-year',
#   'postgraduate',
#   'study',
#   'arts',
#   'monash',
#   'university',
#   'form',
#   '5th',
#   'year',
#   'unit',
#   'offered',
#   'host',
#   'institution',
#   'domain',
#   'translation',
#   'studies'],
#  'APG5900': ['broad',
#   'overview',
#   'conceptual',
#   'historical',
#   'contemporary',
#   'issues',
#   'involved',
#   'notions',
#   'cultural',
#   'economy',
#   'critically_evaluate',
#   'approaches',
#   'cultural',
#   'economy',
#   'and_the',
#   'issues',
#   'raise',
#   'apply',
#   'independent',
#   'research',
#   'skills',
#   'range',
#   'conceptual',
#   'historical',
#   'problems',
#   'field',
#   'cultural',
#   'economy',
#   'ability',
#   'write',
#   'communicate',
#   'effectively',
#   'analytical',
#   'depth',
#   'ability',
#   'effectively',
#   'utilise',
#   'academic',
#   'concepts',
#   'identify_and',
#   'investigate',
#   'concrete',
#   'challenges',
#   'issues',
#   'involved',
#   'specific',
#   'aspects',
#   'cultural',
#   'economy',
#   'this_unit',
#   'introduce',
#   'core',
#   'conceptual',
#   'historical',
#   'dimensions',
#   'mca',
#   'including',
#   'emergence',
#   'arts',
#   'cultural',
#   'policy',
#   'rise',
#   'cultural',
#   'creative',
#   'industries',
#   'urban',
#   'regeneration',
#   'urban',
#   'cultural',
#   'economies',
#   'and_the',
#   'evolution',
#   'cultural',
#   'creative',
#   'work',
#   'explore',
#   'concepts',
#   'claims',
#   'cultural',
#   'economy',
#   'economy',
#   'constructed',
#   'socio-cultural',
#   'phenomenon',
#   'examine',
#   'consequences',
#   'existing',
#   'future',
#   'practices',
#   'individuals',
#   'businesses',
#   'policy',
#   'agencies',
#   'operating',
#   'cultural',
#   'economy',
#   'se',
#   'students_will',
#   'asked',
#   'submit',
#   'assignments',
#   'based',
#   'concepts',
#   'issues',
#   'generated',
#   'the_unit',
#   'content'],
#  'ARC3002': ['demonstrate',
#   'refined',
#   'level',
#   'competence',
#   'architectural',
#   'design',
#   'demonstrated',
#   'ability',
#   'critically',
#   'analyse_and',
#   'successfully',
#   'respond',
#   'complex',
#   'range',
#   'issues',
#   'inherent',
#   'architectural',
#   'design',
#   'project',
#   'developed',
#   'sophisticated',
#   'understanding',
#   'observation',
#   'analysis',
#   'experiment',
#   'critique',
#   'apply',
#   'architectural',
#   'design',
#   'process',
#   'acquired',
#   'advanced',
#   'level',
#   'competence',
#   'consolidation',
#   'presentation',
#   'skills',
#   'verbal',
#   'graphic',
#   '3-dimensional',
#   'understand',
#   'apply_the',
#   'rules',
#   'occupational',
#   'health_and',
#   'safety',
#   'the_unit',
#   'study',
#   'architecture',
#   'design',
#   'studio',
#   '6',
#   'aims',
#   'consolidate',
#   'conceptual',
#   'understanding',
#   'skill',
#   'base',
#   'preceding',
#   'design',
#   'studios',
#   'continues',
#   'elaborate',
#   'architectural',
#   'design',
#   'process',
#   'investigation',
#   'critical',
#   'observation',
#   'experiment',
#   'increases',
#   'emphasis',
#   'design',
#   'synthetic',
#   'process',
#   'encompassing',
#   'range',
#   'complex',
#   'issues',
#   'inherent',
#   'production',
#   'architecture',
#   'material',
#   'structure',
#   'program',
#   'site',
#   'history',
#   'representation',
#   'investigated',
#   'relationship',
#   'production',
#   'architectural',
#   'form'],
#  'ARC5401': ['locate',
#   'design',
#   'research',
#   'relevant',
#   'contexts',
#   'acquired',
#   'proficiency',
#   'architectural',
#   'design',
#   'research',
#   'methods',
#   'the_ability',
#   'critically',
#   'analyse_and',
#   'successfully',
#   'respond',
#   'issues',
#   'inherent',
#   'formulating',
#   'architecture',
#   'research',
#   'developed',
#   'demonstrated',
#   'sophisticated',
#   'understanding',
#   'observation',
#   'analysis',
#   'experiment',
#   'critique',
#   'apply',
#   'the_development',
#   'architecture',
#   'design',
#   'research',
#   'understand',
#   'apply_the',
#   'rules',
#   'occupational',
#   'health_and',
#   'safety',
#   'the_unit',
#   'study',
#   'architecture',
#   'research',
#   'methods',
#   'prelude',
#   'final',
#   'architecture',
#   'design',
#   'research_project',
#   'addressing',
#   'diverse',
#   'methodologies',
#   'tactics',
#   'this_unit',
#   'background',
#   'foundation',
#   'undertaking',
#   'independently',
#   'guided',
#   'design',
#   'research',
#   'the_unit',
#   'establish',
#   'parameters',
#   'for_the',
#   'development',
#   'subsequent',
#   'design',
#   'research',
#   'projects',
#   'including',
#   'methodological',
#   'conceptual',
#   'physical',
#   'contexts',
#   'operative',
#   'frameworks',
#   'architectural',
#   'speculations'],
#  'ASC5001': ['critique',
#   'premises',
#   'foundations',
#   'for_the',
#   'biopsychosocial',
#   'model',
#   'addiction',
#   'relation',
#   'models',
#   'addiction',
#   'critique',
#   'the_role',
#   'factors',
#   'aetiology',
#   'addiction',
#   'reference',
#   'the_research',
#   'evidence',
#   'base',
#   'analyse_the',
#   'neurobiological',
#   'genetic',
#   'bases',
#   'addictive',
#   'behaviours',
#   'critically_evaluate',
#   'psychological',
#   'sociocultural',
#   'bases',
#   'addictive',
#   'behaviours',
#   'demonstrate',
#   'drug',
#   'set',
#   'setting',
#   'model',
#   'understanding',
#   'substance',
#   'effects',
#   'individual',
#   'synthesise',
#   'implications',
#   'harm',
#   'minimisation',
#   'approach',
#   'understanding',
#   'interventions',
#   'present',
#   'argument',
#   'based',
#   'theoretical',
#   'empirical',
#   'literature',
#   'process',
#   'addictions',
#   'gambling',
#   'grouped',
#   'substance',
#   'addictions',
#   'evaluate_the',
#   'role',
#   'research',
#   'evidence',
#   'and_the',
#   'models',
#   'addiction',
#   'the_development',
#   'policies',
#   'relevant',
#   'alcohol',
#   'illicit',
#   'drug',
#   'addictive',
#   'behaviours',
#   'this_unit',
#   'introduction',
#   'overview',
#   'addiction',
#   'concept',
#   'consideration',
#   'biological',
#   'psychological',
#   'developmental',
#   'sociocultural',
#   'environmental',
#   'factors',
#   'contribute',
#   'the_development',
#   'addiction'],
#  'ASC5009': ['identify_and',
#   'contextualise',
#   'developmental',
#   'factors',
#   'contribute',
#   'addictive',
#   'behaviours',
#   'young',
#   'people',
#   'explain',
#   'youth',
#   'substance',
#   'abuse',
#   'terms',
#   'family',
#   'social',
#   'contexts',
#   'trauma',
#   'youth',
#   'disadvantage',
#   'synthesise',
#   'information',
#   'impact',
#   'addictive',
#   'behaviours',
#   'young',
#   'people',
#   'families',
#   'order',
#   'demonstrate',
#   'understanding',
#   'complexity',
#   'issue',
#   'reflect',
#   'critically',
#   'psychological',
#   'sociological',
#   'theories',
#   'relevant',
#   'key',
#   'contemporary',
#   'issues',
#   'youth',
#   'addiction',
#   'evaluate',
#   'critique',
#   'current',
#   'responses',
#   'addiction',
#   'including',
#   'school-based',
#   'interventions',
#   'compare',
#   'contrast',
#   'contemporary',
#   'models',
#   'addiction',
#   'behaviours',
#   'young',
#   'people',
#   'analysis',
#   'national',
#   'international',
#   'research',
#   'critically',
#   'review',
#   'effectiveness',
#   'family-based',
#   'interventions',
#   'including',
#   'family',
#   'inclusive',
#   'practice',
#   'parents',
#   'pressure',
#   'critically',
#   'appraise',
#   'range',
#   'youth-focused',
#   'aod',
#   'treatment',
#   'services',
#   'key',
#   'elements',
#   'youth-focused',
#   'service',
#   'delivery',
#   'critically',
#   'review',
#   'policy',
#   'issues',
#   'relevant',
#   'youth',
#   'including',
#   'pertaining',
#   'social',
#   'media',
#   'this_unit',
#   'begins',
#   'focus',
#   'child',
#   'adolescent',
#   'biopsychosocial',
#   'development',
#   'overview',
#   'prevalence',
#   'patterns',
#   'substance',
#   'and_other',
#   'addictive',
#   'behaviours',
#   'populations'],
#  'ASP3162': ['demonstrate',
#   'basic',
#   'understanding',
#   'astrophysical',
#   'fluid',
#   'dynamics',
#   'involving',
#   'physics',
#   'fluids',
#   'high',
#   'mach',
#   'number',
#   'including',
#   'sound',
#   'waves',
#   'shocks',
#   'demonstrate',
#   'practical',
#   'skills',
#   'scientific',
#   'computing',
#   'computational',
#   'modelling',
#   'data',
#   'analysis_and',
#   'visualisation',
#   'perform',
#   'computer',
#   'simulations',
#   'astrophysical',
#   'flows',
#   'advanced',
#   'astrophysical',
#   'simulation',
#   'codes',
#   'demonstrate',
#   'understanding',
#   'physics',
#   'mathematics',
#   'modern',
#   'large-scale',
#   'astrophysical',
#   'simulations',
#   'this_unit',
#   'students_will',
#   'learn',
#   'basic',
#   'principles',
#   'astrophysical',
#   'fluid',
#   'dynamics',
#   'and_how',
#   'model',
#   'extreme',
#   'events',
#   'universe',
#   'the_unit',
#   'covers',
#   'basic',
#   'equations',
#   'compressible',
#   'hydrodynamics',
#   'including',
#   'behaviour',
#   'linear',
#   'waves',
#   'transition',
#   'shocks',
#   'and_the',
#   'behaviour',
#   'fluids',
#   'high',
#   'mach',
#   'number',
#   'students_will',
#   'apply',
#   'understand_the',
#   'physical',
#   'processes',
#   'power',
#   'accreting',
#   'sources',
#   'including',
#   'white',
#   'dwarfs',
#   'neutron',
#   'stars',
#   'black',
#   'holes',
#   'and_the',
#   'physics',
#   'explosion',
#   'stars',
#   'supernovae',
#   'students_will',
#   'gain',
#   'practical',
#   'experience',
#   'computational',
#   'fluid',
#   'dynamics',
#   'including',
#   'basic',
#   'programming',
#   'skills_and',
#   'understanding',
#   'large',
#   'scale',
#   'astrophysical',
#   'simulations',
#   'performed'],
#  'ATS1062': ['basic',
#   'speaking',
#   'listening',
#   'reading',
#   'writing',
#   'skills_and',
#   'vocabulary',
#   'communicate',
#   'effectively',
#   'french',
#   'range',
#   'past',
#   'present',
#   'future',
#   'situations',
#   'range',
#   'topics',
#   'locate',
#   'information',
#   'basic',
#   'texts',
#   'french',
#   'recognise',
#   'key',
#   'structures',
#   'sounds',
#   'french',
#   'identify_and',
#   'prescribed',
#   'grammatical',
#   'items',
#   'critique',
#   'aspects',
#   'modern',
#   'contemporary',
#   'french',
#   'history',
#   'values',
#   'identity',
#   'and_their',
#   'evolution',
#   'interpret',
#   'prescribed',
#   'sources',
#   'synthesise',
#   'knowledge',
#   'standard',
#   'format',
#   'this_unit',
#   'develops',
#   'basic',
#   'language',
#   'skills',
#   'speaking',
#   'listening',
#   'reading',
#   'writing',
#   'level',
#   'acquired',
#   'ats1061',
#   'introduction',
#   'modern',
#   'french',
#   'society',
#   'designed',
#   'limited',
#   'knowledge',
#   'french',
#   'students_will',
#   'encouraged',
#   'develop',
#   'language',
#   'learning',
#   'strategies',
#   'regular',
#   'assessed',
#   'homework',
#   'tests',
#   'emphasize',
#   'continuous',
#   'nature',
#   'language',
#   'learning',
#   'and_the',
#   'frequent',
#   'practice',
#   'specialized',
#   'culture',
#   'component',
#   'students_will',
#   'explore',
#   'aspect',
#   'french',
#   'culture',
#   'society',
#   'develop',
#   'competence',
#   'year',
#   'level',
#   'theory',
#   'practices',
#   'discourses',
#   'involved',
#   'analysis'],
#  'ATS1208': ['recognise',
#   'evaluate_the',
#   'developing',
#   'role',
#   'digital',
#   'technologies',
#   'society',
#   'culture',
#   'analyse_the',
#   'impact',
#   'digital',
#   'technologies',
#   'areas',
#   'media',
#   'heritage',
#   'scholarship',
#   'examine',
#   'assess',
#   'examples',
#   'application',
#   'digital',
#   'technologies',
#   'analysis_and',
#   'dissemination',
#   'humanities',
#   'data',
#   'identify',
#   'complex',
#   'research',
#   'problems',
#   'conceptualise',
#   'interdisciplinary',
#   'approaches',
#   'communicate',
#   'effectively',
#   'utilising',
#   'traditional',
#   'innovative',
#   'means',
#   'this_unit',
#   'introduces',
#   'students',
#   'central',
#   'concepts',
#   'intersection',
#   'digital',
#   'world',
#   'range',
#   'humanistic',
#   'endeavours',
#   'case',
#   'studies',
#   'based',
#   'themes',
#   'major',
#   'examine',
#   'technological',
#   'possibilities',
#   'interacted',
#   'recent',
#   'work',
#   'scholarship',
#   'media',
#   'heritage',
#   'studies',
#   'allowing',
#   'exciting',
#   'techniques',
#   'methods',
#   'research_and',
#   'presentation',
#   'data',
#   'bases',
#   'work',
#   'data',
#   'sources',
#   'and_the',
#   'tools',
#   'investigate',
#   'communicative',
#   'possibilities',
#   'result',
#   'critically',
#   'engaging',
#   'existing',
#   'applications',
#   'field',
#   'students',
#   'this_unit',
#   'produce',
#   'digital',
#   'objects',
#   'presenting',
#   'work',
#   'exploring',
#   'impact',
#   'technological',
#   'change',
#   'field',
#   'the_unit',
#   'foster',
#   'general',
#   'understanding',
#   'impacts',
#   'inter-relation',
#   'digital',
#   'technologies',
#   'society',
#   'culture'],
#  'ATS1835': ["na'ats1835",
#   'introduction',
#   'metaphysics',
#   'deals',
#   'questions',
#   'nature',
#   'time',
#   'causation',
#   'human',
#   'freedom',
#   'personal',
#   'identity',
#   'and_the',
#   'possibility',
#   'artificial',
#   'intelligence',
#   'unusual',
#   'feature',
#   'subject',
#   'topic',
#   'introduced',
#   'science',
#   'fiction',
#   'stories',
#   'metaphysical',
#   'issues',
#   'explored',
#   'topic',
#   'takes',
#   'discussion',
#   'time',
#   'travel'],
#  'ATS2043': ['weekly',
#   'lecture',
#   'seminar',
#   'prescribed',
#   'texts',
#   'provide',
#   'basic',
#   'concepts',
#   'issues',
#   'translation',
#   'studies',
#   'general',
#   'text',
#   'analysis',
#   'the_unit',
#   'focus',
#   'basic',
#   'principles',
#   'text',
#   'analysis_and',
#   'popular',
#   'theories',
#   'relating',
#   'translation',
#   'source',
#   'texts',
#   'target',
#   'language',
#   'students',
#   'expected',
#   'improve',
#   'understanding',
#   'theories',
#   'relating',
#   'classification',
#   'identification',
#   'source',
#   'texts',
#   'translation',
#   'strategies',
#   'applying',
#   'basic',
#   'concepts',
#   'relating',
#   'text',
#   'analysis_and',
#   'translation',
#   'strategy',
#   'weekly',
#   'project-based',
#   'translation',
#   'practice',
#   'class',
#   'discussion',
#   'students',
#   'expected',
#   'improve',
#   'ability',
#   'determine',
#   'correct',
#   'translation',
#   'strategies',
#   'specific',
#   'professional',
#   'purposes',
#   'supervised',
#   'translation',
#   'projects',
#   'examination',
#   'time',
#   'controlled',
#   'situation',
#   'conducted',
#   'semesters',
#   'order',
#   'test',
#   'progress',
#   'students',
#   'number',
#   'text-analysis',
#   'focused',
#   'projects',
#   'this_unit',
#   'introduce',
#   'students',
#   'basic',
#   'conceptual',
#   'practical',
#   'issues',
#   'chinese',
#   'translation',
#   'students',
#   'identify',
#   'types',
#   'source',
#   'texts',
#   'build',
#   'skills',
#   'text',
#   'analysis_and',
#   'students',
#   'choose',
#   'correct',
#   'strategies',
#   'translating',
#   'texts',
#   'professional',
#   'purposes',
#   'project-based',
#   'exercises',
#   'this_unit',
#   'provide',
#   'opportunity',
#   'students',
#   'improve',
#   'analytical',
#   'skills_and',
#   'understanding',
#   'factors',
#   'affect',
#   'translation',
#   'source',
#   'texts',
#   'target',
#   'language',
#   'integration',
#   'classroom',
#   'teaching',
#   'translation',
#   'projects',
#   'encourages',
#   'students',
#   'apply_the',
#   'theories',
#   'skills',
#   'learnt',
#   'class',
#   'translation',
#   'practices'],
#  'ATS2250': ['exposed',
#   'competent',
#   'understanding',
#   'contemporary',
#   'scholarship',
#   'relationships',
#   'communications',
#   'culture',
#   'acquired',
#   'informed',
#   'understanding',
#   'worldviews',
#   'impact',
#   'communications',
#   'understand_the',
#   'processes',
#   'immigrants',
#   'economic',
#   'cultural',
#   'adaptations',
#   'part',
#   'development',
#   'effective',
#   'intercultural',
#   'communications',
#   'obtained',
#   'in-depth',
#   'understanding',
#   'nonverbal',
#   'communications',
#   'developed',
#   'greater',
#   'capacities',
#   'deal',
#   'inter-ethnic',
#   'tension',
#   'effective',
#   'communications',
#   'understand',
#   'range',
#   'theories',
#   'intercultural',
#   'communications',
#   'cultural',
#   'convergence',
#   'theory',
#   'identity',
#   'management',
#   'theory',
#   'identity',
#   'negotiation',
#   'theory',
#   'communication',
#   'accommodation',
#   'theory',
#   'cultural',
#   'schema',
#   'theory',
#   'acquired',
#   'informed',
#   'understanding',
#   'ethnic',
#   'identities',
#   'immigrant',
#   'life',
#   'represented',
#   'range',
#   'media',
#   'the_unit',
#   'covers',
#   'people',
#   'cultural',
#   'backgrounds',
#   'communicate',
#   'miscommunicate',
#   'and_how',
#   'overcome',
#   'difficulties',
#   'resulting',
#   'cultural',
#   'diversities'],
#  'ATS2275': ['explain',
#   'analyse_the',
#   'dynamics',
#   'european',
#   'integration',
#   'end',
#   'world',
#   'war',
#   'identify_and',
#   'explain_the',
#   'origins',
#   'european',
#   "union's",
#   'current',
#   'crises',
#   'global',
#   'context',
#   'identify_and',
#   'appraise',
#   'architecture',
#   'european',
#   'union',
#   'and_how',
#   'shapes',
#   'responses',
#   'current',
#   'crises',
#   'distinguish',
#   'european',
#   'national',
#   'responses',
#   'crises',
#   'and_the',
#   'inter-play',
#   'levels',
#   'european',
#   'union',
#   'governance',
#   'integrate',
#   'set',
#   'academic',
#   'literature',
#   'european',
#   'integration',
#   'theory',
#   'history',
#   'european',
#   'politics',
#   'international',
#   'relations',
#   'undertake',
#   'research',
#   'analysis',
#   'important',
#   'aspect',
#   'european',
#   'integration',
#   'major',
#   'policy',
#   'area',
#   'utilising',
#   'primary',
#   'secondary-source',
#   'materials',
#   'written',
#   'feedback',
#   'european',
#   'union',
#   'unique',
#   'historic',
#   'political',
#   'achievement',
#   'helped',
#   'turn',
#   'europe',
#   'zone',
#   'peace',
#   'contributed',
#   'consolidation',
#   'democracy',
#   'post-fascist',
#   'communist',
#   'eras',
#   'polity',
#   'profound',
#   'crisis',
#   'challenged',
#   'critics',
#   'democratic',
#   'credentials',
#   'wake',
#   'eurozone',
#   'crisis',
#   'security',
#   'threats',
#   'resurgent',
#   'russia',
#   'influx',
#   'refugees',
#   'students',
#   'completing',
#   'this_unit',
#   'prato',
#   'gain',
#   'deep',
#   'understanding',
#   'origins',
#   "today's",
#   'european',
#   'union',
#   'and_the',
#   'pathologies',
#   'multiple',
#   'crises',
#   'simulate',
#   'policy',
#   'paths',
#   "eu's",
#   'wicked',
#   'problems',
#   'leave',
#   'prato',
#   'equipped',
#   'respond',
#   'global',
#   'repercussions',
#   'challenges',
#   'facing',
#   'world'],
#  'ATS2385': ['demonstrate',
#   'critical',
#   'understanding',
#   'history',
#   "australia's",
#   'involvement',
#   'war',
#   'and_the',
#   'significance',
#   'involvement',
#   'interrogated',
#   'mythologies',
#   'grown',
#   'anzac',
#   'exhibit',
#   'in-depth',
#   'understanding',
#   'lived',
#   'experience',
#   'war',
#   'ability',
#   'interrogate',
#   'personal',
#   'testimonies',
#   'show',
#   'awareness',
#   'historical',
#   'social',
#   'context',
#   "australia's",
#   'involvement',
#   'campaigns',
#   'and_how',
#   'redefined',
#   "australia's",
#   'relationship',
#   'with_the',
#   'region',
#   'and_the',
#   'world',
#   'built',
#   'capacity',
#   'research_and',
#   'critically_evaluate',
#   'topical',
#   'historiographical',
#   'debates',
#   'impact',
#   'war',
#   'australian',
#   'identity',
#   'society',
#   'developed',
#   'skills',
#   'constructing',
#   'evidence-based',
#   'arguments',
#   'variety',
#   'primary',
#   'secondary',
#   'sources',
#   'demonstrated',
#   'ability',
#   'reflect',
#   'critically',
#   'learnt',
#   'developed',
#   'skills',
#   'written',
#   'oral',
#   'presentation',
#   'communication',
#   'war',
#   'shaped',
#   'australians',
#   'australian',
#   'society',
#   'war',
#   'central',
#   'national',
#   'mythology',
#   'identity',
#   'this_unit',
#   'explores',
#   'experience',
#   'australians',
#   'war',
#   'overseas',
#   'home',
#   'front',
#   'confrontations',
#   'indigenous',
#   'australians',
#   'european',
#   'settlers',
#   'colonial',
#   'frontier',
#   'major',
#   'conflicts',
#   'twentieth',
#   'century',
#   'focus',
#   'world',
#   'wars',
#   'examine',
#   'face',
#   'battle',
#   'and_how',
#   'war',
#   'affected',
#   'men',
#   'women',
#   'front',
#   'line',
#   'including',
#   'indigenous',
#   'servicemen',
#   'war',
#   'experienced',
#   'home',
#   'front',
#   'reshaped',
#   'australian',
#   'society',
#   'explore',
#   'contested',
#   'creation',
#   'anzac',
#   'legend',
#   'and_how',
#   'war',
#   'challenged',
#   'consolidated',
#   'social',
#   'relations',
#   'national',
#   'identities',
#   'students_will',
#   'undertake',
#   'hands-on',
#   'research',
#   'rich',
#   'primary',
#   'source',
#   'record',
#   'australians',
#   'war',
#   'including',
#   'service',
#   'records',
#   'diaries',
#   'letters',
#   'oral',
#   'histories',
#   'photographs',
#   'repatriation',
#   'files',
#   'illuminate',
#   'impact',
#   'war',
#   'veterans',
#   'families',
#   'and_their',
#   'communities'],
#  'ATS2394': ['demonstrate',
#   'critical',
#   'understanding',
#   'breadth',
#   'complexity',
#   "australia's",
#   'contacts',
#   'asia',
#   'diplomatic',
#   'economic',
#   'social',
#   'cultural',
#   'levels',
#   'exhibit',
#   'understanding',
#   'ways',
#   'past',
#   'encounters',
#   'discourses',
#   'policies',
#   'affect',
#   'contemporary',
#   'cross-cultural',
#   'international',
#   'relations',
#   'attained',
#   'understanding',
#   'impacts',
#   'representation',
#   'discourse',
#   'shaping',
#   'international',
#   'relations',
#   'developed',
#   'capacity',
#   'reflect',
#   'implications',
#   'personal',
#   'attitudes',
#   'views',
#   'broader',
#   'patterns',
#   'culture',
#   'discourse',
#   'developed',
#   'skills',
#   'constructing',
#   'evidence-based',
#   'arguments',
#   'variety',
#   'primary',
#   'secondary',
#   'sources',
#   'demonstrated',
#   'ability',
#   'reflect',
#   'critically',
#   'learnt',
#   'developed',
#   'skills',
#   'written',
#   'oral',
#   'presentation',
#   'communication',
#   'developed',
#   'capacity',
#   'undertake',
#   'location-based',
#   'fieldwork',
#   'enhancing',
#   'personal',
#   'resilience',
#   'and_the',
#   'capacity',
#   'work',
#   'cooperatively',
#   'teams',
#   'conduct',
#   'independent',
#   'research',
#   'students',
#   'taking',
#   'this_unit',
#   'level',
#   '3',
#   'demonstrate',
#   'higher',
#   'level',
#   'skills',
#   'independent',
#   'research_and',
#   'critical',
#   'analysis',
#   'this_unit',
#   'examines',
#   "australia's",
#   'past',
#   'present',
#   'relations',
#   'asia',
#   'culminating',
#   'study',
#   'tour',
#   'asian',
#   'country',
#   'traverses',
#   'broad',
#   'terrain',
#   'investigating',
#   'cross-cultural',
#   'contact',
#   'political',
#   'diplomatic',
#   'economic',
#   'trade',
#   'cultural',
#   'personal',
#   'levels',
#   'the_unit',
#   'places',
#   'contemporary',
#   'events',
#   'broader',
#   'historical',
#   'contexts',
#   'identify',
#   'enduring',
#   'themes',
#   'influence',
#   'australian-asian',
#   'relations',
#   'ahead',
#   'future',
#   'developments',
#   'australia',
#   'negotiates',
#   'asian',
#   'century',
#   'the_unit',
#   'begins',
#   'australia',
#   'students',
#   'embark',
#   'study',
#   'tour',
#   'asian',
#   'nation',
#   'gain',
#   'in-depth',
#   'awareness',
#   'complex',
#   'social',
#   'cultural',
#   'political',
#   'context',
#   'asia',
#   'and_how',
#   'australia',
#   'fits',
#   'regional',
#   'frame'],
#  'ATS2422': ['develop',
#   'general',
#   'understanding',
#   'ways',
#   'thinking',
#   'writing',
#   'history',
#   'nationhood',
#   'god',
#   'nature',
#   'art',
#   'and_the',
#   'articulated',
#   'romantic',
#   'thinkers',
#   'gain',
#   'in-depth',
#   'knowledge',
#   'work',
#   'romantic',
#   'writers',
#   'aware',
#   'ongoing',
#   'legacy',
#   'romanticism',
#   'literature',
#   'culture',
#   'develop',
#   'skills',
#   'areas',
#   'literary',
#   'research',
#   'textual',
#   'analysis_and',
#   'interpretation',
#   'communication',
#   'oral',
#   'written',
#   'the_unit',
#   'introduce',
#   'students',
#   'forms',
#   'representation',
#   'ways',
#   'thinking',
#   'emerged',
#   'europe',
#   'from_the',
#   'late',
#   'eighteenth',
#   'century',
#   'termed',
#   'romanticism',
#   'focus',
#   'romantic',
#   'conceptualisations',
#   'literature',
#   'history',
#   'nationhood',
#   'god',
#   'nature',
# ...
#   'analysing',
#   'patient',
#   'care',
#   'management',
#   'strategies',
#   'related',
#   'body',
#   'systems',
#   'demonstrating',
#   'provision',
#   'beginner',
#   'level',
#   'multi-disciplinary',
#   'patient',
#   'care',
#   'management',
#   'communication_and',
#   'professional',
#   'skills',
#   'range',
#   'patients',
#   'describe_the',
#   'process',
#   '3d',
#   'datasets',
#   'generated',
#   'evaluate_the',
#   'clinical',
#   '3d',
#   'images',
#   'planning',
#   'verification',
#   'describe',
#   'detail',
#   'and_apply',
#   'principles',
#   'radiation',
#   'safety',
#   'quality',
#   'management',
#   'occupational',
#   'health_and',
#   'safety',
#   'appraise',
#   'protocols',
#   'procedures',
#   'legal',
#   'requirements',
#   'incident',
#   'reporting',
#   'appraise',
#   'imaging',
#   'modalities',
#   'treatment',
#   'verification',
#   'demonstrate',
#   'beginner',
#   'level',
#   'image',
#   'matching',
#   'analyse_and',
#   'synthesis',
#   'principles',
#   'clinical',
#   'applications',
#   'plan',
#   'evaluation',
#   'tools',
#   'demonstrating',
#   'beginner',
#   'level',
#   'evaluate_the',
#   'rationale',
#   'beam',
#   'modification',
#   'accessories',
#   'describe',
#   'discuss',
#   'effective',
#   'respectful',
#   'working',
#   'collaborations',
#   'with_the',
#   'multi-disciplinary',
#   'team',
#   'this_unit',
#   'units',
#   'dealing',
#   'specifically',
#   'with_the',
#   'principles',
#   'applications',
#   'radiation',
#   'therapy',
#   'planning',
#   'treatment',
#   'this_unit',
#   'cover',
#   'loco-motor',
#   'lymphatic',
#   'cardio-vascular',
#   'haematological',
#   'systems',
#   'addition',
#   'students_will',
#   'analyse_and',
#   'evaluate_the',
#   'principles',
#   'quality',
#   'assurance',
#   'and_how',
#   'relate',
#   'practice',
#   'radiation',
#   'therapy',
#   'students_will',
#   'gain',
#   'in-depth',
#   'knowledge',
#   'the_role',
#   'applications',
#   'image',
#   'verification',
#   'radiation',
#   'therapy',
#   'treatment',
#   'delivery',
#   'students_will',
#   'analyse_and',
#   'evaluate',
#   'radiation',
#   'therapy',
#   'beam',
#   'modification',
#   'devices',
#   'planning',
#   'evaluation',
#   'tools',
#   'this_unit',
#   'includes',
#   'week',
#   'clinically',
#   'oriented',
#   'simulated',
#   'learning',
#   'week',
#   'clinical',
#   'placement',
#   'students',
#   'develop',
#   'clinical',
#   'professional',
#   'skills',
#   'beginner',
#   'intermediate',
#   'beginner',
#   'level',
#   'whilst',
#   'studying',
#   'topics',
#   'students_will',
#   'encouraged',
#   'critically',
#   'reflect',
#   'analyse_and',
#   'synthesis',
#   'relevant',
#   'information',
#   'from_the',
#   'literature',
#   'reflect',
#   'clinical',
#   'experiences'],
#  'SCI3716': ['discuss',
#   'selected',
#   'issues',
#   'managing',
#   'scientific',
#   'laboratory',
#   'describe',
#   'obligations',
#   'occupational',
#   'health_and',
#   'safety',
#   'act',
#   'related',
#   'legislation',
#   'recognise',
#   'hazards',
#   'associated_with',
#   'chemical',
#   'biological',
#   'materials',
#   'instruments',
#   'ionising',
#   'radiation',
#   'and_the',
#   'risks',
#   'impose',
#   'undertake',
#   'risk',
#   'assessment',
#   'recommend',
#   'safe',
#   'working',
#   'procedures',
#   'outline',
#   'legislated',
#   'obligations',
#   'recycling',
#   'disposal',
#   'hazardous',
#   'materials',
#   'apply_the',
#   'principles',
#   'chemistry',
#   'biology',
#   'microbiology',
#   'physical',
#   'science',
#   'treatment',
#   'hazardous',
#   'materials',
#   'discuss',
#   'effects',
#   'waste',
#   'materials',
#   'environment',
#   'recommend',
#   'procedures',
#   'for_the',
#   'analysis_and',
#   'treatment',
#   'hazardous',
#   'wastes',
#   'disposal',
#   'environment',
#   'this_unit',
#   'designed',
#   'introduce',
#   'intending',
#   'scientists',
#   'principles',
#   'laboratory',
#   'workplace',
#   'management',
#   'and_their',
#   'obligations',
#   'experts',
#   'supervisors',
#   'cover',
#   'legislation',
#   'and_the',
#   'responsibilities',
#   'employers',
#   'employees',
#   'issues',
#   'occupational',
#   'health_and',
#   'safety',
#   'handling',
#   'dangerous',
#   'goods',
#   'and_the',
#   'analysis',
#   'treatment',
#   'disposal',
#   'hazardous',
#   'materials',
#   'emphasis',
#   'assessment',
#   'management',
#   'issues',
#   'laboratory',
#   'workplace',
#   'environment',
#   'subject',
#   'taught',
#   'programmed',
#   'learning',
#   'material',
#   'practical',
#   'work',
#   'consisting',
#   'assessment',
#   'discussion',
#   'case',
#   'studies',
#   'workplace',
#   'excursions'],
#  'SWK3220': ['describe_the',
#   'nature',
#   'social',
#   'work',
#   'range',
#   'contexts',
#   'settings',
#   'describe',
#   'contemporary',
#   'debates',
#   'nature',
#   'social',
#   'work',
#   'critically',
#   'analyse_the',
#   'ethical',
#   'base',
#   'social',
#   'work',
#   'reference',
#   'human',
#   'rights',
#   'and_the',
#   'promotion',
#   'social',
#   'justice',
#   'critically',
#   'analyse',
#   'key',
#   'global',
#   'social',
#   'policy',
#   'issues',
#   'including',
#   'limited',
#   'mass',
#   'movement',
#   'people',
#   'climate',
#   'change',
#   'reconstruction',
#   'poverty',
#   'critically',
#   'review',
#   'analyse',
#   'contemporary',
#   'trends',
#   'delivery',
#   'social',
#   'work',
#   'services',
#   'articulate',
#   'nature',
#   'social',
#   'change',
#   'and_the',
#   'strategies',
#   'achieve',
#   'this_unit',
#   'offers',
#   'overview',
#   'history',
#   'contemporary',
#   'context',
#   'social',
#   'work',
#   'practice',
#   'framework',
#   'understanding',
#   'connection',
#   'social',
#   'issues',
#   'policy',
#   'development',
#   'strategies',
#   'sustainable',
#   'change',
#   'local',
#   'global',
#   'levels',
#   'the_unit',
#   'underpinned',
#   'notions',
#   'social',
#   'justice',
#   'human',
#   'rights',
#   'offers',
#   'preview',
#   'topics',
#   'studied',
#   'greater',
#   'depth',
#   'subsequent',
#   'units'],
#  'SWM5170': ['work',
#   'collaboratively',
#   'academic',
#   'supervisor',
#   'the_development',
#   'assessment',
#   'topic',
#   'completion',
#   'assessment',
#   'integrate',
#   'research',
#   'knowledge',
#   'past',
#   'present',
#   'professional',
#   'experience',
#   'work',
#   'collaboratively',
#   'academic',
#   'supervisor',
#   'the_development',
#   'assessment',
#   'topic',
#   'completion',
#   'assessment',
#   'combine',
#   'advanced',
#   'specialised',
#   'research',
#   'knowledge',
#   'skills',
#   'develop',
#   'research-based',
#   'practice',
#   'clinical',
#   'program',
#   'policy',
#   'levels',
#   'articulate',
#   'specialised',
#   'practice',
#   'knowledge',
#   'skills',
#   'developing',
#   'the_research',
#   'report',
#   'evaluation',
#   'report',
#   'assignment',
#   'develop',
#   'appraise',
#   'personal',
#   'role',
#   'professional',
#   'social',
#   'work',
#   'practitioner-researcher',
#   'develop',
#   'appraise',
#   'personal',
#   'role',
#   'professional',
#   'social',
#   'work',
#   'practitioner-researcher',
#   'prepare',
#   'report',
#   'suitable',
#   "publication'unit",
#   'content',
#   'developed',
#   'student',
#   'appointed',
#   'staff',
#   'supervisor',
#   'piece',
#   'assessment',
#   'developed',
#   'completed',
#   'student',
#   'this_unit'],
#  'TAD2214': ['recognise',
#   'key',
#   'works',
#   'design_and',
#   'relationship',
#   'critical',
#   'issues',
#   'demonstrate',
#   'understanding',
#   'influence',
#   'impact',
#   'physical',
#   'social',
#   'cultural',
#   'concerns',
#   'the_role',
#   'designer',
#   'and_the',
#   'design',
#   'product',
#   'demonstrate',
#   'critical',
#   'analytical',
#   'skills',
#   'interpretation',
#   'appreciation',
#   'works',
#   'design',
#   'articulate',
#   'evaluative',
#   'responses',
#   'significance',
#   'ideological',
#   'cultural',
#   'forces',
#   'work',
#   'design',
#   'critique',
#   'multiple',
#   'perspectives',
#   'for_the',
#   'interpretation',
#   'design',
#   'understand',
#   'apply_the',
#   'rules',
#   'occupational',
#   'health_and',
#   'safety',
#   'the_unit',
#   'study',
#   'this_unit',
#   'investigates',
#   'visual',
#   'theoretical',
#   'languages',
#   'design',
#   'relation',
#   'number',
#   'key',
#   'critical',
#   'issues',
#   'focuses',
#   'issues',
#   'including',
#   'engagement',
#   'works',
#   'design',
#   'society',
#   'consumerism',
#   'gender',
#   'politics',
#   'and_the',
#   'environment',
#   'the_role',
#   'designer',
#   'responding',
#   'aesthetic',
#   'social',
#   'challenges',
#   'considered',
#   'students_will',
#   'continue',
#   'develop',
#   'range',
#   'approaches',
#   'understanding',
#   'works',
#   'design_and',
#   'related',
#   'issues',
#   'refining',
#   'broader',
#   'critical',
#   'analytical',
#   'skills',
#   'disciplines'],
#  'TDN1002': ['identify_and',
#   'describe_the',
#   'major',
#   'movements',
#   'modernism',
#   'design',
#   'recognise',
#   'analyse',
#   'key',
#   'examples',
#   'practices',
#   'design',
#   'discuss',
#   'legacy',
#   'european',
#   'avant-gardes',
#   'and_their',
#   'lasting',
#   'influence',
#   'social',
#   'role',
#   'designer',
#   'translate',
#   'basic',
#   'theoretical',
#   'contexts',
#   'practice',
#   'critique',
#   'works',
#   'design_and',
#   'articulate',
#   'analyses',
#   'spoken',
#   'written',
#   'form',
#   'identify',
#   'questions',
#   'ways',
#   'search',
#   'information',
#   'this_unit',
#   'examines',
#   'history',
#   'european',
#   'modernism',
#   'relates',
#   'disciplines',
#   'visual',
#   'communication',
#   'industrial',
#   'design_and',
#   'spatial',
#   'design',
#   'key',
#   'modernist',
#   'movements',
#   'practices',
#   'studied',
#   'consideration',
#   'ideological',
#   'political',
#   'cultural',
#   'contexts',
#   'motives',
#   'critical',
#   'tendencies',
#   'twentieth-century',
#   'avant-garde',
#   'practices',
#   'considered',
#   'terms',
#   'lasting',
#   'implications',
#   'for_the',
#   'social',
#   'role',
#   'design',
#   'students_will',
#   'develop',
#   'range',
#   'critical',
#   'approaches',
#   'analysing',
#   'design',
#   'relation',
#   'historical',
#   'social',
#   'cultural',
#   'context',
#   'skills',
#   'disciplines',
#   'practice'],
#  'UPD4002': ['demonstrate',
#   'capabilities',
#   'competencies',
#   'ethical',
#   'approaches',
#   'contemporary',
#   'urban',
#   'planning',
#   'the_ability',
#   'strategically',
#   'respond',
#   'complex',
#   'problems',
#   'develop',
#   'planning',
#   'responses',
#   'processes',
#   'outcomes',
#   'developed',
#   'skills',
#   'research',
#   'applying',
#   'creativity',
#   'critique',
#   'address',
#   'planning',
#   'issues',
#   'acquired',
#   'high',
#   'level',
#   'competence',
#   'communication_and',
#   'presentation',
#   'skills',
#   'written',
#   'verbal',
#   'graphic',
#   'understand',
#   'apply_the',
#   'rules',
#   'occupational',
#   'health_and',
#   'safety',
#   'the_unit',
#   'study',
#   'project',
#   '2',
#   'explores',
#   'creation',
#   'ecologically',
#   'sensitive',
#   'cities',
#   'projects',
#   'coordinate',
#   'built',
#   'natural',
#   'systems',
#   'shape',
#   'cities',
#   'students',
#   'develop',
#   'research',
#   'foundations',
#   'technical',
#   'capacity',
#   'analytical',
#   'approaches',
#   'modes',
#   'articulation',
#   'planning',
#   'systems'],
#  'UPD5001': ['critically',
#   'reflect',
#   'practice',
#   'ethical',
#   'approaches',
#   'contemporary',
#   'urban',
#   'planning',
#   'strategically',
#   'respond',
#   'complex',
#   'problems',
#   'related',
#   'urban',
#   'sprawl',
#   'apply',
#   'skills',
#   'research',
#   'address',
#   'metropolitan',
#   'planning',
#   'issues',
#   'communicate',
#   'written',
#   'verbal',
#   'graphic',
#   'formats',
#   'issues',
#   'pertaining',
#   'urban',
#   'sprawl',
#   'understand',
#   'apply_the',
#   'rules',
#   'occupational',
#   'health_and',
#   'safety',
#   'the_unit',
#   'study',
#   'planning',
#   'project',
#   '3',
#   'sprawling',
#   'city',
#   'considers',
#   'the_role',
#   'metropolitan',
#   'planning',
#   'addressing',
#   'issues',
#   'associated_with',
#   'urban',
#   'sprawl',
#   'the_unit',
#   'expands',
#   'consolidates',
#   'advanced',
#   'concepts',
#   'knowledge',
#   'skills',
#   'encompassing',
#   'range',
#   'complex',
#   'issues',
#   'relevant',
#   'practising',
#   'urban',
#   'planning',
#   'metropolitan',
#   'level',
#   'critical',
#   'research',
#   'analysis_and',
#   'synthesis',
#   'undertaken',
#   'real',
#   'spatial',
#   'settings',
#   'the_unit',
#   'develops',
#   'concepts',
#   'creative',
#   'approaches',
#   'processes',
#   'outcomes',
#   'and_the',
#   'skills',
#   'communicate',
#   'effectively',
#   'diverse',
#   'communities'],
#  'UPD5002': ['critically',
#   'reflect',
#   'practice',
#   'ethical',
#   'approaches',
#   'contemporary',
#   'urban',
#   'planning',
#   'diverse',
#   'communities',
#   'strategically',
#   'respond',
#   'complex',
#   'problems',
#   'develop',
#   'planning',
#   'responses',
#   'processes',
#   'outcomes',
#   'pertinent',
#   'social',
#   'community',
#   'planning',
#   'apply',
#   'skills',
#   'research',
#   'address',
#   'social',
#   'community',
#   'planning',
#   'issues',
#   'communicate',
#   'written',
#   'verbal',
#   'graphic',
#   'formats',
#   'social',
#   'community',
#   'planning',
#   'issues',
#   'understand',
#   'apply_the',
#   'rules',
#   'occupational',
#   'health_and',
#   'safety',
#   'the_unit',
#   'study',
#   'planning',
#   'project',
#   '4',
#   'inclusive',
#   'city',
#   'focusses',
#   'issues',
#   'pertinent',
#   'social',
#   'community',
#   'planning',
#   'address',
#   'challenge',
#   'creating',
#   'people-centred',
#   'cities',
#   'the_unit',
#   'expands',
#   'consolidates',
#   'advanced',
#   'concepts',
#   'knowledge',
#   'skills',
#   'encompassing',
#   'range',
#   'complex',
#   'issues',
#   'relevant',
#   'practising',
#   'urban',
#   'planning',
#   'critical',
#   'research',
#   'analysis_and',
#   'synthesis',
#   'undertaken',
#   'real',
#   'spatial',
#   'settings',
#   'the_unit',
#   'develops',
#   'concepts',
#   'creative',
#   'approaches',
#   'processes',
#   'outcomes',
#   'and_the',
#   'skills',
#   'communicate',
#   'effectively',
#   'diverse',
#   'communities'],
#  'VCM4029': ['utilise',
#   'range',
#   'systems',
#   'analysis',
#   'design',
#   'methodologies',
#   'and_their',
#   'tools',
#   'principles',
#   'understand_the',
#   'main',
#   'participants',
#   'and_their',
#   'roles',
#   'the_development',
#   'interactive',
#   'systems',
#   'apply',
#   'quality',
#   'assurance',
#   'techniques',
#   'for_the',
#   'analysis',
#   'design',
#   'implementation',
#   'maintenance',
#   'interactive',
#   'systems',
#   'understand_the',
#   'advantages',
#   'disadvantages',
#   'alternative',
#   'approaches',
#   'systems',
#   'analysis_and',
#   'design',
#   'convert',
#   'requirement',
#   'analysis',
#   'models',
#   'design',
#   'models',
#   'represent',
#   'workable',
#   'solution',
#   'system',
#   'prepare',
#   'analysis_and',
#   'design',
#   'documentation',
#   'interactive',
#   'system',
#   'apply',
#   'sound',
#   'programming',
#   'principles',
#   'interactive',
#   'scripting',
#   'language',
#   'develop',
#   'skills',
#   'team',
#   'collaboration',
#   'this_unit',
#   'examine',
#   'activities',
#   'integral',
#   'the_development',
#   'interactive',
#   'systems',
#   'detailing',
#   'techniques',
#   'systems',
#   'analysis_and',
#   'design',
#   'the_development',
#   'process',
#   'fundamental',
#   'programming',
#   'concepts',
#   'introduced',
#   'interactive-media',
#   'scripting',
#   'language',
#   'framework',
#   'mechanism',
#   'system',
#   'development',
#   'students_will',
#   'involved',
#   'mixture',
#   'individual',
#   'group-based',
#   'work',
#   'require',
#   'application',
#   'theoretical',
#   'knowledge',
#   'gained',
#   'lectures',
#   'series',
#   'practical',
#   'problems',
#   'interactive',
#   'systems',
#   'development'],
#  'VCM4601': ['recognise',
#   'analyse_and',
#   'elements',
#   'design',
#   'understand_the',
#   'role',
#   'visual',
#   'communication_and',
#   'fundamental',
#   'design',
#   'principles',
#   'applied',
#   'multimedia',
#   'media',
#   'recognise',
#   'theoretical',
#   'psychological',
#   'issues',
#   'selected',
#   'colour',
#   'theories',
#   'understand',
#   'and_apply',
#   'selected',
#   'colour',
#   'theories',
#   'digital',
#   'media',
#   'recognise',
#   'analyse_and',
#   'typography',
#   'express',
#   'ideas',
#   'concepts',
#   'multimedia',
#   'visual',
#   'communication',
#   'forms',
#   'drawing',
#   'digital',
#   'imaging',
#   'graphic',
#   'design_and',
#   'typography',
#   'observe',
#   'employ',
#   'occupational',
#   'health_and',
#   'safety',
#   'studio',
#   'practice',
#   'students',
#   'introduced',
#   'fundamental',
#   'elements',
#   'principles',
#   'three-dimensional',
#   'design',
#   'applied',
#   'multimedia',
#   'students',
#   'gain',
#   'design',
#   'skills_and',
#   'knowledge',
#   'produce',
#   'complex',
#   'integrations',
#   'selected',
#   'principles',
#   'design',
#   'form',
#   'solid',
#   'basis',
#   'support',
#   'visual',
#   'communications',
#   'screen',
#   'based',
#   'media',
#   'set',
#   'projects',
#   'encourage',
#   'experimentation',
#   'techniques',
#   'methods',
#   'interpretation']}

# %% [markdown]
# #### The following function returns all unique cleaned stop words as a key-value pairing.

# %%
def clean_stop_words_sort(key):
    unique_stop_words_cleaned = set(cleaned_stop_words[key])
    return(key,unique_stop_words_cleaned)

cleaned_stpwrds_list =  dict(clean_stop_words_sort(key) for key,values in cleaned_stop_words.items())
removed_stop_words_list = list(chain.from_iterable(cleaned_stpwrds_list.values()))

# %% [markdown]
# #### The frequency distribution of all the removed stop words are calculated as key value pairings with the key showing the token and the value showing their frequency

# %%
from nltk.probability import FreqDist
FreqDist(removed_stop_words_list)
# Out:
# FreqDist({'this_unit': 105, 'skills': 84, 'students': 82, 'and_the': 77, 'research': 73, 'develop': 73, 'the_unit': 73, 'issues': 70, 'understanding': 70, 'demonstrate': 65, ...})

# %% [markdown]
# #### This code block is making a list of all the rare tokens which appear either in less than 5% or more than 95% of the documents (units). This is calculated from the frequency distribution of the removed_stop_words_list

# %%
#making a list of all the rare tokens which appear either less than 5% or more than 95% of the documents
#this is calculated from the frequency distribution of the removed_stop_words_list
rare_tokens = []
count=0
freq_stop_words= FreqDist(removed_stop_words_list)

less_than_5 = int(0.05*len(unit_numbers))
more_than_95 = int(0.95*len(unit_numbers))

for key,value in freq_stop_words.items():
    if (value < less_than_5 or value > more_than_95):
        rare_tokens.append(key)

# %%
rare_tokens
# Out:
# ['express',
#  'labs',
#  'senior',
#  'reflections',
#  'overview',
#  'lawyers',
#  'regulation',
#  'haematological',
#  'dependence',
#  'innovation',
#  'nazi',
#  'childbirth',
#  'special',
#  'serialism',
#  'carried',
#  'generated',
#  'inter',
#  'extratropical',
#  'phase',
#  'contaminant',
#  'disk',
#  'illustrate',
#  'causation',
#  'lived',
#  'advocacy',
#  'tract',
#  'individuals',
#  "professionalism'building",
#  'nature-based',
#  'devise',
#  'derivative',
#  'artists',
#  'buildings',
#  'judge',
#  'isolated',
#  'forge',
#  'comparative',
#  'general',
#  'vicarious',
#  'increasing',
#  'threads',
#  'contained',
#  'classifying',
#  'youth-focused',
#  'funding',
#  'exciting',
#  'modes',
#  'ecology',
#  'extended',
#  'economies',
#  'anatomy',
#  'occurrence',
#  'advertising',
#  'young',
#  'flexible',
#  'execute',
#  'packet-switching',
#  'theorists',
#  'layout',
#  'europe',
#  'anthropological',
#  'well-argued',
#  'discussed',
#  'capacitance',
#  'emphasise',
#  'nutrients',
#  'scope',
#  'finishing',
#  'cooperation',
#  'appropriateness',
#  'obey',
#  'sustains',
#  'family-based',
#  'interpersonal',
#  'technology',
#  'powerful',
#  'potential',
#  'sociological',
#  'played',
#  'drug',
#  'diets',
#  'ethnoecology',
#  'humour',
#  'taxation',
#  'identities',
#  'prepares',
#  'segregation',
#  'educational',
#  'spreads',
#  'seminal',
#  'nii',
#  'adolescent',
#  'discriminate',
#  'attributes',
#  'gaps',
#  'avenue',
#  'nuanced',
#  'density',
#  'windows',
#  'connections',
#  'maximum',
#  'outbreaks',
#  'mode',
#  'protocol',
#  'involve',
#  'customisable',
#  'western',
#  'grounded',
#  'knowing',
#  "lacan's",
#  'prominence',
#  'idea',
#  'banks',
#  "student's",
#  'investigates',
#  'congestion',
#  'lateral',
#  'past',
#  'conditioning',
#  'inclusive',
#  'match',
#  'improving',
#  'exploration',
#  'experienced',
#  "patient's",
#  'copula',
#  'time',
#  'modelling',
#  'sheet',
#  'virtual',
#  'reduction',
#  'requiring',
#  'locate',
#  'consulting',
#  'pre-recorded',
#  'refraction',
#  'entrepreneurs',
#  'enquiry',
#  'located',
#  'implementing',
#  'reason',
#  'bioethical',
#  'strength',
#  'powder',
#  'empirical',
#  'directed',
#  'nuisance',
#  'site',
#  'continuum',
#  'supporting',
#  'ptsd',
#  'challenged',
#  'displaying',
#  'large',
#  'intonation',
#  'japan',
#  'blend',
#  'centred',
#  'terminals',
#  'experts',
#  'compression',
#  'exercises',
#  'advertisements',
#  'pivotal',
#  'code',
#  'organizations',
#  'total',
#  'satisfaction',
#  'algebra',
#  'requirements',
#  'essence',
#  'ecological',
#  'insight',
#  'narratives',
#  'intake',
#  'work-related',
#  'surgery',
#  'minimum',
#  'composite',
#  'lectures',
#  'remediate',
#  'face',
#  'scholars',
#  'japanese-language',
#  'enduring',
#  'alternative',
#  'intervention',
#  'managers',
#  "world's",
#  'commercializing',
#  'constructing',
#  'generate',
#  'marketing',
#  'heighten',
#  'autonomy',
#  'finance',
#  'preparing',
#  'culminating',
#  'disadvantage',
#  'sponsorship',
#  'niv',
#  'practiced',
#  'therapy',
#  'verbally',
#  'text-analysis',
#  'judicial',
#  'dario',
#  'cd-rom',
#  'teach',
#  'attendance',
#  'clarity',
#  'possibility',
#  'efficient',
#  'shape',
#  'brazil',
#  'attend',
#  'presented',
#  'explosion',
#  'democratic',
#  'recent',
#  'location',
#  'piece',
#  'comprehend',
#  'theorem',
#  'brings',
#  'scholarship',
#  'satisfying',
#  'restrictive',
#  'reheat',
#  'eye',
#  'cardio-vascular',
#  'principal',
#  'correlate',
#  'ethically',
#  'advantage',
#  'criteria',
#  'vulnerability',
#  'articulated',
#  'nur4402',
#  'dominating',
#  'wound',
#  'beginner',
#  'journalistic',
#  'schools',
#  'leader',
#  'stability',
#  'coursework',
#  'music',
#  'engine',
#  'poles',
#  'feedback',
#  'screen',
#  'affect',
#  'skin',
#  'store',
#  'mass-casualty',
#  'nnupon',
#  'surrounding',
#  'complements',
#  'affected',
#  "individual's",
#  'transactions',
#  'direction',
#  'psychosocial',
#  'micronutrients',
#  'mca',
#  'approached',
#  'simplicity',
#  'established',
#  'designing',
#  'ramifications',
#  'corporate',
#  'deconstructing',
#  'interviewing',
#  'morphological',
#  'screen-based',
#  'appointed',
#  'influences',
#  'polymeric',
#  'combination',
#  'refusal',
#  'independence',
#  'relative',
#  'surface',
#  'x-rays',
#  'historiographical',
#  'situation',
#  'violence',
#  'primarily',
#  'civilisation',
#  "fo's",
#  'altman',
#  'made',
#  'chosen',
#  'fast-paced',
#  'distributions',
#  'paramedic',
#  'shifts',
#  'selections',
#  'foundations',
#  'protocols',
#  'maintain',
#  'commodity',
#  'flows',
#  'client-orientated',
#  'assists',
#  'managing',
#  'ghettos',
#  'speculations',
#  'small',
#  'genocide',
#  'supervisors',
#  'ordinary',
#  'adherence',
#  'hands-on',
#  'childbearing',
#  'offer',
#  'evidence-base',
#  'addressing',
#  'family',
#  'pathology',
#  'domain',
#  'pedagogies',
#  'marine',
#  'exemplify',
#  'employees',
#  'food',
#  'exist',
#  'learner-centred',
#  'disposal',
#  'internetworking',
#  'scenarios',
#  'electricity',
#  'melodic',
#  'basis',
#  'secondary-source',
#  'twentieth',
#  'reforms',
#  'critics',
#  'sale',
#  'consultation',
#  'focussing',
#  'heart',
#  'additionally',
#  'retention',
#  'unusual',
#  'exercise',
#  'polymers',
#  'choices',
#  'schema',
#  'extraction',
#  'synchronization',
#  'investigating',
#  'tangent',
#  'broaden',
#  'communicating',
#  'associations',
#  'regional',
#  'grave',
#  'adaptations',
#  'operational',
#  'reclaim',
#  'contact',
#  'strengthen',
#  'held',
#  'traditionally',
#  'progress',
#  'jssg2006',
#  'analyze',
#  'ethos',
#  "youth's",
#  'co-marketing',
#  'agent',
#  'jews',
#  'disasters',
#  'record',
#  'measures',
#  'equilibrium',
#  'guided',
#  'servicemen',
#  'enable',
#  'courses',
#  'self-assessment',
#  "development'delivery",
#  'micro-organisms',
#  'neutral',
#  'mechanics',
#  'finding',
#  'enhancement',
#  'intimate',
#  'italy',
#  'disks',
#  'coordinator',
#  'draft',
#  'reasoned',
#  'inference',
#  'introducing',
#  "na'a",
#  'siso',
#  'continually',
#  'advice',
#  "company's",
#  '4',
#  'involves',
#  'passages',
#  'functions',
#  'pipes',
#  'credentials',
#  'qualities',
#  'community',
#  'dwarfs',
#  'archives',
#  'eduardo',
#  'inequities',
#  'members',
#  'files',
#  'observations',
#  'categories',
#  'conflicts',
#  'studios',
#  'clear',
#  'manifestations',
#  'space',
#  'determinants',
#  'formation',
#  'nhave',
#  'bachelor',
#  'taxes',
#  'bills',
#  'non-prescription',
#  'fleet',
#  'imprisonment',
#  'enlargement',
#  'sales',
#  'return',
#  'brought',
#  'expressing',
#  'nunderstanding',
#  'consistent',
#  'philosophies',
#  'fifth-year',
#  'feminist',
#  'title',
#  'demand',
#  'ecologically',
#  'families',
#  'discrete',
#  'sla',
#  'non-drug',
#  'nonverbal',
#  'rule',
#  'motivate',
#  'consumerism',
#  'shelf',
#  'simple',
#  'interpreted',
#  'sensitive',
#  'inverse',
#  'initiate',
#  'masters',
#  'research-based',
#  'nerve',
#  'workable',
#  'fashion',
#  'philosophers',
#  'endeavours',
#  'laboratory-based',
#  'confidence',
#  'gathered',
#  'cyd',
#  'adequate',
#  'dehumidification',
#  'flaw',
#  'midwifery',
#  'companies',
#  'financing',
#  'adjudicate',
#  'book',
#  'values',
#  'constraints',
#  'contingency',
#  'multiculturalism',
#  'bibliographic',
#  'contrast',
#  '1',
#  'entropy',
#  'babies',
#  'airworthiness',
#  'typically',
#  'vehicle',
#  'broadcasters',
#  'aerospace',
#  'convergence',
#  'element',
#  'assist',
#  'insurance',
#  'logical',
#  'unconscious',
#  'escalating',
#  'manipulation',
#  'discusses',
#  'nation',
#  'advocating',
#  'epigenetics',
#  'interaction',
#  'neurosurgical',
#  'interpretive',
#  'disciplinary',
#  'gmp',
#  'variables',
#  'concise',
#  'multivariable',
#  'meteorology',
#  'analysed',
#  'connectivity',
#  'urban',
#  'grammar',
#  'alteration',
#  'service',
#  'lifespace',
#  'travel',
#  'tailored',
#  'criminality',
#  'caused',
#  'immigrant',
#  'collect',
#  'long',
#  'concern',
#  'jazz',
#  'handouts',
#  'invoices',
#  'guidelines',
#  'comicality',
#  'incidents',
#  'antibiotics',
#  'estates',
#  'commencement',
#  'composers',
#  'globalisation',
#  'mathematics',
#  'scenario',
#  'gastrointestinal',
#  'training',
#  'argumentative',
#  'haccp',
#  'conscious',
#  'facilitate',
#  'suggestibility',
#  'submission',
#  'reveals',
#  'malaysia',
#  'focusses',
#  '2',
#  'definition',
#  'geographic',
#  'interact',
#  'submitting',
#  'defaulted',
#  'images',
#  'decision-making',
#  'sprawling',
#  'mental',
#  'prisoners',
#  'emergent',
#  'examination',
#  'parametric',
#  'communities',
#  'salvation',
#  'movements',
#  'requires',
#  'pathological',
#  'larger',
#  'output',
#  'interactive-media',
#  'unmanned',
#  'in-service',
#  'brand',
#  'reputation',
#  'pharmacy',
#  'moves',
#  'overarching',
#  'rapidly',
#  'scripting',
#  'formulating',
#  'zone',
#  'directories',
#  'exegetical',
#  'sensing',
#  'trust',
#  'package',
#  'play',
#  'therapies',
#  'manufacturing',
#  'justification',
#  'intermediate',
#  'assessing',
#  'read',
#  'legislated',
#  'questionnaire',
#  'securities',
#  'pitch',
#  'hazards',
#  'short',
#  'sexual',
#  'prevalent',
#  'proposal',
#  'atonal',
#  'in-country',
#  'takes',
#  'education',
#  'contested',
#  'divided',
#  'facilitation',
#  "prato's",
#  'end',
#  'deductive',
#  'kinds',
#  'eras',
#  'addictive',
#  'concisely',
#  'planned',
#  'discussing',
#  'tasks',
#  'default',
#  'doctrines',
#  'crises',
#  'targeted',
#  'mysticism',
#  'cracking',
#  'museums',
#  'pathologies',
#  'treaties',
#  'papers',
#  'large-scale',
#  'sciences',
#  'develops',
#  'timber',
#  '1977',
#  'tort',
#  'section',
#  'delivering',
#  'arbitrations',
#  'imaging',
#  'completion',
#  'realism',
#  'pathway',
#  'represented',
#  'encourages',
#  'redressed',
#  'system-centric',
#  'pilot',
#  'thermodynamics',
#  'in-depth',
#  'civilization',
#  'motion',
#  'put',
#  'integrations',
#  'successfully',
#  'broadcasting',
#  'pre-experience',
#  'identification',
#  'engagement',
#  'offender',
#  'specialised',
#  'pertinent',
#  'sociocultural',
#  'swapping',
#  'repercussions',
#  "clarity'in",
#  'directional',
#  'university',
#  'sounds',
#  'discern',
#  'back',
#  'domestic',
#  'splines',
#  'metaphysics',
#  'parts',
#  'classes',
#  'embark',
#  'speaks',
#  'shift',
#  'lie',
#  'overdose',
#  'gauss',
#  'correspondent',
#  'postwar',
#  'candidates',
#  'realms',
#  'tax',
#  'probabilities',
#  'market',
#  'active',
#  'initiatives',
#  'testing',
#  'provision',
#  'spirituality',
#  'damage',
#  'suitability',
#  'influx',
#  'ranges',
#  'prevent',
#  'validating',
#  'capability',
#  'earth',
#  'power-laden',
#  'groups',
#  'underpin',
#  'government',
#  'democracy',
#  'thesis',
#  'unpack',
#  'providing',
#  'sampling',
#  'procedure',
#  'omniscience',
#  'entities',
#  'stochastic',
#  'diffusion',
#  'organism',
#  'deconstructed',
#  'engineers',
#  'introductory',
#  'liberty',
#  'face-to',
#  'collecting',
#  'journalists',
#  'start',
#  'truss',
#  'real-world',
#  'cover',
#  'intersections',
#  'pathophysiology',
#  'search',
#  'heat',
#  'pursuing',
#  'drawing',
#  'pressing',
#  'resistant',
#  'wider',
#  'undergoing',
#  'differentiate',
#  'fatigue',
#  'merits',
#  'matches',
#  'giving',
#  'greater',
#  'wrongs',
#  'organisations',
#  'bank',
#  'grown',
#  'black',
#  'stereolithography',
#  'police',
#  'photographs',
#  'reconstruction',
#  'asset',
#  'profound',
#  'forward',
#  'correct',
#  'selecting',
#  'homework',
#  'allowing',
#  'biotechnology',
#  'nutrient',
#  'stiffness',
#  'geoenvironmental',
#  'common',
#  'pluralism',
#  'experiences',
#  'sensor',
#  'integration',
#  'nationhood',
#  'participation',
#  'loan',
#  'mitigate',
#  'hard',
#  'turbulent',
#  'wars',
#  'mythology',
#  'master',
#  'difficulties',
#  'organ',
#  'audio',
#  'uneven',
#  '18000',
#  'subject',
#  'unit_will',
#  'men',
#  'contextual',
#  'considers',
#  'forms',
#  'otto',
#  'employee',
#  'simulate',
#  'begins',
#  'traces',
#  'numerical',
#  'mainstream',
#  'specialty',
#  'piles',
#  'external',
#  'injuries',
#  'twentieth-century',
#  'explaining',
#  'globe',
#  'locally',
#  'prepare',
#  'responsibility',
#  'biological',
#  'honours',
#  'learned',
#  'link',
#  'wicked',
#  'treasury',
#  'excursions',
#  'base',
#  "union's",
#  'redundancy',
#  'brands',
#  'response',
#  'studied',
#  'development-in',
#  'non-native',
#  'significance',
#  'logically',
#  'optimum',
#  'pre-hospital',
#  'preferred',
#  'classical',
#  'covering',
#  'hand',
#  'logistical',
#  'project-based',
#  'assignment',
#  'seminars',
#  'disaster',
#  'ambit',
#  'collision',
#  'phonological',
#  'unions',
#  'stages',
#  'graphs',
#  'centres',
#  'surrogate',
#  'expressionism',
#  'institutionalised',
#  'teams',
#  'strand',
#  'productive',
#  'abilities',
#  'value-creating',
#  'socio-political',
#  'levels',
#  'explicit',
#  'picture',
#  'networking',
#  'deadline',
#  'ill-defined',
#  'vectors',
#  'compare',
#  'negotiates',
#  'achieved',
#  'addictions',
#  'loyalty',
#  'neonates',
#  'algorithms',
#  'evaluating',
#  'articulation',
#  'deliverables',
#  'respiration',
#  'morph-syntactic',
#  'postmodern',
#  'nnstudents',
#  'scheduling',
#  'antidotes',
#  'treatment',
#  '1374',
#  'divergence',
#  'justice',
#  'universe',
#  'buckling',
#  'ii',
#  'migrants',
#  'differential',
#  'shaping',
#  'psychoanalytic',
#  'intelligence',
#  'logic',
#  'consumer',
#  'artificial',
#  'programmatic',
#  'impacts',
#  'prato',
#  'dance',
#  'risks',
#  'programming',
#  'taylor',
#  'nutrigenomics',
#  'regulates',
#  'appeal',
#  'cell',
#  'antimicrobial',
#  'extend',
#  'accountant',
#  'anthropocene',
#  'nur2228',
#  'three-dimensional',
#  'involving',
#  'on-campus',
#  'wastes',
#  'publishable',
#  'schemes',
#  'beam',
#  'perform',
#  'data-link',
#  'deductible',
#  'minimising',
#  'availability',
#  'culturally',
#  'collected',
#  'rose',
#  'point',
#  "na'the",
#  'citizenship',
#  'equally',
#  'verbal',
#  'newborn',
#  'practitioners',
#  'retail',
#  'aids',
#  'transmission',
#  'torrens',
#  'user',
#  'interest',
#  'recognize',
#  'integrity',
#  'outcome',
#  'innovative',
#  'aspire',
#  'practising',
#  'subsequently',
#  'postcolonial',
#  "women's",
#  'illuminate',
#  'mimo',
#  'sector',
#  'respective',
#  'ideological',
#  'joints',
#  'determined',
#  'antisemitism',
#  'ahead',
#  'computer-aided',
#  "dell'attore",
#  'ecosystem',
#  'requested',
#  'aforementioned',
#  "system's",
#  'mechanical',
#  'unfamiliar',
#  'optimal',
#  'eighteenth',
#  'grounding',
#  'mathematical',
#  'formulations',
#  'heating',
#  'intermediality',
#  'diversities',
#  'planes',
#  'mentored',
#  'caveat',
#  'linguistic',
#  'revolution',
#  'pharmaceutical',
#  'makers',
#  'interacted',
#  'predicting',
#  'carry',
#  'se',
#  'terminology',
#  'destination',
#  'syntactic',
#  'statement',
#  'self-reliance',
#  'socket-level',
#  'nnmore',
#  'trading',
#  'fluidisation',
#  'newly',
#  "child's",
#  'leaders',
#  'cycling',
#  'tracing',
#  'iso',
#  'commercialisation',
#  'installation',
#  'agencies',
#  'fan',
#  'adaptive',
#  ...]

# %% [markdown]
# #### A dictionary is thus made from the above cleaning of rare tokens, to make a dictionary which contains regular words which appear for every unit. This will be later used for finding out word stems.

# %%
def clean_rare_tokens(key):
    cleaned_rare_list = []
    for token in cleaned_stop_words[key]:
        if token not in rare_tokens:
            cleaned_rare_list.append(token)
    return (key,cleaned_rare_list)
stem_dictionary =  dict(clean_rare_tokens(key) for key,values in cleaned_stop_words.items())

# %%
stem_dictionary
# Out:
# {'ACB3021': ['apply',
#   'contemporary',
#   'performance',
#   'control',
#   'techniques',
#   'organisational',
#   'performance',
#   'analyse_and',
#   'design',
#   'performance',
#   'control',
#   'systems',
#   'explain',
#   'implications',
#   'for_the',
#   'effective',
#   'design',
#   'performance',
#   'control',
#   'systems',
#   'apply',
#   'critical',
#   'thinking',
#   'problem',
#   'solving',
#   'presentation',
#   'skills',
#   'individual',
#   'group',
#   'activities',
#   'dealing',
#   'performance',
#   'control',
#   'demonstrate',
#   'individual',
#   'summative',
#   'assessment',
#   'task',
#   'acquisition',
#   'comprehensive',
#   'understanding',
#   'topics',
#   'covered',
#   'topics',
#   'include',
#   'planning',
#   'process',
#   'including',
#   'standard',
#   'analysis',
#   'management',
#   'performance',
#   'performance',
#   'issues',
#   'and_other',
#   'approaches',
#   'planning',
#   'control'],
#  'ACW3041': ['demonstrate',
#   'understanding',
#   'the_role',
#   'modern',
#   'society',
#   'including',
#   'professional',
#   'ethical',
#   'legal',
#   'examine',
#   'role',
#   'emphasis',
#   'describe_the',
#   'framework',
#   'and_apply',
#   'planning',
#   'processes',
#   'evidence',
#   'procedures',
#   'form',
#   'apply',
#   'critical',
#   'thinking',
#   'problem',
#   'solving',
#   'presentation',
#   'skills',
#   'individual',
#   'group',
#   'activities',
#   'dealing',
#   'demonstrate',
#   'individual',
#   'summative',
#   'assessment',
#   'task',
#   'acquisition',
#   'comprehensive',
#   'understanding',
#   'topics',
#   'covered',
#   'legal',
#   'process',
#   'evidence',
#   'concepts',
#   'study',
#   'evaluation',
#   'control',
#   'techniques',
#   'and_the'],
#  'ACX4018': ['implement',
#   'research',
#   'recognise',
#   'practical',
#   'problems',
#   'scientific',
#   'research_and',
#   'solutions',
#   'research',
#   'develop',
#   'the_ability',
#   'conduct',
#   'manage',
#   'study',
#   'apply',
#   'critical',
#   'thinking',
#   'problem',
#   'solving',
#   'presentation',
#   'skills',
#   'individual',
#   'group',
#   'activities',
#   'dealing',
#   'research',
#   'students',
#   'conduct',
#   'critical',
#   'review',
#   'literature',
#   'relevant',
#   'study',
#   'practical',
#   'problems',
#   'research',
#   'ethical',
#   'principles',
#   'scientific',
#   'conduct',
#   'study',
#   'manage',
#   'problems',
#   'data',
#   'conduct',
#   'analysis',
#   'data',
#   'write',
#   'report',
#   'project',
#   'relevant'],
#  'ADA3111': ['demonstrate',
#   'understanding',
#   'concepts',
#   'design',
#   'thinking',
#   'and_their',
#   'application',
#   'identify_and',
#   'analyse',
#   'project',
#   'problems',
#   'relevant',
#   'design',
#   'thinking',
#   'approaches',
#   'apply',
#   'design',
#   'thinking',
#   'methods',
#   'approaches',
#   'problem',
#   'develop',
#   'perspectives',
#   'key',
#   'issues',
#   'identify',
#   'develop',
#   'evaluate',
#   'problems',
#   'develop',
#   'awareness',
#   'approaches',
#   'complex',
#   'ways',
#   'design',
#   'thinking',
#   'design',
#   'thinking',
#   'skills_and',
#   'strategies',
#   'developed',
#   'range',
#   'problems',
#   'situations',
#   'skills_and',
#   'strategies',
#   'include',
#   'range',
#   'conceptual',
#   'communication',
#   'approaches',
#   'ways',
#   'explore',
#   'context',
#   'work',
#   'design',
#   'thinking',
#   'approaches',
#   'analysis_and',
#   'ways',
#   'design',
#   'approach',
#   'design',
#   'thinking',
#   'approach',
#   'problem',
#   'solving',
#   'with_the',
#   'complex',
#   'issues',
#   'contemporary',
#   'world',
#   'this_unit',
#   'introduce',
#   'students',
#   'key',
#   'skills_and',
#   'practices',
#   'associated_with',
#   'design',
#   'thinking',
#   'explore',
#   'application',
#   'basic',
#   'techniques',
#   'range',
#   'disciplines'],
#  'ADA5001': ['part',
#   'team',
#   'develop',
#   'research',
#   'communication_and',
#   'information',
#   'skills',
#   'contribute',
#   'context',
#   'conduct',
#   'critical',
#   'provide',
#   'summative',
#   'disciplines',
#   'design_and',
#   'problem',
#   'understand',
#   'and_apply',
#   'rules',
#   'occupational',
#   'health_and',
#   'safety',
#   'practice',
#   'order',
#   'studio',
#   'environment',
#   'project',
#   'activities',
#   'learning',
#   'application',
#   'knowledge',
#   'techniques',
#   'methodologies',
#   'from_the',
#   'students',
#   'individual',
#   'disciplines',
#   'complex',
#   'problem',
#   'the_unit',
#   'design',
#   'students',
#   'the_ability',
#   'critically',
#   'engage',
#   'research_and',
#   'world',
#   'problems',
#   'approaches',
#   'this_unit',
#   'students_will',
#   'develop',
#   'skills',
#   'communication',
#   'tools',
#   'professional',
#   'practice',
#   'research',
#   'activities',
#   'field',
#   'outcomes',
#   'from_the',
#   'unit',
#   'individual'],
#  'AHT3801': ['understand',
#   'articulate',
#   'analyse_the',
#   'debates',
#   'and_the',
#   'studio',
#   'practice',
#   'conceptual',
#   'models',
#   'the_unit',
#   'reflect',
#   'engage',
#   'critical',
#   'importance',
#   'this_unit',
#   'examines',
#   'range',
#   'visual',
#   'practices',
#   'including',
#   'social',
#   'practices',
#   'performance',
#   'historical',
#   'disciplines',
#   'and_how',
#   'diverse',
#   'range',
#   'academic',
#   'concepts',
#   'modern',
#   'understanding',
#   'form',
#   'the_unit',
#   'introduces',
#   'key',
#   'theoretical',
#   'analyse',
#   'contemporary',
#   'practices',
#   'case',
#   'studies',
#   'introduces',
#   'students',
#   'critical',
#   'material',
#   'processes'],
#  'AMG5743': ['knowledge',
#   'skills_and',
#   'understanding',
#   'advanced',
#   'research',
#   'ability',
#   'design',
#   'write',
#   'research',
#   'ability',
#   'advanced',
#   'level',
#   'analyse_and',
#   'evaluate',
#   'understand',
#   'critical',
#   'approaches',
#   'relating',
#   'communication',
#   'communication',
#   'issues',
#   'capacity',
#   'contribute',
#   'advanced',
#   'knowledge',
#   'area',
#   'research',
#   'critical',
#   'professional',
#   'the_unit',
#   'students',
#   'research',
#   'media',
#   'studies',
#   'students',
#   'develop',
#   'independent',
#   'research_project',
#   'student',
#   'developed',
#   'with_the',
#   'support',
#   'project',
#   'written',
#   'student',
#   'demonstrate',
#   'advanced',
#   'skills',
#   'research',
#   'writing',
#   'project',
#   'management',
#   'students',
#   'project',
#   'for_the',
#   'professional',
#   'development'],
#  'APG5050': ['with_the',
#   'major',
#   'research',
#   'methods',
#   'communication_and',
#   'media',
#   'studies',
#   'understanding',
#   'research',
#   'topics',
#   'research',
#   'questions',
#   'ability',
#   'identify',
#   'research',
#   'questions',
#   'ability',
#   'apply',
#   'research',
#   'methods',
#   'critically',
#   'research',
#   'questions',
#   'capacity',
#   'design',
#   'research',
#   'projects',
#   'communication_and',
#   'media',
#   'studies',
#   'project',
#   'planning',
#   'ability',
#   'develop',
#   'solutions',
#   'problems',
#   'communication_and',
#   'media',
#   'studies',
#   'policy',
#   'ability',
#   'apply',
#   'research',
#   'skills',
#   'range',
#   'challenges',
#   'communication_and',
#   'media',
#   'studies',
#   'policy',
#   'the_unit',
#   'introduces',
#   'students',
#   'principles',
#   'communication_and',
#   'media',
#   'research',
#   'range',
#   'research',
#   'methods',
#   'including',
#   'analysis',
#   'content',
#   'analysis',
#   'approaches',
#   'analysis_and',
#   'research',
#   'focus',
#   'learning',
#   'methods',
#   'understanding',
#   'relation',
#   'problems',
#   'address',
#   'the_unit',
#   'develop',
#   'skills',
#   'research',
#   'design',
#   'research',
#   'questions',
#   'methodologies',
#   'project',
#   'planning',
#   'skills',
#   'provide',
#   'development',
#   'research_project'],
#  'APG5052': ['critically',
#   'analyse_the',
#   'media',
#   'problem',
#   'field',
#   'contribute',
#   'thinking',
#   'solutions',
#   'contemporary',
#   'problems',
#   'communication_and',
#   'media',
#   'articulate',
#   'ethical',
#   'relevant',
#   'development',
#   'communication_and',
#   'media',
#   'impact',
#   'technologies',
#   'research',
#   'skills',
#   'evaluate',
#   'issues',
#   'field',
#   'communicate',
#   'findings',
#   'professional',
#   'context',
#   'the_unit',
#   'students_will',
#   'engage',
#   'study',
#   'development',
#   'communication_and',
#   'media',
#   'year',
#   'the_unit',
#   'address',
#   'field',
#   'media',
#   'developing',
#   'media',
#   'industry',
#   'the_unit',
#   'research',
#   'focus',
#   'include',
#   'development',
#   'professional',
#   'industry',
#   'practice',
#   'students_will',
#   'work',
#   'with_the',
#   'work',
#   'problems',
#   'media',
#   'studies',
#   'practices',
#   'media',
#   'communication'],
#  'APG5077': ['identify',
#   'assess',
#   'interpret',
#   'cultural',
#   'effective',
#   'management',
#   'strategy',
#   'cultural',
#   'development',
#   'solutions',
#   'cultural',
#   'challenges',
#   'ethical',
#   'the_development',
#   'diverse',
#   'cultural',
#   'contexts',
#   'effectively',
#   'communicate',
#   'strategy',
#   'diverse',
#   'cultural',
#   'development',
#   'this_unit',
#   'students',
#   'learn',
#   'identify',
#   'assess',
#   'interpret',
#   'manage',
#   'critical',
#   'experience',
#   'environmental',
#   'cultural',
#   'students_will',
#   'learn',
#   'industry',
#   'field',
#   'study',
#   'cultural',
#   'development'],
#  'APG5082': ['explain',
#   'identify',
#   'business',
#   'specific',
#   'cultural',
#   'academic',
#   'concepts',
#   'understand',
#   'challenges',
#   'products',
#   'develop',
#   'strategy',
#   'independent',
#   'research',
#   'skills',
#   'engage',
#   'cultural',
#   'contexts',
#   'communicate',
#   'ideas',
#   'effectively',
#   'this_unit',
#   'students',
#   'analyse',
#   'business',
#   'approaches',
#   'cultural',
#   'models',
#   'and_their',
#   'identify',
#   'key',
#   'approaches',
#   'global',
#   'cultural',
#   'identify',
#   'challenges',
#   'solutions',
#   'management',
#   'important',
#   'order',
#   'culture',
#   'business',
#   'contemporary',
#   'society'],
#  'APG5103': ['knowledge',
#   'skills',
#   'policy',
#   'analysis_and',
#   'evaluation',
#   'discipline',
#   'based',
#   'solutions',
#   'relevant',
#   'diverse',
#   'business',
#   'professional',
#   'public',
#   'policy',
#   'solutions',
#   'challenges',
#   'advanced',
#   'critical',
#   'thinking',
#   'evaluation',
#   'research',
#   'skills',
#   'communicate',
#   'policy',
#   'analysis_and',
#   'the_unit',
#   'students',
#   'conceptual',
#   'theoretical',
#   'policy',
#   'analysis_and',
#   'evaluation',
#   'present',
#   'effective',
#   'policy',
#   'public',
#   'policy',
#   'the_unit',
#   'explores',
#   'challenges',
#   'problem',
#   'evidence',
#   'policy',
#   'developing',
#   'policy',
#   'policy'],
#  'APG5230': ['explain',
#   'key',
#   'concepts',
#   'including',
#   'apply',
#   'concepts',
#   'environmental',
#   'contexts',
#   'understand_the',
#   'role',
#   'policy',
#   'design_and',
#   'implementation',
#   'critically_evaluate',
#   'approaches',
#   'and_their',
#   'practice',
#   'terms',
#   'outcomes',
#   'the_unit',
#   'introduction',
#   'environmental',
#   'management',
#   'science',
#   'policy',
#   'understand',
#   'policy',
#   'works',
#   'practice',
#   'professional',
#   'experience',
#   'required',
#   'australian',
#   'international',
#   'case',
#   'studies',
#   'the_unit',
#   'introduce',
#   'challenges',
#   'knowledge',
#   'effective',
#   'policy',
#   'tools'],
#  'APG5348': ['key',
#   'theoretical',
#   'debates',
#   'relation',
#   'language',
#   'acquisition',
#   'evaluate',
#   'relevant',
#   'evidence',
#   'work',
#   'recognise',
#   'role',
#   'the_development',
#   'theory',
#   'reflect',
#   'language',
#   'learning',
#   'experience',
#   'practice',
#   'theoretical',
#   'studies',
#   'evaluate',
#   'major',
#   'approaches',
#   'study',
#   'language',
#   'acquisition',
#   'conduct',
#   'major',
#   'research_project',
#   'area',
#   'language',
#   'acquisition',
#   'address',
#   'key',
#   'concepts',
#   'theoretical',
#   'models',
#   'approaches',
#   'theories',
#   'field',
#   'language',
#   'acquisition',
#   'topics',
#   'covered',
#   'include',
#   'models',
#   'theories',
#   'language',
#   'acquisition',
#   'language',
#   'acquisition',
#   'analysis_and',
#   'strategies',
#   'learning',
#   'processes',
#   'language',
#   'identity',
#   'methods',
#   'research'],
#  'APG5351': ['identify_and',
#   'explain',
#   'international',
#   'approaches',
#   'global',
#   'ethical',
#   'explore',
#   'analyse',
#   'international',
#   'design',
#   'international',
#   'research_project',
#   'media',
#   'theories',
#   'methodologies',
#   'evaluate',
#   'communicate',
#   'results',
#   'media',
#   'project',
#   'presentation',
#   'writing',
#   'media',
#   'report',
#   'the_unit',
#   'students',
#   'understand',
#   'international',
#   'world',
#   'the_unit',
#   'explores',
#   'nature',
#   'media',
#   'staff',
#   'working',
#   'international',
#   'local',
#   'content',
#   'this_unit',
#   'history',
#   'international',
#   'global',
#   'the_role',
#   'and_the',
#   'world',
#   'international',
#   'students_will',
#   'international',
#   'research',
#   'study',
#   'write',
#   'international',
#   'media',
#   'research',
#   'report'],
#  'APG5400': ['sound',
#   'understanding',
#   'media',
#   'analyse',
#   'global',
#   'media',
#   'and_the',
#   'problems',
#   'communication_and',
#   'major',
#   'theories',
#   'developed',
#   'explain',
#   'understand',
#   'global',
#   'with_the',
#   'implications',
#   'processes',
#   'personal',
#   'identity',
#   'major',
#   'legal',
#   'ethical',
#   'challenges',
#   'media',
#   'demonstrate',
#   'ability',
#   'conduct',
#   'independent',
#   'research',
#   'explores',
#   'key',
#   'issues',
#   'from_the',
#   'development',
#   'international',
#   'examines',
#   'impact',
#   'international',
#   'students_will',
#   'cultural',
#   'development',
#   'communication',
#   'communication',
#   'international',
#   'public',
#   'legal',
#   'ethical',
#   'issues',
#   'international',
#   'including',
#   'case',
#   'studies',
#   'media',
#   'and_the'],
#  'APG5628': ['critically',
#   'assess',
#   'development',
#   'academic',
#   'field',
#   'explores',
#   'history',
#   'development',
#   'thinking',
#   'and_the',
#   'development',
#   'practice',
#   'articulate',
#   'approaches',
#   'practices',
#   'development',
#   'evaluate',
#   'work',
#   'contemporary',
#   'development',
#   'contemporary',
#   'development',
#   'personal',
#   'development',
#   'ideas',
#   'systems',
#   'social',
#   'practice',
#   'diverse',
#   'cultural',
#   'contexts',
#   'designed',
#   'ideas',
#   'development',
#   'this_unit',
#   'questions',
#   'conceptual',
#   'practical',
#   'development',
#   'concepts',
#   'economic',
#   'development',
#   'and_their',
#   'ideas',
#   'the_unit',
#   'nature',
#   'contemporary',
#   'development',
#   'practices',
#   'world',
#   'case',
#   'studies',
#   'development',
#   'the_unit',
#   'explores',
#   'development',
#   'theories',
#   'practice',
#   'explores',
#   'ways',
#   'diverse',
#   'social',
#   'social',
#   'development',
#   'questions',
#   'development',
#   'contemporary',
#   'development',
#   'practice'],
#  'APG5849': ['formulate',
#   'research_project',
#   'conduct',
#   'research',
#   'demonstrate',
#   'relevant',
#   'literature',
#   'critically',
#   'analyse_the',
#   'relevant',
#   'academic',
#   'literature',
#   'develop',
#   'sound',
#   'demonstrate',
#   'written',
#   'skills',
#   'academic',
#   'staff',
#   'students_will',
#   'conduct',
#   'independent',
#   'research',
#   'research',
#   'process',
#   'research',
#   'part',
#   'students',
#   'research'],
#  'APG5881': ['undertake',
#   'study',
#   'study',
#   'study',
#   'form',
#   'year',
#   'unit',
#   'studies'],
#  'APG5900': ['conceptual',
#   'historical',
#   'contemporary',
#   'issues',
#   'involved',
#   'cultural',
#   'critically_evaluate',
#   'approaches',
#   'cultural',
#   'and_the',
#   'issues',
#   'apply',
#   'independent',
#   'research',
#   'skills',
#   'range',
#   'conceptual',
#   'historical',
#   'problems',
#   'field',
#   'cultural',
#   'ability',
#   'write',
#   'communicate',
#   'effectively',
#   'analytical',
#   'ability',
#   'effectively',
#   'academic',
#   'concepts',
#   'identify_and',
#   'challenges',
#   'issues',
#   'involved',
#   'specific',
#   'aspects',
#   'cultural',
#   'this_unit',
#   'introduce',
#   'conceptual',
#   'historical',
#   'including',
#   'cultural',
#   'policy',
#   'cultural',
#   'cultural',
#   'and_the',
#   'cultural',
#   'work',
#   'explore',
#   'concepts',
#   'cultural',
#   'examine',
#   'existing',
#   'future',
#   'practices',
#   'policy',
#   'cultural',
#   'students_will',
#   'based',
#   'concepts',
#   'issues',
#   'the_unit',
#   'content'],
#  'ARC3002': ['demonstrate',
#   'level',
#   'design',
#   'ability',
#   'critically',
#   'analyse_and',
#   'respond',
#   'complex',
#   'range',
#   'issues',
#   'design',
#   'project',
#   'developed',
#   'understanding',
#   'analysis',
#   'critique',
#   'apply',
#   'design',
#   'process',
#   'advanced',
#   'level',
#   'presentation',
#   'skills',
#   'understand',
#   'apply_the',
#   'rules',
#   'occupational',
#   'health_and',
#   'safety',
#   'the_unit',
#   'study',
#   'design',
#   'studio',
#   'conceptual',
#   'understanding',
#   'design',
#   'design',
#   'process',
#   'critical',
#   'emphasis',
#   'design',
#   'process',
#   'range',
#   'complex',
#   'issues',
#   'material',
#   'structure',
#   'history',
#   'relationship',
#   'form'],
#  'ARC5401': ['design',
#   'research',
#   'relevant',
#   'contexts',
#   'design',
#   'research',
#   'methods',
#   'the_ability',
#   'critically',
#   'analyse_and',
#   'respond',
#   'issues',
#   'research',
#   'developed',
#   'understanding',
#   'analysis',
#   'critique',
#   'apply',
#   'the_development',
#   'design',
#   'research',
#   'understand',
#   'apply_the',
#   'rules',
#   'occupational',
#   'health_and',
#   'safety',
#   'the_unit',
#   'study',
#   'research',
#   'methods',
#   'design',
#   'research_project',
#   'diverse',
#   'methodologies',
#   'this_unit',
#   'design',
#   'research',
#   'the_unit',
#   'for_the',
#   'development',
#   'design',
#   'research',
#   'projects',
#   'including',
#   'conceptual',
#   'physical',
#   'contexts'],
#  'ASC5001': ['critique',
#   'for_the',
#   'relation',
#   'models',
#   'critique',
#   'the_role',
#   'factors',
#   'reference',
#   'the_research',
#   'evidence',
#   'analyse_the',
#   'critically_evaluate',
#   'demonstrate',
#   'setting',
#   'understanding',
#   'individual',
#   'synthesise',
#   'implications',
#   'approach',
#   'understanding',
#   'present',
#   'based',
#   'theoretical',
#   'literature',
#   'process',
#   'evaluate_the',
#   'role',
#   'research',
#   'evidence',
#   'and_the',
#   'models',
#   'the_development',
#   'relevant',
#   'this_unit',
#   'introduction',
#   'environmental',
#   'factors',
#   'contribute',
#   'the_development'],
#  'ASC5009': ['identify_and',
#   'factors',
#   'contribute',
#   'people',
#   'explain',
#   'terms',
#   'social',
#   'contexts',
#   'synthesise',
#   'information',
#   'impact',
#   'people',
#   'order',
#   'demonstrate',
#   'understanding',
#   'reflect',
#   'critically',
#   'theories',
#   'relevant',
#   'key',
#   'contemporary',
#   'issues',
#   'evaluate',
#   'critique',
#   'current',
#   'responses',
#   'including',
#   'contemporary',
#   'models',
#   'people',
#   'analysis',
#   'international',
#   'research',
#   'critically',
#   'review',
#   'including',
#   'practice',
#   'critically',
#   'appraise',
#   'range',
#   'services',
#   'key',
#   'elements',
#   'critically',
#   'review',
#   'policy',
#   'issues',
#   'relevant',
#   'including',
#   'social',
#   'media',
#   'this_unit',
#   'focus',
#   'development',
#   'and_other'],
#  'ASP3162': ['demonstrate',
#   'basic',
#   'understanding',
#   'high',
#   'including',
#   'sound',
#   'demonstrate',
#   'practical',
#   'skills',
#   'scientific',
#   'data',
#   'analysis_and',
#   'advanced',
#   'demonstrate',
#   'understanding',
#   'modern',
#   'this_unit',
#   'students_will',
#   'learn',
#   'basic',
#   'principles',
#   'and_how',
#   'the_unit',
#   'covers',
#   'basic',
#   'including',
#   'and_the',
#   'high',
#   'students_will',
#   'apply',
#   'understand_the',
#   'physical',
#   'processes',
#   'sources',
#   'including',
#   'and_the',
#   'students_will',
#   'gain',
#   'practical',
#   'experience',
#   'including',
#   'basic',
#   'skills_and',
#   'understanding'],
#  'ATS1062': ['basic',
#   'writing',
#   'skills_and',
#   'communicate',
#   'effectively',
#   'range',
#   'present',
#   'future',
#   'situations',
#   'range',
#   'topics',
#   'information',
#   'basic',
#   'recognise',
#   'key',
#   'identify_and',
#   'critique',
#   'aspects',
#   'modern',
#   'contemporary',
#   'history',
#   'identity',
#   'and_their',
#   'interpret',
#   'sources',
#   'synthesise',
#   'knowledge',
#   'standard',
#   'this_unit',
#   'basic',
#   'language',
#   'skills',
#   'writing',
#   'level',
#   'introduction',
#   'modern',
#   'society',
#   'designed',
#   'knowledge',
#   'students_will',
#   'develop',
#   'language',
#   'learning',
#   'strategies',
#   'nature',
#   'language',
#   'learning',
#   'and_the',
#   'practice',
#   'culture',
#   'students_will',
#   'explore',
#   'culture',
#   'society',
#   'develop',
#   'year',
#   'level',
#   'theory',
#   'practices',
#   'involved',
#   'analysis'],
#  'ATS1208': ['recognise',
#   'evaluate_the',
#   'developing',
#   'role',
#   'technologies',
#   'society',
#   'culture',
#   'analyse_the',
#   'impact',
#   'technologies',
#   'areas',
#   'media',
#   'examine',
#   'assess',
#   'application',
#   'technologies',
#   'analysis_and',
#   'data',
#   'identify',
#   'complex',
#   'research',
#   'problems',
#   'approaches',
#   'communicate',
#   'effectively',
#   'this_unit',
#   'introduces',
#   'students',
#   'concepts',
#   'world',
#   'range',
#   'case',
#   'studies',
#   'based',
#   'major',
#   'examine',
#   'work',
#   'media',
#   'studies',
#   'techniques',
#   'methods',
#   'research_and',
#   'presentation',
#   'data',
#   'work',
#   'data',
#   'sources',
#   'and_the',
#   'tools',
#   'critically',
#   'existing',
#   'field',
#   'students',
#   'this_unit',
#   'work',
#   'impact',
#   'field',
#   'the_unit',
#   'understanding',
#   'technologies',
#   'society',
#   'culture'],
#  'ATS1835': ['introduction',
#   'questions',
#   'nature',
#   'human',
#   'personal',
#   'identity',
#   'and_the',
#   'introduced',
#   'science',
#   'issues'],
#  'ATS2043': ['provide',
#   'basic',
#   'concepts',
#   'issues',
#   'studies',
#   'analysis',
#   'the_unit',
#   'focus',
#   'basic',
#   'principles',
#   'analysis_and',
#   'theories',
#   'relating',
#   'language',
#   'students',
#   'understanding',
#   'theories',
#   'relating',
#   'strategies',
#   'basic',
#   'concepts',
#   'relating',
#   'analysis_and',
#   'strategy',
#   'practice',
#   'students',
#   'ability',
#   'determine',
#   'strategies',
#   'specific',
#   'professional',
#   'projects',
#   'order',
#   'students',
#   'projects',
#   'this_unit',
#   'introduce',
#   'students',
#   'basic',
#   'conceptual',
#   'practical',
#   'issues',
#   'students',
#   'identify',
#   'types',
#   'skills',
#   'analysis_and',
#   'students',
#   'strategies',
#   'professional',
#   'this_unit',
#   'provide',
#   'opportunity',
#   'students',
#   'analytical',
#   'skills_and',
#   'understanding',
#   'factors',
#   'language',
#   'projects',
#   'students',
#   'apply_the',
#   'theories',
#   'skills',
#   'practices'],
#  'ATS2250': ['understanding',
#   'contemporary',
#   'culture',
#   'understanding',
#   'impact',
#   'understand_the',
#   'processes',
#   'economic',
#   'cultural',
#   'part',
#   'development',
#   'effective',
#   'understanding',
#   'developed',
#   'effective',
#   'understand',
#   'range',
#   'theories',
#   'cultural',
#   'theory',
#   'identity',
#   'management',
#   'theory',
#   'identity',
#   'theory',
#   'communication',
#   'theory',
#   'cultural',
#   'theory',
#   'understanding',
#   'range',
#   'media',
#   'the_unit',
#   'covers',
#   'people',
#   'cultural',
#   'communicate',
#   'and_how',
#   'cultural'],
#  'ATS2275': ['explain',
#   'analyse_the',
#   'world',
#   'identify_and',
#   'explain_the',
#   'current',
#   'global',
#   'context',
#   'identify_and',
#   'appraise',
#   'and_how',
#   'responses',
#   'current',
#   'responses',
#   'and_the',
#   'integrate',
#   'academic',
#   'literature',
#   'theory',
#   'history',
#   'politics',
#   'international',
#   'undertake',
#   'research',
#   'analysis',
#   'important',
#   'major',
#   'policy',
#   'area',
#   'primary',
#   'written',
#   'political',
#   'students',
#   'this_unit',
#   'gain',
#   'understanding',
#   'and_the',
#   'policy',
#   'problems',
#   'respond',
#   'global',
#   'challenges',
#   'world'],
#  'ATS2385': ['demonstrate',
#   'critical',
#   'understanding',
#   'history',
#   'and_the',
#   'understanding',
#   'experience',
#   'ability',
#   'personal',
#   'awareness',
#   'historical',
#   'social',
#   'context',
#   'and_how',
#   'relationship',
#   'with_the',
#   'and_the',
#   'world',
#   'capacity',
#   'research_and',
#   'critically_evaluate',
#   'debates',
#   'impact',
#   'australian',
#   'identity',
#   'society',
#   'developed',
#   'skills',
#   'variety',
#   'primary',
#   'sources',
#   'ability',
#   'reflect',
#   'critically',
#   'developed',
#   'skills',
#   'written',
#   'oral',
#   'presentation',
#   'communication',
#   'australian',
#   'society',
#   'identity',
#   'this_unit',
#   'explores',
#   'experience',
#   'major',
#   'focus',
#   'world',
#   'examine',
#   'and_how',
#   'including',
#   'australian',
#   'society',
#   'explore',
#   'and_how',
#   'social',
#   'students_will',
#   'undertake',
#   'research',
#   'primary',
#   'including',
#   'oral',
#   'impact',
#   'and_their'],
#  'ATS2394': ['demonstrate',
#   'critical',
#   'understanding',
#   'economic',
#   'social',
#   'cultural',
#   'understanding',
#   'ways',
#   'contemporary',
#   'international',
#   'understanding',
#   'international',
#   'developed',
#   'capacity',
#   'reflect',
#   'implications',
#   'personal',
#   'culture',
#   'developed',
#   'skills',
#   'variety',
#   'primary',
#   'sources',
#   'ability',
#   'reflect',
#   'critically',
#   'developed',
#   'skills',
#   'written',
#   'oral',
#   'presentation',
#   'communication',
#   'developed',
#   'capacity',
#   'undertake',
#   'personal',
#   'and_the',
#   'capacity',
#   'work',
#   'conduct',
#   'independent',
#   'research',
#   'students',
#   'this_unit',
#   'level',
#   'demonstrate',
#   'level',
#   'skills',
#   'independent',
#   'research_and',
#   'critical',
#   'analysis',
#   'this_unit',
#   'examines',
#   'present',
#   'study',
#   'political',
#   'economic',
#   'cultural',
#   'personal',
#   'the_unit',
#   'contemporary',
#   'historical',
#   'contexts',
#   'identify',
#   'influence',
#   'future',
#   'the_unit',
#   'students',
#   'study',
#   'gain',
#   'awareness',
#   'complex',
#   'social',
#   'cultural',
#   'political',
#   'context',
#   'and_how'],
#  'ATS2422': ['develop',
#   'understanding',
#   'ways',
#   'thinking',
#   'writing',
#   'history',
#   'nature',
#   'and_the',
#   'gain',
#   'knowledge',
#   'work',
#   'literature',
#   'culture',
#   'develop',
#   'skills',
#   'areas',
#   'research',
#   'analysis_and',
#   'communication',
#   'oral',
#   'written',
#   'the_unit',
#   'introduce',
#   'students',
#   'ways',
#   'thinking',
#   'from_the',
#   'focus',
#   'literature',
#   'history',
#   'nature',
#   'visual',
#   'and_the',
#   'history',
#   'culture',
#   'diverse'],
#  'ATS2586': ['explain_the',
#   'historical',
#   'development',
#   'with_the',
#   'major',
#   'identify_and',
#   'discuss',
#   'key',
#   'practices',
#   'and_their',
#   'variety',
#   'history',
#   'analyse',
#   'primary',
#   'sources',
#   'and_the',
#   'order',
#   'respond',
#   'critically',
#   'material',
#   'work',
#   'effectively',
#   'group',
#   'situations',
#   'communicate',
#   'ideas',
#   'the_unit',
#   'examines',
#   'influence',
#   'emphasis',
#   'principles',
#   'law',
#   'philosophy',
#   'examines',
#   'works',
#   'history',
#   'literature',
#   'ways',
#   'principles',
#   'practice',
#   'historical',
#   'review',
#   'modern',
#   'history',
#   'concepts',
#   'society',
#   'roles',
#   'politics',
#   'world',
#   'important',
#   'primary',
#   'sources'],
#  'ATS2600': ['knowledge',
#   'understanding',
#   'responses',
#   'understanding',
#   'responses',
#   'understanding',
#   'issues',
#   'involved',
#   'including',
#   'this_unit',
#   'examines',
#   'history',
#   'major',
#   'topics',
#   'covered',
#   'include',
#   'state',
#   'responses',
#   'and_the',
#   'role',
#   'reflect',
#   'modern',
#   'relationship',
#   'world'],
#  'ATS2687': ['identify_and',
#   'explain_the',
#   'theoretical',
#   'practical',
#   'aspects',
#   'discuss',
#   'relationship',
#   'culture',
#   'practices',
#   'interpret',
#   'processes',
#   'practices',
#   'diverse',
#   'range',
#   'cultural',
#   'sources',
#   'implement',
#   'practical',
#   'skills_and',
#   'strategies',
#   'developing',
#   'individual',
#   'approaches',
#   'this_unit',
#   'strategies',
#   'developing',
#   'approach',
#   'based',
#   'skills',
#   'elements',
#   'terms',
#   'systems',
#   'processes',
#   'developing',
#   'approaches',
#   'and_other',
#   'sources',
#   'the_unit',
#   'practical',
#   'theoretical',
#   'components'],
#  'ATS2699': ['understanding',
#   'importance',
#   'political',
#   'influence',
#   'understanding',
#   'systems',
#   'develop',
#   'knowledge',
#   'political',
#   'science',
#   'systems',
#   'understanding',
#   'theories',
#   'organisation',
#   'analysis',
#   'political',
#   'develop',
#   'understanding',
#   'politics',
#   'and_the',
#   'impact',
#   'debates',
#   'public',
#   'policy',
#   'develop',
#   'advanced',
#   'analytical',
#   'skills',
#   'analyse',
#   'organisational',
#   'communicate',
#   'skills',
#   'situations',
#   'present',
#   'analytical',
#   'research',
#   'advanced',
#   'unit',
#   'politics',
#   'political',
#   'system'],
#  'ATS2868': ['explain_the',
#   'state',
#   'critically_evaluate',
#   'state',
#   'critically_evaluate',
#   'the_unit',
#   'discuss',
#   'state',
#   'role',
#   'law',
#   'relation',
#   'issues',
#   'work',
#   'reference',
#   'contemporary',
#   'political'],
#  'ATS2898': ['understanding',
#   'culture',
#   'oral',
#   'written',
#   'language',
#   'cultural',
#   'knowledge',
#   'history',
#   'contemporary',
#   'cultural',
#   'understanding',
#   'work',
#   'develop',
#   'research',
#   'skills',
#   'understanding',
#   'theoretical',
#   'issues',
#   'society',
#   'culture',
#   'history',
#   'this_unit',
#   'explores',
#   'works',
#   'and_their',
#   'literature',
#   'social',
#   'modern',
#   'literature',
#   'students_will',
#   'written',
#   'visual',
#   'with_the',
#   'challenges',
#   'focus',
#   'the_unit',
#   'from_the',
#   'present',
#   'include',
#   'economic',
#   'history',
#   'identity',
#   'and_how',
#   'culture',
#   'contemporary'],
#  'ATS2910': ['identify',
#   'discuss',
#   'and_apply',
#   'theoretical',
#   'concepts',
#   'associated_with',
#   'physical',
#   'presentation',
#   'skills',
#   'contribute',
#   'reflect',
#   'key',
#   'components',
#   'undertake',
#   'projects',
#   'disciplines',
#   'practical',
#   'strategies',
#   'present',
#   'findings',
#   'range',
#   'academic',
#   'professional',
#   'contexts',
#   'this_unit',
#   'students',
#   'learning',
#   'practices',
#   'activities',
#   'presentation',
#   'skills',
#   'academic',
#   'professional',
#   'students',
#   'introduced',
#   'key',
#   'performance',
#   'presentation',
#   'concepts',
#   'opportunity',
#   'practice',
#   'develop',
#   'skills',
#   'the_unit',
#   'approaches',
#   'study',
#   'presentation',
#   'skills',
#   'specific',
#   'ways'],
#  'ATS3038': ['develop',
#   'understanding',
#   'media',
#   'written',
#   'interpret',
#   'range',
#   'develop',
#   'skills',
#   'understanding',
#   'develop',
#   'understanding',
#   'political',
#   'economic',
#   'social',
#   'major',
#   'issues',
#   'people',
#   'and_other',
#   'high',
#   'study',
#   'this_unit',
#   'introduce',
#   'students',
#   'language',
#   'issues',
#   'international',
#   'current',
#   'topics',
#   'covered',
#   'include',
#   'society',
#   'culture',
#   'politics',
#   'environment',
#   'international',
#   'current',
#   'international',
#   'current',
#   'social',
#   'issues',
#   'students_will',
#   'develop',
#   'research_and',
#   'language',
#   'skills',
#   'language'],
#  'ATS3066': ['writing',
#   'range',
#   'topics',
#   'contexts',
#   'including',
#   'situations',
#   'information',
#   'information',
#   'ideas',
#   'ideas',
#   'writing',
#   'understand',
#   'demonstrate',
#   'understanding',
#   'written',
#   'demonstrate',
#   'areas',
#   'demonstrate',
#   'language',
#   'reference',
#   'material',
#   'demonstrate',
#   'learning',
#   'strategies',
#   'demonstrate',
#   'critical',
#   'knowledge',
#   'understanding',
#   'modern',
#   'culture',
#   'demonstrate',
#   'theory',
#   'basic',
#   'research',
#   'practices',
#   'involved',
#   'critical',
#   'understanding',
#   'analysis',
#   'area',
#   'studies',
#   'demonstrate',
#   'individual',
#   'research',
#   'skills',
#   'this_unit',
#   'language',
#   'skills_and',
#   'cultural',
#   'language',
#   'culture',
#   'this_unit',
#   'develop',
#   'students',
#   'skills_and',
#   'capacity',
#   'ideas',
#   'oral',
#   'written',
#   'range',
#   'activities',
#   'written',
#   'students',
#   'develop',
#   'language',
#   'skills',
#   'area',
#   'studies',
#   'developing',
#   'theory',
#   'research',
#   'practices',
#   'involved',
#   'critical',
#   'understanding',
#   'analysis',
#   'discipline',
#   'area'],
#  'ATS3070': ['advanced',
#   'analytical',
#   'skills',
#   'context',
#   'writing',
#   'making',
#   'presentation',
#   'advanced',
#   'knowledge',
#   'understanding',
#   'modern',
#   'contemporary',
#   'culture',
#   'understanding',
#   'theory',
#   'research',
#   'practices',
#   'area',
#   'studies',
#   'advanced',
#   'language',
#   'skills',
#   'involved',
#   'developing',
#   'critical',
#   'analysis_and',
#   'outcomes',
#   'framework',
#   'research',
#   'individual',
#   'research',
#   'skills',
#   'including',
#   'individual',
#   'research',
#   'skills',
#   'with_the',
#   'research',
#   'development',
#   'framework',
#   'this_unit',
#   'students',
#   'learning',
#   'activities',
#   'developing',
#   'language',
#   'skills_and',
#   'cultural',
#   'skills',
#   'developed',
#   'areas',
#   'focus',
#   'specific',
#   'techniques',
#   'oral',
#   'presentation',
#   'critical',
#   'awareness',
#   'issues',
#   'contemporary',
#   'students',
#   'develop',
#   'advanced',
#   'language',
#   'skills_and',
#   'theory',
#   'research',
#   'practices',
#   'involved',
#   'critical',
#   'understanding',
#   'analysis',
#   'area',
#   'studies',
#   'working',
#   'project'],
#  'ATS3176': ['manage',
#   'social',
#   'situations',
#   'information',
#   'written',
#   'sources',
#   'required',
#   'discuss',
#   'issues',
#   'contemporary',
#   'society',
#   'demonstrate',
#   'the_ability',
#   'information',
#   'disciplines',
#   'develop',
#   'advanced',
#   'unit',
#   'designed',
#   'students',
#   'develop',
#   'language',
#   'skills_and',
#   'knowledge',
#   'history',
#   'culture',
#   'society',
#   'emphasis',
#   'disciplines',
#   'advanced',
#   'skills',
#   'support',
#   'study'],
#  'ATS3190': ['understand',
#   'debates',
#   'modern',
#   'understand_the',
#   'complex',
#   'modern',
#   'the_role',
#   'relationship',
#   'society',
#   'the_unit',
#   'with_the',
#   'from_the',
#   'contemporary',
#   'historical',
#   'relationship',
#   'historical',
#   'this_unit',
#   'relationship',
#   'the_unit',
#   'debates',
#   'modern',
#   'social',
#   'economic',
#   'topics',
#   'including',
#   'and_the',
#   'state',
#   'and_the',
#   'contemporary',
#   'debates'],
#  'ATS3223': ['analyse_and',
#   'explain_the',
#   'designed',
#   'respond',
#   'engage',
#   'variety',
#   'critical',
#   'theoretical',
#   'debates',
#   'identify_and',
#   'critically_evaluate',
#   'literature',
#   'appraise',
#   'range',
#   'approaches',
#   'communicate',
#   'oral',
#   'written',
#   'research_project',
#   'this_unit',
#   'students_will',
#   'examine',
#   'key',
#   'and_the',
#   'designed',
#   'respond',
#   'students_will',
#   'identify',
#   'specific',
#   'area',
#   'area',
#   'students_will',
#   'undertake',
#   'review',
#   'relevant',
#   'academic',
#   'literature',
#   'independent',
#   'research',
#   'research',
#   'the_unit',
#   'staff'],
#  'ATS3241': ['unit',
#   'the_development',
#   'from_the',
#   'modern',
#   'works',
#   'the_unit',
#   'critical',
#   'approaches',
#   'examine',
#   'aspects',
#   'modern',
#   'issues',
#   'relating',
#   'and_the',
#   'individual',
#   'issues',
#   'relating',
#   'social',
#   'identity'],
#  'ATS3265': ['content',
#   'range',
#   'for_the',
#   'visual',
#   'content',
#   'including',
#   'studio',
#   'present',
#   'visual',
#   'content',
#   'understand',
#   'key',
#   'ethical',
#   'legal',
#   'issues',
#   'associated_with',
#   'visual',
#   'content',
#   'situations',
#   'demonstrate',
#   'awareness',
#   'local',
#   'international',
#   'people',
#   'relevant',
#   'current',
#   'media',
#   'issues',
#   'work',
#   'part',
#   'team',
#   'content',
#   'information',
#   'studio',
#   'introduces',
#   'students'],
#  'ATS3359': ['explore',
#   'people',
#   'describe',
#   'relationship',
#   'explore',
#   'environmental',
#   'knowledge',
#   'study',
#   'scientific',
#   'systems',
#   'context',
#   'culture',
#   'explore',
#   'language',
#   'history',
#   'material',
#   'culture',
#   'politics',
#   'ways',
#   'people',
#   'relationship',
#   'with_the',
#   'environment',
#   'study',
#   'and_how',
#   'knowledge',
#   'issues',
#   'language',
#   'understanding',
#   'case',
#   'studies',
#   'material',
#   'and_other',
#   'address',
#   'academic',
#   'debates',
#   'relation',
#   'from_the',
#   'discipline',
#   'issues',
#   'culture',
#   'concepts',
#   'influence',
#   'people',
#   'and_their',
#   'relationship',
#   'environment',
#   'systems',
#   'knowledge',
#   'knowledge',
#   'systems',
#   'systems',
#   'based',
#   'scientific',
#   'science',
#   'research',
#   'knowledge',
#   'knowledge',
#   'system',
#   'ethics',
#   'knowledge',
#   'systems',
#   'knowledge',
#   'care',
#   'order'],
#  'ATS3407': ['students_will',
#   'knowledge',
#   'theories',
#   'students_will',
#   'key',
#   'debates',
#   'developed',
#   'awareness',
#   'historical',
#   'the_development',
#   'developed',
#   'ability',
#   'analyse_and',
#   'interpret',
#   'works',
#   'literature',
#   'social',
#   'reference',
#   'framework',
#   'students_will',
#   'present',
#   'results',
#   'research',
#   'form',
#   'written',
#   'introduction',
#   'theories',
#   'based',
#   'key',
#   'concepts',
#   'historical',
#   'context',
#   'and_the',
#   'structure',
#   'theory',
#   'critique',
#   'application',
#   'literature',
#   'social'],
#  'ATS3679': ['demonstrate',
#   'understanding',
#   'process',
#   'language',
#   'acquisition',
#   'discuss',
#   'theories',
#   'language',
#   'acquisition',
#   'describe',
#   'language',
#   'data',
#   'terms',
#   'understand',
#   'area',
#   'language',
#   'acquisition',
#   'literature',
#   'students',
#   'develop',
#   'critical',
#   'skills',
#   'skills',
#   'dealing',
#   'language',
#   'data',
#   'the_ability',
#   'assess',
#   'evidence',
#   'theories',
#   'evaluate',
#   'theories',
#   'the_ability',
#   'present',
#   'writing',
#   'the_unit',
#   'the_development',
#   'language',
#   'acquisition',
#   'including',
#   'the_development',
#   'examines',
#   'the_development',
#   'system',
#   'development',
#   'models',
#   'theories'],
#  'ATS3743': ['practical',
#   'experience',
#   'awareness',
#   'application',
#   'processes',
#   'including',
#   'opportunity',
#   'understand',
#   'work',
#   'terms',
#   'history',
#   'politics',
#   'understanding',
#   'concepts',
#   'theories',
#   'and_their',
#   'application',
#   'decision',
#   'making',
#   'opportunity',
#   'develop',
#   'plan',
#   'skills',
#   'opportunity',
#   'awareness',
#   'strategies',
#   'development',
#   'unit',
#   'students',
#   'with_the',
#   'capacity',
#   'manage',
#   'understanding',
#   'history',
#   'future',
#   'work',
#   'work',
#   'and_the',
#   'role',
#   'professional',
#   'provide',
#   'setting',
#   'concepts',
#   'theories',
#   'and_their',
#   'application',
#   'individual',
#   'students_will',
#   'develop',
#   'plan',
#   'based',
#   'awareness',
#   'skills_and',
#   'understanding',
#   'approaches',
#   'decision',
#   'making'],
#  'ATS3825': ['demonstrate',
#   'knowledge',
#   'major',
#   'and_the',
#   'ways',
#   'analyse',
#   'specific',
#   'areas',
#   'works',
#   'important',
#   'specific',
#   'area',
#   'understand_the',
#   'principles',
#   'modern',
#   'this_unit',
#   'primary',
#   'the_unit',
#   'works',
#   'major',
#   'topics',
#   'include',
#   'system',
#   'including',
#   'techniques',
#   'the_unit',
#   'contemporary',
#   'australian',
#   'context'],
#  'ATS3829': ['demonstrate',
#   'knowledge',
#   'history',
#   'critically_evaluate',
#   'analyse',
#   'theory',
#   'performance',
#   'techniques',
#   'and_how',
#   'reflect',
#   'local',
#   'cultural',
#   'the_unit',
#   'examines',
#   'social',
#   'concepts',
#   'practices',
#   'reference',
#   'and_the',
#   'and_the',
#   'related'],
#  'ATS3852': ['developed',
#   'knowledge',
#   'contemporary',
#   'social',
#   'variety',
#   'critical',
#   'theoretical',
#   'debates',
#   'developed',
#   'the_ability',
#   'critically_evaluate',
#   'literature',
#   'knowledge',
#   'range',
#   'approaches',
#   'examine',
#   'developed',
#   'the_ability',
#   'communicate',
#   'oral',
#   'written',
#   'developed',
#   'research',
#   'this_unit',
#   'students_will',
#   'identify',
#   'studies',
#   'studies',
#   'studies',
#   'students_will',
#   'undertake',
#   'review',
#   'relevant',
#   'academic',
#   'literature',
#   'independent',
#   'research',
#   'research',
#   'the_unit',
#   'staff'],
#  'ATS3862': ['students',
#   'opportunity',
#   'understanding',
#   'history',
#   'practices',
#   'students',
#   'develop',
#   'skills',
#   'interpret',
#   'explain',
#   'integrate',
#   'analysis',
#   'contemporary',
#   'critical',
#   'material',
#   'develop',
#   'students',
#   'engage',
#   'critical',
#   'thinking',
#   'capacity',
#   'critically',
#   'analyse_and',
#   'evaluate',
#   'concepts',
#   'role',
#   'ideas',
#   'this_unit',
#   'ways',
#   'thinking',
#   'historical',
#   'social',
#   'scientific',
#   'questions',
#   'the_role',
#   'and_the',
#   'relationship',
#   'evidence',
#   'questions',
#   'examines',
#   'and_the',
#   'range',
#   'responses',
#   'diverse'],
#  'ATS3876': ['students',
#   'analytical',
#   'philosophy',
#   'from_the',
#   'present',
#   'provide',
#   'students',
#   'environment',
#   'learn',
#   'skills',
#   'issues',
#   'students',
#   'material',
#   'for_the',
#   'form',
#   'problems',
#   'knowledge',
#   'based',
#   'for_the',
#   'case'],
#  'ATS3905': ['explain',
#   'basic',
#   'advanced',
#   'concepts',
#   'theory',
#   'including',
#   'analysis',
#   'major',
#   'theoretical',
#   'involved',
#   'discuss',
#   'concepts',
#   'social',
#   'theory',
#   'evaluate',
#   'important',
#   'issues',
#   'relating',
#   'history',
#   'politics',
#   'relation',
#   'human',
#   'identify',
#   'relevant',
#   'literature',
#   'for_the',
#   'work',
#   'nature',
#   'apply',
#   'independent',
#   'research',
#   'academic',
#   'communication',
#   'skills',
#   'contemporary',
#   'world',
#   'diverse',
#   'types',
#   'systems',
#   'system',
#   'people',
#   'modern',
#   'this_unit',
#   'contemporary',
#   'political',
#   'and_how'],
#  'ATS3969': ['identify_and',
#   'evaluate',
#   'theory',
#   'relation',
#   'debates',
#   'contemporary',
#   'historical',
#   'methods',
#   'apply',
#   'range',
#   'theoretical',
#   'approaches',
#   'media',
#   'range',
#   'media',
#   'apply',
#   'advanced',
#   'research',
#   'skills',
#   'critically',
#   'reflect',
#   'synthesise',
#   'theoretical',
#   'approaches',
#   'studies',
#   'communicate',
#   'written',
#   'oral',
#   'form',
#   'design',
#   'problem',
#   'solving',
#   'group',
#   'project',
#   'task',
#   'interpret',
#   'analyse',
#   'critical',
#   'cultural',
#   'political',
#   'theoretical',
#   'practices',
#   'context',
#   'this_unit',
#   'provide',
#   'opportunity',
#   'students',
#   'critically',
#   'reflect',
#   'key',
#   'critical',
#   'approaches',
#   'concepts',
#   'studies',
#   'focus',
#   'technologies',
#   'theoretical',
#   'critical',
#   'issues',
#   'field',
#   'apply',
#   'range',
#   'research_project',
#   'approach',
#   'provide',
#   'students',
#   'advanced',
#   'research',
#   'skills_and',
#   'methodologies'],
#  'ATS3978': ['variety',
#   'written',
#   'written',
#   'professional',
#   'situations',
#   'identity',
#   'situations',
#   'strategies',
#   'apply',
#   'range',
#   'approaches',
#   'understanding',
#   'business',
#   'context',
#   'demonstrate',
#   'critical',
#   'understanding',
#   'concepts',
#   'terms',
#   'describe',
#   'discuss',
#   'approaches',
#   'work',
#   'professional',
#   'critically',
#   'engage',
#   'existing',
#   'research',
#   'with_the',
#   'learning',
#   'demonstrate',
#   'independent',
#   'research',
#   'skills',
#   'including',
#   'techniques',
#   'critical',
#   'thinking',
#   'skills',
#   'oral',
#   'written',
#   'communication',
#   'the_unit',
#   'advanced',
#   'students',
#   'language',
#   'theoretical',
#   'practical',
#   'knowledge',
#   'challenges',
#   'language',
#   'and_the',
#   'strategies',
#   'challenges',
#   'the_unit',
#   'variety',
#   'professional',
#   'settings',
#   'roles',
#   'including',
#   'working',
#   'organisation',
#   'cultural',
#   'students_will',
#   'existing',
#   'language',
#   'skills',
#   'communication_and',
#   'engage',
#   'key',
#   'ideas'],
#  'ATS4002': ['apply',
#   'contemporary',
#   'media',
#   'research',
#   'methods',
#   'undertake',
#   'independent',
#   'project',
#   'analyse_and',
#   'engage',
#   'conceptual',
#   'critical',
#   'review',
#   'existing',
#   'literature',
#   'structure',
#   'communicate',
#   'project',
#   'this_unit',
#   'students',
#   'year',
#   'media',
#   'designed',
#   'students',
#   'key',
#   'disciplines',
#   'studies',
#   'communication_and',
#   'media',
#   'studies',
#   'engage',
#   'research',
#   'methods',
#   'develop',
#   'the_research',
#   'conceptual',
#   'skills',
#   'required',
#   'study',
#   'level'],
#  'ATS4231': ['planning',
#   'research',
#   'discipline',
#   'demonstrate',
#   'planning',
#   'implementation',
#   'research',
#   'demonstrate',
#   'the_research',
#   'literature',
#   'relating',
#   'research_project',
#   'academic',
#   'staff',
#   'students_will',
#   'develop',
#   'implementation',
#   'research_project',
#   'this_unit',
#   'project'],
#  'AZA1011': ['understand_the',
#   'major',
#   'concepts',
#   'international',
#   'including',
#   'international',
#   'system',
#   'human',
#   'global',
#   'understand',
#   'critically_evaluate',
#   'theories',
#   'approaches',
#   'international',
#   'critical',
#   'perspectives',
#   'social',
#   'politics',
#   'identify',
#   'key',
#   'international',
#   'understand',
#   'international',
#   'undertake',
#   'variety',
#   'research_and',
#   'writing',
#   'demonstrate',
#   'oral',
#   'written',
#   'communication',
#   'skills',
#   'relation',
#   'analysis_and',
#   'ideas',
#   'and_the',
#   'development',
#   'the_unit',
#   'introduce',
#   'students',
#   'international',
#   'including',
#   'major',
#   'international',
#   'theory',
#   'key',
#   'international',
#   'issues',
#   'human',
#   'global',
#   'and_the',
#   'global',
#   'international',
#   'law',
#   'the_unit',
#   'introduces',
#   'international',
#   'including',
#   'global',
#   'society'],
#  'AZA1308': ['understand_the',
#   'major',
#   'ideas',
#   'understand_the',
#   'present',
#   'emphasis',
#   'environment',
#   'synthesise',
#   'interpret',
#   'relevant',
#   'material',
#   'communicate',
#   'ideas',
#   'written',
#   'techniques',
#   'basic',
#   'physical',
#   'environmental',
#   'information',
#   'basic',
#   'techniques',
#   'undertake',
#   'independent',
#   'field',
#   'study',
#   'environment',
#   'understand_the',
#   'problems',
#   'associated_with',
#   'making',
#   'field',
#   'this_unit',
#   'with_the',
#   'basic',
#   'understanding',
#   'world',
#   'advanced',
#   'study',
#   'related',
#   'disciplines'],
#  'AZA1328': ['demonstrate',
#   'ability',
#   'identify_and',
#   'research',
#   'conduct',
#   'evidence',
#   'demonstrate',
#   'ability',
#   'report',
#   'media',
#   'key',
#   'ethical',
#   'legal',
#   'associated_with',
#   'context',
#   'reflect',
#   'critically',
#   'performance',
#   'work',
#   'learning',
#   'processes',
#   'including',
#   'demonstrate',
#   'ability',
#   'report',
#   'demonstrate',
#   'awareness',
#   'local',
#   'international',
#   'people',
#   'relevant',
#   'current',
#   'issues',
#   'media',
#   'issues',
#   'demonstrate',
#   'critical',
#   'awareness',
#   'implications',
#   'practices',
#   'media',
#   'the_unit',
#   'critical',
#   'introduction',
#   'key',
#   'concepts',
#   'practices',
#   'research_and',
#   'social',
#   'professional',
#   'legal',
#   'context',
#   'technical',
#   'media',
#   'students',
#   'research_and',
#   'media',
#   'critical',
#   'evaluation',
#   'performance'],
#  'AZA2030': ['demonstrate',
#   'understanding',
#   'communication',
#   'strategy',
#   'apply',
#   'principles',
#   'environmental',
#   'writing',
#   'demonstrate',
#   'understanding',
#   'content',
#   'communication',
#   'strategy',
#   'apply_the',
#   'process',
#   'developing',
#   'communication',
#   'strategy',
#   'demonstrate',
#   'understanding',
#   'identity',
#   'research_and',
#   'identity',
#   'identify_and',
#   'explain',
#   'describe',
#   'communication_and',
#   'communication',
#   'identify',
#   'situations',
#   'demonstrate',
#   'high',
#   'standard',
#   'written',
#   'oral',
#   'communication',
#   'skills_and',
#   'organisation',
#   'skills_and',
#   'planning',
#   'analyse',
#   'case',
#   'studies',
#   'relating',
#   'identity',
#   'the_unit',
#   'students',
#   'apply',
#   'advanced',
#   'principles',
#   'communication',
#   'public',
#   'practices',
#   'the_unit',
#   'role',
#   'public',
#   'communication',
#   'organisational',
#   'context',
#   'the_unit',
#   'planning',
#   'implementation',
#   'management',
#   'evaluation',
#   'strategies',
#   'relating',
#   'identity',
#   'the_unit',
#   'related',
#   'practices',
#   'communication',
#   'public',
#   'communication'],
#  'AZA2765': ['information',
#   'sources',
#   'conceptual',
#   'academic',
#   'debates',
#   'communication',
#   'skills',
#   'this_unit',
#   'demonstrate',
#   'knowledge',
#   'with_the',
#   'types',
#   'information',
#   'academic',
#   'perspectives',
#   'skills',
#   'services',
#   'setting',
#   'environmental',
#   'social',
#   'development',
#   'principles',
#   'group',
#   'models',
#   'care',
#   'ability',
#   'evaluate',
#   'system',
#   'design',
#   'services',
#   'setting',
#   'apply',
#   'environmental',
#   'understanding',
#   'social',
#   'development',
#   'principles',
#   'group',
#   'models',
#   'care',
#   'the_ability',
#   'evaluate',
#   'system',
#   'design',
#   'care',
#   'this_unit',
#   'students',
#   'theoretical',
#   'knowledge',
#   'related',
#   'problems',
#   'this_unit',
#   'group',
#   'environmental',
#   'models',
#   'care',
#   'important',
#   'student',
#   'evaluate_the'],
#  'AZA3184': ['critically',
#   'reflect',
#   'analyse_and',
#   'undertake',
#   'public',
#   'task',
#   'critically',
#   'appraise',
#   'theoretical',
#   'concepts',
#   'public',
#   'work',
# ...
#   'patient',
#   'assessment',
#   'care',
#   'care',
#   'decision',
#   'complex',
#   'patient',
#   'based',
#   'understanding',
#   'determine',
#   'human',
#   'factors',
#   'effective',
#   'management',
#   'complex',
#   'patients',
#   'case',
#   'settings',
#   'reflect',
#   'awareness',
#   'appraise',
#   'ethical',
#   'professional',
#   'advanced',
#   'practice',
#   'identify',
#   'process',
#   'professional',
#   'developed',
#   'evaluate_the',
#   'the_role',
#   'advanced',
#   'care',
#   'and_the',
#   'importance',
#   'effective',
#   'communication_and',
#   'complex',
#   'this_unit',
#   'introduces',
#   'concepts',
#   'related',
#   'patient',
#   'care',
#   'advanced',
#   'care',
#   'level'],
#  'PAR5440': ['examine',
#   'and_apply',
#   'knowledge',
#   'structure',
#   'systems',
#   'related',
#   'including',
#   'support',
#   'and_the',
#   'related',
#   'role',
#   'health',
#   'analyse_the',
#   'environmental',
#   'specific',
#   'care',
#   'clinical',
#   'management',
#   'strategies',
#   'formulate',
#   'relevant',
#   'for_the',
#   'care',
#   'management',
#   'environmental',
#   'implement',
#   'knowledge',
#   'skills_and',
#   'evidence',
#   'based',
#   'practice',
#   'manage',
#   'environmental',
#   'care',
#   'synthesise',
#   'environmental',
#   'determine',
#   'management',
#   'patients',
#   'critical',
#   'care',
#   'framework',
#   'system',
#   'this_unit',
#   'introduces',
#   'students',
#   'advanced',
#   'level',
#   'knowledge',
#   'understanding',
#   'related',
#   'care',
#   'management',
#   'patients',
#   'environmental',
#   'care',
#   'from_the',
#   'contemporary',
#   'systems',
#   'critical',
#   'specific',
#   'related',
#   'student',
#   'development',
#   'advanced',
#   'skills',
#   'effectively',
#   'manage'],
#  'PBH3006': ['apply',
#   'knowledge',
#   'skills',
#   'research',
#   'design',
#   'data',
#   'analysis',
#   'practice',
#   'public',
#   'health',
#   'research',
#   'demonstrate',
#   'understanding',
#   'practical',
#   'issues',
#   'public',
#   'health',
#   'research',
#   'critically',
#   'reflect',
#   'skills',
#   'required',
#   'research',
#   'practice',
#   'including',
#   'professional',
#   'ethical',
#   'practical',
#   'issues',
#   'present',
#   'oral',
#   'written',
#   'research',
#   'processes',
#   'research',
#   'outcomes',
#   'this_unit',
#   'opportunity',
#   'high',
#   'students',
#   'experience',
#   'public',
#   'health',
#   'research',
#   'practice',
#   'application',
#   'this_unit'],
#  'PGP5011': ['demonstrate',
#   'sound',
#   'understanding',
#   'legal',
#   'professional',
#   'ethical',
#   'framework',
#   'practice',
#   'demonstrate',
#   'problem',
#   'solving',
#   'skills_and',
#   'apply',
#   'professional',
#   'range',
#   'areas',
#   'including',
#   'problems',
#   'problems',
#   'legal',
#   'ethical',
#   'problems',
#   'apply',
#   'principles',
#   'practice',
#   'contribute',
#   'provide',
#   'primary',
#   'health',
#   'care',
#   'including',
#   'patients',
#   'evaluation',
#   'products',
#   'effectively',
#   'communicate',
#   'information',
#   'patients',
#   'and_other',
#   'health',
#   'complex',
#   'understand_the',
#   'nature',
#   'importance',
#   'care',
#   'apply',
#   'organisational',
#   'skills_and',
#   'manage',
#   'work',
#   'issues',
#   'practice',
#   'applied',
#   'practice',
#   'year',
#   'this_unit',
#   'knowledge',
#   'experience',
#   'develop',
#   'required',
#   'independent',
#   'practice',
#   'the_unit',
#   'explores',
#   'practice',
#   'including',
#   'problem',
#   'solving',
#   'evidence',
#   'based',
#   'practice',
#   'management',
#   'patient',
#   'application',
#   'professional',
#   'standards',
#   'ethical',
#   'legal',
#   'aspects',
#   'practice',
#   'approaches',
#   'health',
#   'care',
#   'primary',
#   'care',
#   'communication_and',
#   'health',
#   'management',
#   'dealing',
#   'situations',
#   'practice',
#   'this_unit',
#   'students_will',
#   'technical',
#   'clinical',
#   'personal',
#   'professional',
#   'skills'],
#  'PGW5211': ['examine',
#   'including',
#   'factors',
#   'apply',
#   'patient',
#   'assessment',
#   'setting',
#   'management',
#   'individual',
#   'critically',
#   'appraise',
#   'patient',
#   'develop',
#   'implement',
#   'team',
#   'approach',
#   'management',
#   'patient',
#   'formulate',
#   'management',
#   'plan',
#   'assessment',
#   'tools',
#   'critically',
#   'appraise',
#   'effective',
#   'management',
#   'develop',
#   'strategies',
#   'examine',
#   'quality',
#   'issues',
#   'relation',
#   'individual',
#   'factors',
#   'related',
#   'patient',
#   'professional',
#   'this_unit',
#   'explores',
#   'complex',
#   'issues',
#   'challenges',
#   'associated_with',
#   'care',
#   'challenges',
#   'assessment',
#   'effective',
#   'management',
#   'plan'],
#  'PHH1112': ['explain_the',
#   'health_and',
#   'world',
#   'address',
#   'global',
#   'health',
#   'challenges',
#   'identify',
#   'design',
#   'relevant',
#   'approaches',
#   'global',
#   'health',
#   'challenges',
#   'identify',
#   'future',
#   'global',
#   'health',
#   'challenges',
#   'and_their',
#   'analyse_the',
#   'global',
#   'health',
#   'critically',
#   'reflect',
#   'contemporary',
#   'debates',
#   'health',
#   'this_unit',
#   'health',
#   'world',
#   'and_the',
#   'challenges',
#   'people',
#   'developing',
#   'explore',
#   'including',
#   'development',
#   'social',
#   'political',
#   'research',
#   'case',
#   'studies',
#   'examine',
#   'context',
#   'working',
#   'international',
#   'settings',
#   'issues',
#   'explore',
#   'global',
#   'ways'],
#  'PSY5104': ['students',
#   'knowledge',
#   'ethical',
#   'principles',
#   'research_and',
#   'professional',
#   'practice',
#   'understand',
#   'apply',
#   'knowledge',
#   'relevant',
#   'professional',
#   'conduct',
#   'issues',
#   'information',
#   'professional',
#   'professional',
#   'conduct',
#   'understanding',
#   'issues',
#   'impact',
#   'practice',
#   'range',
#   'topics',
#   'associated_with',
#   'services',
#   'including',
#   'basic',
#   'skills',
#   'review',
#   'relevant',
#   'ethical',
#   'professional',
#   'standards',
#   'developing',
#   'practice',
#   'this_unit',
#   'material',
#   'including',
#   'group',
#   'role'],
#  'RTS5103': ['identify_and',
#   'describe',
#   'related',
#   'systems',
#   'critically',
#   'analyse',
#   'planning',
#   'techniques',
#   'reference',
#   'international',
#   'standards',
#   'personal',
#   'for_the',
#   'systems',
#   'demonstrate',
#   'level',
#   'planning',
#   'procedures',
#   'range',
#   'describe',
#   'reference',
#   'patient',
#   'care',
#   'management',
#   'strategies',
#   'related',
#   'systems',
#   'level',
#   'patient',
#   'care',
#   'management',
#   'communication_and',
#   'professional',
#   'skills',
#   'range',
#   'patients',
#   'describe_the',
#   'process',
#   'evaluate_the',
#   'clinical',
#   'planning',
#   'describe',
#   'and_apply',
#   'principles',
#   'safety',
#   'quality',
#   'management',
#   'occupational',
#   'health_and',
#   'safety',
#   'appraise',
#   'procedures',
#   'legal',
#   'appraise',
#   'demonstrate',
#   'level',
#   'analyse_and',
#   'principles',
#   'clinical',
#   'plan',
#   'evaluation',
#   'tools',
#   'level',
#   'evaluate_the',
#   'describe',
#   'discuss',
#   'effective',
#   'working',
#   'with_the',
#   'team',
#   'this_unit',
#   'dealing',
#   'with_the',
#   'principles',
#   'planning',
#   'this_unit',
#   'systems',
#   'students_will',
#   'analyse_and',
#   'evaluate_the',
#   'principles',
#   'quality',
#   'and_how',
#   'practice',
#   'students_will',
#   'gain',
#   'knowledge',
#   'the_role',
#   'students_will',
#   'analyse_and',
#   'evaluate',
#   'planning',
#   'evaluation',
#   'tools',
#   'this_unit',
#   'learning',
#   'clinical',
#   'students',
#   'develop',
#   'clinical',
#   'professional',
#   'skills',
#   'level',
#   'topics',
#   'students_will',
#   'critically',
#   'reflect',
#   'analyse_and',
#   'relevant',
#   'information',
#   'from_the',
#   'literature',
#   'reflect',
#   'clinical'],
#  'SCI3716': ['discuss',
#   'issues',
#   'scientific',
#   'describe',
#   'occupational',
#   'health_and',
#   'safety',
#   'related',
#   'recognise',
#   'associated_with',
#   'and_the',
#   'undertake',
#   'assessment',
#   'working',
#   'procedures',
#   'apply_the',
#   'principles',
#   'physical',
#   'science',
#   'discuss',
#   'environment',
#   'procedures',
#   'for_the',
#   'analysis_and',
#   'environment',
#   'this_unit',
#   'designed',
#   'introduce',
#   'principles',
#   'management',
#   'and_their',
#   'and_the',
#   'issues',
#   'occupational',
#   'health_and',
#   'safety',
#   'and_the',
#   'analysis',
#   'emphasis',
#   'assessment',
#   'management',
#   'issues',
#   'environment',
#   'learning',
#   'material',
#   'practical',
#   'work',
#   'assessment',
#   'case',
#   'studies'],
#  'SWK3220': ['describe_the',
#   'nature',
#   'social',
#   'work',
#   'range',
#   'contexts',
#   'settings',
#   'describe',
#   'contemporary',
#   'debates',
#   'nature',
#   'social',
#   'work',
#   'critically',
#   'analyse_the',
#   'ethical',
#   'social',
#   'work',
#   'reference',
#   'human',
#   'and_the',
#   'social',
#   'critically',
#   'analyse',
#   'key',
#   'global',
#   'social',
#   'policy',
#   'issues',
#   'including',
#   'people',
#   'critically',
#   'review',
#   'analyse',
#   'contemporary',
#   'social',
#   'work',
#   'services',
#   'articulate',
#   'nature',
#   'social',
#   'and_the',
#   'strategies',
#   'this_unit',
#   'history',
#   'contemporary',
#   'context',
#   'social',
#   'work',
#   'practice',
#   'framework',
#   'understanding',
#   'social',
#   'issues',
#   'policy',
#   'development',
#   'strategies',
#   'local',
#   'global',
#   'the_unit',
#   'social',
#   'human',
#   'topics'],
#  'SWM5170': ['work',
#   'academic',
#   'the_development',
#   'assessment',
#   'assessment',
#   'integrate',
#   'research',
#   'knowledge',
#   'present',
#   'professional',
#   'experience',
#   'work',
#   'academic',
#   'the_development',
#   'assessment',
#   'assessment',
#   'advanced',
#   'research',
#   'knowledge',
#   'skills',
#   'develop',
#   'practice',
#   'clinical',
#   'policy',
#   'articulate',
#   'practice',
#   'knowledge',
#   'skills',
#   'developing',
#   'the_research',
#   'report',
#   'evaluation',
#   'report',
#   'develop',
#   'appraise',
#   'personal',
#   'role',
#   'professional',
#   'social',
#   'work',
#   'develop',
#   'appraise',
#   'personal',
#   'role',
#   'professional',
#   'social',
#   'work',
#   'report',
#   'content',
#   'developed',
#   'student',
#   'staff',
#   'assessment',
#   'developed',
#   'student',
#   'this_unit'],
#  'TAD2214': ['recognise',
#   'key',
#   'works',
#   'design_and',
#   'relationship',
#   'critical',
#   'issues',
#   'demonstrate',
#   'understanding',
#   'influence',
#   'impact',
#   'physical',
#   'social',
#   'cultural',
#   'the_role',
#   'and_the',
#   'design',
#   'demonstrate',
#   'critical',
#   'analytical',
#   'skills',
#   'works',
#   'design',
#   'articulate',
#   'responses',
#   'cultural',
#   'work',
#   'design',
#   'critique',
#   'perspectives',
#   'for_the',
#   'design',
#   'understand',
#   'apply_the',
#   'rules',
#   'occupational',
#   'health_and',
#   'safety',
#   'the_unit',
#   'study',
#   'this_unit',
#   'visual',
#   'theoretical',
#   'design',
#   'relation',
#   'key',
#   'critical',
#   'issues',
#   'issues',
#   'including',
#   'works',
#   'design',
#   'society',
#   'politics',
#   'and_the',
#   'environment',
#   'the_role',
#   'social',
#   'challenges',
#   'students_will',
#   'develop',
#   'range',
#   'approaches',
#   'understanding',
#   'works',
#   'design_and',
#   'related',
#   'issues',
#   'critical',
#   'analytical',
#   'skills',
#   'disciplines'],
#  'TDN1002': ['identify_and',
#   'describe_the',
#   'major',
#   'design',
#   'recognise',
#   'analyse',
#   'key',
#   'practices',
#   'design',
#   'discuss',
#   'and_their',
#   'influence',
#   'social',
#   'role',
#   'basic',
#   'theoretical',
#   'contexts',
#   'practice',
#   'critique',
#   'works',
#   'design_and',
#   'articulate',
#   'written',
#   'form',
#   'identify',
#   'questions',
#   'ways',
#   'information',
#   'this_unit',
#   'examines',
#   'history',
#   'disciplines',
#   'visual',
#   'communication',
#   'design_and',
#   'design',
#   'key',
#   'practices',
#   'political',
#   'cultural',
#   'contexts',
#   'critical',
#   'practices',
#   'terms',
#   'implications',
#   'for_the',
#   'social',
#   'role',
#   'design',
#   'students_will',
#   'develop',
#   'range',
#   'critical',
#   'approaches',
#   'design',
#   'relation',
#   'historical',
#   'social',
#   'cultural',
#   'context',
#   'skills',
#   'disciplines',
#   'practice'],
#  'UPD4002': ['demonstrate',
#   'ethical',
#   'approaches',
#   'contemporary',
#   'planning',
#   'the_ability',
#   'respond',
#   'complex',
#   'problems',
#   'develop',
#   'planning',
#   'responses',
#   'processes',
#   'outcomes',
#   'developed',
#   'skills',
#   'research',
#   'critique',
#   'address',
#   'planning',
#   'issues',
#   'high',
#   'level',
#   'communication_and',
#   'presentation',
#   'skills',
#   'written',
#   'understand',
#   'apply_the',
#   'rules',
#   'occupational',
#   'health_and',
#   'safety',
#   'the_unit',
#   'study',
#   'project',
#   'explores',
#   'projects',
#   'systems',
#   'students',
#   'develop',
#   'research',
#   'technical',
#   'capacity',
#   'analytical',
#   'approaches',
#   'planning',
#   'systems'],
#  'UPD5001': ['critically',
#   'reflect',
#   'practice',
#   'ethical',
#   'approaches',
#   'contemporary',
#   'planning',
#   'respond',
#   'complex',
#   'problems',
#   'related',
#   'apply',
#   'skills',
#   'research',
#   'address',
#   'planning',
#   'issues',
#   'communicate',
#   'written',
#   'issues',
#   'understand',
#   'apply_the',
#   'rules',
#   'occupational',
#   'health_and',
#   'safety',
#   'the_unit',
#   'study',
#   'planning',
#   'project',
#   'the_role',
#   'planning',
#   'issues',
#   'associated_with',
#   'the_unit',
#   'advanced',
#   'concepts',
#   'knowledge',
#   'skills',
#   'range',
#   'complex',
#   'issues',
#   'relevant',
#   'planning',
#   'level',
#   'critical',
#   'research',
#   'analysis_and',
#   'settings',
#   'the_unit',
#   'concepts',
#   'approaches',
#   'processes',
#   'outcomes',
#   'and_the',
#   'skills',
#   'communicate',
#   'effectively',
#   'diverse'],
#  'UPD5002': ['critically',
#   'reflect',
#   'practice',
#   'ethical',
#   'approaches',
#   'contemporary',
#   'planning',
#   'diverse',
#   'respond',
#   'complex',
#   'problems',
#   'develop',
#   'planning',
#   'responses',
#   'processes',
#   'outcomes',
#   'social',
#   'planning',
#   'apply',
#   'skills',
#   'research',
#   'address',
#   'social',
#   'planning',
#   'issues',
#   'communicate',
#   'written',
#   'social',
#   'planning',
#   'issues',
#   'understand',
#   'apply_the',
#   'rules',
#   'occupational',
#   'health_and',
#   'safety',
#   'the_unit',
#   'study',
#   'planning',
#   'project',
#   'issues',
#   'social',
#   'planning',
#   'address',
#   'the_unit',
#   'advanced',
#   'concepts',
#   'knowledge',
#   'skills',
#   'range',
#   'complex',
#   'issues',
#   'relevant',
#   'planning',
#   'critical',
#   'research',
#   'analysis_and',
#   'settings',
#   'the_unit',
#   'concepts',
#   'approaches',
#   'processes',
#   'outcomes',
#   'and_the',
#   'skills',
#   'communicate',
#   'effectively',
#   'diverse'],
#  'VCM4029': ['range',
#   'systems',
#   'analysis',
#   'design',
#   'methodologies',
#   'and_their',
#   'tools',
#   'principles',
#   'understand_the',
#   'and_their',
#   'roles',
#   'the_development',
#   'systems',
#   'apply',
#   'quality',
#   'techniques',
#   'for_the',
#   'analysis',
#   'design',
#   'implementation',
#   'systems',
#   'understand_the',
#   'approaches',
#   'systems',
#   'analysis_and',
#   'design',
#   'analysis',
#   'models',
#   'design',
#   'models',
#   'system',
#   'analysis_and',
#   'design',
#   'system',
#   'apply',
#   'sound',
#   'principles',
#   'language',
#   'develop',
#   'skills',
#   'team',
#   'this_unit',
#   'examine',
#   'activities',
#   'the_development',
#   'systems',
#   'techniques',
#   'systems',
#   'analysis_and',
#   'design',
#   'the_development',
#   'process',
#   'fundamental',
#   'concepts',
#   'introduced',
#   'language',
#   'framework',
#   'system',
#   'development',
#   'students_will',
#   'involved',
#   'individual',
#   'work',
#   'application',
#   'theoretical',
#   'knowledge',
#   'practical',
#   'problems',
#   'systems',
#   'development'],
#  'VCM4601': ['recognise',
#   'analyse_and',
#   'elements',
#   'design',
#   'understand_the',
#   'role',
#   'visual',
#   'communication_and',
#   'fundamental',
#   'design',
#   'principles',
#   'applied',
#   'media',
#   'recognise',
#   'theoretical',
#   'issues',
#   'theories',
#   'understand',
#   'and_apply',
#   'theories',
#   'media',
#   'recognise',
#   'analyse_and',
#   'ideas',
#   'concepts',
#   'visual',
#   'communication',
#   'design_and',
#   'occupational',
#   'health_and',
#   'safety',
#   'studio',
#   'practice',
#   'students',
#   'introduced',
#   'fundamental',
#   'elements',
#   'principles',
#   'design',
#   'applied',
#   'students',
#   'gain',
#   'design',
#   'skills_and',
#   'knowledge',
#   'complex',
#   'principles',
#   'design',
#   'form',
#   'support',
#   'visual',
#   'based',
#   'media',
#   'projects',
#   'techniques',
#   'methods']}

# %% [markdown]
# #### The Porter Stemmer is used to find out the stems of all the words appearing in the `stem_dictionary`
# #### These word stems are then appended to a list which is added to a dictionary containing the keys as the unit codes and the values as the stems inside `word_stem_dictionary`

# %%
from nltk.stem import PorterStemmer

def word_stemmer(key):
    word_stems = [PorterStemmer().stem(vals) for vals in  stem_dictionary[key]]
    return(key,word_stems)
word_stem_dictionary =  dict(word_stemmer(key) for key,values in stem_dictionary.items())

word_stem_dictionary
# Out:
# {'ACB3021': ['appli',
#   'contemporari',
#   'perform',
#   'control',
#   'techniqu',
#   'organis',
#   'perform',
#   'analyse_and',
#   'design',
#   'perform',
#   'control',
#   'system',
#   'explain',
#   'implic',
#   'for_th',
#   'effect',
#   'design',
#   'perform',
#   'control',
#   'system',
#   'appli',
#   'critic',
#   'think',
#   'problem',
#   'solv',
#   'present',
#   'skill',
#   'individu',
#   'group',
#   'activ',
#   'deal',
#   'perform',
#   'control',
#   'demonstr',
#   'individu',
#   'summ',
#   'assess',
#   'task',
#   'acquisit',
#   'comprehens',
#   'understand',
#   'topic',
#   'cover',
#   'topic',
#   'includ',
#   'plan',
#   'process',
#   'includ',
#   'standard',
#   'analysi',
#   'manag',
#   'perform',
#   'perform',
#   'issu',
#   'and_oth',
#   'approach',
#   'plan',
#   'control'],
#  'ACW3041': ['demonstr',
#   'understand',
#   'the_rol',
#   'modern',
#   'societi',
#   'includ',
#   'profession',
#   'ethic',
#   'legal',
#   'examin',
#   'role',
#   'emphasi',
#   'describe_th',
#   'framework',
#   'and_appli',
#   'plan',
#   'process',
#   'evid',
#   'procedur',
#   'form',
#   'appli',
#   'critic',
#   'think',
#   'problem',
#   'solv',
#   'present',
#   'skill',
#   'individu',
#   'group',
#   'activ',
#   'deal',
#   'demonstr',
#   'individu',
#   'summ',
#   'assess',
#   'task',
#   'acquisit',
#   'comprehens',
#   'understand',
#   'topic',
#   'cover',
#   'legal',
#   'process',
#   'evid',
#   'concept',
#   'studi',
#   'evalu',
#   'control',
#   'techniqu',
#   'and_th'],
#  'ACX4018': ['implement',
#   'research',
#   'recognis',
#   'practic',
#   'problem',
#   'scientif',
#   'research_and',
#   'solut',
#   'research',
#   'develop',
#   'the_abl',
#   'conduct',
#   'manag',
#   'studi',
#   'appli',
#   'critic',
#   'think',
#   'problem',
#   'solv',
#   'present',
#   'skill',
#   'individu',
#   'group',
#   'activ',
#   'deal',
#   'research',
#   'student',
#   'conduct',
#   'critic',
#   'review',
#   'literatur',
#   'relev',
#   'studi',
#   'practic',
#   'problem',
#   'research',
#   'ethic',
#   'principl',
#   'scientif',
#   'conduct',
#   'studi',
#   'manag',
#   'problem',
#   'data',
#   'conduct',
#   'analysi',
#   'data',
#   'write',
#   'report',
#   'project',
#   'relev'],
#  'ADA3111': ['demonstr',
#   'understand',
#   'concept',
#   'design',
#   'think',
#   'and_their',
#   'applic',
#   'identify_and',
#   'analys',
#   'project',
#   'problem',
#   'relev',
#   'design',
#   'think',
#   'approach',
#   'appli',
#   'design',
#   'think',
#   'method',
#   'approach',
#   'problem',
#   'develop',
#   'perspect',
#   'key',
#   'issu',
#   'identifi',
#   'develop',
#   'evalu',
#   'problem',
#   'develop',
#   'awar',
#   'approach',
#   'complex',
#   'way',
#   'design',
#   'think',
#   'design',
#   'think',
#   'skills_and',
#   'strategi',
#   'develop',
#   'rang',
#   'problem',
#   'situat',
#   'skills_and',
#   'strategi',
#   'includ',
#   'rang',
#   'conceptu',
#   'commun',
#   'approach',
#   'way',
#   'explor',
#   'context',
#   'work',
#   'design',
#   'think',
#   'approach',
#   'analysis_and',
#   'way',
#   'design',
#   'approach',
#   'design',
#   'think',
#   'approach',
#   'problem',
#   'solv',
#   'with_th',
#   'complex',
#   'issu',
#   'contemporari',
#   'world',
#   'this_unit',
#   'introduc',
#   'student',
#   'key',
#   'skills_and',
#   'practic',
#   'associated_with',
#   'design',
#   'think',
#   'explor',
#   'applic',
#   'basic',
#   'techniqu',
#   'rang',
#   'disciplin'],
#  'ADA5001': ['part',
#   'team',
#   'develop',
#   'research',
#   'communication_and',
#   'inform',
#   'skill',
#   'contribut',
#   'context',
#   'conduct',
#   'critic',
#   'provid',
#   'summ',
#   'disciplin',
#   'design_and',
#   'problem',
#   'understand',
#   'and_appli',
#   'rule',
#   'occup',
#   'health_and',
#   'safeti',
#   'practic',
#   'order',
#   'studio',
#   'environ',
#   'project',
#   'activ',
#   'learn',
#   'applic',
#   'knowledg',
#   'techniqu',
#   'methodolog',
#   'from_th',
#   'student',
#   'individu',
#   'disciplin',
#   'complex',
#   'problem',
#   'the_unit',
#   'design',
#   'student',
#   'the_abl',
#   'critic',
#   'engag',
#   'research_and',
#   'world',
#   'problem',
#   'approach',
#   'this_unit',
#   'students_wil',
#   'develop',
#   'skill',
#   'commun',
#   'tool',
#   'profession',
#   'practic',
#   'research',
#   'activ',
#   'field',
#   'outcom',
#   'from_th',
#   'unit',
#   'individu'],
#  'AHT3801': ['understand',
#   'articul',
#   'analyse_th',
#   'debat',
#   'and_th',
#   'studio',
#   'practic',
#   'conceptu',
#   'model',
#   'the_unit',
#   'reflect',
#   'engag',
#   'critic',
#   'import',
#   'this_unit',
#   'examin',
#   'rang',
#   'visual',
#   'practic',
#   'includ',
#   'social',
#   'practic',
#   'perform',
#   'histor',
#   'disciplin',
#   'and_how',
#   'divers',
#   'rang',
#   'academ',
#   'concept',
#   'modern',
#   'understand',
#   'form',
#   'the_unit',
#   'introduc',
#   'key',
#   'theoret',
#   'analys',
#   'contemporari',
#   'practic',
#   'case',
#   'studi',
#   'introduc',
#   'student',
#   'critic',
#   'materi',
#   'process'],
#  'AMG5743': ['knowledg',
#   'skills_and',
#   'understand',
#   'advanc',
#   'research',
#   'abil',
#   'design',
#   'write',
#   'research',
#   'abil',
#   'advanc',
#   'level',
#   'analyse_and',
#   'evalu',
#   'understand',
#   'critic',
#   'approach',
#   'relat',
#   'commun',
#   'commun',
#   'issu',
#   'capac',
#   'contribut',
#   'advanc',
#   'knowledg',
#   'area',
#   'research',
#   'critic',
#   'profession',
#   'the_unit',
#   'student',
#   'research',
#   'media',
#   'studi',
#   'student',
#   'develop',
#   'independ',
#   'research_project',
#   'student',
#   'develop',
#   'with_th',
#   'support',
#   'project',
#   'written',
#   'student',
#   'demonstr',
#   'advanc',
#   'skill',
#   'research',
#   'write',
#   'project',
#   'manag',
#   'student',
#   'project',
#   'for_th',
#   'profession',
#   'develop'],
#  'APG5050': ['with_th',
#   'major',
#   'research',
#   'method',
#   'communication_and',
#   'media',
#   'studi',
#   'understand',
#   'research',
#   'topic',
#   'research',
#   'question',
#   'abil',
#   'identifi',
#   'research',
#   'question',
#   'abil',
#   'appli',
#   'research',
#   'method',
#   'critic',
#   'research',
#   'question',
#   'capac',
#   'design',
#   'research',
#   'project',
#   'communication_and',
#   'media',
#   'studi',
#   'project',
#   'plan',
#   'abil',
#   'develop',
#   'solut',
#   'problem',
#   'communication_and',
#   'media',
#   'studi',
#   'polici',
#   'abil',
#   'appli',
#   'research',
#   'skill',
#   'rang',
#   'challeng',
#   'communication_and',
#   'media',
#   'studi',
#   'polici',
#   'the_unit',
#   'introduc',
#   'student',
#   'principl',
#   'communication_and',
#   'media',
#   'research',
#   'rang',
#   'research',
#   'method',
#   'includ',
#   'analysi',
#   'content',
#   'analysi',
#   'approach',
#   'analysis_and',
#   'research',
#   'focu',
#   'learn',
#   'method',
#   'understand',
#   'relat',
#   'problem',
#   'address',
#   'the_unit',
#   'develop',
#   'skill',
#   'research',
#   'design',
#   'research',
#   'question',
#   'methodolog',
#   'project',
#   'plan',
#   'skill',
#   'provid',
#   'develop',
#   'research_project'],
#  'APG5052': ['critic',
#   'analyse_th',
#   'media',
#   'problem',
#   'field',
#   'contribut',
#   'think',
#   'solut',
#   'contemporari',
#   'problem',
#   'communication_and',
#   'media',
#   'articul',
#   'ethic',
#   'relev',
#   'develop',
#   'communication_and',
#   'media',
#   'impact',
#   'technolog',
#   'research',
#   'skill',
#   'evalu',
#   'issu',
#   'field',
#   'commun',
#   'find',
#   'profession',
#   'context',
#   'the_unit',
#   'students_wil',
#   'engag',
#   'studi',
#   'develop',
#   'communication_and',
#   'media',
#   'year',
#   'the_unit',
#   'address',
#   'field',
#   'media',
#   'develop',
#   'media',
#   'industri',
#   'the_unit',
#   'research',
#   'focu',
#   'includ',
#   'develop',
#   'profession',
#   'industri',
#   'practic',
#   'students_wil',
#   'work',
#   'with_th',
#   'work',
#   'problem',
#   'media',
#   'studi',
#   'practic',
#   'media',
#   'commun'],
#  'APG5077': ['identifi',
#   'assess',
#   'interpret',
#   'cultur',
#   'effect',
#   'manag',
#   'strategi',
#   'cultur',
#   'develop',
#   'solut',
#   'cultur',
#   'challeng',
#   'ethic',
#   'the_develop',
#   'divers',
#   'cultur',
#   'context',
#   'effect',
#   'commun',
#   'strategi',
#   'divers',
#   'cultur',
#   'develop',
#   'this_unit',
#   'student',
#   'learn',
#   'identifi',
#   'assess',
#   'interpret',
#   'manag',
#   'critic',
#   'experi',
#   'environment',
#   'cultur',
#   'students_wil',
#   'learn',
#   'industri',
#   'field',
#   'studi',
#   'cultur',
#   'develop'],
#  'APG5082': ['explain',
#   'identifi',
#   'busi',
#   'specif',
#   'cultur',
#   'academ',
#   'concept',
#   'understand',
#   'challeng',
#   'product',
#   'develop',
#   'strategi',
#   'independ',
#   'research',
#   'skill',
#   'engag',
#   'cultur',
#   'context',
#   'commun',
#   'idea',
#   'effect',
#   'this_unit',
#   'student',
#   'analys',
#   'busi',
#   'approach',
#   'cultur',
#   'model',
#   'and_their',
#   'identifi',
#   'key',
#   'approach',
#   'global',
#   'cultur',
#   'identifi',
#   'challeng',
#   'solut',
#   'manag',
#   'import',
#   'order',
#   'cultur',
#   'busi',
#   'contemporari',
#   'societi'],
#  'APG5103': ['knowledg',
#   'skill',
#   'polici',
#   'analysis_and',
#   'evalu',
#   'disciplin',
#   'base',
#   'solut',
#   'relev',
#   'divers',
#   'busi',
#   'profession',
#   'public',
#   'polici',
#   'solut',
#   'challeng',
#   'advanc',
#   'critic',
#   'think',
#   'evalu',
#   'research',
#   'skill',
#   'commun',
#   'polici',
#   'analysis_and',
#   'the_unit',
#   'student',
#   'conceptu',
#   'theoret',
#   'polici',
#   'analysis_and',
#   'evalu',
#   'present',
#   'effect',
#   'polici',
#   'public',
#   'polici',
#   'the_unit',
#   'explor',
#   'challeng',
#   'problem',
#   'evid',
#   'polici',
#   'develop',
#   'polici',
#   'polici'],
#  'APG5230': ['explain',
#   'key',
#   'concept',
#   'includ',
#   'appli',
#   'concept',
#   'environment',
#   'context',
#   'understand_th',
#   'role',
#   'polici',
#   'design_and',
#   'implement',
#   'critically_evalu',
#   'approach',
#   'and_their',
#   'practic',
#   'term',
#   'outcom',
#   'the_unit',
#   'introduct',
#   'environment',
#   'manag',
#   'scienc',
#   'polici',
#   'understand',
#   'polici',
#   'work',
#   'practic',
#   'profession',
#   'experi',
#   'requir',
#   'australian',
#   'intern',
#   'case',
#   'studi',
#   'the_unit',
#   'introduc',
#   'challeng',
#   'knowledg',
#   'effect',
#   'polici',
#   'tool'],
#  'APG5348': ['key',
#   'theoret',
#   'debat',
#   'relat',
#   'languag',
#   'acquisit',
#   'evalu',
#   'relev',
#   'evid',
#   'work',
#   'recognis',
#   'role',
#   'the_develop',
#   'theori',
#   'reflect',
#   'languag',
#   'learn',
#   'experi',
#   'practic',
#   'theoret',
#   'studi',
#   'evalu',
#   'major',
#   'approach',
#   'studi',
#   'languag',
#   'acquisit',
#   'conduct',
#   'major',
#   'research_project',
#   'area',
#   'languag',
#   'acquisit',
#   'address',
#   'key',
#   'concept',
#   'theoret',
#   'model',
#   'approach',
#   'theori',
#   'field',
#   'languag',
#   'acquisit',
#   'topic',
#   'cover',
#   'includ',
#   'model',
#   'theori',
#   'languag',
#   'acquisit',
#   'languag',
#   'acquisit',
#   'analysis_and',
#   'strategi',
#   'learn',
#   'process',
#   'languag',
#   'ident',
#   'method',
#   'research'],
#  'APG5351': ['identify_and',
#   'explain',
#   'intern',
#   'approach',
#   'global',
#   'ethic',
#   'explor',
#   'analys',
#   'intern',
#   'design',
#   'intern',
#   'research_project',
#   'media',
#   'theori',
#   'methodolog',
#   'evalu',
#   'commun',
#   'result',
#   'media',
#   'project',
#   'present',
#   'write',
#   'media',
#   'report',
#   'the_unit',
#   'student',
#   'understand',
#   'intern',
#   'world',
#   'the_unit',
#   'explor',
#   'natur',
#   'media',
#   'staff',
#   'work',
#   'intern',
#   'local',
#   'content',
#   'this_unit',
#   'histori',
#   'intern',
#   'global',
#   'the_rol',
#   'and_th',
#   'world',
#   'intern',
#   'students_wil',
#   'intern',
#   'research',
#   'studi',
#   'write',
#   'intern',
#   'media',
#   'research',
#   'report'],
#  'APG5400': ['sound',
#   'understand',
#   'media',
#   'analys',
#   'global',
#   'media',
#   'and_th',
#   'problem',
#   'communication_and',
#   'major',
#   'theori',
#   'develop',
#   'explain',
#   'understand',
#   'global',
#   'with_th',
#   'implic',
#   'process',
#   'person',
#   'ident',
#   'major',
#   'legal',
#   'ethic',
#   'challeng',
#   'media',
#   'demonstr',
#   'abil',
#   'conduct',
#   'independ',
#   'research',
#   'explor',
#   'key',
#   'issu',
#   'from_th',
#   'develop',
#   'intern',
#   'examin',
#   'impact',
#   'intern',
#   'students_wil',
#   'cultur',
#   'develop',
#   'commun',
#   'commun',
#   'intern',
#   'public',
#   'legal',
#   'ethic',
#   'issu',
#   'intern',
#   'includ',
#   'case',
#   'studi',
#   'media',
#   'and_th'],
#  'APG5628': ['critic',
#   'assess',
#   'develop',
#   'academ',
#   'field',
#   'explor',
#   'histori',
#   'develop',
#   'think',
#   'and_th',
#   'develop',
#   'practic',
#   'articul',
#   'approach',
#   'practic',
#   'develop',
#   'evalu',
#   'work',
#   'contemporari',
#   'develop',
#   'contemporari',
#   'develop',
#   'person',
#   'develop',
#   'idea',
#   'system',
#   'social',
#   'practic',
#   'divers',
#   'cultur',
#   'context',
#   'design',
#   'idea',
#   'develop',
#   'this_unit',
#   'question',
#   'conceptu',
#   'practic',
#   'develop',
#   'concept',
#   'econom',
#   'develop',
#   'and_their',
#   'idea',
#   'the_unit',
#   'natur',
#   'contemporari',
#   'develop',
#   'practic',
#   'world',
#   'case',
#   'studi',
#   'develop',
#   'the_unit',
#   'explor',
#   'develop',
#   'theori',
#   'practic',
#   'explor',
#   'way',
#   'divers',
#   'social',
#   'social',
#   'develop',
#   'question',
#   'develop',
#   'contemporari',
#   'develop',
#   'practic'],
#  'APG5849': ['formul',
#   'research_project',
#   'conduct',
#   'research',
#   'demonstr',
#   'relev',
#   'literatur',
#   'critic',
#   'analyse_th',
#   'relev',
#   'academ',
#   'literatur',
#   'develop',
#   'sound',
#   'demonstr',
#   'written',
#   'skill',
#   'academ',
#   'staff',
#   'students_wil',
#   'conduct',
#   'independ',
#   'research',
#   'research',
#   'process',
#   'research',
#   'part',
#   'student',
#   'research'],
#  'APG5881': ['undertak',
#   'studi',
#   'studi',
#   'studi',
#   'form',
#   'year',
#   'unit',
#   'studi'],
#  'APG5900': ['conceptu',
#   'histor',
#   'contemporari',
#   'issu',
#   'involv',
#   'cultur',
#   'critically_evalu',
#   'approach',
#   'cultur',
#   'and_th',
#   'issu',
#   'appli',
#   'independ',
#   'research',
#   'skill',
#   'rang',
#   'conceptu',
#   'histor',
#   'problem',
#   'field',
#   'cultur',
#   'abil',
#   'write',
#   'commun',
#   'effect',
#   'analyt',
#   'abil',
#   'effect',
#   'academ',
#   'concept',
#   'identify_and',
#   'challeng',
#   'issu',
#   'involv',
#   'specif',
#   'aspect',
#   'cultur',
#   'this_unit',
#   'introduc',
#   'conceptu',
#   'histor',
#   'includ',
#   'cultur',
#   'polici',
#   'cultur',
#   'cultur',
#   'and_th',
#   'cultur',
#   'work',
#   'explor',
#   'concept',
#   'cultur',
#   'examin',
#   'exist',
#   'futur',
#   'practic',
#   'polici',
#   'cultur',
#   'students_wil',
#   'base',
#   'concept',
#   'issu',
#   'the_unit',
#   'content'],
#  'ARC3002': ['demonstr',
#   'level',
#   'design',
#   'abil',
#   'critic',
#   'analyse_and',
#   'respond',
#   'complex',
#   'rang',
#   'issu',
#   'design',
#   'project',
#   'develop',
#   'understand',
#   'analysi',
#   'critiqu',
#   'appli',
#   'design',
#   'process',
#   'advanc',
#   'level',
#   'present',
#   'skill',
#   'understand',
#   'apply_th',
#   'rule',
#   'occup',
#   'health_and',
#   'safeti',
#   'the_unit',
#   'studi',
#   'design',
#   'studio',
#   'conceptu',
#   'understand',
#   'design',
#   'design',
#   'process',
#   'critic',
#   'emphasi',
#   'design',
#   'process',
#   'rang',
#   'complex',
#   'issu',
#   'materi',
#   'structur',
#   'histori',
#   'relationship',
#   'form'],
#  'ARC5401': ['design',
#   'research',
#   'relev',
#   'context',
#   'design',
#   'research',
#   'method',
#   'the_abl',
#   'critic',
#   'analyse_and',
#   'respond',
#   'issu',
#   'research',
#   'develop',
#   'understand',
#   'analysi',
#   'critiqu',
#   'appli',
#   'the_develop',
#   'design',
#   'research',
#   'understand',
#   'apply_th',
#   'rule',
#   'occup',
#   'health_and',
#   'safeti',
#   'the_unit',
#   'studi',
#   'research',
#   'method',
#   'design',
#   'research_project',
#   'divers',
#   'methodolog',
#   'this_unit',
#   'design',
#   'research',
#   'the_unit',
#   'for_th',
#   'develop',
#   'design',
#   'research',
#   'project',
#   'includ',
#   'conceptu',
#   'physic',
#   'context'],
#  'ASC5001': ['critiqu',
#   'for_th',
#   'relat',
#   'model',
#   'critiqu',
#   'the_rol',
#   'factor',
#   'refer',
#   'the_research',
#   'evid',
#   'analyse_th',
#   'critically_evalu',
#   'demonstr',
#   'set',
#   'understand',
#   'individu',
#   'synthesis',
#   'implic',
#   'approach',
#   'understand',
#   'present',
#   'base',
#   'theoret',
#   'literatur',
#   'process',
#   'evaluate_th',
#   'role',
#   'research',
#   'evid',
#   'and_th',
#   'model',
#   'the_develop',
#   'relev',
#   'this_unit',
#   'introduct',
#   'environment',
#   'factor',
#   'contribut',
#   'the_develop'],
#  'ASC5009': ['identify_and',
#   'factor',
#   'contribut',
#   'peopl',
#   'explain',
#   'term',
#   'social',
#   'context',
#   'synthesis',
#   'inform',
#   'impact',
#   'peopl',
#   'order',
#   'demonstr',
#   'understand',
#   'reflect',
#   'critic',
#   'theori',
#   'relev',
#   'key',
#   'contemporari',
#   'issu',
#   'evalu',
#   'critiqu',
#   'current',
#   'respons',
#   'includ',
#   'contemporari',
#   'model',
#   'peopl',
#   'analysi',
#   'intern',
#   'research',
#   'critic',
#   'review',
#   'includ',
#   'practic',
#   'critic',
#   'apprais',
#   'rang',
#   'servic',
#   'key',
#   'element',
#   'critic',
#   'review',
#   'polici',
#   'issu',
#   'relev',
#   'includ',
#   'social',
#   'media',
#   'this_unit',
#   'focu',
#   'develop',
#   'and_oth'],
#  'ASP3162': ['demonstr',
#   'basic',
#   'understand',
#   'high',
#   'includ',
#   'sound',
#   'demonstr',
#   'practic',
#   'skill',
#   'scientif',
#   'data',
#   'analysis_and',
#   'advanc',
#   'demonstr',
#   'understand',
#   'modern',
#   'this_unit',
#   'students_wil',
#   'learn',
#   'basic',
#   'principl',
#   'and_how',
#   'the_unit',
#   'cover',
#   'basic',
#   'includ',
#   'and_th',
#   'high',
#   'students_wil',
#   'appli',
#   'understand_th',
#   'physic',
#   'process',
#   'sourc',
#   'includ',
#   'and_th',
#   'students_wil',
#   'gain',
#   'practic',
#   'experi',
#   'includ',
#   'basic',
#   'skills_and',
#   'understand'],
#  'ATS1062': ['basic',
#   'write',
#   'skills_and',
#   'commun',
#   'effect',
#   'rang',
#   'present',
#   'futur',
#   'situat',
#   'rang',
#   'topic',
#   'inform',
#   'basic',
#   'recognis',
#   'key',
#   'identify_and',
#   'critiqu',
#   'aspect',
#   'modern',
#   'contemporari',
#   'histori',
#   'ident',
#   'and_their',
#   'interpret',
#   'sourc',
#   'synthesis',
#   'knowledg',
#   'standard',
#   'this_unit',
#   'basic',
#   'languag',
#   'skill',
#   'write',
#   'level',
#   'introduct',
#   'modern',
#   'societi',
#   'design',
#   'knowledg',
#   'students_wil',
#   'develop',
#   'languag',
#   'learn',
#   'strategi',
#   'natur',
#   'languag',
#   'learn',
#   'and_th',
#   'practic',
#   'cultur',
#   'students_wil',
#   'explor',
#   'cultur',
#   'societi',
#   'develop',
#   'year',
#   'level',
#   'theori',
#   'practic',
#   'involv',
#   'analysi'],
#  'ATS1208': ['recognis',
#   'evaluate_th',
#   'develop',
#   'role',
#   'technolog',
#   'societi',
#   'cultur',
#   'analyse_th',
#   'impact',
#   'technolog',
#   'area',
#   'media',
#   'examin',
#   'assess',
#   'applic',
#   'technolog',
#   'analysis_and',
#   'data',
#   'identifi',
#   'complex',
#   'research',
#   'problem',
#   'approach',
#   'commun',
#   'effect',
#   'this_unit',
#   'introduc',
#   'student',
#   'concept',
#   'world',
#   'rang',
#   'case',
#   'studi',
#   'base',
#   'major',
#   'examin',
#   'work',
#   'media',
#   'studi',
#   'techniqu',
#   'method',
#   'research_and',
#   'present',
#   'data',
#   'work',
#   'data',
#   'sourc',
#   'and_th',
#   'tool',
#   'critic',
#   'exist',
#   'field',
#   'student',
#   'this_unit',
#   'work',
#   'impact',
#   'field',
#   'the_unit',
#   'understand',
#   'technolog',
#   'societi',
#   'cultur'],
#  'ATS1835': ['introduct',
#   'question',
#   'natur',
#   'human',
#   'person',
#   'ident',
#   'and_th',
#   'introduc',
#   'scienc',
#   'issu'],
#  'ATS2043': ['provid',
#   'basic',
#   'concept',
#   'issu',
#   'studi',
#   'analysi',
#   'the_unit',
#   'focu',
#   'basic',
#   'principl',
#   'analysis_and',
#   'theori',
#   'relat',
#   'languag',
#   'student',
#   'understand',
#   'theori',
#   'relat',
#   'strategi',
#   'basic',
#   'concept',
#   'relat',
#   'analysis_and',
#   'strategi',
#   'practic',
#   'student',
#   'abil',
#   'determin',
#   'strategi',
#   'specif',
#   'profession',
#   'project',
#   'order',
#   'student',
#   'project',
#   'this_unit',
#   'introduc',
#   'student',
#   'basic',
#   'conceptu',
#   'practic',
#   'issu',
#   'student',
#   'identifi',
#   'type',
#   'skill',
#   'analysis_and',
#   'student',
#   'strategi',
#   'profession',
#   'this_unit',
#   'provid',
#   'opportun',
#   'student',
#   'analyt',
#   'skills_and',
#   'understand',
#   'factor',
#   'languag',
#   'project',
#   'student',
#   'apply_th',
#   'theori',
#   'skill',
#   'practic'],
#  'ATS2250': ['understand',
#   'contemporari',
#   'cultur',
#   'understand',
#   'impact',
#   'understand_th',
#   'process',
#   'econom',
#   'cultur',
#   'part',
#   'develop',
#   'effect',
#   'understand',
#   'develop',
#   'effect',
#   'understand',
#   'rang',
#   'theori',
#   'cultur',
#   'theori',
#   'ident',
#   'manag',
#   'theori',
#   'ident',
#   'theori',
#   'commun',
#   'theori',
#   'cultur',
#   'theori',
#   'understand',
#   'rang',
#   'media',
#   'the_unit',
#   'cover',
#   'peopl',
#   'cultur',
#   'commun',
#   'and_how',
#   'cultur'],
#  'ATS2275': ['explain',
#   'analyse_th',
#   'world',
#   'identify_and',
#   'explain_th',
#   'current',
#   'global',
#   'context',
#   'identify_and',
#   'apprais',
#   'and_how',
#   'respons',
#   'current',
#   'respons',
#   'and_th',
#   'integr',
#   'academ',
#   'literatur',
#   'theori',
#   'histori',
#   'polit',
#   'intern',
#   'undertak',
#   'research',
#   'analysi',
#   'import',
#   'major',
#   'polici',
#   'area',
#   'primari',
#   'written',
#   'polit',
#   'student',
#   'this_unit',
#   'gain',
#   'understand',
#   'and_th',
#   'polici',
#   'problem',
#   'respond',
#   'global',
#   'challeng',
#   'world'],
#  'ATS2385': ['demonstr',
#   'critic',
#   'understand',
#   'histori',
#   'and_th',
#   'understand',
#   'experi',
#   'abil',
#   'person',
#   'awar',
#   'histor',
#   'social',
#   'context',
#   'and_how',
#   'relationship',
#   'with_th',
#   'and_th',
#   'world',
#   'capac',
#   'research_and',
#   'critically_evalu',
#   'debat',
#   'impact',
#   'australian',
#   'ident',
#   'societi',
#   'develop',
#   'skill',
#   'varieti',
#   'primari',
#   'sourc',
#   'abil',
#   'reflect',
#   'critic',
#   'develop',
#   'skill',
#   'written',
#   'oral',
#   'present',
#   'commun',
#   'australian',
#   'societi',
#   'ident',
#   'this_unit',
#   'explor',
#   'experi',
#   'major',
#   'focu',
#   'world',
#   'examin',
#   'and_how',
#   'includ',
#   'australian',
#   'societi',
#   'explor',
#   'and_how',
#   'social',
#   'students_wil',
#   'undertak',
#   'research',
#   'primari',
#   'includ',
#   'oral',
#   'impact',
#   'and_their'],
#  'ATS2394': ['demonstr',
#   'critic',
#   'understand',
#   'econom',
#   'social',
#   'cultur',
#   'understand',
#   'way',
#   'contemporari',
#   'intern',
#   'understand',
#   'intern',
#   'develop',
#   'capac',
#   'reflect',
#   'implic',
#   'person',
#   'cultur',
#   'develop',
#   'skill',
#   'varieti',
#   'primari',
#   'sourc',
#   'abil',
#   'reflect',
#   'critic',
#   'develop',
#   'skill',
#   'written',
#   'oral',
#   'present',
#   'commun',
#   'develop',
#   'capac',
#   'undertak',
#   'person',
#   'and_th',
#   'capac',
#   'work',
#   'conduct',
#   'independ',
#   'research',
#   'student',
#   'this_unit',
#   'level',
#   'demonstr',
#   'level',
#   'skill',
#   'independ',
#   'research_and',
#   'critic',
#   'analysi',
#   'this_unit',
#   'examin',
#   'present',
#   'studi',
#   'polit',
#   'econom',
#   'cultur',
#   'person',
#   'the_unit',
#   'contemporari',
#   'histor',
#   'context',
#   'identifi',
#   'influenc',
#   'futur',
#   'the_unit',
#   'student',
#   'studi',
#   'gain',
#   'awar',
#   'complex',
#   'social',
#   'cultur',
#   'polit',
#   'context',
#   'and_how'],
#  'ATS2422': ['develop',
#   'understand',
#   'way',
#   'think',
#   'write',
#   'histori',
#   'natur',
#   'and_th',
#   'gain',
#   'knowledg',
#   'work',
#   'literatur',
#   'cultur',
#   'develop',
#   'skill',
#   'area',
#   'research',
#   'analysis_and',
#   'commun',
#   'oral',
#   'written',
#   'the_unit',
#   'introduc',
#   'student',
#   'way',
#   'think',
#   'from_th',
#   'focu',
#   'literatur',
#   'histori',
#   'natur',
#   'visual',
#   'and_th',
#   'histori',
#   'cultur',
#   'divers'],
#  'ATS2586': ['explain_th',
#   'histor',
#   'develop',
#   'with_th',
#   'major',
#   'identify_and',
#   'discuss',
#   'key',
#   'practic',
#   'and_their',
#   'varieti',
#   'histori',
#   'analys',
#   'primari',
#   'sourc',
#   'and_th',
#   'order',
#   'respond',
#   'critic',
#   'materi',
#   'work',
#   'effect',
#   'group',
#   'situat',
#   'commun',
#   'idea',
#   'the_unit',
#   'examin',
#   'influenc',
#   'emphasi',
#   'principl',
#   'law',
#   'philosophi',
#   'examin',
#   'work',
#   'histori',
#   'literatur',
#   'way',
#   'principl',
#   'practic',
#   'histor',
#   'review',
#   'modern',
#   'histori',
#   'concept',
#   'societi',
#   'role',
#   'polit',
#   'world',
#   'import',
#   'primari',
#   'sourc'],
#  'ATS2600': ['knowledg',
#   'understand',
#   'respons',
#   'understand',
#   'respons',
#   'understand',
#   'issu',
#   'involv',
#   'includ',
#   'this_unit',
#   'examin',
#   'histori',
#   'major',
#   'topic',
#   'cover',
#   'includ',
#   'state',
#   'respons',
#   'and_th',
#   'role',
#   'reflect',
#   'modern',
#   'relationship',
#   'world'],
#  'ATS2687': ['identify_and',
#   'explain_th',
#   'theoret',
#   'practic',
#   'aspect',
#   'discuss',
#   'relationship',
#   'cultur',
#   'practic',
#   'interpret',
#   'process',
#   'practic',
#   'divers',
#   'rang',
#   'cultur',
#   'sourc',
#   'implement',
#   'practic',
#   'skills_and',
#   'strategi',
#   'develop',
#   'individu',
#   'approach',
#   'this_unit',
#   'strategi',
#   'develop',
#   'approach',
#   'base',
#   'skill',
#   'element',
#   'term',
#   'system',
#   'process',
#   'develop',
#   'approach',
#   'and_oth',
#   'sourc',
#   'the_unit',
#   'practic',
#   'theoret',
#   'compon'],
#  'ATS2699': ['understand',
#   'import',
#   'polit',
#   'influenc',
#   'understand',
#   'system',
#   'develop',
#   'knowledg',
#   'polit',
#   'scienc',
#   'system',
#   'understand',
#   'theori',
#   'organis',
#   'analysi',
#   'polit',
#   'develop',
#   'understand',
#   'polit',
#   'and_th',
#   'impact',
#   'debat',
#   'public',
#   'polici',
#   'develop',
#   'advanc',
#   'analyt',
#   'skill',
#   'analys',
#   'organis',
#   'commun',
#   'skill',
#   'situat',
#   'present',
#   'analyt',
#   'research',
#   'advanc',
#   'unit',
#   'polit',
#   'polit',
#   'system'],
#  'ATS2868': ['explain_th',
#   'state',
#   'critically_evalu',
#   'state',
#   'critically_evalu',
#   'the_unit',
#   'discuss',
#   'state',
#   'role',
#   'law',
#   'relat',
#   'issu',
#   'work',
#   'refer',
#   'contemporari',
#   'polit'],
#  'ATS2898': ['understand',
#   'cultur',
#   'oral',
#   'written',
#   'languag',
#   'cultur',
#   'knowledg',
#   'histori',
#   'contemporari',
#   'cultur',
#   'understand',
#   'work',
#   'develop',
#   'research',
#   'skill',
#   'understand',
#   'theoret',
#   'issu',
#   'societi',
#   'cultur',
#   'histori',
#   'this_unit',
#   'explor',
#   'work',
#   'and_their',
#   'literatur',
#   'social',
#   'modern',
#   'literatur',
#   'students_wil',
#   'written',
#   'visual',
#   'with_th',
#   'challeng',
#   'focu',
#   'the_unit',
#   'from_th',
#   'present',
#   'includ',
#   'econom',
#   'histori',
#   'ident',
#   'and_how',
#   'cultur',
#   'contemporari'],
#  'ATS2910': ['identifi',
#   'discuss',
#   'and_appli',
#   'theoret',
#   'concept',
#   'associated_with',
#   'physic',
#   'present',
#   'skill',
#   'contribut',
#   'reflect',
#   'key',
#   'compon',
#   'undertak',
#   'project',
#   'disciplin',
#   'practic',
#   'strategi',
#   'present',
#   'find',
#   'rang',
#   'academ',
#   'profession',
#   'context',
#   'this_unit',
#   'student',
#   'learn',
#   'practic',
#   'activ',
#   'present',
#   'skill',
#   'academ',
#   'profession',
#   'student',
#   'introduc',
#   'key',
#   'perform',
#   'present',
#   'concept',
#   'opportun',
#   'practic',
#   'develop',
#   'skill',
#   'the_unit',
#   'approach',
#   'studi',
#   'present',
#   'skill',
#   'specif',
#   'way'],
#  'ATS3038': ['develop',
#   'understand',
#   'media',
#   'written',
#   'interpret',
#   'rang',
#   'develop',
#   'skill',
#   'understand',
#   'develop',
#   'understand',
#   'polit',
#   'econom',
#   'social',
#   'major',
#   'issu',
#   'peopl',
#   'and_oth',
#   'high',
#   'studi',
#   'this_unit',
#   'introduc',
#   'student',
#   'languag',
#   'issu',
#   'intern',
#   'current',
#   'topic',
#   'cover',
#   'includ',
#   'societi',
#   'cultur',
#   'polit',
#   'environ',
#   'intern',
#   'current',
#   'intern',
#   'current',
#   'social',
#   'issu',
#   'students_wil',
#   'develop',
#   'research_and',
#   'languag',
#   'skill',
#   'languag'],
#  'ATS3066': ['write',
#   'rang',
#   'topic',
#   'context',
#   'includ',
#   'situat',
#   'inform',
#   'inform',
#   'idea',
#   'idea',
#   'write',
#   'understand',
#   'demonstr',
#   'understand',
#   'written',
#   'demonstr',
#   'area',
#   'demonstr',
#   'languag',
#   'refer',
#   'materi',
#   'demonstr',
#   'learn',
#   'strategi',
#   'demonstr',
#   'critic',
#   'knowledg',
#   'understand',
#   'modern',
#   'cultur',
#   'demonstr',
#   'theori',
#   'basic',
#   'research',
#   'practic',
#   'involv',
#   'critic',
#   'understand',
#   'analysi',
#   'area',
#   'studi',
#   'demonstr',
#   'individu',
#   'research',
#   'skill',
#   'this_unit',
#   'languag',
#   'skills_and',
#   'cultur',
#   'languag',
#   'cultur',
#   'this_unit',
#   'develop',
#   'student',
#   'skills_and',
#   'capac',
#   'idea',
#   'oral',
#   'written',
#   'rang',
#   'activ',
#   'written',
#   'student',
#   'develop',
#   'languag',
#   'skill',
#   'area',
#   'studi',
#   'develop',
#   'theori',
#   'research',
#   'practic',
#   'involv',
#   'critic',
#   'understand',
#   'analysi',
#   'disciplin',
#   'area'],
#  'ATS3070': ['advanc',
#   'analyt',
#   'skill',
#   'context',
#   'write',
#   'make',
#   'present',
#   'advanc',
#   'knowledg',
#   'understand',
#   'modern',
#   'contemporari',
#   'cultur',
#   'understand',
#   'theori',
#   'research',
#   'practic',
#   'area',
#   'studi',
#   'advanc',
#   'languag',
#   'skill',
#   'involv',
#   'develop',
#   'critic',
#   'analysis_and',
#   'outcom',
#   'framework',
#   'research',
#   'individu',
#   'research',
#   'skill',
#   'includ',
#   'individu',
#   'research',
#   'skill',
#   'with_th',
#   'research',
#   'develop',
#   'framework',
#   'this_unit',
#   'student',
#   'learn',
#   'activ',
#   'develop',
#   'languag',
#   'skills_and',
#   'cultur',
#   'skill',
#   'develop',
#   'area',
#   'focu',
#   'specif',
#   'techniqu',
#   'oral',
#   'present',
#   'critic',
#   'awar',
#   'issu',
#   'contemporari',
#   'student',
#   'develop',
#   'advanc',
#   'languag',
#   'skills_and',
#   'theori',
#   'research',
#   'practic',
#   'involv',
#   'critic',
#   'understand',
#   'analysi',
#   'area',
#   'studi',
#   'work',
#   'project'],
#  'ATS3176': ['manag',
#   'social',
#   'situat',
#   'inform',
#   'written',
#   'sourc',
#   'requir',
#   'discuss',
#   'issu',
#   'contemporari',
#   'societi',
#   'demonstr',
#   'the_abl',
#   'inform',
#   'disciplin',
#   'develop',
#   'advanc',
#   'unit',
#   'design',
#   'student',
#   'develop',
#   'languag',
#   'skills_and',
#   'knowledg',
#   'histori',
#   'cultur',
#   'societi',
#   'emphasi',
#   'disciplin',
#   'advanc',
#   'skill',
#   'support',
#   'studi'],
#  'ATS3190': ['understand',
#   'debat',
#   'modern',
#   'understand_th',
#   'complex',
#   'modern',
#   'the_rol',
#   'relationship',
#   'societi',
#   'the_unit',
#   'with_th',
#   'from_th',
#   'contemporari',
#   'histor',
#   'relationship',
#   'histor',
#   'this_unit',
#   'relationship',
#   'the_unit',
#   'debat',
#   'modern',
#   'social',
#   'econom',
#   'topic',
#   'includ',
#   'and_th',
#   'state',
#   'and_th',
#   'contemporari',
#   'debat'],
#  'ATS3223': ['analyse_and',
#   'explain_th',
#   'design',
#   'respond',
#   'engag',
#   'varieti',
#   'critic',
#   'theoret',
#   'debat',
#   'identify_and',
#   'critically_evalu',
#   'literatur',
#   'apprais',
#   'rang',
#   'approach',
#   'commun',
#   'oral',
#   'written',
#   'research_project',
#   'this_unit',
#   'students_wil',
#   'examin',
#   'key',
#   'and_th',
#   'design',
#   'respond',
#   'students_wil',
#   'identifi',
#   'specif',
#   'area',
#   'area',
#   'students_wil',
#   'undertak',
#   'review',
#   'relev',
#   'academ',
#   'literatur',
#   'independ',
#   'research',
#   'research',
#   'the_unit',
#   'staff'],
#  'ATS3241': ['unit',
#   'the_develop',
#   'from_th',
#   'modern',
#   'work',
#   'the_unit',
#   'critic',
#   'approach',
#   'examin',
#   'aspect',
#   'modern',
#   'issu',
#   'relat',
#   'and_th',
#   'individu',
#   'issu',
#   'relat',
#   'social',
#   'ident'],
#  'ATS3265': ['content',
#   'rang',
#   'for_th',
#   'visual',
#   'content',
#   'includ',
#   'studio',
#   'present',
#   'visual',
#   'content',
#   'understand',
#   'key',
#   'ethic',
#   'legal',
#   'issu',
#   'associated_with',
#   'visual',
#   'content',
#   'situat',
#   'demonstr',
#   'awar',
#   'local',
#   'intern',
#   'peopl',
#   'relev',
#   'current',
#   'media',
#   'issu',
#   'work',
#   'part',
#   'team',
#   'content',
#   'inform',
#   'studio',
#   'introduc',
#   'student'],
#  'ATS3359': ['explor',
#   'peopl',
#   'describ',
#   'relationship',
#   'explor',
#   'environment',
#   'knowledg',
#   'studi',
#   'scientif',
#   'system',
#   'context',
#   'cultur',
#   'explor',
#   'languag',
#   'histori',
#   'materi',
#   'cultur',
#   'polit',
#   'way',
#   'peopl',
#   'relationship',
#   'with_th',
#   'environ',
#   'studi',
#   'and_how',
#   'knowledg',
#   'issu',
#   'languag',
#   'understand',
#   'case',
#   'studi',
#   'materi',
#   'and_oth',
#   'address',
#   'academ',
#   'debat',
#   'relat',
#   'from_th',
#   'disciplin',
#   'issu',
#   'cultur',
#   'concept',
#   'influenc',
#   'peopl',
#   'and_their',
#   'relationship',
#   'environ',
#   'system',
#   'knowledg',
#   'knowledg',
#   'system',
#   'system',
#   'base',
#   'scientif',
#   'scienc',
#   'research',
#   'knowledg',
#   'knowledg',
#   'system',
#   'ethic',
#   'knowledg',
#   'system',
#   'knowledg',
#   'care',
#   'order'],
#  'ATS3407': ['students_wil',
#   'knowledg',
#   'theori',
#   'students_wil',
#   'key',
#   'debat',
#   'develop',
#   'awar',
#   'histor',
#   'the_develop',
#   'develop',
#   'abil',
#   'analyse_and',
#   'interpret',
#   'work',
#   'literatur',
#   'social',
#   'refer',
#   'framework',
#   'students_wil',
#   'present',
#   'result',
#   'research',
#   'form',
#   'written',
#   'introduct',
#   'theori',
#   'base',
#   'key',
#   'concept',
#   'histor',
#   'context',
#   'and_th',
#   'structur',
#   'theori',
#   'critiqu',
#   'applic',
#   'literatur',
#   'social'],
#  'ATS3679': ['demonstr',
#   'understand',
#   'process',
#   'languag',
#   'acquisit',
#   'discuss',
#   'theori',
#   'languag',
#   'acquisit',
#   'describ',
#   'languag',
#   'data',
#   'term',
#   'understand',
#   'area',
#   'languag',
#   'acquisit',
#   'literatur',
#   'student',
#   'develop',
#   'critic',
#   'skill',
#   'skill',
#   'deal',
#   'languag',
#   'data',
#   'the_abl',
#   'assess',
#   'evid',
#   'theori',
#   'evalu',
#   'theori',
#   'the_abl',
#   'present',
#   'write',
#   'the_unit',
#   'the_develop',
#   'languag',
#   'acquisit',
#   'includ',
#   'the_develop',
#   'examin',
#   'the_develop',
#   'system',
#   'develop',
#   'model',
#   'theori'],
#  'ATS3743': ['practic',
#   'experi',
#   'awar',
#   'applic',
#   'process',
#   'includ',
#   'opportun',
#   'understand',
#   'work',
#   'term',
#   'histori',
#   'polit',
#   'understand',
#   'concept',
#   'theori',
#   'and_their',
#   'applic',
#   'decis',
#   'make',
#   'opportun',
#   'develop',
#   'plan',
#   'skill',
#   'opportun',
#   'awar',
#   'strategi',
#   'develop',
#   'unit',
#   'student',
#   'with_th',
#   'capac',
#   'manag',
#   'understand',
#   'histori',
#   'futur',
#   'work',
#   'work',
#   'and_th',
#   'role',
#   'profession',
#   'provid',
#   'set',
#   'concept',
#   'theori',
#   'and_their',
#   'applic',
#   'individu',
#   'students_wil',
#   'develop',
#   'plan',
#   'base',
#   'awar',
#   'skills_and',
#   'understand',
#   'approach',
#   'decis',
#   'make'],
#  'ATS3825': ['demonstr',
#   'knowledg',
#   'major',
#   'and_th',
#   'way',
#   'analys',
#   'specif',
#   'area',
#   'work',
#   'import',
#   'specif',
#   'area',
#   'understand_th',
#   'principl',
#   'modern',
#   'this_unit',
#   'primari',
#   'the_unit',
#   'work',
#   'major',
#   'topic',
#   'includ',
#   'system',
#   'includ',
#   'techniqu',
#   'the_unit',
#   'contemporari',
#   'australian',
#   'context'],
#  'ATS3829': ['demonstr',
#   'knowledg',
#   'histori',
#   'critically_evalu',
#   'analys',
#   'theori',
#   'perform',
#   'techniqu',
#   'and_how',
#   'reflect',
#   'local',
#   'cultur',
#   'the_unit',
#   'examin',
#   'social',
#   'concept',
#   'practic',
#   'refer',
#   'and_th',
#   'and_th',
#   'relat'],
#  'ATS3852': ['develop',
#   'knowledg',
#   'contemporari',
#   'social',
#   'varieti',
#   'critic',
#   'theoret',
#   'debat',
#   'develop',
#   'the_abl',
#   'critically_evalu',
#   'literatur',
#   'knowledg',
#   'rang',
#   'approach',
#   'examin',
#   'develop',
#   'the_abl',
#   'commun',
#   'oral',
#   'written',
#   'develop',
#   'research',
#   'this_unit',
#   'students_wil',
#   'identifi',
#   'studi',
#   'studi',
#   'studi',
#   'students_wil',
#   'undertak',
#   'review',
#   'relev',
#   'academ',
#   'literatur',
#   'independ',
#   'research',
#   'research',
#   'the_unit',
#   'staff'],
#  'ATS3862': ['student',
#   'opportun',
#   'understand',
#   'histori',
#   'practic',
#   'student',
#   'develop',
#   'skill',
#   'interpret',
#   'explain',
#   'integr',
#   'analysi',
#   'contemporari',
#   'critic',
#   'materi',
#   'develop',
#   'student',
#   'engag',
#   'critic',
#   'think',
#   'capac',
#   'critic',
#   'analyse_and',
#   'evalu',
#   'concept',
#   'role',
#   'idea',
#   'this_unit',
#   'way',
#   'think',
#   'histor',
#   'social',
#   'scientif',
#   'question',
#   'the_rol',
#   'and_th',
#   'relationship',
#   'evid',
#   'question',
#   'examin',
#   'and_th',
#   'rang',
#   'respons',
#   'divers'],
#  'ATS3876': ['student',
#   'analyt',
#   'philosophi',
#   'from_th',
#   'present',
#   'provid',
#   'student',
#   'environ',
#   'learn',
#   'skill',
#   'issu',
#   'student',
#   'materi',
#   'for_th',
#   'form',
#   'problem',
#   'knowledg',
#   'base',
#   'for_th',
#   'case'],
#  'ATS3905': ['explain',
#   'basic',
#   'advanc',
#   'concept',
#   'theori',
#   'includ',
#   'analysi',
#   'major',
#   'theoret',
#   'involv',
#   'discuss',
#   'concept',
#   'social',
#   'theori',
#   'evalu',
#   'import',
#   'issu',
#   'relat',
#   'histori',
#   'polit',
#   'relat',
#   'human',
#   'identifi',
#   'relev',
#   'literatur',
#   'for_th',
#   'work',
#   'natur',
#   'appli',
#   'independ',
#   'research',
#   'academ',
#   'commun',
#   'skill',
#   'contemporari',
#   'world',
#   'divers',
#   'type',
#   'system',
#   'system',
#   'peopl',
#   'modern',
#   'this_unit',
#   'contemporari',
#   'polit',
#   'and_how'],
#  'ATS3969': ['identify_and',
#   'evalu',
#   'theori',
#   'relat',
#   'debat',
#   'contemporari',
#   'histor',
#   'method',
#   'appli',
#   'rang',
#   'theoret',
#   'approach',
#   'media',
#   'rang',
#   'media',
#   'appli',
#   'advanc',
#   'research',
#   'skill',
#   'critic',
#   'reflect',
#   'synthesis',
#   'theoret',
#   'approach',
#   'studi',
#   'commun',
#   'written',
#   'oral',
#   'form',
#   'design',
#   'problem',
#   'solv',
#   'group',
#   'project',
#   'task',
#   'interpret',
#   'analys',
#   'critic',
#   'cultur',
#   'polit',
#   'theoret',
#   'practic',
#   'context',
#   'this_unit',
#   'provid',
#   'opportun',
#   'student',
#   'critic',
#   'reflect',
#   'key',
#   'critic',
#   'approach',
#   'concept',
#   'studi',
#   'focu',
#   'technolog',
#   'theoret',
#   'critic',
#   'issu',
#   'field',
#   'appli',
#   'rang',
#   'research_project',
#   'approach',
#   'provid',
#   'student',
#   'advanc',
#   'research',
#   'skills_and',
#   'methodolog'],
#  'ATS3978': ['varieti',
#   'written',
#   'written',
#   'profession',
#   'situat',
#   'ident',
#   'situat',
#   'strategi',
#   'appli',
#   'rang',
#   'approach',
#   'understand',
#   'busi',
#   'context',
#   'demonstr',
#   'critic',
#   'understand',
#   'concept',
#   'term',
#   'describ',
#   'discuss',
#   'approach',
#   'work',
#   'profession',
#   'critic',
#   'engag',
#   'exist',
#   'research',
#   'with_th',
#   'learn',
#   'demonstr',
#   'independ',
#   'research',
#   'skill',
#   'includ',
#   'techniqu',
#   'critic',
#   'think',
#   'skill',
#   'oral',
#   'written',
#   'commun',
#   'the_unit',
#   'advanc',
#   'student',
#   'languag',
#   'theoret',
#   'practic',
#   'knowledg',
#   'challeng',
#   'languag',
#   'and_th',
#   'strategi',
#   'challeng',
#   'the_unit',
#   'varieti',
#   'profession',
#   'set',
#   'role',
#   'includ',
#   'work',
#   'organis',
#   'cultur',
#   'students_wil',
#   'exist',
#   'languag',
#   'skill',
#   'communication_and',
#   'engag',
#   'key',
#   'idea'],
#  'ATS4002': ['appli',
#   'contemporari',
#   'media',
#   'research',
#   'method',
#   'undertak',
#   'independ',
#   'project',
#   'analyse_and',
#   'engag',
#   'conceptu',
#   'critic',
#   'review',
#   'exist',
#   'literatur',
#   'structur',
#   'commun',
#   'project',
#   'this_unit',
#   'student',
#   'year',
#   'media',
#   'design',
#   'student',
#   'key',
#   'disciplin',
#   'studi',
#   'communication_and',
#   'media',
#   'studi',
#   'engag',
#   'research',
#   'method',
#   'develop',
#   'the_research',
#   'conceptu',
#   'skill',
#   'requir',
#   'studi',
#   'level'],
#  'ATS4231': ['plan',
#   'research',
#   'disciplin',
#   'demonstr',
#   'plan',
#   'implement',
#   'research',
#   'demonstr',
#   'the_research',
#   'literatur',
#   'relat',
#   'research_project',
#   'academ',
#   'staff',
#   'students_wil',
#   'develop',
#   'implement',
#   'research_project',
#   'this_unit',
#   'project'],
#  'AZA1011': ['understand_th',
#   'major',
#   'concept',
#   'intern',
#   'includ',
#   'intern',
#   'system',
#   'human',
#   'global',
#   'understand',
#   'critically_evalu',
#   'theori',
#   'approach',
#   'intern',
#   'critic',
#   'perspect',
#   'social',
#   'polit',
#   'identifi',
#   'key',
#   'intern',
#   'understand',
#   'intern',
#   'undertak',
#   'varieti',
#   'research_and',
#   'write',
#   'demonstr',
#   'oral',
#   'written',
#   'commun',
#   'skill',
#   'relat',
#   'analysis_and',
#   'idea',
#   'and_th',
#   'develop',
#   'the_unit',
#   'introduc',
#   'student',
#   'intern',
#   'includ',
#   'major',
#   'intern',
#   'theori',
#   'key',
#   'intern',
#   'issu',
#   'human',
#   'global',
#   'and_th',
#   'global',
#   'intern',
#   'law',
#   'the_unit',
#   'introduc',
#   'intern',
#   'includ',
#   'global',
#   'societi'],
#  'AZA1308': ['understand_th',
#   'major',
#   'idea',
#   'understand_th',
#   'present',
#   'emphasi',
#   'environ',
#   'synthesis',
#   'interpret',
#   'relev',
#   'materi',
#   'commun',
#   'idea',
#   'written',
#   'techniqu',
#   'basic',
#   'physic',
#   'environment',
#   'inform',
#   'basic',
#   'techniqu',
#   'undertak',
#   'independ',
#   'field',
#   'studi',
#   'environ',
#   'understand_th',
#   'problem',
#   'associated_with',
#   'make',
#   'field',
#   'this_unit',
#   'with_th',
#   'basic',
#   'understand',
#   'world',
#   'advanc',
#   'studi',
#   'relat',
#   'disciplin'],
#  'AZA1328': ['demonstr',
#   'abil',
#   'identify_and',
#   'research',
#   'conduct',
#   'evid',
#   'demonstr',
#   'abil',
#   'report',
#   'media',
#   'key',
#   'ethic',
#   'legal',
#   'associated_with',
#   'context',
#   'reflect',
#   'critic',
#   'perform',
#   'work',
#   'learn',
#   'process',
#   'includ',
#   'demonstr',
#   'abil',
#   'report',
#   'demonstr',
#   'awar',
#   'local',
#   'intern',
#   'peopl',
#   'relev',
#   'current',
#   'issu',
#   'media',
#   'issu',
#   'demonstr',
#   'critic',
#   'awar',
#   'implic',
#   'practic',
#   'media',
#   'the_unit',
#   'critic',
#   'introduct',
#   'key',
#   'concept',
#   'practic',
#   'research_and',
#   'social',
#   'profession',
#   'legal',
#   'context',
#   'technic',
#   'media',
#   'student',
#   'research_and',
#   'media',
#   'critic',
#   'evalu',
#   'perform'],
#  'AZA2030': ['demonstr',
#   'understand',
#   'commun',
#   'strategi',
#   'appli',
#   'principl',
#   'environment',
#   'write',
#   'demonstr',
#   'understand',
#   'content',
#   'commun',
#   'strategi',
#   'apply_th',
#   'process',
#   'develop',
#   'commun',
#   'strategi',
#   'demonstr',
#   'understand',
#   'ident',
#   'research_and',
#   'ident',
#   'identify_and',
#   'explain',
#   'describ',
#   'communication_and',
#   'commun',
#   'identifi',
#   'situat',
#   'demonstr',
#   'high',
#   'standard',
#   'written',
#   'oral',
#   'commun',
#   'skills_and',
#   'organis',
#   'skills_and',
#   'plan',
#   'analys',
#   'case',
#   'studi',
#   'relat',
#   'ident',
#   'the_unit',
#   'student',
#   'appli',
#   'advanc',
#   'principl',
#   'commun',
#   'public',
#   'practic',
#   'the_unit',
#   'role',
#   'public',
#   'commun',
#   'organis',
#   'context',
#   'the_unit',
#   'plan',
#   'implement',
#   'manag',
#   'evalu',
#   'strategi',
#   'relat',
#   'ident',
#   'the_unit',
#   'relat',
#   'practic',
#   'commun',
#   'public',
#   'commun'],
#  'AZA2765': ['inform',
#   'sourc',
#   'conceptu',
#   'academ',
#   'debat',
#   'commun',
#   'skill',
#   'this_unit',
#   'demonstr',
#   'knowledg',
#   'with_th',
#   'type',
#   'inform',
#   'academ',
#   'perspect',
#   'skill',
#   'servic',
#   'set',
#   'environment',
#   'social',
#   'develop',
#   'principl',
#   'group',
#   'model',
#   'care',
#   'abil',
#   'evalu',
#   'system',
#   'design',
#   'servic',
#   'set',
#   'appli',
#   'environment',
#   'understand',
#   'social',
#   'develop',
#   'principl',
#   'group',
#   'model',
#   'care',
#   'the_abl',
#   'evalu',
#   'system',
#   'design',
#   'care',
#   'this_unit',
#   'student',
#   'theoret',
#   'knowledg',
#   'relat',
#   'problem',
#   'this_unit',
#   'group',
#   'environment',
#   'model',
#   'care',
#   'import',
#   'student',
#   'evaluate_th'],
#  'AZA3184': ['critic',
#   'reflect',
#   'analyse_and',
#   'undertak',
#   'public',
#   'task',
#   'critic',
#   'apprais',
#   'theoret',
#   'concept',
#   'public',
#   'work',
#   'organis',
#   'environ',
#   'effect',
#   'public',
#   'the_unit',
#   'student',
#   'develop',
#   'approach',
#   'learn',
#   'academ',
#   'activ',
#   'work',
#   'learn',
#   'provid',
#   'student',
#   'with_th',
#   'opportun',
#   'integr',
#   'theori',
#   'practic',
#   'gain',
#   'experi',
#   'work',
#   'public',
#   'the_unit',
#   'rang',
#   'approach',
#   'integr',
#   'theori',
#   'with_th',
#   'practic',
#   'work',
#   'design',
#   'the_unit',
#   'activ',
#   'the_unit',
#   'approach',
#   'student',
#   'appli',
#   'theoret',
#   'concept',
#   'work',
#   'relat',
#   'activ',
#   'activ',
#   'includ',
#   'project',
#   'learn',
#   'learn'],
#  'AZA3770': ['understand',
#   'experi',
#   'set',
#   'and_th',
#   'commun',
#   'abil',
#   'conduct',
#   'impact',
#   'refer',
#   'manag',
#   'understand',
#   'demonstr',
#   'process',
#   'procedur',
#   'for_th',
#   'care',
#   'with_th',
#   'relev',
#   'experi',
#   'student',
#   'this_unit',
#   'major',
#   'and_th'],
#  'AZA3771': ['identify_and',
#   'describe_th',
#   'project',
#   'manag',
#   'project',
#   'team',
#   'understand',
#   'principl',
#   'basic',
#   'project',
#   'understand_th',
#   'implement',
#   'for_th',
#   'problem',
#   'solv',
#   'demonstr',
#   'organis',
#   'care',
#   'context',
#   'student',
#   'project',
#   'manag',
#   'plan',
#   'evalu',
#   'relat',
#   'skill',
#   'includ',
#   'think',
#   'practic',
#   'strategi',
#   'task',
#   'and_th',
#   'group',
#   'techniqu',
#   'students_wil',
#   'opportun',
#   'work',
#   'team',
#   'skill',
#   'field',
#   'student',
#   'this_unit',
#   'major'],
#  'BEH1042': ['demonstr',
#   'level',
#   'knowledg',
#   'australian',
#   'legal',
#   'system',
#   'principl',
#   'understand',
#   'law',
#   'profession',
#   'practic',
#   'identifi',
#   'import',
#   'legal',
#   'concept',
#   'principl',
#   'profession',
#   'practic',
#   'identifi',
#   'applic',
#   'fundament',
#   'involv',
#   'care',
#   'principl',
#   'person',
#   'health',
#   'care',
#   'discuss',
#   'analyse_th',
#   'practic',
#   'way',
#   'issu',
#   'profession',
#   'health',
#   'practic',
#   'identify_and',
#   'assess',
#   'issu',
#   'associated_with',
#   'decis',
#   'make',
#   'health',
#   'care',
#   'environ',
#   'assess',
#   'apply_th',
#   'health',
#   'care',
#   'practic',
#   'identify_and',
#   'discuss',
#   'ethic',
#   'theori',
#   'the_rol',
#   'describ',
#   'contemporari',
#   'model',
#   'and_their',
#   'applic',
#   'the_rol',
#   'model',
#   'problem',
#   'base',
#   'law',
#   'ethic',
#   'provid',
#   'health',
#   'student',
#   'sound',
#   'legal',
#   'ethic',
#   'practic',
#   'the_unit',
#   'understand',
#   'legal',
#   'principl',
#   'applic',
#   'legal',
#   'standard',
#   'assess',
#   'applic',
#   'ethic',
#   'practic',
#   'concept',
#   'develop',
#   'area',
#   'health',
#   'practic'],
#  'BEH3121': ['describe_th',
#   'health',
#   'clinic',
#   'associated_with',
#   'environment',
#   'practic',
#   'evalu',
#   'evid',
#   'clinic',
#   'practic',
#   'care',
#   'patient',
#   'environment',
#   'demonstr',
#   'patient',
#   'assess',
#   'health',
#   'demonstr',
#   'plan',
#   'implement',
#   'care',
#   'commun',
#   'care',
#   'demonstr',
#   'effect',
#   'communication_and',
#   'patient',
#   'and_oth',
#   'health',
#   'care',
#   'team',
#   'evaluate_th',
#   'care',
#   'relat',
#   'patient',
#   'and_th',
#   'patient',
#   'divers',
#   'associated_with',
#   'for_th',
#   'manag',
#   'reflect',
#   'clinic',
#   'problem',
#   'solv',
#   'clinic',
#   'decis',
#   'make',
#   'process',
#   'influenc',
#   'care',
#   'patient',
#   'environment',
#   'order',
#   'evalu',
#   'manag',
#   'identifi',
#   'patient',
#   'safeti',
#   'describe_th',
#   'australian',
#   'health',
#   'system',
#   'relat',
#   'manag',
#   'health',
#   'relat',
#   'environment',
#   'this_unit',
#   'develop',
#   'the_rol',
#   'clinic',
#   'decis',
#   'make',
#   'skill',
#   'introduc',
#   'clinic',
#   'the_unit',
#   'cover',
#   'environment',
#   'the_unit',
#   'case',
#   'base',
#   'includ',
#   'clinic',
#   'skill',
#   'develop',
#   'clinic',
#   'skill',
#   'clinic',
#   'problem',
#   'solv',
#   'decis',
#   'make',
#   'the_unit',
#   'the_develop',
#   'skill',
#   'provid',
#   'effect',
#   'care',
#   'patient',
#   'health',
#   'relat',
#   'environment'],
#  'BEW3100': ['appli',
#   'conceptu',
#   'theoret',
#   'knowledg',
#   'practic',
#   'work',
#   'situat',
#   'commun',
#   'effect',
#   'write',
#   'work',
#   'effect',
#   'part',
#   'team',
#   'undertak',
#   'appli',
#   'research',
#   'project',
#   'area',
#   'manag',
#   'area',
#   'busi',
#   'students_wil',
#   'undertak',
#   'project',
#   'contribut',
#   'organis',
#   'the_develop',
#   'work',
#   'skills_and',
#   'applic',
#   'knowledg',
#   'practic'],
#  'BEX5870': ['undertak',
#   'sound',
#   'research',
#   'health',
#   'knowledg',
#   'major',
#   'issu',
#   'health',
#   'and_th',
#   'capac',
#   'import',
#   'issu',
#   'independ',
#   'profession',
#   'health',
#   'health',
#   'approach',
#   'manag',
#   'aspect',
#   'evalu',
#   'techniqu',
#   'includ',
#   'qualiti',
#   'issu',
#   'techniqu'],
#  'BEX6011': ['this_unit',
#   'introduc',
#   'current',
#   'research',
#   'issu',
#   'tool',
#   'this_unit',
#   'research',
#   'provid',
#   'student',
#   'with_th',
#   'skills_and',
#   'conduct',
#   'research'],
#  'BFC5380': ['develop',
#   'model',
# ...
#   'major',
#   'this_unit',
#   'the_rol',
#   'clinic',
#   'with_th',
#   'focu',
#   'major',
#   'the_unit',
#   'explor',
#   'plan',
#   'and_th',
#   'role',
#   'patient',
#   'complex',
#   'set',
#   'major',
#   'health'],
#  'PAR3022': ['examin',
#   'implement',
#   'health',
#   'strategi',
#   'design',
#   'patient',
#   'analys',
#   'develop',
#   'strategi',
#   'clinic',
#   'set',
#   'discuss',
#   'specif',
#   'set',
#   'demonstr',
#   'skill',
#   'clinic',
#   'set',
#   'effect',
#   'commun',
#   'critic',
#   'apprais',
#   'research_and',
#   'evid',
#   'examin',
#   'approach',
#   'research',
#   'clinic',
#   'set',
#   'design_and',
#   'implement',
#   'research_project',
#   'practic',
#   'research',
#   'procedur',
#   'this_unit',
#   'year',
#   'student',
#   'futur',
#   'research',
#   'for_th'],
#  'PAR3031': ['describe_th',
#   'present',
#   'manag',
#   'health',
#   'strategi',
#   'describ',
#   'model',
#   'care',
#   'servic',
#   'identify_and',
#   'interpret',
#   'evid',
#   'care',
#   'and_their',
#   'level',
#   'care',
#   'explain_th',
#   'process',
#   'assess',
#   'situat',
#   'patient',
#   'manag',
#   'discuss',
#   'cultur',
#   'influenc',
#   'care',
#   'approach',
#   'care',
#   'varieti',
#   'situat',
#   'this_unit',
#   'develop',
#   'the_rol',
#   'develop',
#   'knowledg',
#   'skill',
#   'care',
#   'the_unit',
#   'case',
#   'base',
#   'includ',
#   'clinic',
#   'skill',
#   'develop',
#   'clinic',
#   'skill',
#   'clinic',
#   'problem',
#   'solv',
#   'decis',
#   'make'],
#  'PAR5400': ['interpret',
#   'contemporari',
#   'research',
#   'evid',
#   'advanc',
#   'set',
#   'and_th',
#   'care',
#   'formul',
#   'advanc',
#   'manag',
#   'plan',
#   'complex',
#   'patient',
#   'base',
#   'advanc',
#   'patient',
#   'assess',
#   'care',
#   'care',
#   'decis',
#   'complex',
#   'patient',
#   'base',
#   'understand',
#   'determin',
#   'human',
#   'factor',
#   'effect',
#   'manag',
#   'complex',
#   'patient',
#   'case',
#   'set',
#   'reflect',
#   'awar',
#   'apprais',
#   'ethic',
#   'profession',
#   'advanc',
#   'practic',
#   'identifi',
#   'process',
#   'profession',
#   'develop',
#   'evaluate_th',
#   'the_rol',
#   'advanc',
#   'care',
#   'and_th',
#   'import',
#   'effect',
#   'communication_and',
#   'complex',
#   'this_unit',
#   'introduc',
#   'concept',
#   'relat',
#   'patient',
#   'care',
#   'advanc',
#   'care',
#   'level'],
#  'PAR5440': ['examin',
#   'and_appli',
#   'knowledg',
#   'structur',
#   'system',
#   'relat',
#   'includ',
#   'support',
#   'and_th',
#   'relat',
#   'role',
#   'health',
#   'analyse_th',
#   'environment',
#   'specif',
#   'care',
#   'clinic',
#   'manag',
#   'strategi',
#   'formul',
#   'relev',
#   'for_th',
#   'care',
#   'manag',
#   'environment',
#   'implement',
#   'knowledg',
#   'skills_and',
#   'evid',
#   'base',
#   'practic',
#   'manag',
#   'environment',
#   'care',
#   'synthesis',
#   'environment',
#   'determin',
#   'manag',
#   'patient',
#   'critic',
#   'care',
#   'framework',
#   'system',
#   'this_unit',
#   'introduc',
#   'student',
#   'advanc',
#   'level',
#   'knowledg',
#   'understand',
#   'relat',
#   'care',
#   'manag',
#   'patient',
#   'environment',
#   'care',
#   'from_th',
#   'contemporari',
#   'system',
#   'critic',
#   'specif',
#   'relat',
#   'student',
#   'develop',
#   'advanc',
#   'skill',
#   'effect',
#   'manag'],
#  'PBH3006': ['appli',
#   'knowledg',
#   'skill',
#   'research',
#   'design',
#   'data',
#   'analysi',
#   'practic',
#   'public',
#   'health',
#   'research',
#   'demonstr',
#   'understand',
#   'practic',
#   'issu',
#   'public',
#   'health',
#   'research',
#   'critic',
#   'reflect',
#   'skill',
#   'requir',
#   'research',
#   'practic',
#   'includ',
#   'profession',
#   'ethic',
#   'practic',
#   'issu',
#   'present',
#   'oral',
#   'written',
#   'research',
#   'process',
#   'research',
#   'outcom',
#   'this_unit',
#   'opportun',
#   'high',
#   'student',
#   'experi',
#   'public',
#   'health',
#   'research',
#   'practic',
#   'applic',
#   'this_unit'],
#  'PGP5011': ['demonstr',
#   'sound',
#   'understand',
#   'legal',
#   'profession',
#   'ethic',
#   'framework',
#   'practic',
#   'demonstr',
#   'problem',
#   'solv',
#   'skills_and',
#   'appli',
#   'profession',
#   'rang',
#   'area',
#   'includ',
#   'problem',
#   'problem',
#   'legal',
#   'ethic',
#   'problem',
#   'appli',
#   'principl',
#   'practic',
#   'contribut',
#   'provid',
#   'primari',
#   'health',
#   'care',
#   'includ',
#   'patient',
#   'evalu',
#   'product',
#   'effect',
#   'commun',
#   'inform',
#   'patient',
#   'and_oth',
#   'health',
#   'complex',
#   'understand_th',
#   'natur',
#   'import',
#   'care',
#   'appli',
#   'organis',
#   'skills_and',
#   'manag',
#   'work',
#   'issu',
#   'practic',
#   'appli',
#   'practic',
#   'year',
#   'this_unit',
#   'knowledg',
#   'experi',
#   'develop',
#   'requir',
#   'independ',
#   'practic',
#   'the_unit',
#   'explor',
#   'practic',
#   'includ',
#   'problem',
#   'solv',
#   'evid',
#   'base',
#   'practic',
#   'manag',
#   'patient',
#   'applic',
#   'profession',
#   'standard',
#   'ethic',
#   'legal',
#   'aspect',
#   'practic',
#   'approach',
#   'health',
#   'care',
#   'primari',
#   'care',
#   'communication_and',
#   'health',
#   'manag',
#   'deal',
#   'situat',
#   'practic',
#   'this_unit',
#   'students_wil',
#   'technic',
#   'clinic',
#   'person',
#   'profession',
#   'skill'],
#  'PGW5211': ['examin',
#   'includ',
#   'factor',
#   'appli',
#   'patient',
#   'assess',
#   'set',
#   'manag',
#   'individu',
#   'critic',
#   'apprais',
#   'patient',
#   'develop',
#   'implement',
#   'team',
#   'approach',
#   'manag',
#   'patient',
#   'formul',
#   'manag',
#   'plan',
#   'assess',
#   'tool',
#   'critic',
#   'apprais',
#   'effect',
#   'manag',
#   'develop',
#   'strategi',
#   'examin',
#   'qualiti',
#   'issu',
#   'relat',
#   'individu',
#   'factor',
#   'relat',
#   'patient',
#   'profession',
#   'this_unit',
#   'explor',
#   'complex',
#   'issu',
#   'challeng',
#   'associated_with',
#   'care',
#   'challeng',
#   'assess',
#   'effect',
#   'manag',
#   'plan'],
#  'PHH1112': ['explain_th',
#   'health_and',
#   'world',
#   'address',
#   'global',
#   'health',
#   'challeng',
#   'identifi',
#   'design',
#   'relev',
#   'approach',
#   'global',
#   'health',
#   'challeng',
#   'identifi',
#   'futur',
#   'global',
#   'health',
#   'challeng',
#   'and_their',
#   'analyse_th',
#   'global',
#   'health',
#   'critic',
#   'reflect',
#   'contemporari',
#   'debat',
#   'health',
#   'this_unit',
#   'health',
#   'world',
#   'and_th',
#   'challeng',
#   'peopl',
#   'develop',
#   'explor',
#   'includ',
#   'develop',
#   'social',
#   'polit',
#   'research',
#   'case',
#   'studi',
#   'examin',
#   'context',
#   'work',
#   'intern',
#   'set',
#   'issu',
#   'explor',
#   'global',
#   'way'],
#  'PSY5104': ['student',
#   'knowledg',
#   'ethic',
#   'principl',
#   'research_and',
#   'profession',
#   'practic',
#   'understand',
#   'appli',
#   'knowledg',
#   'relev',
#   'profession',
#   'conduct',
#   'issu',
#   'inform',
#   'profession',
#   'profession',
#   'conduct',
#   'understand',
#   'issu',
#   'impact',
#   'practic',
#   'rang',
#   'topic',
#   'associated_with',
#   'servic',
#   'includ',
#   'basic',
#   'skill',
#   'review',
#   'relev',
#   'ethic',
#   'profession',
#   'standard',
#   'develop',
#   'practic',
#   'this_unit',
#   'materi',
#   'includ',
#   'group',
#   'role'],
#  'RTS5103': ['identify_and',
#   'describ',
#   'relat',
#   'system',
#   'critic',
#   'analys',
#   'plan',
#   'techniqu',
#   'refer',
#   'intern',
#   'standard',
#   'person',
#   'for_th',
#   'system',
#   'demonstr',
#   'level',
#   'plan',
#   'procedur',
#   'rang',
#   'describ',
#   'refer',
#   'patient',
#   'care',
#   'manag',
#   'strategi',
#   'relat',
#   'system',
#   'level',
#   'patient',
#   'care',
#   'manag',
#   'communication_and',
#   'profession',
#   'skill',
#   'rang',
#   'patient',
#   'describe_th',
#   'process',
#   'evaluate_th',
#   'clinic',
#   'plan',
#   'describ',
#   'and_appli',
#   'principl',
#   'safeti',
#   'qualiti',
#   'manag',
#   'occup',
#   'health_and',
#   'safeti',
#   'apprais',
#   'procedur',
#   'legal',
#   'apprais',
#   'demonstr',
#   'level',
#   'analyse_and',
#   'principl',
#   'clinic',
#   'plan',
#   'evalu',
#   'tool',
#   'level',
#   'evaluate_th',
#   'describ',
#   'discuss',
#   'effect',
#   'work',
#   'with_th',
#   'team',
#   'this_unit',
#   'deal',
#   'with_th',
#   'principl',
#   'plan',
#   'this_unit',
#   'system',
#   'students_wil',
#   'analyse_and',
#   'evaluate_th',
#   'principl',
#   'qualiti',
#   'and_how',
#   'practic',
#   'students_wil',
#   'gain',
#   'knowledg',
#   'the_rol',
#   'students_wil',
#   'analyse_and',
#   'evalu',
#   'plan',
#   'evalu',
#   'tool',
#   'this_unit',
#   'learn',
#   'clinic',
#   'student',
#   'develop',
#   'clinic',
#   'profession',
#   'skill',
#   'level',
#   'topic',
#   'students_wil',
#   'critic',
#   'reflect',
#   'analyse_and',
#   'relev',
#   'inform',
#   'from_th',
#   'literatur',
#   'reflect',
#   'clinic'],
#  'SCI3716': ['discuss',
#   'issu',
#   'scientif',
#   'describ',
#   'occup',
#   'health_and',
#   'safeti',
#   'relat',
#   'recognis',
#   'associated_with',
#   'and_th',
#   'undertak',
#   'assess',
#   'work',
#   'procedur',
#   'apply_th',
#   'principl',
#   'physic',
#   'scienc',
#   'discuss',
#   'environ',
#   'procedur',
#   'for_th',
#   'analysis_and',
#   'environ',
#   'this_unit',
#   'design',
#   'introduc',
#   'principl',
#   'manag',
#   'and_their',
#   'and_th',
#   'issu',
#   'occup',
#   'health_and',
#   'safeti',
#   'and_th',
#   'analysi',
#   'emphasi',
#   'assess',
#   'manag',
#   'issu',
#   'environ',
#   'learn',
#   'materi',
#   'practic',
#   'work',
#   'assess',
#   'case',
#   'studi'],
#  'SWK3220': ['describe_th',
#   'natur',
#   'social',
#   'work',
#   'rang',
#   'context',
#   'set',
#   'describ',
#   'contemporari',
#   'debat',
#   'natur',
#   'social',
#   'work',
#   'critic',
#   'analyse_th',
#   'ethic',
#   'social',
#   'work',
#   'refer',
#   'human',
#   'and_th',
#   'social',
#   'critic',
#   'analys',
#   'key',
#   'global',
#   'social',
#   'polici',
#   'issu',
#   'includ',
#   'peopl',
#   'critic',
#   'review',
#   'analys',
#   'contemporari',
#   'social',
#   'work',
#   'servic',
#   'articul',
#   'natur',
#   'social',
#   'and_th',
#   'strategi',
#   'this_unit',
#   'histori',
#   'contemporari',
#   'context',
#   'social',
#   'work',
#   'practic',
#   'framework',
#   'understand',
#   'social',
#   'issu',
#   'polici',
#   'develop',
#   'strategi',
#   'local',
#   'global',
#   'the_unit',
#   'social',
#   'human',
#   'topic'],
#  'SWM5170': ['work',
#   'academ',
#   'the_develop',
#   'assess',
#   'assess',
#   'integr',
#   'research',
#   'knowledg',
#   'present',
#   'profession',
#   'experi',
#   'work',
#   'academ',
#   'the_develop',
#   'assess',
#   'assess',
#   'advanc',
#   'research',
#   'knowledg',
#   'skill',
#   'develop',
#   'practic',
#   'clinic',
#   'polici',
#   'articul',
#   'practic',
#   'knowledg',
#   'skill',
#   'develop',
#   'the_research',
#   'report',
#   'evalu',
#   'report',
#   'develop',
#   'apprais',
#   'person',
#   'role',
#   'profession',
#   'social',
#   'work',
#   'develop',
#   'apprais',
#   'person',
#   'role',
#   'profession',
#   'social',
#   'work',
#   'report',
#   'content',
#   'develop',
#   'student',
#   'staff',
#   'assess',
#   'develop',
#   'student',
#   'this_unit'],
#  'TAD2214': ['recognis',
#   'key',
#   'work',
#   'design_and',
#   'relationship',
#   'critic',
#   'issu',
#   'demonstr',
#   'understand',
#   'influenc',
#   'impact',
#   'physic',
#   'social',
#   'cultur',
#   'the_rol',
#   'and_th',
#   'design',
#   'demonstr',
#   'critic',
#   'analyt',
#   'skill',
#   'work',
#   'design',
#   'articul',
#   'respons',
#   'cultur',
#   'work',
#   'design',
#   'critiqu',
#   'perspect',
#   'for_th',
#   'design',
#   'understand',
#   'apply_th',
#   'rule',
#   'occup',
#   'health_and',
#   'safeti',
#   'the_unit',
#   'studi',
#   'this_unit',
#   'visual',
#   'theoret',
#   'design',
#   'relat',
#   'key',
#   'critic',
#   'issu',
#   'issu',
#   'includ',
#   'work',
#   'design',
#   'societi',
#   'polit',
#   'and_th',
#   'environ',
#   'the_rol',
#   'social',
#   'challeng',
#   'students_wil',
#   'develop',
#   'rang',
#   'approach',
#   'understand',
#   'work',
#   'design_and',
#   'relat',
#   'issu',
#   'critic',
#   'analyt',
#   'skill',
#   'disciplin'],
#  'TDN1002': ['identify_and',
#   'describe_th',
#   'major',
#   'design',
#   'recognis',
#   'analys',
#   'key',
#   'practic',
#   'design',
#   'discuss',
#   'and_their',
#   'influenc',
#   'social',
#   'role',
#   'basic',
#   'theoret',
#   'context',
#   'practic',
#   'critiqu',
#   'work',
#   'design_and',
#   'articul',
#   'written',
#   'form',
#   'identifi',
#   'question',
#   'way',
#   'inform',
#   'this_unit',
#   'examin',
#   'histori',
#   'disciplin',
#   'visual',
#   'commun',
#   'design_and',
#   'design',
#   'key',
#   'practic',
#   'polit',
#   'cultur',
#   'context',
#   'critic',
#   'practic',
#   'term',
#   'implic',
#   'for_th',
#   'social',
#   'role',
#   'design',
#   'students_wil',
#   'develop',
#   'rang',
#   'critic',
#   'approach',
#   'design',
#   'relat',
#   'histor',
#   'social',
#   'cultur',
#   'context',
#   'skill',
#   'disciplin',
#   'practic'],
#  'UPD4002': ['demonstr',
#   'ethic',
#   'approach',
#   'contemporari',
#   'plan',
#   'the_abl',
#   'respond',
#   'complex',
#   'problem',
#   'develop',
#   'plan',
#   'respons',
#   'process',
#   'outcom',
#   'develop',
#   'skill',
#   'research',
#   'critiqu',
#   'address',
#   'plan',
#   'issu',
#   'high',
#   'level',
#   'communication_and',
#   'present',
#   'skill',
#   'written',
#   'understand',
#   'apply_th',
#   'rule',
#   'occup',
#   'health_and',
#   'safeti',
#   'the_unit',
#   'studi',
#   'project',
#   'explor',
#   'project',
#   'system',
#   'student',
#   'develop',
#   'research',
#   'technic',
#   'capac',
#   'analyt',
#   'approach',
#   'plan',
#   'system'],
#  'UPD5001': ['critic',
#   'reflect',
#   'practic',
#   'ethic',
#   'approach',
#   'contemporari',
#   'plan',
#   'respond',
#   'complex',
#   'problem',
#   'relat',
#   'appli',
#   'skill',
#   'research',
#   'address',
#   'plan',
#   'issu',
#   'commun',
#   'written',
#   'issu',
#   'understand',
#   'apply_th',
#   'rule',
#   'occup',
#   'health_and',
#   'safeti',
#   'the_unit',
#   'studi',
#   'plan',
#   'project',
#   'the_rol',
#   'plan',
#   'issu',
#   'associated_with',
#   'the_unit',
#   'advanc',
#   'concept',
#   'knowledg',
#   'skill',
#   'rang',
#   'complex',
#   'issu',
#   'relev',
#   'plan',
#   'level',
#   'critic',
#   'research',
#   'analysis_and',
#   'set',
#   'the_unit',
#   'concept',
#   'approach',
#   'process',
#   'outcom',
#   'and_th',
#   'skill',
#   'commun',
#   'effect',
#   'divers'],
#  'UPD5002': ['critic',
#   'reflect',
#   'practic',
#   'ethic',
#   'approach',
#   'contemporari',
#   'plan',
#   'divers',
#   'respond',
#   'complex',
#   'problem',
#   'develop',
#   'plan',
#   'respons',
#   'process',
#   'outcom',
#   'social',
#   'plan',
#   'appli',
#   'skill',
#   'research',
#   'address',
#   'social',
#   'plan',
#   'issu',
#   'commun',
#   'written',
#   'social',
#   'plan',
#   'issu',
#   'understand',
#   'apply_th',
#   'rule',
#   'occup',
#   'health_and',
#   'safeti',
#   'the_unit',
#   'studi',
#   'plan',
#   'project',
#   'issu',
#   'social',
#   'plan',
#   'address',
#   'the_unit',
#   'advanc',
#   'concept',
#   'knowledg',
#   'skill',
#   'rang',
#   'complex',
#   'issu',
#   'relev',
#   'plan',
#   'critic',
#   'research',
#   'analysis_and',
#   'set',
#   'the_unit',
#   'concept',
#   'approach',
#   'process',
#   'outcom',
#   'and_th',
#   'skill',
#   'commun',
#   'effect',
#   'divers'],
#  'VCM4029': ['rang',
#   'system',
#   'analysi',
#   'design',
#   'methodolog',
#   'and_their',
#   'tool',
#   'principl',
#   'understand_th',
#   'and_their',
#   'role',
#   'the_develop',
#   'system',
#   'appli',
#   'qualiti',
#   'techniqu',
#   'for_th',
#   'analysi',
#   'design',
#   'implement',
#   'system',
#   'understand_th',
#   'approach',
#   'system',
#   'analysis_and',
#   'design',
#   'analysi',
#   'model',
#   'design',
#   'model',
#   'system',
#   'analysis_and',
#   'design',
#   'system',
#   'appli',
#   'sound',
#   'principl',
#   'languag',
#   'develop',
#   'skill',
#   'team',
#   'this_unit',
#   'examin',
#   'activ',
#   'the_develop',
#   'system',
#   'techniqu',
#   'system',
#   'analysis_and',
#   'design',
#   'the_develop',
#   'process',
#   'fundament',
#   'concept',
#   'introduc',
#   'languag',
#   'framework',
#   'system',
#   'develop',
#   'students_wil',
#   'involv',
#   'individu',
#   'work',
#   'applic',
#   'theoret',
#   'knowledg',
#   'practic',
#   'problem',
#   'system',
#   'develop'],
#  'VCM4601': ['recognis',
#   'analyse_and',
#   'element',
#   'design',
#   'understand_th',
#   'role',
#   'visual',
#   'communication_and',
#   'fundament',
#   'design',
#   'principl',
#   'appli',
#   'media',
#   'recognis',
#   'theoret',
#   'issu',
#   'theori',
#   'understand',
#   'and_appli',
#   'theori',
#   'media',
#   'recognis',
#   'analyse_and',
#   'idea',
#   'concept',
#   'visual',
#   'commun',
#   'design_and',
#   'occup',
#   'health_and',
#   'safeti',
#   'studio',
#   'practic',
#   'student',
#   'introduc',
#   'fundament',
#   'element',
#   'principl',
#   'design',
#   'appli',
#   'student',
#   'gain',
#   'design',
#   'skills_and',
#   'knowledg',
#   'complex',
#   'principl',
#   'design',
#   'form',
#   'support',
#   'visual',
#   'base',
#   'media',
#   'project',
#   'techniqu',
#   'method']}

# %% [markdown]
# #### The word stems are then made unique by using a set, and then sorted so that they are in alphabetical order

# %%
word_stem_dictionary
word_stem_list = list(chain.from_iterable(word_stem_dictionary.values()))
vocab_sorted_stem = []
for elem in sorted(list(set(word_stem_list))):
    vocab_sorted_stem.append(elem)
vocab_sorted_stem
# Out:
# ['abil',
#  'academ',
#  'acquisit',
#  'activ',
#  'address',
#  'advanc',
#  'analys',
#  'analyse_and',
#  'analyse_th',
#  'analysi',
#  'analysis_and',
#  'analyt',
#  'and_appli',
#  'and_how',
#  'and_oth',
#  'and_th',
#  'and_their',
#  'appli',
#  'applic',
#  'apply_th',
#  'apprais',
#  'approach',
#  'area',
#  'articul',
#  'aspect',
#  'assess',
#  'associated_with',
#  'australian',
#  'awar',
#  'base',
#  'basic',
#  'busi',
#  'capac',
#  'care',
#  'case',
#  'challeng',
#  'clinic',
#  'commun',
#  'communication_and',
#  'complex',
#  'compon',
#  'comprehens',
#  'concept',
#  'conceptu',
#  'conduct',
#  'contemporari',
#  'content',
#  'context',
#  'contribut',
#  'control',
#  'cover',
#  'critic',
#  'critically_evalu',
#  'critiqu',
#  'cultur',
#  'current',
#  'data',
#  'deal',
#  'debat',
#  'decis',
#  'demonstr',
#  'describ',
#  'describe_th',
#  'design',
#  'design_and',
#  'determin',
#  'develop',
#  'disciplin',
#  'discuss',
#  'divers',
#  'econom',
#  'effect',
#  'element',
#  'emphasi',
#  'engag',
#  'engin',
#  'environ',
#  'environment',
#  'ethic',
#  'evalu',
#  'evaluate_th',
#  'evid',
#  'examin',
#  'exist',
#  'experi',
#  'explain',
#  'explain_th',
#  'explor',
#  'factor',
#  'field',
#  'find',
#  'focu',
#  'for_th',
#  'form',
#  'formul',
#  'framework',
#  'from_th',
#  'fundament',
#  'futur',
#  'gain',
#  'global',
#  'group',
#  'health',
#  'health_and',
#  'high',
#  'histor',
#  'histori',
#  'human',
#  'idea',
#  'ident',
#  'identifi',
#  'identify_and',
#  'impact',
#  'implement',
#  'implic',
#  'import',
#  'includ',
#  'independ',
#  'individu',
#  'industri',
#  'influenc',
#  'inform',
#  'integr',
#  'intern',
#  'interpret',
#  'introduc',
#  'introduct',
#  'involv',
#  'issu',
#  'key',
#  'knowledg',
#  'languag',
#  'law',
#  'learn',
#  'legal',
#  'level',
#  'literatur',
#  'local',
#  'major',
#  'make',
#  'manag',
#  'materi',
#  'media',
#  'method',
#  'methodolog',
#  'model',
#  'modern',
#  'natur',
#  'occup',
#  'opportun',
#  'oral',
#  'order',
#  'organis',
#  'outcom',
#  'part',
#  'patient',
#  'peopl',
#  'perform',
#  'person',
#  'perspect',
#  'philosophi',
#  'physic',
#  'plan',
#  'polici',
#  'polit',
#  'practic',
#  'present',
#  'primari',
#  'principl',
#  'problem',
#  'procedur',
#  'process',
#  'product',
#  'profession',
#  'project',
#  'provid',
#  'public',
#  'qualiti',
#  'question',
#  'rang',
#  'recognis',
#  'refer',
#  'reflect',
#  'relat',
#  'relationship',
#  'relev',
#  'report',
#  'requir',
#  'research',
#  'research_and',
#  'research_project',
#  'respond',
#  'respons',
#  'result',
#  'review',
#  'role',
#  'rule',
#  'safeti',
#  'scienc',
#  'scientif',
#  'servic',
#  'set',
#  'situat',
#  'skill',
#  'skills_and',
#  'social',
#  'societi',
#  'solut',
#  'solv',
#  'sound',
#  'sourc',
#  'specif',
#  'staff',
#  'standard',
#  'state',
#  'strategi',
#  'structur',
#  'student',
#  'students_wil',
#  'studi',
#  'studio',
#  'summ',
#  'support',
#  'synthesis',
#  'system',
#  'task',
#  'team',
#  'technic',
#  'techniqu',
#  'technolog',
#  'term',
#  'the_abl',
#  'the_develop',
#  'the_research',
#  'the_rol',
#  'the_unit',
#  'theoret',
#  'theori',
#  'think',
#  'this_unit',
#  'tool',
#  'topic',
#  'type',
#  'understand',
#  'understand_th',
#  'undertak',
#  'unit',
#  'varieti',
#  'visual',
#  'way',
#  'with_th',
#  'work',
#  'world',
#  'write',
#  'written',
#  'year']

# %% [markdown]
# #### Once the vocabulary is obtained, they are put into a file `29819253_vocab.txt` with their indices starting from 0

# %%
fileWriter = open("29819253_vocab.txt", "w")
vocab_dictionary = dict()

index = 0
for word in vocab_sorted_stem:
    string_file = word+ ":" + str(index) + "\n"
    vocab_dictionary[word] = index
    index += 1    

    fileWriter.write(string_file)
    
fileWriter.close()

# %% [markdown]
# #### The counts of every word is taken according to their indices, and put in together as a sparse representation according to their unit codes.
# #### The output is then written to a file `29819253_countVec.txt`

# %%
fileWriter_1 = open("29819253_countVec.txt", "w")

append_string=''

for key,values in word_stem_dictionary.items():
    append_string = append_string + key
    
    token_list = values
    
    token_dict_1 = dict()
    
    
    for tokens in token_list:
        if tokens not in token_dict_1:
            token_dict_1[tokens] = token_list.count(tokens)
   
    for key,value in sorted(token_dict_1.items()):
        append_string = append_string +","+ str(vocab_dictionary[key])+":"+str(value)
    append_string = append_string + "\n"


fileWriter_1.write(append_string)
    
fileWriter_1.close()
